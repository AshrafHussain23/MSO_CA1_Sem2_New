# %% [markdown]
# # Prelude

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import pulp
import math
import random
import pandas as pd
import numpy as np
import simpy

# %% [markdown]
# # Utilities

# %% [markdown]
# ## Points and Distances

# %%
def dist(p1, p2):
    (x1, y1) = p1
    (x2, y2) = p2
    return int(math.sqrt((x1-x2)**2+(y1-y2)**2))

# %% [markdown]
# ## PlotMap

# %%
def label(i):
    return (label(i//26-1)+chr(65+i%26)) if i>25 else chr(65+i)

# %%
def plotMap(G, T=[], P=[], w=None, frame=None,
            style='r-o', lw=1, ms=3, 
            styleT='go', msT=3,
            styleP='b-o', lwP=2, msP=3,
            stylePT='go', msPT=7,
            styleW='ro', msW=9,
            text=None, grid=False, labels=False, 
            size=4, scale=False):


    def round_down(x, level): return (x//level)*level
    def round_up(x, level): return (x//level+1)*level

    if frame is not None:
        V, E = frame
    else:
        V, E = G
        
    xmin = round_down(min([ x for (x, _) in V ]), 100)
    xmax = round_up(max([ x for (x, _) in V ]), 100)
    ymin = round_down(min([ y for (_, y) in V ]), 100)
    ymax = round_up(max([ y for (_, y) in V ]), 100)
    dx = xmax-xmin
    dy = ymax-ymin
    yoffset = (ymax-ymin)//10

    V, E = G

    fig = plt.gcf()
    fig.set_size_inches(size, size)
    plt.xlim(xmin, xmax)
    plt.ylim(ymin-yoffset, ymax)
    
    if not grid:
        plt.axis('off')

    if frame is not None:
        for e in frame[1]:
            if e not in E:
                p1, p2 = e
                plt.plot( [ p1[0], p2[0] ],  [ p1[1], p2[1] ], 
                          'k-', lw=0.5, ms=2)
            
    for e in E:
        p1, p2 = e
        plt.plot( [ p1[0], p2[0] ],
                  [ p1[1], p2[1] ], 
                  style, lw=lw, ms=ms)
    if scale:
        # plot 1000m scale
        ybar = ymin-0.9*yoffset
        D = [ (xmin, ybar+50), (xmin, ybar), (xmin+1000, ybar), (xmin+1000, ybar+50) ]
        plt.plot( [ d[0] for d in D ], [ d[1] for d in D ], 'k-', lw=0.5)
        plt.text(xmin+500, ymin-0.7*yoffset, '1000m' , horizontalalignment='center', size=8)
    
    if labels:
        for i in range(len(V)):
            x, y = V[i]
            plt.text(x+0.0150*dx, y-0.0350*dy, label(i), size=8)
        
    for t in T:
        plt.plot( [ t[0] ], [ t[1] ], 
                  styleT, ms=msT)
        
    plt.plot( [ p[0] for p in P ],
              [ p[1] for p in P ], 
              styleP, lw=lwP, ms=msP)
    
    for p in P:
        if p in T:
            plt.plot( [ p[0] ], [ p[1] ], 
                      stylePT, ms=msPT)
    if w is not None:
        plt.plot( [ w[0] ], [ w[1] ], 
                      styleW, ms=msW)
    if text is not None:
        plt.text(xmax, ymin-0.7*yoffset, text, horizontalalignment='right', size=8)
    if grid:
        plt.grid()
    plt.show()

# %% [markdown]
# ## Add Targets

# %%
def addTargets(M, T):
    V, E = M
    E = E.copy()
    V = V.copy()
    for t in T:
        minD = math.inf
        minE = None
        for e in E:
            P, Q = e
            distT = dist(P, t)+dist(t, Q)-dist(P, Q)
            if distT < minD:
                minD = distT
                minE = e
        P, Q = minE
        E.remove( (P, Q) )
        E.append( (P, t) )
        E.append( (t, Q) )
        V.append(t)
    return V, E

# %% [markdown]
# ## Generate Central Warehouse Location

# %%
from statistics import median

def generateWarehouseLocation(M):
    V, _ = M
    xc = median([ x for (x, y) in V ])
    yc = median([ y for (x, y) in V ])
    cloc = (xc, yc)
    minloc = V[0]
    mindist = dist(minloc, cloc)
    for i in range(1, len(V)):
        d = dist(V[i], cloc)
        if d<mindist:
            minloc = V[i]
            mindist = dist(V[i], cloc)
    return minloc

# %% [markdown]
# ## Time Handling

# %% [markdown]
# **Convention:** In this project we measure simulation time in seconds. The simulation will start at 0:00. Time related methods will be added as they are needed.

# %% [markdown]
# `timestamp(t)` generates a timestamp string in the form `[dd] hh:mm:ss.d`

# %%
def timestamp(t):
    t = round(t, 1)
    day = int(t)//(24*3600)
    t = t - day*24*3600
    hour = int(t)//3600
    t = t - hour*3600
    mins = int(t)//60
    t = t - mins*60
    secs = int(t)
    t = int(round((t-secs)*10,1)) 
    return f"[{day:2d}] {hour:02d}:{mins:02d}:{secs:02d}.{t:1d}"

# %%
timestamp(24*3600*3+17*3600+615.1)
# Out:
# '[ 3] 17:10:15.1'

# %%
timestamp(24*3600*12+3*3600+122.1)
# Out:
# '[12] 03:02:02.1'

# %%
def day(now):
    return int(now//(24*3600))

# %%
def nextHour(env, hour):
    beginningOfDay = int(env.now//(24*3600))*24*3600
    timeOfDay = env.now-beginningOfDay
    if hour*3600 > timeOfDay:
        return hour*3600 - timeOfDay
    else:
        return hour*3600 + 24*3600 - timeOfDay

# %% [markdown]
# ## Plotting Routines

# %%
import scipy.stats as stats

def histPlot(data, title="", xlabel="",
             discrete=False, width=None, height=None):
    
    minx = min(data)
    maxx = max(data)
    μ = np.mean(data)
    σ = np.std(data)
    
    fig = plt.figure()
    fig.set_figwidth(width if width is not None else 4)
    fig.set_figheight(height if height is not None else 2.5)
    ax = fig.gca()

    if discrete:
        bins = [ i-0.5 for i in range(maxx+2) ]
        ax.xaxis.set_major_locator(mpl.ticker.MaxNLocator(integer=True))
        hist=plt.hist(data, bins=bins, rwidth=0.9, density=True)
    else:
        hist=plt.hist(data, density=True)
    plt.xlabel(xlabel)
    plt.ylabel('Density')
    plt.title(title)

    if discrete:
        poisson=stats.poisson(μ)
        x = [ i for i in range(maxx+1) ]
        y =[ poisson.pmf(i) for i in range(maxx+1) ]
        ax.plot(x, y, lw=1, color='red')
    else:
        x = np.linspace(minx, maxx, 100)
        y = [ stats.norm(loc=μ, scale=σ).pdf(p) for p in x]
        ax.plot(x, y, lw=1, color='red')
        
    ax.axvline(x=μ, color='red')
    maxy = max(max(y), max(hist[0]))
    ax.text(maxx, maxy, 
            f'μ={μ:2.2f}\nσ={σ:2.2f}', 
            ha='right', va='top', 
            color='red', fontsize=12)
    
    # ax.grid(True)
    plt.show()

def dailyPlot(data, 
              title="", ylabel="",
              width=None, height=None):
    
    days = len(data)
    
    fig = plt.figure()
    fig.set_figwidth(width if width is not None else 6)
    fig.set_figheight(height if height is not None else 2)
    
    ax = fig.gca()
    diff = (max(data)-min(data)+1)*0.1
    ymin = math.floor(min(data))-diff
    ymax = math.ceil(max(data))+diff
    ax.set_xlim(-0.5, days-1+0.5)
    ax.set_ylim(ymin-0.5, ymax+0.5)
    ax.grid(True)
    
    ms = 2 if len(data)>=100 else 3
    lw = 0.5 if len(data)>=100 else 1

    x = np.arange(0, len(data))
    y = np.array([ y for y in data ])
    b, m = np.polynomial.polynomial.polyfit(x, y, 1)
    ax.xaxis.set_major_locator(mpl.ticker.MaxNLocator(integer=True))
    ax.yaxis.set_major_locator(mpl.ticker.MaxNLocator(integer=True))
    
    plt.plot(x, y, 'bo-', linewidth=lw, markersize=ms)
    plt.plot(x, m*x+b, 'r-')
    
    plt.xlabel('Day')
    plt.ylabel(ylabel)
    plt.title(title)
    plt.show()

def countPlot(A, B, 
              title="", ylabel="",
              width=None, height=None):

    assert(len(A)==len (B))
    days = len(A)
    xmax = days-1
    ymax = A.max()
    
    fig = plt.figure()
    fig.set_figwidth(width if width is not None else 6)
    fig.set_figheight(height if height is not None else 4)
    ax = fig.gca()
    ax.set_xlim(-0.5, xmax+0.5)
    ax.set_ylim(0, ymax)
    
    def double(l, offset=0):
        return [] if l==[] else [l[0]+offset, l[0]+offset]+double(l[1:], offset)
            
    x = double([i for i in range(days)])+[days]
    xz = double([i+days*0.006 for i in range(days)])+[days]
    y = [0+ymax*0.006] + double(list(A), offset=ymax*0.006)
    z = [0] + double(list(B))
        
    ax.yaxis.set_major_locator(mpl.ticker.MaxNLocator(integer=True))
    ax.xaxis.set_major_locator(mpl.ticker.MaxNLocator(integer=True))

    for i in range(days):
        ax.fill_between([i, i+1], 
                        [z[2*i+1], z[2*i+2]], 
                        [y[2*i+1], y[2*i+2]], color='blue', alpha=0.2)

    lw = 1 if days>=50 or ymax>=100 else 2
    ax.plot(x, y, color='blue', lw=lw)
    ax.plot(xz, z, color='red', lw=lw)
    plt.xlabel('Day')
    plt.ylabel(ylabel)
    plt.title(title)
    ax.grid(True)
    plt.show()

# %% [markdown]
# # Finding Shortest Path (as before)

# %%
def pathLength(P):
    return 0 if len(P)<=1 else \
            dist(P[0], P[1])+pathLength(P[1:])

# %%
def shortestPath(M, A, B):

    def h(p): 
        return pathLength(p)+dist(p[-1],B)
    
    # candidates C are pairs of the path so far and 
    # the heuristic function of that path, 
    # sorted by the heuristic function, as maintained by
    # insert function
    def insert(C, p):
        hp = h(p)
        c = (p, hp)
        for i in range(len(C)):
            if C[i][1]>hp:
                return C[:i]+[c]+C[i:]
        return C+[c]   
        
    V, E = M
    assert(A in V and B in V)    
    C = insert([], [A])

    while len(C)>0:
        # take the first candidate out of the list of candidates
        path, _ = C[0]
        C = C[1:]
        if path[-1]==B:
            return path
        else:
            for (x, y) in E:
                if path[-1]==x and y not in path:
                    C = insert(C, path+[y])
                elif path[-1]==y and x not in path:
                    C = insert(C, path+[x])
    return None

# %% [markdown]
# # Finding Short Delivery Route (as before)

# %% [markdown]
# ## Greedy Algorithm

# %%
def FW(M):
    
    V, E = M

    n = len(V)
    d = [ [ math.inf for j in range(n) ] for i in range(n) ]
    p = [ [ None for j in range(n) ] for i in range(n) ]

    for (A, B) in E:
        a = V.index(A)
        b = V.index(B)
        d[a][b] = d[b][a] = dist(A, B)
        p[a][b] = [A, B]
        p[b][a] = [B, A]
    
    for i in range(n):
        d[i][i] = 0
        p[i][i] = [V[i]]
    
    for k in range(n):
        for i in range(n):
            for j in range(n):
                dk = d[i][k] + d[k][j]
                if d[i][j] > dk:
                    d[i][j] = dk
                    p[i][j] = p[i][k][:-1] + p[k][j]
                    
    return d, p

# %%
def createLoopG(M, T, timing=False):
    
    def makeLoop(L, V, P):
        loop = []
        for i in range(len(L)-1):
            A = L[i]
            B = L[i+1]
            a = V.index(A)
            b = V.index(B)
            sub = P[a][b]
            loop += sub if len(loop)==0 else sub[1:]
        return loop
        
    if timing:
        start_time = time.time()
        last_time = time.time()
    
    V, E = M
    D, P = FW(M)   # note these are the distances between all vertices in M (and T)
    W = T[0]
    customers = T[1:]
    if len(T)==1:
        L = T
    elif len(T)<=3:
        L = T + [T[0]]
    else:
        L = T[:3]+[T[0]]
        T = T[3:]
        while len(T)>0:
            
            minExt = math.inf
            minInd = None
            selInd = None
            for k in range(len(T)):
                C = T[k]
                c = V.index(C)
                for i in range(0, len(L)-1):
                    A = L[i]
                    B = L[i+1]
                    a = V.index(A)
                    b = V.index(B)
                    ext = D[a][c] + D[c][b] - D[a][b]
                    if ext<minExt:
                        minExt, minInd, selInd = ext, i+1, k
            L = L[:minInd]+[T[selInd]]+L[minInd:]
            T = T[:selInd]+T[selInd+1:]
            
    if timing:
        print(f"createLoopG:    {time.time()-start_time:6.2f}s")

    return makeLoop(L, V, P)

# %% [markdown]
# # Finding Optimal Delivery Route

# %% [markdown]
# ## Iterative Integer Programming

# %%
def createTables(M, T):

    def reverse(P):
        return [ P[-i] for i in range(1,len(P)+1) ]
    
    def index(x, L):
        for i in range(len(L)):
            if x==L[i]: 
                return i
        return None

    n = len(T)
    d = [ [ math.inf for t in T ] for t in T ]
    p = [ [ None for t in T ] for t in T ]
    for i in range(n):
        d[i][i] = 0
        p[i][i] = [ T[i] ]
    for i in range(n):
        for j in range(n):
            if p[i][j] is None:
                s = shortestPath(M, T[i], T[j])
                d[i][j] = d[j][i] = pathLength(s)
                p[i][j] = s
                p[j][i] = reverse(s)
                for m in range(len(s)-1):
                    smi = index(s[m], T)
                    if smi is None:
                        continue
                    for l in range(m+1, len(s)):
                        sli = index(s[l], T)
                        if sli is None:
                            continue  
                        sub = s[m:l+1]
                        if p[smi][sli] is None:
                            p[smi][sli] = sub
                            p[sli][smi] = reverse(sub)
                            d[smi][sli] = d[sli][smi] = pathLength(sub)
    return d,p

# %%
def roundtrips(x, n):
    
    def isElem(x, l):
        for i in range(len(l)):
            if l[i]==x:
                return True
        return False

    def startpoint(trips):
        for i in range(n):
            for t in trips:
                if isElem(i, t):
                    break
            else:
                return i
    
    def totalLength(trips):
        s=0
        for i in range(0, len(trips)):
            s += len(trips[i])-1
        return s

    trips = []
    while totalLength(trips)<n:
        start = startpoint(trips)
        trip = [ start ]
        i = start
        while len(trip) < n-totalLength(trips):
            for j in range(0, n):
                if pulp.value(x[i][j])==1:
                    trip.append(j)
                    i=j
                    break        
            if pulp.value(x[trip[-1]][start])==1:
                trip.append(start)
                break
        trips.append(trip)
    return sorted(trips, key=lambda t: len(t), reverse=True)

# %%
import time

def createLoop(M, T, timing=False):
    
    if timing:
        start_time = last_time = time.time()
        
    D, P = createTables(M, T)   # These are the distances between customers and warehouse only
    
    if timing:
        print(f"createTables:   {time.time()-start_time:6.2f}s")
        last_time = time.time()
        
    n = len(T)
    # create variables
    x = pulp.LpVariable.dicts("x", ( range(n), range(n) ),
                            lowBound=0, upBound=1, cat=pulp.LpInteger)
    # create problem
    prob = pulp.LpProblem("Loop",pulp.LpMinimize)
    # add objective function
    prob += pulp.lpSum([ D[i][j]*x[i][j] 
                             for i in range(n) for j in range(n) ])
    # add constraints
    constraints=0
    for j in range(n):
        prob += pulp.lpSum([ x[i][j] for i in range(n) if i!=j ]) ==1
    constraints += n
    for i in range(n):
        prob += pulp.lpSum([ x[i][j] for j in range(n) if i!=j ]) ==1
    constraints += n
    for i in range(n):
        for j in range(n):
            if i!=j:
                prob += x[i][j]+x[j][i] <= 1
                constraints += 1
                
    def cycles(k, n):
        if k==1:
            return [ [i] for i in range(0,n) ]
        else:
            sc=cycles(k-1, n)
            all=[]
            for c in sc:
                for i in range(0,n):
                    if c.count(i)==0:
                        all.append(c+[i])
            return all

    for k in range(3, 4):   
        cycs=cycles(k,n)
        for c in cycs:
            c.append(c[0])
            prob+=pulp.lpSum([ x[c[i]][c[i+1]] for i in range(0,k)]) <= k-1
            constraints += 1    
            
    # initialise solver
    solvers = pulp.listSolvers(onlyAvailable=True)
    solver = pulp.getSolver(solvers[0], msg=0, timeLimit=2)
    res = prob.solve(solver)

    if timing:
        print(f"Solver:         {time.time()-last_time:6.2f}s {constraints:6,d} Constraints")
        last_time = time.time()
        
    trips = roundtrips(x, n)
    while len(trips)>1:
        longest = max([ len(t) for t in trips ])
        for t in trips:
            if len(t)<longest:
                prob += pulp.lpSum([ x[t[i]][t[i+1]] + x[t[i+1]][t[i]]
                                        for i in range(0,len(t)-1) ]) <= len(t)-2
                constraints += 1
            else:
                longest = math.inf
                
        res = prob.solve(solver)
        
        if timing:
            print(f"Solver:         {time.time()-last_time:6.2f}s {constraints:6,d} Constraints")
            last_time = time.time()

        trips = roundtrips(x, n)
    trip = trips[0]
    # print(trip)
    loop = []
    for k in range(len(trip)-1):
        sub = P[trip[k]][trip[k+1]]
        loop += sub if len(loop)==0 else sub[1:]
        
    if timing:
        print(f"createLoop:     {time.time()-start_time:6.2f}s")

    return loop

# %% [markdown]
# # Static Route Assignment

# %% [markdown]
# ## Split Customers into Regions

# %%
def pickRegion(C, Maps):
    options = []
    for m in range(len(Maps)):
        V, E = Maps[m]
        for (A, B) in E:  
            if dist(A, C)+dist(C, B) - dist(A, B) <= 1:
                options.append(m)
    return random.choice(options)

# %%
def splitCustomers(C, Maps):
    return [ pickRegion(C[i], Maps) for i in range(len(C)) ]

# %% [markdown]
# # Class Recorder

# %% [markdown]
# We willl use a class Recorder as a reference point for capturing data during the simulation. There will be only one recorder. It will be created at the beginning of every simulation run. Every entity will carry a reference to the Recorder.

# %%
import time

class Recorder:
    
    def __init__(self, env, M, Maps, W, C, D, days,
                 log=False, plot=False, timing=False):
        self.env = env
        self.M = M
        self.Maps = Maps
        self.W = W
        self.C = C
        self.D = D

        self.parcels = sum([ len(d) for d in D ])
        self.days = days
        self.drivers = len(Maps)
        
        self.log = log
        self.plot = plot

        # create a data frame for time records per working day
        self.daily = [ pd.DataFrame() for d in range(self.drivers) ]

        for driver in range(self.drivers):
            self.daily[driver]['begin work at'] = [None]*days
            self.daily[driver]['end work at'] = [None]*days
            self.daily[driver]['tour length'] = [None]*days

            self.daily[driver]['parcels left over'] = [0]*days
            self.daily[driver]['parcels arrived'] = [0]*days
            self.daily[driver]['parcels out for delivery'] = [0]*days
            self.daily[driver]['parcels returned from delivery'] = [0]*days
            self.daily[driver]['parcels delivered'] = [0]*days
        

        self.parcel = pd.DataFrame()
        self.parcel['arrived at'] = [None]*self.parcels
        self.parcel['delivered at'] = [None]*self.parcels
        
    def trace(self, event, driver=None):
        if self.log:
            prefix = "" if driver is None else f"D{driver.id:d}: "
            print(timestamp(self.env.now), prefix+event)

    def recordDriverBeginsWork(self, driver):
        self.trace("arrives for work", driver)
        self.daily[driver.id].at[day(self.env.now), 'begin work at'] = int(round(self.env.now))
        
    def recordDriverEndsWork(self, driver):
        self.trace("goes home", driver)
        self.daily[driver.id].at[day(self.env.now), 'end work at'] = int(round(self.env.now))
        
    def recordTourLength(self, driver, length):
        self.daily[driver.id].at[day(self.env.now), 'tour length'] = int(length)

    def recordParcelArrived(self, driver, parcel):
        self.trace(str(parcel)+" arr at delivery centre", driver)
        today = day(self.env.now)
        self.daily[driver.id].at[today, 'parcels arrived'] += 1
        self.parcel.at[parcel.i, 'arrived at'] = today

    def recordParcelOutForDelivery(self, driver, parcel):
        self.trace(str(parcel)+" out for delivery", driver)
        self.daily[driver.id].at[day(self.env.now), 'parcels out for delivery'] += 1
   
    def recordParcelReturnedFromDelivery(self, driver, parcel):
        self.trace(str(parcel)+" returned from delivery", driver)
        self.daily[driver.id].at[day(self.env.now), 'parcels returned from delivery'] += 1

    def recordParcelDelivered(self, driver, parcel):
        self.trace(str(parcel)+" delivered", driver)
        today = day(self.env.now)
        self.daily[driver.id].at[today, 'parcels delivered'] += 1
        self.parcel.at[parcel.i, 'delivered at'] = today
        
    def recordParcelsLeftOver(self, driver, n):
        self.trace(f"{n:d} parcels left over for next day", driver)
        self.daily[driver.id].at[day(self.env.now), 'parcels left over'] = n
        
    def finish(self):
        # simulation is finished for good
        # by removing the simulation environment we can
        # pickle recorder
        self.env = None

        for driver in range(self.drivers):
            self.daily[driver]['working time'] = (self.daily[driver]['end work at']-self.daily[driver]['begin work at'])//60
            self.daily[driver]['cost'] = self.daily[driver]['working time'].apply(lambda x: max(60, x*30/60))
            self.daily[driver]['cost'] += 0.08/1000*self.daily[driver]['tour length']

        self.parcel['delivery delay'] = self.parcel['delivered at']-self.parcel['arrived at']

        self.totalDaily = pd.DataFrame()
        self.totalDaily['cum arrival'] = self.__Data('parcels arrived').cumsum()
        self.totalDaily['cum delivery'] = self.__Data('parcels delivered').cumsum()

    # the Title() and Data() functions have been introduced
    # solely to maintain the code of the plot/hist methods below
    # as far as possible
    
    def __Title(self, title, driver):
        return ("Total " if driver is None else "") + \
                title + \
                " (" + f"{self.days:d} days" + \
                ("" if driver is None else f", Driver {driver:d} only") +")"
        
    def __Data(self, col, driver=None):
        if driver is None:
            total = pd.DataFrame()
            total['sum'] = [0] * self.days
            for d in range(self.drivers):
                total['sum'] += self.daily[d][col]
            return total['sum']
        else:
            return self.daily[driver][col]
        
    def histWorkingTime(self, driver=None):
        histPlot(self.__Data('working time', driver),
                 xlabel='Working Time [min]',
                 title=self.__Title('Daily Working Time', driver))
        
    def plotWorkingTime(self, driver=None):
        dailyPlot(self.__Data('working time', driver),
                  ylabel='Working Time [min]',
                  title=self.__Title('Daily Working Time', driver))

    def histTourLength(self, driver=None):
        histPlot(self.__Data('tour length', driver),
                 xlabel='Tour Length [m]',
                 title=self.__Title('Daily Tour Length', driver))
            
    def plotTourLength(self, driver=None):
        dailyPlot(self.__Data('tour length', driver),
                  ylabel='Tour Length [m]',
                  title=self.__Title('Daily Tour Length', driver))

    def histDailyCost(self, driver=None):
        histPlot(self.__Data('cost', driver),
                 xlabel='Cost [€]',
                 title=self.__Title('Daily Cost', driver))
            
    def plotDailyCost(self, driver=None):
        dailyPlot(self.__Data('cost', driver),
                  ylabel='Cost [€]',
                  title=self.__Title('Daily Cost', driver))

    def histParcelsArrived(self, driver=None):
        histPlot(self.__Data('parcels arrived', driver),
                 discrete=True,
                 xlabel='Parcels Arrived',
                 title=self.__Title('Daily Parcels Arrived', driver))
                
    def plotParcelsArrived(self, driver=None):
        dailyPlot(self.__Data('parcels arrived', driver),
                  ylabel='Parcels',
                  title=self.__Title('Parcels Arrived Daily', driver))

    def histParcelsOutForDelivery(self, driver=None):
        histPlot(self.__Data('parcels out for delivery', driver),
                 discrete=True,
                 xlabel='Parcels',
                 title=self.__Title('Parcels Daily out for Delivery', driver))
        
    def plotParcelsOutForDelivery(self, driver=None):
        dailyPlot(self.__Data('parcels out for delivery', driver),
                  ylabel='Parcels',
                  title=self.__Title('Parcels Daily out for Delivery', driver))
        
    def histParcelsReturnedFromDelivery(self, driver=None):
        histPlot(self.__Data('parcels returned from delivery', driver),
                 discrete=True,
                 xlabel='Parcels',
                 title=self.__Title('Parcels Daily Returned From Delivery', driver))
                
    def plotParcelsReturnedFromDelivery(self, driver=None):
        dailyPlot(self.__Data('parcels returned from delivery', driver),
                  ylabel='Parcels',
                  title=self.__Title('Daily Parcels Returned From Delivery', driver))

    def histParcelsDelivered(self, driver=None):
        histPlot(self.__Data('parcels delivered', driver),
                 discrete=True,
                 xlabel='Left-Over Parcels',
                 title=self.__Title('Parcels Delivered Daily', driver))

    def plotParcelsDelivered(self, driver=None):
        dailyPlot(self.__Data('parcels delivered', driver),
                  ylabel='Parcels',
                  title=self.__Title('Parcels Delivered Daily', driver))

    def histParcelsLeftOver(self, driver=None):
        histPlot(self.__Data('parcels left over', driver),
                 discrete=True,
                 xlabel='Left-Over Parcels',
                 title=self.__Title('Daily Left-Over Parcels', driver))
                
    def plotParcelsLeftOver(self, driver=None):
        dailyPlot(self.__Data('parcels left over', driver),
                  ylabel='Parcels',
                  title=self.__Title('Daily Left-Over Parcels', driver))

    def countPlot(self):
        countPlot(self.totalDaily['cum arrival'], 
                  self.totalDaily['cum delivery'], 
                  ylabel='Parcels',
                  title=f'Parcel Arrival/Delivery ({self.parcels:3,d} Parcels, {self.days:d} Days)')
        
    def histParcelDeliveryDelay(self):
        histPlot(self.parcel['delivery delay'].dropna(), 
                 discrete=True,
                 xlabel='Days',
                 title=f'Parcel Delivery Delay in Days ({self.parcels:3,d} Parcels)')

# %% [markdown]
# # Class Customer

# %% [markdown]
# <img src='img/EventGraph Customer.png' width=500/>

# %%
class Customer:
    
    def __init__(self, rec, id, location):
        self.rec = rec
        self.id = id
        self.location = location
        self.atHome = True
        self.answersDoor = False
        self.parcelsReceived = []
        rec.env.process(self.process())
        
    def __str__(self):
        return f"Customer {self.id:d} at {str(self.location):s}"
    
    def leaveHouse(self):
        assert(self.atHome and not self.answersDoor)
        # self.rec.trace(str(self)+" leaves house")
        self.atHome = False
     
    def returnHome(self):
        assert(not self.atHome)
        # self.rec.trace(str(self)+" returns home")
        self.atHome = True
        
    def answerDoor(self, driver):
        if self.atHome:
            answerTime = random.expovariate(1/AVG_TIME_ANSWER_DOOR)
            if answerTime < WAIT_TIME_IF_CUSTOMER_DOESNT_ANSWER_DOOR:                            
                yield self.rec.env.timeout(answerTime)
                self.rec.trace(str(self)+" answers door", driver)
                self.answersDoor = True
            else:
                yield self.rec.env.timeout(WAIT_TIME_IF_CUSTOMER_DOESNT_ANSWER_DOOR)
                self.rec.trace(str(self)+" to slow to answer the door", driver)
                self.answersDoor = False
        else:
            yield self.rec.env.timeout(WAIT_TIME_IF_CUSTOMER_DOESNT_ANSWER_DOOR)
            self.rec.trace(str(self)+" not at home", driver)
            self.answersDoot = False
            
    def acceptParcel(self, driver, parcel):
        assert(self.answersDoor)
        self.parcelsReceived += [parcel]
        self.rec.recordParcelDelivered(driver, parcel)
        
    def signOff(self, driver):
        assert(self.answersDoor)
        self.rec.trace(str(self)+" signs off", driver)
        self.answersDoor = False
        
    def process(self):
        yield self.rec.env.timeout(nextHour(self.rec.env, 8))
        while day(self.rec.env.now)<self.rec.days:
            # in a refinement we may use random times
            self.leaveHouse()
            returnTime = 22 if random.random()<CUSTOMER_NOT_AT_HOME else 18
            yield self.rec.env.timeout(nextHour(self.rec.env, returnTime))
            self.returnHome()
            yield self.rec.env.timeout(nextHour(self.rec.env, 8))

# %% [markdown]
# # Class Parcel

# %% [markdown]
# <img src='img/EventGraph Parcel.png' width=500/>

# %% [markdown]
# Parcels follow through a sequence of states:
# - processing
# - in transit (from manufacture to distribution centre)
# - arrived in distribution centre
# - ready for delivery
# - out for delivery
# - customer not present
# - returned to distribution centre
# - delivered

# %%
class Parcel:
    
    def __init__(self, rec, i, day, cust):
        self.rec = rec
        self.i = i  
        self.arrival = day
        self.cust = cust
        self.status = [  ] # status record and
        self.timing = [  ] # timing

    def __str__(self):
        return f"Parcel {self.i:d} (for cust {self.cust.id:d}"

    def index(self):
        return self.i
    
    def destination(self):
        return self.cust.location
    
    def __reg(self, state):
        self.status += [ state ]
        self.timing += [ self.rec.env.now ]
        
    def arrivedAtDeliveryCentre(self, driver):
        self.__reg('arr at delivery centre')
        self.rec.recordParcelArrived(driver, self)
        
    def outForDelivery(self, driver): 
        self.__reg('out for delivery')
        self.rec.recordParcelOutForDelivery(driver, self)
        
    def returnFromDelivery(self, driver):
        self.__reg('return from delivery')
        self.rec.recordParcelReturnedFromDelivery(driver, self)

# %% [markdown]
# # Class Driver

# %% [markdown]
# <img src='img/EventGraph Driver.png' width=500/>

# %%
class Driver:
    
    def __init__(self, rec, id, DC):
        self.rec = rec
        self.id = id
        self.DC = DC
        self.location = None
        self.parcels = None
        self.returns = None
        self.tour = None
        self.rec.env.process(self.process())
        
    # activity
    def __drive(self, target):
        assert(self.tour[0] == self.location)
        while self.location!=target:
            d = dist(self.location, self.tour[1])
            yield self.rec.env.timeout(d / AVG_SPEED)
            self.location = self.tour[1]
            self.tour = self.tour[1:]
        assert(self.tour[0] == self.location == target)
    
    def arriveForWork(self):
        self.location = self.DC.W
        self.parcels = []
        self.returns = []
        self.tour = [ self.DC.W ]
        # self.rec.trace("arrives for work", self)
        self.rec.recordDriverBeginsWork(self)
    
    def goesHome(self):
        self.location = None
        self.parcels = None
        self.returns = None
        self.tour = None
        # self.rec.trace("goes home", self)
        self.rec.recordDriverEndsWork(self)
        
    def leaveForDelivery(self, tour, parcels, addresses):
        self.tour, self.parcels = tour, parcels
        self.rec.trace(f"leaves for delivery " 
                       f"of {len(parcels):d} parcels "
                       f"to {len(addresses):d} customers", self)
        self.rec.trace(f"Length of delivery tour: {pathLength(tour):,d}m", self)
        if self.rec.plot:
            plotMap(self.rec.Maps[self.id], frame=self.rec.M,
                    T=addresses, P=tour, w=tour[0], 
                    text=f"Day {day(self.rec.env.now):d} D{self.id:d}: {pathLength(tour):,d}m")
        
    def process(self):
        yield self.rec.env.timeout(nextHour(self.rec.env, 18))
        while day(self.rec.env.now)<self.rec.days:
            self.arriveForWork()

            ## chnge to deal with time limit
            startTime = self.rec.env.now 
            
            tour, parcels, addresses = self.DC.sendForDelivery(self)
            if len(parcels)==0: 
                self.rec.trace("Nothing to do today", self)
                self.rec.recordTourLength(self, 0)
            else:
                yield self.rec.env.timeout(PREP_TIME_PER_PARCEL*len(parcels))
                self.rec.recordTourLength(self, pathLength(tour))
                self.leaveForDelivery(tour, parcels, addresses)        
                while len(self.parcels)>0:

                    ## change to deal with time limit
                    currentTime = self.rec.env.now
                    if currentTime-startTime>=self.DC.timeLimit:
                        self.rec.trace("Timelimit reached", self)
                        while len(self.parcels)>0:
                            self.returns += [self.parcels[0]]
                            self.parcels = self.parcels[1:]
                        break
                        
                    # drive to customer
                    custLocation = self.parcels[0].destination()
                    cust = self.parcels[0].cust
                    self.rec.trace("drives to "+str(cust), self)
                    yield from self.__drive(custLocation)
                    self.rec.trace("arrived at "+str(cust), self)
                    # call at customer
                    yield from cust.answerDoor(self)
                    
                    if cust.answersDoor:
                        while len(self.parcels)>0 and \
                                custLocation == self.parcels[0].destination():
                            cust.acceptParcel(self, self.parcels[0])
                            yield self.rec.env.timeout(random.expovariate(1/AVG_TIME_HANDOVER))
                            self.parcels = self.parcels[1:]
                        cust.signOff(self)
                        yield self.rec.env.timeout(random.expovariate(1/AVG_TIME_SIGNOFF))
                    else:
                        while len(self.parcels)>0 and  \
                                custLocation == self.parcels[0].destination():
                            self.returns += [self.parcels[0]]
                            self.parcels = self.parcels[1:]

                # return to delivery centre
                self.rec.trace("returns to delivery centre", self)
                yield from self.__drive(self.DC.W)
                self.rec.trace("arrived at delivery centre", self)

                for parcel in self.returns:
                    self.DC.returnFromDelivery(self, parcel)
                    yield self.rec.env.timeout(RETURN_TIME_PER_PARCEL)
                            
            self.rec.recordParcelsLeftOver(self,
                                           len(self.returns)+
                                           len(self.DC.leftOver[self.id]))
            
            yield self.rec.env.timeout(DAY_END_PROCEDURE)

            self.goesHome()
            
            yield self.rec.env.timeout(nextHour(self.rec.env, 18))

# %% [markdown]
# # Class Delivery Centre

# %% [markdown]
# <img src="img/EventGraph Delivery Centre.png" width=300/>

# %%
class DeliveryCentre:
    
    def __init__(self, rec, M, Maps, W, C, D, 
                 limit, timeLimit):
        self.rec = rec
        self.M = M
        self.Maps = Maps
        self.W = W
        self.C = C
        self.D = D
        
        self.limit = limit
        self.timeLimit = timeLimit

        self.overhang = []   # list of parcels to be delivered next day

        # generate and initialise all customers
        self.customers = [ Customer(rec, i, C[i]) for i in range(len(C)) ]
        
        # generate and initialise all drivers
        self.drivers = [ Driver(rec, i, self) for i in range(len(Maps)) ]

        self.PARCELS = []    # registry of all the parcels processed
        
        rec.env.process(self.process())
        
    def __accept(self, d, parcel):
        custLoc = parcel.destination()
        
        assert(0<=d<len(self.Maps))
        
        ## chnge to deal with time limit estimate
        timeEstimate = \
            len(self.parcels[d])*(PREP_TIME_PER_PARCEL + AVG_TIME_HANDOVER) \
            + len(self.dest[d])*(AVG_TIME_ANSWER_DOOR + AVG_TIME_SIGNOFF)
        
        if custLoc not in self.dest[d]:

            targets = [self.W] + self.dest[d] + [custLoc]

            if self.rec.plot:
                plotMap(self.Maps[d], T=targets,  w=self.W, frame=self.M, 
                    size=2, text=f"Driver {d:d}: accept Parcel")

            MT = addTargets(self.Maps[d], targets)
            SH = createLoopG(MT, targets)

            ## chnge to deal with time limit estimate
            if pathLength(SH)<self.limit and \
                timeEstimate + pathLength(SH)/AVG_SPEED + \
                PREP_TIME_PER_PARCEL + AVG_TIME_ANSWER_DOOR + \
                AVG_TIME_HANDOVER + AVG_TIME_SIGNOFF <= self.timeLimit:
            
                self.parcels[d].append(parcel)
                self.dest[d] += [custLoc]
                self.tour[d] = SH
            else: 
                self.leftOver[d].append(parcel)

            ## chnge to deal with time limit estimate
        elif timeEstimate + pathLength(self.tour[d])/AVG_SPEED + \
                PREP_TIME_PER_PARCEL + AVG_TIME_HANDOVER <= self.timeLimit:
            self.parcels[d].append(parcel)
        else:
            self.leftOver[d].append(parcel)
        
    def sendForDelivery(self, driver):
        d = driver.id
        parcels = []
        tour = self.tour[d]
        addresses = []
        
        # pick parcels in sequence to be delivered
        for i in range(1, len(tour)-1):
            dest = tour[i]
            for p in self.parcels[d]:
                if p.destination() == dest and p not in parcels:
                    parcels += [p]
                    p.outForDelivery(driver)
                    if dest not in addresses:
                        addresses += [dest]
         
        # what cant go out goes straigt for next day
        for p in self.leftOver[d]:
            self.overhang.append(p)
            
        return tour, parcels, addresses
                 
    def returnFromDelivery(self, driver, parcel):
        parcel.returnFromDelivery(driver)
        self.overhang.append(parcel)
        
    def getInventory(self):
        return len(self.overhang)
        
    def process(self):
        for day in range(len(self.D)):
            yield self.rec.env.timeout(nextHour(self.rec.env, 17.00))
            # make plan how to split workload for the day
            regions = splitCustomers(self.C, self.Maps)

            # initialise the workload for all drivers
            self.leftOver = [ [] for driver in self.drivers ]   # list of parcels that can't go out today
            self.parcels = [ [] for driver in self.drivers ]    # list of parcels scheduled for delivery
            self.dest = [ [] for driver in self.drivers ]       # list of unique customer destinations
            self.tour = [ [self.W] for driver in self.drivers ] # tour planned for delivery
            
            # process overhang from previous day (if any)
            for p in self.overhang:
                driverId = regions[p.cust.id]
                self.__accept(driverId, p)
            self.overhang = []

            # generate the parcels newly arriving this day
            for c in self.D[day]:
                parcel = Parcel(self.rec, len(self.PARCELS), 
                                day, self.customers[c])
                self.PARCELS.append(parcel)
                driverId = regions[c]
                parcel.arrivedAtDeliveryCentre(self.drivers[driverId])
                self.__accept(driverId, parcel)

# %% [markdown]
# # Simulation

# %% [markdown]
# ## Parameters from Specification

# %% [markdown]
# The hard time limit for the driver. When this time limit is reached
# on a delivery tour, the driver is supposed to return immediately

# %%
DELIVERY_TIME_LIMIT = 3*3600 # 3 hours

# %% [markdown]
# The proportion of customers that for whatever are not at home or return home late

# %%
CUSTOMER_NOT_AT_HOME = 0.1  # 10%

# %% [markdown]
# The maximum bike range. This is passed as parameter to the Delivery Centre
# and taken into account for the daily tour planning

# %%
BIKE_RANGE = 40000

# %% [markdown]
# The time required for driving is based on the distance between way points at an average speed of 15km/h.

# %%
AVG_SPEED = 15/3.6

# %% [markdown]
# The **cumulative preparation time** (route planning and
# sorting of the parcels in the delivery order and
# packing the cargo-bike) is assumed to be 50 sec per
# parcel to be delivered.

# %%
PREP_TIME_PER_PARCEL = 50

# %% [markdown]
# **Additional assumption:** The time to **process returned parcels** in the delivery centre is 30 sec per parce.

# %%
RETURN_TIME_PER_PARCEL = 30

# %% [markdown]
# The average time to answer the door.

# %%
AVG_TIME_ANSWER_DOOR = 40

# %%
WAIT_TIME_IF_CUSTOMER_DOESNT_ANSWER_DOOR = 60

# %%
AVG_TIME_HANDOVER = 10
AVG_TIME_SIGNOFF = 10

# %%
DAY_END_PROCEDURE = 600

# %% [markdown]
# ## Generate Input Data

# %%
def generateDeliveries(p, C, days, seed=0):
    ## p is the average number of parcels per day per customer
    ## C is the number of customers to be served
    ## days is the number of days for which data are to be generated.
    random.seed(seed)
    deliveries = [ [ ] for _ in range(days) ]
    for c in range(C):
        arr = 0
        while True:
            arr += random.expovariate(p)
            day = int(arr)
            if day>=days:
                break
            deliveries[day].append(c)
    return deliveries

# %% [markdown]
# ## Simulation Routine

# %%
def simulation(M, Maps, W, C, p=0.2, days=10, seed=0, 
               log=False, plot=False, timing=False):

    random.seed(seed)
    D = generateDeliveries(p, len(C), days, seed)
    
    env = simpy.Environment()
    rec = Recorder(env, M, Maps, W, C, D, days,
                   log=log, plot=plot, timing=timing)

    print(f"Simulating delivery of {sum([len(d) for d in D]):d} parcels "
          f"over {len(D):d} days to {len(C):d} customers "
          f"using {len(Maps):d} drivers")

    # initialise all customer processes
 

    # initialises delivery center and creates all parcels
    DC = DeliveryCentre(rec, M, Maps, W, C, D,
                        BIKE_RANGE, DELIVERY_TIME_LIMIT)

    env.run()

    rec.finish()

    if DC.getInventory()>0:
        print(f"Delivery Centre Inventory at the end of last day: {DC.getInventory():d} parcels")

    return rec

# %% [markdown]
# ## Testing

# %% [markdown]
# ### Simple Test Case

# %%
import pickle
with open('simpleData.pickled', 'rb') as f:
    MS, CS = pickle.load(f)

# %%
WS = generateWarehouseLocation(MS)

# %%
plotMap(MS, T=CS, w=WS, scale=True, size=3)

# %%
rec1 = simulation(MS, [MS], WS, CS, p=0.3, days=7, log=True)
# Out:
# Simulating delivery of 201 parcels over 7 days to 100 customers using 1 drivers
# [ 0] 17:00:00.0 D0: Parcel 0 (for cust 13 arr at delivery centre
# [ 0] 17:00:00.0 D0: Parcel 1 (for cust 15 arr at delivery centre
# [ 0] 17:00:00.0 D0: Parcel 2 (for cust 16 arr at delivery centre
# [ 0] 17:00:00.0 D0: Parcel 3 (for cust 18 arr at delivery centre
# [ 0] 17:00:00.0 D0: Parcel 4 (for cust 19 arr at delivery centre
# [ 0] 17:00:00.0 D0: Parcel 5 (for cust 38 arr at delivery centre
# [ 0] 17:00:00.0 D0: Parcel 6 (for cust 40 arr at delivery centre
# [ 0] 17:00:00.0 D0: Parcel 7 (for cust 45 arr at delivery centre
# [ 0] 17:00:00.0 D0: Parcel 8 (for cust 45 arr at delivery centre
# [ 0] 17:00:00.0 D0: Parcel 9 (for cust 46 arr at delivery centre
# [ 0] 17:00:00.0 D0: Parcel 10 (for cust 48 arr at delivery centre
# [ 0] 17:00:00.0 D0: Parcel 11 (for cust 50 arr at delivery centre
# [ 0] 17:00:00.0 D0: Parcel 12 (for cust 52 arr at delivery centre
# [ 0] 17:00:00.0 D0: Parcel 13 (for cust 53 arr at delivery centre
# [ 0] 17:00:00.0 D0: Parcel 14 (for cust 55 arr at delivery centre
# [ 0] 17:00:00.0 D0: Parcel 15 (for cust 57 arr at delivery centre
# [ 0] 17:00:00.0 D0: Parcel 16 (for cust 70 arr at delivery centre
# [ 0] 17:00:00.0 D0: Parcel 17 (for cust 77 arr at delivery centre
# [ 0] 17:00:00.0 D0: Parcel 18 (for cust 78 arr at delivery centre
# [ 0] 17:00:00.0 D0: Parcel 19 (for cust 82 arr at delivery centre
# [ 0] 17:00:00.0 D0: Parcel 20 (for cust 82 arr at delivery centre
# [ 0] 17:00:00.0 D0: Parcel 21 (for cust 85 arr at delivery centre
# [ 0] 17:00:00.0 D0: Parcel 22 (for cust 89 arr at delivery centre
# [ 0] 17:00:00.0 D0: Parcel 23 (for cust 91 arr at delivery centre
# [ 0] 17:00:00.0 D0: Parcel 24 (for cust 91 arr at delivery centre
# [ 0] 17:00:00.0 D0: Parcel 25 (for cust 93 arr at delivery centre
# [ 0] 18:00:00.0 D0: arrives for work
# [ 0] 18:00:00.0 D0: Parcel 5 (for cust 38 out for delivery
# [ 0] 18:00:00.0 D0: Parcel 7 (for cust 45 out for delivery
# [ 0] 18:00:00.0 D0: Parcel 8 (for cust 45 out for delivery
# [ 0] 18:00:00.0 D0: Parcel 12 (for cust 52 out for delivery
# [ 0] 18:00:00.0 D0: Parcel 14 (for cust 55 out for delivery
# [ 0] 18:00:00.0 D0: Parcel 18 (for cust 78 out for delivery
# [ 0] 18:00:00.0 D0: Parcel 19 (for cust 82 out for delivery
# [ 0] 18:00:00.0 D0: Parcel 20 (for cust 82 out for delivery
# [ 0] 18:00:00.0 D0: Parcel 21 (for cust 85 out for delivery
# [ 0] 18:00:00.0 D0: Parcel 3 (for cust 18 out for delivery
# [ 0] 18:00:00.0 D0: Parcel 0 (for cust 13 out for delivery
# [ 0] 18:00:00.0 D0: Parcel 1 (for cust 15 out for delivery
# [ 0] 18:00:00.0 D0: Parcel 2 (for cust 16 out for delivery
# [ 0] 18:00:00.0 D0: Parcel 4 (for cust 19 out for delivery
# [ 0] 18:00:00.0 D0: Parcel 6 (for cust 40 out for delivery
# [ 0] 18:00:00.0 D0: Parcel 9 (for cust 46 out for delivery
# [ 0] 18:00:00.0 D0: Parcel 10 (for cust 48 out for delivery
# [ 0] 18:00:00.0 D0: Parcel 11 (for cust 50 out for delivery
# [ 0] 18:00:00.0 D0: Parcel 16 (for cust 70 out for delivery
# [ 0] 18:00:00.0 D0: Parcel 17 (for cust 77 out for delivery
# [ 0] 18:00:00.0 D0: Parcel 22 (for cust 89 out for delivery
# [ 0] 18:00:00.0 D0: Parcel 15 (for cust 57 out for delivery
# [ 0] 18:00:00.0 D0: Parcel 13 (for cust 53 out for delivery
# [ 0] 18:19:10.0 D0: leaves for delivery of 23 parcels to 21 customers
# [ 0] 18:19:10.0 D0: Length of delivery tour: 34,751m
# [ 0] 18:19:10.0 D0: drives to Customer 38 at (3440, 4276)
# [ 0] 18:20:03.8 D0: arrived at Customer 38 at (3440, 4276)
# [ 0] 18:20:20.9 D0: Customer 38 at (3440, 4276) answers door
# [ 0] 18:20:20.9 D0: Parcel 5 (for cust 38 delivered
# [ 0] 18:20:21.0 D0: Customer 38 at (3440, 4276) signs off
# [ 0] 18:20:57.6 D0: drives to Customer 45 at (3981, 3440)
# [ 0] 18:26:28.1 D0: arrived at Customer 45 at (3981, 3440)
# [ 0] 18:27:28.1 D0: Customer 45 at (3981, 3440) to slow to answer the door
# [ 0] 18:27:28.1 D0: drives to Customer 52 at (4718, 3220)
# [ 0] 18:30:46.8 D0: arrived at Customer 52 at (4718, 3220)
# [ 0] 18:30:49.7 D0: Customer 52 at (4718, 3220) answers door
# [ 0] 18:30:49.7 D0: Parcel 12 (for cust 52 delivered
# [ 0] 18:31:12.1 D0: Customer 52 at (4718, 3220) signs off
# [ 0] 18:31:14.4 D0: drives to Customer 55 at (4980, 740)
# [ 0] 18:43:31.0 D0: arrived at Customer 55 at (4980, 740)
# [ 0] 18:43:40.2 D0: Customer 55 at (4980, 740) answers door
# [ 0] 18:43:40.2 D0: Parcel 14 (for cust 55 delivered
# [ 0] 18:43:51.4 D0: Customer 55 at (4980, 740) signs off
# [ 0] 18:44:19.2 D0: drives to Customer 78 at (6082, 795)
# [ 0] 18:50:33.6 D0: arrived at Customer 78 at (6082, 795)
# [ 0] 20:09:35.5 D0: Customer 46 at (3984, 6620) to slow to answer the door
# [ 0] 20:09:35.5 D0: drives to Customer 48 at (4280, 6620)
# [ 0] 20:10:46.6 D0: arrived at Customer 48 at (4280, 6620)
# [ 0] 20:11:46.6 D0: Customer 48 at (4280, 6620) to slow to answer the door
# [ 0] 20:11:46.6 D0: drives to Customer 50 at (4500, 6283)
# [ 0] 20:14:00.3 D0: arrived at Customer 50 at (4500, 6283)
# [ 0] 20:14:15.4 D0: Customer 50 at (4500, 6283) answers door
# [ 0] 20:14:15.4 D0: Parcel 11 (for cust 50 delivered
# [ 0] 20:14:18.2 D0: Customer 50 at (4500, 6283) signs off
# [ 0] 20:14:32.3 D0: drives to Customer 70 at (5560, 7234)
# [ 0] 20:22:34.9 D0: arrived at Customer 70 at (5560, 7234)
# [ 0] 20:23:34.9 D0: Customer 70 at (5560, 7234) not at home
# [ 0] 20:23:34.9 D0: drives to Customer 77 at (6047, 7680)
# [ 0] 20:27:18.8 D0: arrived at Customer 77 at (6047, 7680)
# [ 0] 20:27:32.6 D0: Customer 77 at (6047, 7680) answers door
# [ 0] 20:27:32.6 D0: Parcel 17 (for cust 77 delivered
# [ 0] 20:27:38.0 D0: Customer 77 at (6047, 7680) signs off
# [ 0] 20:27:38.5 D0: drives to Customer 89 at (6513, 7680)
# [ 0] 20:29:30.4 D0: arrived at Customer 89 at (6513, 7680)
# [ 0] 20:29:36.0 D0: Customer 89 at (6513, 7680) answers door
# [ 0] 20:29:36.0 D0: Parcel 22 (for cust 89 delivered
# [ 0] 20:29:36.2 D0: Customer 89 at (6513, 7680) signs off
# [ 0] 20:29:37.1 D0: drives to Customer 57 at (5209, 5560)
# [ 0] 20:43:18.8 D0: arrived at Customer 57 at (5209, 5560)
# [ 0] 20:43:21.9 D0: Customer 57 at (5209, 5560) answers door
# [ 0] 20:43:21.9 D0: Parcel 15 (for cust 57 delivered
# [ 0] 20:43:27.3 D0: Customer 57 at (5209, 5560) signs off
# [ 0] 20:43:35.3 D0: drives to Customer 53 at (4722, 5560)
# [ 0] 20:45:32.2 D0: arrived at Customer 53 at (4722, 5560)
# [ 0] 20:46:26.2 D0: Customer 53 at (4722, 5560) answers door
# [ 0] 20:46:26.2 D0: Parcel 13 (for cust 53 delivered
# [ 0] 20:46:27.7 D0: Customer 53 at (4722, 5560) signs off
# [ 0] 20:46:33.2 D0: returns to delivery centre
# [ 0] 20:53:26.3 D0: arrived at delivery centre
# [ 0] 20:53:26.3 D0: Parcel 7 (for cust 45 returned from delivery
# [ 0] 20:53:56.3 D0: Parcel 8 (for cust 45 returned from delivery
# [ 0] 20:54:26.3 D0: Parcel 1 (for cust 15 returned from delivery
# [ 0] 20:54:56.3 D0: Parcel 6 (for cust 40 returned from delivery
# [ 0] 20:55:26.3 D0: Parcel 9 (for cust 46 returned from delivery
# [ 0] 20:55:56.3 D0: Parcel 10 (for cust 48 returned from delivery
# [ 0] 20:56:26.3 D0: Parcel 16 (for cust 70 returned from delivery
# [ 0] 20:56:56.3 D0: 10 parcels left over for next day
# [ 0] 21:06:56.3 D0: goes home
# [ 1] 17:00:00.0 D0: Parcel 26 (for cust 1 arr at delivery centre
# [ 1] 17:00:00.0 D0: Parcel 27 (for cust 2 arr at delivery centre
# [ 1] 17:00:00.0 D0: Parcel 28 (for cust 7 arr at delivery centre
# [ 1] 17:00:00.0 D0: Parcel 29 (for cust 12 arr at delivery centre
# [ 1] 17:00:00.0 D0: Parcel 30 (for cust 18 arr at delivery centre
# [ 1] 17:00:00.0 D0: Parcel 31 (for cust 24 arr at delivery centre
# [ 1] 17:00:00.0 D0: Parcel 32 (for cust 24 arr at delivery centre
# [ 1] 17:00:00.0 D0: Parcel 33 (for cust 30 arr at delivery centre
# [ 1] 17:00:00.0 D0: Parcel 34 (for cust 39 arr at delivery centre
# [ 1] 17:00:00.0 D0: Parcel 35 (for cust 44 arr at delivery centre
# [ 1] 17:00:00.0 D0: Parcel 36 (for cust 46 arr at delivery centre
# [ 1] 17:00:00.0 D0: Parcel 37 (for cust 46 arr at delivery centre
# [ 1] 17:00:00.0 D0: Parcel 38 (for cust 48 arr at delivery centre
# [ 1] 17:00:00.0 D0: Parcel 39 (for cust 49 arr at delivery centre
# [ 1] 17:00:00.0 D0: Parcel 40 (for cust 54 arr at delivery centre
# [ 1] 17:00:00.0 D0: Parcel 41 (for cust 58 arr at delivery centre
# [ 1] 17:00:00.0 D0: Parcel 42 (for cust 58 arr at delivery centre
# [ 1] 17:00:00.0 D0: Parcel 43 (for cust 59 arr at delivery centre
# [ 1] 17:00:00.0 D0: Parcel 44 (for cust 61 arr at delivery centre
# [ 1] 17:00:00.0 D0: Parcel 45 (for cust 62 arr at delivery centre
# [ 1] 17:00:00.0 D0: Parcel 46 (for cust 64 arr at delivery centre
# [ 1] 17:00:00.0 D0: Parcel 47 (for cust 65 arr at delivery centre
# [ 1] 17:00:00.0 D0: Parcel 48 (for cust 66 arr at delivery centre
# [ 1] 17:00:00.0 D0: Parcel 49 (for cust 66 arr at delivery centre
# [ 1] 17:00:00.0 D0: Parcel 50 (for cust 73 arr at delivery centre
# [ 1] 17:00:00.0 D0: Parcel 51 (for cust 76 arr at delivery centre
# [ 1] 17:00:00.0 D0: Parcel 52 (for cust 78 arr at delivery centre
# [ 1] 17:00:00.0 D0: Parcel 53 (for cust 92 arr at delivery centre
# [ 1] 17:00:00.0 D0: Parcel 54 (for cust 93 arr at delivery centre
# [ 1] 17:00:00.0 D0: Parcel 55 (for cust 93 arr at delivery centre
# [ 1] 17:00:00.0 D0: Parcel 56 (for cust 94 arr at delivery centre
# [ 1] 17:00:00.0 D0: Parcel 57 (for cust 97 arr at delivery centre
# [ 1] 17:00:00.0 D0: Parcel 58 (for cust 98 arr at delivery centre
# [ 1] 18:00:00.0 D0: arrives for work
# [ 1] 18:00:00.0 D0: Parcel 31 (for cust 24 out for delivery
# [ 1] 18:00:00.0 D0: Parcel 32 (for cust 24 out for delivery
# [ 1] 18:00:00.0 D0: Parcel 30 (for cust 18 out for delivery
# [ 1] 18:00:00.0 D0: Parcel 27 (for cust 2 out for delivery
# [ 1] 18:00:00.0 D0: Parcel 33 (for cust 30 out for delivery
# [ 1] 18:00:00.0 D0: Parcel 1 (for cust 15 out for delivery
# [ 1] 18:00:00.0 D0: Parcel 26 (for cust 1 out for delivery
# [ 1] 18:00:00.0 D0: Parcel 28 (for cust 7 out for delivery
# [ 1] 18:00:00.0 D0: Parcel 6 (for cust 40 out for delivery
# [ 1] 18:00:00.0 D0: Parcel 9 (for cust 46 out for delivery
# [ 1] 18:00:00.0 D0: Parcel 36 (for cust 46 out for delivery
# [ 1] 18:00:00.0 D0: Parcel 10 (for cust 48 out for delivery
# [ 1] 18:00:00.0 D0: Parcel 16 (for cust 70 out for delivery
# [ 1] 18:00:00.0 D0: Parcel 23 (for cust 91 out for delivery
# [ 1] 18:00:00.0 D0: Parcel 24 (for cust 91 out for delivery
# [ 1] 18:00:00.0 D0: Parcel 34 (for cust 39 out for delivery
# [ 1] 18:00:00.0 D0: Parcel 7 (for cust 45 out for delivery
# [ 1] 18:00:00.0 D0: Parcel 8 (for cust 45 out for delivery
# [ 1] 18:00:00.0 D0: Parcel 25 (for cust 93 out for delivery
# [ 1] 18:15:50.0 D0: leaves for delivery of 19 parcels to 15 customers
# [ 1] 18:15:50.0 D0: Length of delivery tour: 37,005m
# [ 1] 18:15:50.0 D0: drives to Customer 24 at (2251, 4500)
# [ 1] 18:20:35.4 D0: arrived at Customer 24 at (2251, 4500)
# [ 1] 18:20:44.8 D0: Customer 24 at (2251, 4500) answers door
# [ 1] 18:20:44.8 D0: Parcel 31 (for cust 24 delivered
# [ 1] 18:20:52.2 D0: Parcel 32 (for cust 24 delivered
# [ 1] 18:20:54.3 D0: Customer 24 at (2251, 4500) signs off
# [ 1] 18:20:56.5 D0: drives to Customer 18 at (2033, 4500)
# [ 1] 18:21:48.9 D0: arrived at Customer 18 at (2033, 4500)
# [ 1] 18:22:33.5 D0: Customer 18 at (2033, 4500) answers door
# [ 1] 18:22:33.5 D0: Parcel 30 (for cust 18 delivered
# [ 1] 18:22:46.8 D0: Customer 18 at (2033, 4500) signs off
# [ 1] 18:22:50.6 D0: drives to Customer 2 at (1320, 4082)
# [ 1] 18:27:22.0 D0: arrived at Customer 2 at (1320, 4082)
# [ 1] 18:28:22.0 D0: Customer 2 at (1320, 4082) to slow to answer the door
# [ 1] 18:28:22.0 D0: drives to Customer 30 at (2380, 5128)
# [ 1] 18:36:47.5 D0: arrived at Customer 30 at (2380, 5128)
# [ 1] 18:36:59.2 D0: Customer 30 at (2380, 5128) answers door
# [ 1] 18:36:59.2 D0: Parcel 33 (for cust 30 delivered
# [ 1] 18:37:03.4 D0: Customer 30 at (2380, 5128) signs off
# [ 1] 18:37:15.9 D0: drives to Customer 15 at (1896, 5560)
# [ 2] 20:50:11.1 D0: arrived at Customer 49 at (4500, 6156)
# [ 2] 20:51:11.1 D0: Customer 49 at (4500, 6156) to slow to answer the door
# [ 2] 20:51:11.1 D0: returns to delivery centre
# [ 2] 20:59:33.7 D0: arrived at delivery centre
# [ 2] 20:59:33.7 D0: Parcel 56 (for cust 94 returned from delivery
# [ 2] 21:00:03.7 D0: Parcel 45 (for cust 62 returned from delivery
# [ 2] 21:00:33.7 D0: Parcel 52 (for cust 78 returned from delivery
# [ 2] 21:01:03.7 D0: Parcel 50 (for cust 73 returned from delivery
# [ 2] 21:01:33.7 D0: Parcel 38 (for cust 48 returned from delivery
# [ 2] 21:02:03.7 D0: Parcel 10 (for cust 48 returned from delivery
# [ 2] 21:02:33.7 D0: Parcel 39 (for cust 49 returned from delivery
# [ 2] 21:03:03.7 D0: 42 parcels left over for next day
# [ 2] 21:13:03.7 D0: goes home
# [ 3] 17:00:00.0 D0: Parcel 89 (for cust 2 arr at delivery centre
# [ 3] 17:00:00.0 D0: Parcel 90 (for cust 3 arr at delivery centre
# [ 3] 17:00:00.0 D0: Parcel 91 (for cust 4 arr at delivery centre
# [ 3] 17:00:00.0 D0: Parcel 92 (for cust 8 arr at delivery centre
# [ 3] 17:00:00.0 D0: Parcel 93 (for cust 9 arr at delivery centre
# [ 3] 17:00:00.0 D0: Parcel 94 (for cust 14 arr at delivery centre
# [ 3] 17:00:00.0 D0: Parcel 95 (for cust 14 arr at delivery centre
# [ 3] 17:00:00.0 D0: Parcel 96 (for cust 16 arr at delivery centre
# [ 3] 17:00:00.0 D0: Parcel 97 (for cust 18 arr at delivery centre
# [ 3] 17:00:00.0 D0: Parcel 98 (for cust 19 arr at delivery centre
# [ 3] 17:00:00.0 D0: Parcel 99 (for cust 22 arr at delivery centre
# [ 3] 17:00:00.0 D0: Parcel 100 (for cust 23 arr at delivery centre
# [ 3] 17:00:00.0 D0: Parcel 101 (for cust 43 arr at delivery centre
# [ 3] 17:00:00.0 D0: Parcel 102 (for cust 48 arr at delivery centre
# [ 3] 17:00:00.0 D0: Parcel 103 (for cust 53 arr at delivery centre
# [ 3] 17:00:00.0 D0: Parcel 104 (for cust 56 arr at delivery centre
# [ 3] 17:00:00.0 D0: Parcel 105 (for cust 57 arr at delivery centre
# [ 3] 17:00:00.0 D0: Parcel 106 (for cust 57 arr at delivery centre
# [ 3] 17:00:00.0 D0: Parcel 107 (for cust 58 arr at delivery centre
# [ 3] 17:00:00.0 D0: Parcel 108 (for cust 60 arr at delivery centre
# [ 3] 17:00:00.0 D0: Parcel 109 (for cust 61 arr at delivery centre
# [ 3] 17:00:00.0 D0: Parcel 110 (for cust 64 arr at delivery centre
# [ 3] 17:00:00.0 D0: Parcel 111 (for cust 68 arr at delivery centre
# [ 3] 17:00:00.0 D0: Parcel 112 (for cust 71 arr at delivery centre
# [ 3] 17:00:00.0 D0: Parcel 113 (for cust 71 arr at delivery centre
# [ 3] 17:00:00.0 D0: Parcel 114 (for cust 75 arr at delivery centre
# [ 3] 17:00:00.0 D0: Parcel 115 (for cust 78 arr at delivery centre
# [ 3] 17:00:00.0 D0: Parcel 116 (for cust 86 arr at delivery centre
# [ 3] 17:00:00.0 D0: Parcel 117 (for cust 88 arr at delivery centre
# [ 3] 17:00:00.0 D0: Parcel 118 (for cust 89 arr at delivery centre
# [ 3] 17:00:00.0 D0: Parcel 119 (for cust 89 arr at delivery centre
# [ 3] 17:00:00.0 D0: Parcel 120 (for cust 97 arr at delivery centre
# [ 3] 17:00:00.0 D0: Parcel 121 (for cust 98 arr at delivery centre
# [ 3] 18:00:00.0 D0: arrives for work
# [ 3] 18:00:00.0 D0: Parcel 65 (for cust 24 out for delivery
# [ 3] 18:00:00.0 D0: Parcel 62 (for cust 15 out for delivery
# [ 3] 18:00:00.0 D0: Parcel 73 (for cust 48 out for delivery
# [ 3] 18:00:00.0 D0: Parcel 38 (for cust 48 out for delivery
# [ 3] 18:00:00.0 D0: Parcel 6 (for cust 40 out for delivery
# [ 3] 18:00:00.0 D0: Parcel 72 (for cust 42 out for delivery
# [ 3] 18:00:00.0 D0: Parcel 66 (for cust 25 out for delivery
# [ 3] 18:00:00.0 D0: Parcel 67 (for cust 25 out for delivery
# [ 3] 18:00:00.0 D0: Parcel 61 (for cust 11 out for delivery
# [ 3] 18:00:00.0 D0: Parcel 28 (for cust 7 out for delivery
# [ 3] 18:00:00.0 D0: Parcel 26 (for cust 1 out for delivery
# [ 3] 18:00:00.0 D0: Parcel 59 (for cust 1 out for delivery
# [ 3] 18:00:00.0 D0: Parcel 60 (for cust 3 out for delivery
# [ 3] 18:00:00.0 D0: Parcel 27 (for cust 2 out for delivery
# [ 3] 18:00:00.0 D0: Parcel 64 (for cust 21 out for delivery
# [ 3] 18:00:00.0 D0: Parcel 68 (for cust 29 out for delivery
# [ 3] 18:00:00.0 D0: Parcel 69 (for cust 32 out for delivery
# [ 3] 18:00:00.0 D0: Parcel 57 (for cust 97 out for delivery
# [ 3] 18:00:00.0 D0: Parcel 58 (for cust 98 out for delivery
# [ 3] 18:15:50.0 D0: leaves for delivery of 19 parcels to 16 customers
# [ 3] 18:15:50.0 D0: Length of delivery tour: 36,773m
# [ 3] 18:15:50.0 D0: drives to Customer 24 at (2251, 4500)
# [ 3] 18:20:35.4 D0: arrived at Customer 24 at (2251, 4500)
# [ 3] 18:21:35.4 D0: Customer 24 at (2251, 4500) to slow to answer the door
# [ 3] 18:21:35.4 D0: drives to Customer 15 at (1896, 5560)
# [ 3] 18:28:16.9 D0: arrived at Customer 15 at (1896, 5560)
# [ 3] 18:28:43.3 D0: Customer 15 at (1896, 5560) answers door
# [ 3] 18:28:43.3 D0: Parcel 62 (for cust 15 delivered
# [ 3] 18:29:05.1 D0: Customer 15 at (1896, 5560) signs off
# [ 3] 18:29:16.5 D0: drives to Customer 48 at (4280, 6620)
# [ 3] 18:40:34.0 D0: arrived at Customer 48 at (4280, 6620)
# [ 3] 18:40:35.8 D0: Customer 48 at (4280, 6620) answers door
# [ 3] 18:40:35.8 D0: Parcel 73 (for cust 48 delivered
# [ 3] 18:40:38.6 D0: Parcel 38 (for cust 48 delivered
# [ 3] 18:40:41.9 D0: Customer 48 at (4280, 6620) signs off
# [ 3] 18:40:43.7 D0: drives to Customer 40 at (3440, 6776)
# [ 3] 18:44:42.8 D0: arrived at Customer 40 at (3440, 6776)
# [ 3] 18:44:53.7 D0: Customer 40 at (3440, 6776) answers door
# [ 3] 18:44:53.7 D0: Parcel 6 (for cust 40 delivered
# [ 3] 18:44:56.2 D0: Customer 40 at (3440, 6776) signs off
# [ 3] 18:45:17.3 D0: drives to Customer 42 at (3440, 7122)
# [ 3] 18:46:40.3 D0: arrived at Customer 42 at (3440, 7122)
# [ 3] 18:47:05.2 D0: Customer 42 at (3440, 7122) answers door
# [ 3] 18:47:05.2 D0: Parcel 72 (for cust 42 delivered
# [ 3] 18:47:26.1 D0: Customer 42 at (3440, 7122) signs off
# [ 3] 18:47:27.6 D0: drives to Customer 25 at (2252, 7680)
# [ 3] 18:54:26.6 D0: arrived at Customer 25 at (2252, 7680)
# [ 3] 18:54:59.9 D0: Customer 25 at (2252, 7680) answers door
# [ 3] 18:54:59.9 D0: Parcel 66 (for cust 25 delivered
# [ 3] 18:55:00.1 D0: Parcel 67 (for cust 25 delivered
# [ 3] 18:55:26.7 D0: Customer 25 at (2252, 7680) signs off
# [ 3] 18:55:26.7 D0: drives to Customer 11 at (1664, 7680)
# [ 3] 18:57:47.9 D0: arrived at Customer 11 at (1664, 7680)
# [ 3] 18:58:07.6 D0: Customer 11 at (1664, 7680) answers door
# [ 3] 18:58:07.6 D0: Parcel 61 (for cust 11 delivered
# [ 3] 18:58:23.8 D0: Customer 11 at (1664, 7680) signs off
# [ 3] 18:59:54.2 D0: drives to Customer 7 at (1449, 7680)
# [ 3] 19:00:45.8 D0: arrived at Customer 7 at (1449, 7680)
# [ 3] 19:00:46.6 D0: Customer 7 at (1449, 7680) answers door
# [ 3] 19:00:46.6 D0: Parcel 28 (for cust 7 delivered
# [ 3] 19:01:04.0 D0: Customer 7 at (1449, 7680) signs off
# [ 3] 19:01:11.1 D0: drives to Customer 1 at (1078, 6620)
# [ 3] 19:06:54.6 D0: arrived at Customer 1 at (1078, 6620)
# [ 3] 19:06:56.1 D0: Customer 1 at (1078, 6620) answers door
# [ 3] 19:06:56.1 D0: Parcel 26 (for cust 1 delivered
# [ 3] 19:07:11.1 D0: Parcel 59 (for cust 1 delivered
# [ 3] 19:07:12.3 D0: Customer 1 at (1078, 6620) signs off
# [ 3] 19:07:21.8 D0: drives to Customer 3 at (1320, 4193)
# [ 3] 19:18:02.3 D0: arrived at Customer 3 at (1320, 4193)
# [ 3] 19:19:02.3 D0: Customer 3 at (1320, 4193) to slow to answer the door
# [ 3] 19:19:02.3 D0: drives to Customer 2 at (1320, 4082)
# [ 3] 19:19:29.0 D0: arrived at Customer 2 at (1320, 4082)
# [ 3] 19:20:13.8 D0: Customer 2 at (1320, 4082) answers door
# [ 3] 19:20:13.8 D0: Parcel 27 (for cust 2 delivered
# [ 3] 19:20:18.5 D0: Customer 2 at (1320, 4082) signs off
# [ 3] 19:20:18.8 D0: drives to Customer 21 at (2100, 2659)
# [ 3] 19:27:17.6 D0: arrived at Customer 21 at (2100, 2659)
# [ 3] 19:27:40.5 D0: Customer 21 at (2100, 2659) answers door
# [ 3] 19:27:40.5 D0: Parcel 64 (for cust 21 delivered
# [ 3] 19:28:05.0 D0: Customer 21 at (2100, 2659) signs off
# [ 3] 19:28:09.1 D0: drives to Customer 29 at (2380, 1941)
# [ 3] 19:31:29.2 D0: arrived at Customer 29 at (2380, 1941)
# [ 3] 19:32:29.2 D0: Customer 29 at (2380, 1941) not at home
# [ 3] 19:32:29.2 D0: drives to Customer 32 at (2738, 2738)
# [ 3] 19:39:25.6 D0: arrived at Customer 32 at (2738, 2738)
# [ 3] 19:39:37.0 D0: Customer 32 at (2738, 2738) answers door
# [ 3] 19:39:37.0 D0: Parcel 69 (for cust 32 delivered
# [ 3] 19:39:38.5 D0: Customer 32 at (2738, 2738) signs off
# [ 3] 19:39:45.7 D0: drives to Customer 97 at (8543, 4303)
# [ 3] 20:09:04.9 D0: arrived at Customer 97 at (8543, 4303)
# [ 3] 20:09:35.3 D0: Customer 97 at (8543, 4303) answers door
# [ 3] 20:09:35.3 D0: Parcel 57 (for cust 97 delivered
# [ 3] 20:09:36.1 D0: Customer 97 at (8543, 4303) signs off
# [ 3] 20:09:41.3 D0: drives to Customer 98 at (8592, 2380)
# [ 3] 20:22:27.4 D0: arrived at Customer 98 at (8592, 2380)
# [ 3] 20:23:10.4 D0: Customer 98 at (8592, 2380) answers door
# [ 3] 20:23:10.4 D0: Parcel 58 (for cust 98 delivered
# [ 3] 20:23:44.2 D0: Customer 98 at (8592, 2380) signs off
# [ 3] 20:23:49.9 D0: returns to delivery centre
# [ 3] 20:56:25.9 D0: arrived at delivery centre
# [ 3] 20:56:25.9 D0: Parcel 65 (for cust 24 returned from delivery
# [ 3] 20:56:55.9 D0: Parcel 60 (for cust 3 returned from delivery
# [ 3] 20:57:25.9 D0: Parcel 68 (for cust 29 returned from delivery
# [ 3] 20:57:55.9 D0: 59 parcels left over for next day
# [ 3] 21:07:55.9 D0: goes home
# [ 4] 17:00:00.0 D0: Parcel 122 (for cust 4 arr at delivery centre
# [ 4] 17:00:00.0 D0: Parcel 123 (for cust 13 arr at delivery centre
# [ 4] 17:00:00.0 D0: Parcel 124 (for cust 16 arr at delivery centre
# [ 4] 17:00:00.0 D0: Parcel 125 (for cust 23 arr at delivery centre
# [ 4] 17:00:00.0 D0: Parcel 126 (for cust 29 arr at delivery centre
# [ 4] 17:00:00.0 D0: Parcel 127 (for cust 33 arr at delivery centre
# [ 4] 17:00:00.0 D0: Parcel 128 (for cust 40 arr at delivery centre
# [ 4] 17:00:00.0 D0: Parcel 129 (for cust 40 arr at delivery centre
# [ 4] 17:00:00.0 D0: Parcel 130 (for cust 48 arr at delivery centre
# [ 4] 17:00:00.0 D0: Parcel 131 (for cust 49 arr at delivery centre
# [ 4] 17:00:00.0 D0: Parcel 132 (for cust 49 arr at delivery centre
# [ 4] 17:00:00.0 D0: Parcel 133 (for cust 49 arr at delivery centre
# [ 4] 17:00:00.0 D0: Parcel 134 (for cust 52 arr at delivery centre
# [ 4] 17:00:00.0 D0: Parcel 135 (for cust 55 arr at delivery centre
# [ 4] 17:00:00.0 D0: Parcel 136 (for cust 59 arr at delivery centre
# [ 4] 17:00:00.0 D0: Parcel 137 (for cust 66 arr at delivery centre
# [ 4] 17:00:00.0 D0: Parcel 138 (for cust 67 arr at delivery centre
# [ 4] 17:00:00.0 D0: Parcel 139 (for cust 74 arr at delivery centre
# [ 4] 17:00:00.0 D0: Parcel 140 (for cust 74 arr at delivery centre
# [ 4] 17:00:00.0 D0: Parcel 141 (for cust 82 arr at delivery centre
# [ 4] 17:00:00.0 D0: Parcel 142 (for cust 85 arr at delivery centre
# [ 4] 17:00:00.0 D0: Parcel 143 (for cust 88 arr at delivery centre
# [ 4] 17:00:00.0 D0: Parcel 144 (for cust 89 arr at delivery centre
# [ 4] 17:00:00.0 D0: Parcel 145 (for cust 90 arr at delivery centre
# [ 4] 17:00:00.0 D0: Parcel 146 (for cust 93 arr at delivery centre
# [ 4] 17:00:00.0 D0: Parcel
arr at delivery centre
# [ 5] 17:00:00.0 D0: Parcel 167 (for cust 68 arr at delivery centre
# [ 5] 17:00:00.0 D0: Parcel 168 (for cust 73 arr at delivery centre
# [ 5] 17:00:00.0 D0: Parcel 169 (for cust 80 arr at delivery centre
# [ 5] 17:00:00.0 D0: Parcel 170 (for cust 89 arr at delivery centre
# [ 5] 17:00:00.0 D0: Parcel 171 (for cust 90 arr at delivery centre
# [ 5] 17:00:00.0 D0: Parcel 172 (for cust 92 arr at delivery centre
# [ 5] 18:00:00.0 D0: arrives for work
# [ 5] 18:00:00.0 D0: Parcel 101 (for cust 43 out for delivery
# [ 5] 18:00:00.0 D0: Parcel 104 (for cust 56 out for delivery
# [ 5] 18:00:00.0 D0: Parcel 110 (for cust 64 out for delivery
# [ 5] 18:00:00.0 D0: Parcel 109 (for cust 61 out for delivery
# [ 5] 18:00:00.0 D0: Parcel 108 (for cust 60 out for delivery
# [ 5] 18:00:00.0 D0: Parcel 107 (for cust 58 out for delivery
# [ 5] 18:00:00.0 D0: Parcel 68 (for cust 29 out for delivery
# [ 5] 18:00:00.0 D0: Parcel 94 (for cust 14 out for delivery
# [ 5] 18:00:00.0 D0: Parcel 95 (for cust 14 out for delivery
# [ 5] 18:00:00.0 D0: Parcel 89 (for cust 2 out for delivery
# [ 5] 18:00:00.0 D0: Parcel 90 (for cust 3 out for delivery
# [ 5] 18:00:00.0 D0: Parcel 60 (for cust 3 out for delivery
# [ 5] 18:00:00.0 D0: Parcel 91 (for cust 4 out for delivery
# [ 5] 18:00:00.0 D0: Parcel 93 (for cust 9 out for delivery
# [ 5] 18:00:00.0 D0: Parcel 100 (for cust 23 out for delivery
# [ 5] 18:00:00.0 D0: Parcel 92 (for cust 8 out for delivery
# [ 5] 18:00:00.0 D0: Parcel 96 (for cust 16 out for delivery
# [ 5] 18:00:00.0 D0: Parcel 98 (for cust 19 out for delivery
# [ 5] 18:00:00.0 D0: Parcel 102 (for cust 48 out for delivery
# [ 5] 18:00:00.0 D0: Parcel 112 (for cust 71 out for delivery
# [ 5] 18:00:00.0 D0: Parcel 113 (for cust 71 out for delivery
# [ 5] 18:00:00.0 D0: Parcel 111 (for cust 68 out for delivery
# [ 5] 18:00:00.0 D0: Parcel 105 (for cust 57 out for delivery
# [ 5] 18:00:00.0 D0: Parcel 106 (for cust 57 out for delivery
# [ 5] 18:00:00.0 D0: Parcel 103 (for cust 53 out for delivery
# [ 5] 18:20:50.0 D0: leaves for delivery of 25 parcels to 21 customers
# [ 5] 18:20:50.0 D0: Length of delivery tour: 34,221m
# [ 5] 18:20:50.0 D0: drives to Customer 43 at (3847, 3440)
# [ 5] 18:26:42.1 D0: arrived at Customer 43 at (3847, 3440)
# [ 5] 18:27:21.8 D0: Customer 43 at (3847, 3440) answers door
# [ 5] 18:27:21.8 D0: Parcel 101 (for cust 43 delivered
# [ 5] 18:27:24.8 D0: Customer 43 at (3847, 3440) signs off
# [ 5] 18:27:26.1 D0: drives to Customer 56 at (5106, 2833)
# [ 5] 18:33:28.5 D0: arrived at Customer 56 at (5106, 2833)
# [ 5] 18:33:42.3 D0: Customer 56 at (5106, 2833) answers door
# [ 5] 18:33:42.3 D0: Parcel 104 (for cust 56 delivered
# [ 5] 18:33:51.8 D0: Customer 56 at (5106, 2833) signs off
# [ 5] 18:34:02.0 D0: drives to Customer 64 at (5560, 1912)
# [ 5] 18:38:28.1 D0: arrived at Customer 64 at (5560, 1912)
# [ 5] 18:39:22.8 D0: Customer 64 at (5560, 1912) answers door
# [ 5] 18:39:22.8 D0: Parcel 110 (for cust 64 delivered
# [ 5] 18:39:30.6 D0: Customer 64 at (5560, 1912) signs off
# [ 5] 18:39:31.2 D0: drives to Customer 61 at (5363, 1123)
# [ 5] 18:43:00.0 D0: arrived at Customer 61 at (5363, 1123)
# [ 5] 18:43:29.0 D0: Customer 61 at (5363, 1123) answers door
# [ 5] 18:43:29.0 D0: Parcel 109 (for cust 61 delivered
# [ 5] 18:43:29.1 D0: Customer 61 at (5363, 1123) signs off
# [ 5] 18:43:53.0 D0: drives to Customer 60 at (5273, 1033)
# [ 5] 18:44:23.5 D0: arrived at Customer 60 at (5273, 1033)
# [ 5] 18:45:23.5 D0: Customer 60 at (5273, 1033) not at home
# [ 5] 18:45:23.5 D0: drives to Customer 58 at (5217, 977)
# [ 5] 18:45:42.4 D0: arrived at Customer 58 at (5217, 977)
# [ 5] 18:46:42.4 D0: Customer 58 at (5217, 977) to slow to answer the door
# [ 5] 18:46:42.4 D0: drives to Customer 29 at (2380, 1941)
arr at delivery centre
# [ 6] 17:00:00.0 D0: Parcel 185 (for cust 42 arr at delivery centre
# [ 6] 17:00:00.0 D0: Parcel 186 (for cust 50 arr at delivery centre
# [ 6] 17:00:00.0 D0: Parcel 187 (for cust 60 arr at delivery centre
# [ 6] 17:00:00.0 D0: Parcel 188 (for cust 61 arr at delivery centre
# [ 6] 17:00:00.0 D0: Parcel 189 (for cust 61 arr at delivery centre
# [ 6] 17:00:00.0 D0: Parcel 190 (for cust 63 arr at delivery centre
# [ 6] 17:00:00.0 D0: Parcel 191 (for cust 66 arr at delivery centre
# [ 6] 17:00:00.0 D0: Parcel 192 (for cust 69 arr at delivery centre
# [ 6] 17:00:00.0 D0: Parcel 193 (for cust 73 arr at delivery centre
# [ 6] 17:00:00.0 D0: Parcel 194 (for cust 75 arr at delivery centre
# [ 6] 17:00:00.0 D0: Parcel 195 (for cust 77 arr at delivery centre
# [ 6] 17:00:00.0 D0: Parcel 196 (for cust 79 arr at delivery centre
# [ 6] 17:00:00.0 D0: Parcel 197 (for cust 81 arr at delivery centre
# [ 6] 17:00:00.0 D0: Parcel 198 (for cust 82 arr at delivery centre
# [ 6] 17:00:00.0 D0: Parcel 199 (for cust 92 arr at delivery centre
# [ 6] 17:00:00.0 D0: Parcel 200 (for cust 93 arr at delivery centre
# [ 6] 18:00:00.0 D0: arrives for work
# [ 6] 18:00:00.0 D0: Parcel 65 (for cust 24 out for delivery
# [ 6] 18:00:00.0 D0: Parcel 123 (for cust 13 out for delivery
# [ 6] 18:00:00.0 D0: Parcel 122 (for cust 4 out for delivery
# [ 6] 18:00:00.0 D0: Parcel 118 (for cust 89 out for delivery
# [ 6] 18:00:00.0 D0: Parcel 119 (for cust 89 out for delivery
# [ 6] 18:00:00.0 D0: Parcel 114 (for cust 75 out for delivery
# [ 6] 18:00:00.0 D0: Parcel 116 (for cust 86 out for delivery
# [ 6] 18:00:00.0 D0: Parcel 117 (for cust 88 out for delivery
# [ 6] 18:00:00.0 D0: Parcel 143 (for cust 88 out for delivery
# [ 6] 18:00:00.0 D0: Parcel 121 (for cust 98 out for delivery
# [ 6] 18:00:00.0 D0: Parcel 120 (for cust 97 out for delivery
# [ 6] 18:00:00.0 D0: Parcel 115 (for cust 78 out for delivery
# [ 6] 18:10:00.0 D0: leaves for delivery of 12 parcels to 10 customers
# [ 6] 18:10:00.0 D0: Length of delivery tour: 39,890m
# [ 6] 18:10:00.0 D0: drives to Customer 24 at (2251, 4500)
# [ 6] 18:14:45.4 D0: arrived at Customer 24 at (2251, 4500)
# [ 6] 18:15:02.8 D0: Customer 24 at (2251, 4500) answers door
# [ 6] 18:15:02.8 D0: Parcel 65 (for cust 24 delivered
# [ 6] 18:15:05.1 D0: Customer 24 at (2251, 4500) signs off
# [ 6] 18:15:30.5 D0: drives to Customer 13 at (1798, 4500)
# [ 6] 18:17:19.2 D0: arrived at Customer 13 at (1798, 4500)
# [ 6] 18:17:28.0 D0: Customer 13 at (1798, 4500) answers door
# [ 6] 18:17:28.0 D0: Parcel 123 (for cust 13 delivered
# [ 6] 18:17:30.0 D0: Customer 13 at (1798, 4500) signs off
# [ 6] 18:17:32.0 D0: drives to Customer 4 at (1320, 4285)
# [ 6] 18:20:18.3 D0: arrived at Customer 4 at (1320, 4285)
# [ 6] 18:21:01.2 D0: Customer 4 at (1320, 4285) answers door
# [ 6] 18:21:01.2 D0: Parcel 122 (for cust 4 delivered
# [ 6] 18:21:10.7 D0: Customer 4 at (1320, 4285) signs off
# [ 6] 18:21:17.7 D0: drives to Customer 89 at (6513, 7680)
# [ 6] 18:53:09.8 D0: arrived at Customer 89 at (6513, 7680)
# [ 6] 18:53:45.2 D0: Customer 89 at (6513, 7680) answers door
# [ 6] 18:53:45.2 D0: Parcel 118 (for cust 89 delivered
# [ 6] 18:54:13.4 D0: Parcel 119 (for cust 89 delivered
# [ 6] 18:54:33.1 D0: Customer 89 at (6513, 7680) signs off
# [ 6] 18:54:56.8 D0: drives to Customer 75 at (5972, 5560)
# [ 6] 19:08:53.2 D0: arrived at Customer 75 at (5972, 5560)
# [ 6] 19:08:55.4 D0: Customer 75 at (5972, 5560) answers door
# [ 6] 19:08:55.4 D0: Parcel 114 (for cust 75 delivered
# [ 6] 19:09:18.2 D0: Customer 75 at (5972, 5560) signs off
# [ 6] 19:09:18.5 D0: drives to Customer 86 at (6369, 5560)
# [ 6] 19:10:53.8 D0: arrived at Customer 86 at (6369, 5560)
# [ 6] 19:11:35.5 D0: Customer 86 at (6369, 5560) answers door
# [ 6] 19:11:35.5 D0: Parcel 116 (for cust 86 delivered
# [ 6] 19:12:02.2 D0: Customer 86 at (6369, 5560) signs off
# [ 6] 19:12:09.2 D0: drives to Customer 88 at (6439, 3259)
# [ 6] 19:45:04.4 D0: arrived at Customer 88 at (6439, 3259)
# [ 6] 19:45:26.1 D0: Customer 88 at (6439, 3259) answers door
# [ 6] 19:45:26.1 D0: Parcel 117 (for cust 88 delivered
# [ 6] 19:45:30.2 D0: Parcel 143 (for cust 88 delivered
# [ 6] 19:45:54.9 D0: Customer 88 at (6439, 3259) signs off
# [ 6] 19:46:21.0 D0: drives to Customer 98 at (8592, 2380)
# [ 6] 19:59:29.9 D0: arrived at Customer 98 at (8592, 2380)
# [ 6] 20:00:29.9 D0: Customer 98 at (8592, 2380) not at home
# [ 6] 20:00:29.9 D0: drives to Customer 97 at (8543, 4303)
# [ 6] 20:13:15.9 D0: arrived at Customer 97 at (8543, 4303)
# [ 6] 20:13:54.5 D0: Customer 97 at (8543, 4303) answers door
# [ 6] 20:13:54.5 D0: Parcel 120 (for cust 97 delivered
# [ 6] 20:14:07.1 D0: Customer 97 at (8543, 4303) signs off
# [ 6] 20:14:11.2 D0: drives to Customer 78 at (6082, 795)
# [ 6] 20:36:29.9 D0: arrived at Customer 78 at (6082, 795)
# [ 6] 20:36:35.9 D0: Customer 78 at (6082, 795) answers door
# [ 6] 20:36:35.9 D0: Parcel 115 (for cust 78 delivered
# [ 6] 20:37:14.5 D0: Customer 78 at (6082, 795) signs off
# [ 6] 20:37:25.2 D0: returns to delivery centre
# [ 6] 20:59:05.8 D0: arrived at delivery centre
# [ 6] 20:59:05.8 D0: Parcel 121 (for cust 98 returned from delivery
# [ 6] 20:59:35.8 D0: 90 parcels left over for next day
# [ 6] 21:09:35.8 D0: goes home
# Delivery Centre Inventory at the end of last day: 90 parcels

# %%
rec1.plotParcelsLeftOver(0)

# %%
rec1.plotParcelsLeftOver()

# %%
rec1.histParcelsLeftOver()

# %% [markdown]
# ### Stable Base Case

# %%
import pickle
with open('testData.pickled', 'rb') as f:
    MT, CT = pickle.load(f)

# %%
WT = generateWarehouseLocation(MT)

# %%
plotMap(MT, T=CT, w=WT, scale=True)

# %%
rec2 = simulation(MT, [ MT ], WT, CT, p=0.15, days=50)
# Out:
# Simulating delivery of 134 parcels over 50 days to 20 customers using 1 drivers
# Delivery Centre Inventory at the end of last day: 1 parcels

# %%
rec2.histWorkingTime()
rec2.plotWorkingTime()

# %%
rec2.histTourLength()
rec2.plotTourLength()

# %%
rec2.plotParcelsLeftOver()

# %%
rec2.countPlot()

# %% [markdown]
# ### High Demand System

# %% [markdown]
# #### Using Utilising 1 Driver

# %%
import pickle
with open('data.pickled', 'rb') as f:
    M, C = pickle.load(f)

# %%
W = generateWarehouseLocation(M)

# %%
plotMap(M, T=C, w=W, scale=True)

# %%
rec3 = simulation(M, [ M ], W, C, p=0.25, days=50)
# Out:
# Simulating delivery of 1249 parcels over 50 days to 100 customers using 1 drivers
# Delivery Centre Inventory at the end of last day: 480 parcels

# %%
rec3.histTourLength()
rec3.plotTourLength()

# %%
rec3.histWorkingTime()
rec3.plotWorkingTime()

# %%
rec3.plotParcelsLeftOver()

# %%
rec3.countPlot()

# %% [markdown]
# #### High Demand System (2 Drivers, Static Allocation)

# %%
import pickle
with open('data.pickled', 'rb') as f:
    M, C = pickle.load(f)

# %%
W = generateWarehouseLocation(M)

# %% [markdown]
# ##### **Step 1: Make a plan how to cover M with two subgraphs A and B**

# %%
plotMap(M, w=W, grid=True)

# %% [markdown]
# We need to split the graph M into two (or more) subgraphs, so that each subgraph is connected, that the union of the subgraphs is M and that the warehouse location W is in each subgraph.
#
# For the default Map (seed: 9999) we could use A and B as indicated below.
#
# **Note:** You need to find suitable A and B to cover the map corresponding to your seed value.

# %% [markdown]
# <img src='img/data.pickle split.png' width='70%'/>

# %%
V, E = M

# %%
VA = [ (x, y) for (x, y) in V if y>5000 or (4000<y<5000 and 1000<x<4000) ]
VB = [ (x, y) for (x, y) in V if y<5000 or (5000<y<5500 and 4000<x<5000) ]

# %%
EA = [ (P, Q) for (P, Q) in E if P in VA and Q in VA ]
EB = [ (P, Q) for (P, Q) in E if P in VB and Q in VB ]

# %%
A = VA, EA
B = VB, EB

# %% [markdown]
# ##### **Step 2: Check if A and B match the *plan*.**

# %%
plotMap(A, frame=M, w=W, text="Region A", grid=True)

# %%
plotMap(B, frame=M, w=W, text="Region B", grid=True)

# %% [markdown]
# ##### **Step 3: Test if A and B are suitable**

# %% [markdown]
# If your subgraphs A and B do not pass the following test, you need to rethink how you draw the borders between A and B.

# %% [markdown]
# `closure(M,W)` computes the set of all nodes in the map M that can be reached from W.

# %%
def closure(M, W):
    V, E = M
    C = set([W])
    success = True
    while success:
        success = False
        for (P, Q) in E:
            if P in C and Q not in C: 
                C.add(Q)
                success = True
                break
            if Q in C and P not in C: 
                C.add(P)
                success = True
                break
    return C

# %% [markdown]
# A and B together cover all the nodes and all edges in M:

# %%
assert(set(VA) | set(VB) == set(V))

# %%
assert(set(EA) | set(EB) == set(E))

# %% [markdown]
# The warehouse must be a node in A and in B:

# %%
assert(W in set(VA) & set(VB))

# %% [markdown]
# All nodes in A must be reachable from W:

# %%
assert(closure(A, W) == set(VA))

# %% [markdown]
# All nodes in B must be reachable from W:

# %%
assert(closure(B, W) == set(VB))

# %% [markdown]
# ##### **Step 4: Run the simulation with A and B**

# %%
rec4 = simulation(M, [A, B], W, C, p=0.25, days=50)
# Out:
# Simulating delivery of 1249 parcels over 50 days to 100 customers using 2 drivers
# Delivery Centre Inventory at the end of last day: 15 parcels

# %%
for i in range(rec4.drivers):
    rec4.histTourLength(i)
rec4.histTourLength()

# %%
for i in range(rec4.drivers):
    rec4.plotTourLength(i)
rec4.plotTourLength()

# %%
for i in range(rec4.drivers):
    rec4.histWorkingTime(i)
rec4.histWorkingTime()

# %%
for i in range(rec4.drivers):
    rec4.plotWorkingTime(i)
rec4.plotWorkingTime()

# %%
for i in range(rec4.drivers):
    rec4.plotDailyCost(i)
rec4.plotDailyCost()

# %%
rec4.histDailyCost()

# %%
rec4.histParcelsArrived()

# %%
rec4.histParcelsDelivered()

# %%
rec4.plotParcelsLeftOver()

# %%
rec4.countPlot()

# %%
rec4.histParcelDeliveryDelay()
