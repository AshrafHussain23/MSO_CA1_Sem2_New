# %% [markdown]
# # Prelude

# %%
import matplotlib.pyplot as plt
import pulp
import math
import random
import pandas as pd
import numpy as np
import simpy

# %% [markdown]
# # Utilities

# %% [markdown]
# ## Points and Distances

# %%
def dist(p1, p2):
    (x1, y1) = p1
    (x2, y2) = p2
    return int(math.sqrt((x1-x2)**2+(y1-y2)**2))

# %% [markdown]
# ## PlotMap

# %%
def label(i):
    return (label(i//26-1)+chr(65+i%26)) if i>25 else chr(65+i)

# %%
def plotMap(G, T=[], P=[], w=None,
            style='r-o', lw=1, ms=3, 
            styleT='go', msT=3,
            styleP='b-o', lwP=2, msP=3,
            stylePT='go', msPT=7,
            styleW='ro', msW=9,
            text=None, grid=False, labels=False, scale=False):

    V, E = G

    def round_down(x, level): return (x//level)*level
    def round_up(x, level): return (x//level+1)*level
    
    xmin = round_down(min([ x for (x, _) in V ]), 100)
    xmax = round_up(max([ x for (x, _) in V ]), 100)
    ymin = round_down(min([ y for (_, y) in V ]), 100)
    ymax = round_up(max([ y for (_, y) in V ]), 100)
    dx = xmax-xmin
    dy = ymax-ymin
    yoffset = (ymax-ymin)//10
    
    fig = plt.gcf()
    fig.set_size_inches(4, 4)
    plt.xlim(xmin, xmax)
    plt.ylim(ymin-yoffset, ymax)
    
    if not grid:
        plt.axis('off')

    for e in E:
        p1, p2 = e
        plt.plot( [ p1[0], p2[0] ],
                  [ p1[1], p2[1] ], 
                  style, lw=lw, ms=ms)
    if scale:
        # plot 1000m scale
        ybar = ymin-0.9*yoffset
        D = [ (xmin, ybar+50), (xmin, ybar), (xmin+1000, ybar), (xmin+1000, ybar+50) ]
        plt.plot( [ d[0] for d in D ], [ d[1] for d in D ], 'k-', lw=0.5)
        plt.text(xmin+500, ymin-0.7*yoffset, '1000m' , horizontalalignment='center', size=8)
    
    if labels:
        for i in range(len(V)):
            x, y = V[i]
            plt.text(x+0.0150*dx, y-0.0350*dy, label(i), size=8)
        
    for t in T:
        plt.plot( [ t[0] ], [ t[1] ], 
                  styleT, ms=msT)
        
    plt.plot( [ p[0] for p in P ],
              [ p[1] for p in P ], 
              styleP, lw=lwP, ms=msP)
    
    for p in P:
        if p in T:
            plt.plot( [ p[0] ], [ p[1] ], 
                      stylePT, ms=msPT)
    if w is not None:
        plt.plot( [ w[0] ], [ w[1] ], 
                      styleW, ms=msW)
    if text is not None:
        plt.text(xmax, ymin-0.7*yoffset, text, horizontalalignment='right', size=8)
    if grid:
        plt.grid()
    plt.show()

# %% [markdown]
# ## Add Targets

# %%
def addTargets(M, T):
    V, E = M
    E = E.copy()
    V = V.copy()
    for t in T:
        minD = math.inf
        minE = None
        for e in E:
            P, Q = e
            distT = dist(P, t)+dist(t, Q)-dist(P, Q)
            if distT < minD:
                minD = distT
                minE = e
        P, Q = minE
        E.remove( (P, Q) )
        E.append( (P, t) )
        E.append( (t, Q) )
        V.append(t)
    return V, E

# %% [markdown]
# ## Generate Central Warehouse Location

# %%
from statistics import median

def generateWarehouseLocation(M):
    V, _ = M
    xc = median([ x for (x, y) in V ])
    yc = median([ y for (x, y) in V ])
    cloc = (xc, yc)
    minloc = V[0]
    mindist = dist(minloc, cloc)
    for i in range(1, len(V)):
        d = dist(V[i], cloc)
        if d<mindist:
            minloc = V[i]
            mindist = dist(V[i], cloc)
    return minloc

# %% [markdown]
# ## Time Handling (NEW)

# %% [markdown]
# **Convention:** In this project we measure simulation time in seconds. The simulation will start at 0:00. Time related methods will be added as they are needed.

# %% [markdown]
# `timestamp(t)` generates a timestamp string in the form `[dd] hh:mm:ss.d`

# %%
def timestamp(t):
    t = round(t, 1)
    day = int(t)//(24*3600)
    t = t - day*24*3600
    hour = int(t)//3600
    t = t - hour*3600
    mins = int(t)//60
    t = t - mins*60
    secs = int(t)
    t = int(round((t-secs)*10,1)) 
    return f"[{day:2d}] {hour:02d}:{mins:02d}:{secs:02d}.{t:1d}"

# %%
timestamp(24*3600*3+17*3600+615.1)
# Out:
# '[ 3] 17:10:15.1'

# %%
timestamp(24*3600*12+3*3600+122.96)
# Out:
# '[12] 03:02:03.0'

# %%
def day(now):
    return int(now//(24*3600))

# %%
def nextHour(env, hour):
    beginningOfDay = int(env.now//(24*3600))*24*3600
    timeOfDay = env.now-beginningOfDay
    if hour*3600 > timeOfDay:
        return hour*3600 - timeOfDay
    else:
        return hour*3600 + 24*3600 - timeOfDay

# %% [markdown]
# # Finding Shortest Path (as before)

# %%
def pathLength(P):
    return 0 if len(P)<=1 else \
            dist(P[0], P[1])+pathLength(P[1:])

# %%
def shortestPath(M, A, B):

    def h(p): 
        return pathLength(p)+dist(p[-1],B)
    
    # candidates C are pairs of the path so far and 
    # the heuristic function of that path, 
    # sorted by the heuristic function, as maintained by
    # insert function
    def insert(C, p):
        hp = h(p)
        c = (p, hp)
        for i in range(len(C)):
            if C[i][1]>hp:
                return C[:i]+[c]+C[i:]
        return C+[c]   
        
    V, E = M
    assert(A in V and B in V)    
    C = insert([], [A])

    while len(C)>0:
        # take the first candidate out of the list of candidates
        path, _ = C[0]
        C = C[1:]
        if path[-1]==B:
            return path
        else:
            for (x, y) in E:
                if path[-1]==x and y not in path:
                    C = insert(C, path+[y])
                elif path[-1]==y and x not in path:
                    C = insert(C, path+[x])
    return None

# %% [markdown]
# # Finding Short Delivery Route (as before)

# %% [markdown]
# ## Greedy Algorithm

# %%
def FW(M):
    
    V, E = M

    n = len(V)
    d = [ [ math.inf for j in range(n) ] for i in range(n) ]
    p = [ [ None for j in range(n) ] for i in range(n) ]

    for (A, B) in E:
        a = V.index(A)
        b = V.index(B)
        d[a][b] = d[b][a] = dist(A, B)
        p[a][b] = [A, B]
        p[b][a] = [B, A]
    
    for i in range(n):
        d[i][i] = 0
        p[i][i] = [V[i]]
    
    for k in range(n):
        for i in range(n):
            for j in range(n):
                dk = d[i][k] + d[k][j]
                if d[i][j] > dk:
                    d[i][j] = dk
                    p[i][j] = p[i][k][:-1] + p[k][j]
                    
    return d, p

# %%
def createLoopG(M, T, timing=False):
    
    def makeLoop(L):
        loop = []
        for i in range(len(L)-1):
            A = L[i]
            B = L[i+1]
            a = V.index(A)
            b = V.index(B)
            sub = P[a][b]
            loop += sub if len(loop)==0 else sub[1:]
        return loop
        
    if timing:
        start_time = time.time()
        last_time = time.time()
        
    V, E = M
    D, P = FW(M)   # note these are the distances between all vertices in M (and T)
        
    W = T[0]
    customers = T[1:]
    if len(T)==1:
        L = T
    elif len(T)<=3:
        L = T + [T[0]]
    else:
        L = T[:3]+[T[0]]
        T = T[3:]
        while len(T)>0:
            minExt = math.inf
            minInd = None
            selInd = None
            for k in range(len(T)):
                C = T[k]
                c = V.index(C)
                for i in range(0, len(L)-1):
                    A = L[i]
                    B = L[i+1]
                    a = V.index(A)
                    b = V.index(B)
                    ext = D[a][c] + D[c][b] - D[a][b]
                    if ext<minExt:
                        minExt, minInd, selInd = ext, i+1, k
            L = L[:minInd]+[T[selInd]]+L[minInd:]
            T = T[:selInd]+T[selInd+1:]
            
    if timing:
        print(f"createLoopH:    {time.time()-start_time:6.2f}s")

    return makeLoop(L)

# %% [markdown]
# # Finding Optimal Delivery Route

# %% [markdown]
# ## Iterative Integer Programming

# %%
def createTables(M, T):

    def reverse(P):
        return [ P[-i] for i in range(1,len(P)+1) ]
    
    def index(x, L):
        for i in range(len(L)):
            if x==L[i]: 
                return i
        return None

    n = len(T)
    d = [ [ math.inf for t in T ] for t in T ]
    p = [ [ None for t in T ] for t in T ]
    for i in range(n):
        d[i][i] = 0
        p[i][i] = [ T[i] ]
    for i in range(n):
        for j in range(n):
            if p[i][j] is None:
                s = shortestPath(M, T[i], T[j])
                d[i][j] = d[j][i] = pathLength(s)
                p[i][j] = s
                p[j][i] = reverse(s)
                for m in range(len(s)-1):
                    smi = index(s[m], T)
                    if smi is None:
                        continue
                    for l in range(m+1, len(s)):
                        sli = index(s[l], T)
                        if sli is None:
                            continue  
                        sub = s[m:l+1]
                        if p[smi][sli] is None:
                            p[smi][sli] = sub
                            p[sli][smi] = reverse(sub)
                            d[smi][sli] = d[sli][smi] = pathLength(sub)
    return d,p

# %%
def roundtrips(x, n):
    
    def isElem(x, l):
        for i in range(len(l)):
            if l[i]==x:
                return True
        return False

    def startpoint(trips):
        for i in range(n):
            for t in trips:
                if isElem(i, t):
                    break
            else:
                return i
    
    def totalLength(trips):
        s=0
        for i in range(0, len(trips)):
            s += len(trips[i])-1
        return s

    trips = []
    while totalLength(trips)<n:
        start = startpoint(trips)
        trip = [ start ]
        i = start
        while len(trip) < n-totalLength(trips):
            for j in range(0, n):
                if pulp.value(x[i][j])==1:
                    trip.append(j)
                    i=j
                    break        
            if pulp.value(x[trip[-1]][start])==1:
                trip.append(start)
                break
        trips.append(trip)
    return sorted(trips, key=lambda t: len(t), reverse=True)

# %%
import time

def createLoop(M, T, timing=False):
    
    if timing:
        start_time = last_time = time.time()
        
    D, P = createTables(M, T)   # These are the distances between customers and warehouse only
    
    if timing:
        print(f"createTables:   {time.time()-start_time:6.2f}s")
        last_time = time.time()
        
    n = len(T)
    # create variables
    x = pulp.LpVariable.dicts("x", ( range(n), range(n) ),
                            lowBound=0, upBound=1, cat=pulp.LpInteger)
    # create problem
    prob = pulp.LpProblem("Loop",pulp.LpMinimize)
    # add objective function
    prob += pulp.lpSum([ D[i][j]*x[i][j] 
                             for i in range(n) for j in range(n) ])
    # add constraints
    constraints=0
    for j in range(n):
        prob += pulp.lpSum([ x[i][j] for i in range(n) if i!=j ]) ==1
    constraints += n
    for i in range(n):
        prob += pulp.lpSum([ x[i][j] for j in range(n) if i!=j ]) ==1
    constraints += n
    for i in range(n):
        for j in range(n):
            if i!=j:
                prob += x[i][j]+x[j][i] <= 1
                constraints += 1
                
    def cycles(k, n):
        if k==1:
            return [ [i] for i in range(0,n) ]
        else:
            sc=cycles(k-1, n)
            all=[]
            for c in sc:
                for i in range(0,n):
                    if c.count(i)==0:
                        all.append(c+[i])
            return all

    for k in range(3, 4):   
        cycs=cycles(k,n)
        for c in cycs:
            c.append(c[0])
            prob+=pulp.lpSum([ x[c[i]][c[i+1]] for i in range(0,k)]) <= k-1
            constraints += 1    
            
    # initialise solver
    solvers = pulp.listSolvers(onlyAvailable=True)
    solver = pulp.getSolver(solvers[0], msg=0, timeLimit=2)
    res = prob.solve(solver)

    if timing:
        print(f"Solver:         {time.time()-last_time:6.2f}s {constraints:6,d} Constraints")
        last_time = time.time()
        
    trips = roundtrips(x, n)
    while len(trips)>1:
        longest = max([ len(t) for t in trips ])
        for t in trips:
            if len(t)<longest:
                prob += pulp.lpSum([ x[t[i]][t[i+1]] + x[t[i+1]][t[i]]
                                        for i in range(0,len(t)-1) ]) <= len(t)-2
                constraints += 1
            else:
                longest = math.inf
                
        res = prob.solve(solver)
        
        if timing:
            print(f"Solver:         {time.time()-last_time:6.2f}s {constraints:6,d} Constraints")
            last_time = time.time()

        trips = roundtrips(x, n)
    trip = trips[0]
    # print(trip)
    loop = []
    for k in range(len(trip)-1):
        sub = P[trip[k]][trip[k+1]]
        loop += sub if len(loop)==0 else sub[1:]
        
    if timing:
        print(f"createLoop:     {time.time()-start_time:6.2f}s")

    return loop

# %% [markdown]
# # Class Recorder

# %% [markdown]
# We willl use a class Recorder as a reference point for capturing data during the simulation. There will be only one recorder. It will be created at the beginning of every simulation run. Every entity will carry a reference to the Recorder.

# %%
import time

class Recorder:
    
    def __init__(self, env, M, W, C, days, 
                 log=False, plot=False, timing=False):
        self.env = env
        self.M = M
        self.W = W
        self.C = C
        self.days = days
        self.log = log
        self.plot = plot

    def trace(self, event):
        if self.log:
            print(timestamp(self.env.now), event)

    def finish(self):
        # simulation is finished for good
        # by removing the simulation environment we can
        # pickle recorder
        self.env = None

# %% [markdown]
# # Class Customer

# %% [markdown]
# <img src='img/EventGraph Customer.png' width=500/>

# %%
class Customer:
    
    def __init__(self, rec, id, location):
        self.rec = rec
        self.id = id
        self.location = location
        self.atHome = True
        self.answersDoor = False
        self.parcelsReceived = []
        rec.env.process(self.process())
        
    def __str__(self):
        return f"Customer {self.id:d} at {str(self.location):s}"
    
    def leaveHouse(self):
        assert(self.atHome and not self.answersDoor)
        # self.rec.trace(str(self)+" leaves house")
        self.atHome = False
     
    def returnHome(self):
        assert(not self.atHome)
        # self.rec.trace(str(self)+" returns home")
        self.atHome = True
        
    def answerDoor(self):
        if self.atHome:
            yield self.rec.env.timeout(random.expovariate(1/AVERAGE_TIME_ANSWER_DOOR))
            self.rec.trace(str(self)+" answers door")
            self.answersDoor = True
        else:
            yield self.rec.env.timeout(WAIT_TIME_IF_CUSTOMER_DOESNT_ANSWER_DOOR)
            self.rec(str(self)+" not at home")
            
    def acceptParcel(self, parcel):
        assert(self.answersDoor)
        self.parcelsReceived += [parcel]
        self.rec.trace(str(self)+" accepts "+str(parcel))
        
    def signOff(self):
        assert(self.answersDoor)
        self.rec.trace(str(self)+" signs off")
        self.answersDoor = False
        
    def process(self):
        yield self.rec.env.timeout(nextHour(self.rec.env, 8))
        while day(self.rec.env.now)<self.rec.days:
            # in a refinement we may use random times
            self.leaveHouse()
            yield self.rec.env.timeout(nextHour(self.rec.env, 18))
            self.returnHome()
            yield self.rec.env.timeout(nextHour(self.rec.env, 8))

# %% [markdown]
# # Class Parcel

# %% [markdown]
# <img src='img/EventGraph Parcel.png' width=500/>

# %% [markdown]
# Parcels follow through a sequence of states:
# - processing
# - in transit (from manufacture to distribution centre)
# - arrived in distribution centre
# - ready for delivery
# - out for delivery
# - customer not present
# - returned to distribution centre
# - delivered

# %%
class Parcel:
    
    def __init__(self, rec, i, day, cust):
        self.rec = rec
        self.i = i  
        self.arrival = day
        self.cust = cust
        self.status = [  ] # status record and
        self.timing = [  ] # timing

    def __str__(self):
        return f"Parcel {self.i:d} for cust {self.cust.id:d}"

    def index(self):
        return self.i
    
    def destination(self):
        return self.cust.location
    
    def __reg(self, state):
        self.status += [ state ]
        self.timing += [ self.rec.env.now ]
        self.rec.trace(str(self)+" "+state)
        
    def arrivedAtDeliveryCentre(self):
        self.__reg('arr at delivery centre')
        
    def outForDelivery(self): 
        self.__reg('out for delivery')
        
    def returnFromDelivery(self):
        self.__reg('return from delivery')

# %% [markdown]
# # Class Driver

# %% [markdown]
# <img src='img/EventGraph Driver.png' width=500/>

# %%
class Driver:
    
    def __init__(self, rec, DC):
        self.rec = rec
        self.DC = DC
        self.location = None
        self.parcels = None
        self.tour = None
        self.rec.env.process(self.process())
        
    # activity
    def __drive(self, target):
        assert(self.tour[0] == self.location)
        while self.location!=target:
            d = dist(self.location, self.tour[1])
            yield self.rec.env.timeout(d / AVERAGE_SPEED)
            self.location = self.tour[1]
            self.tour = self.tour[1:]
        assert(self.tour[0] == self.location == target)
    
    def arriveForWork(self):
        self.location = self.DC.W
        self.parcels = []
        self.returns = []
        self.tour = [ self.DC.W ]
        self.rec.trace("Driver arrives for work")
        
    def leaveForDelivery(self, tour, parcels, addresses):
        self.tour, self.parcels = tour, parcels
        self.rec.trace(f"Driver leaves for delivery " 
                       f"of {len(parcels):d} parcels "
                       f"to {len(addresses):d} customers")
        self.rec.trace(f"Length of delivery tour: {pathLength(tour):,d}m")
        if self.rec.plot:
            plotMap(self.rec.M, T=addresses, P=tour, w=tour[0], 
                    text=f"Day {day(self.rec.env.now):d}:, {pathLength(tour):,d}m")
        
    def process(self):
        yield self.rec.env.timeout(nextHour(self.rec.env, 18))
        while day(self.rec.env.now)<self.rec.days:
            self.arriveForWork()
            tour, parcels, addresses = self.DC.sendForDelivery()
            if len(parcels)==0: 
                self.rec.trace("Nothing to do today")
            else:
                yield self.rec.env.timeout(PREP_TIME_PER_PARCEL*len(parcels))
                self.leaveForDelivery(tour, parcels, addresses)        
                while len(self.parcels)>0:
                    # drive to customer
                    custLocation = self.parcels[0].destination()
                    cust = self.parcels[0].cust
                    self.rec.trace("Driver drives to "+str(cust))
                    yield from self.__drive(custLocation)
                    self.rec.trace("Driver arrived at "+str(cust))
                    # call at customer
                    yield from cust.answerDoor()
                    
                    if cust.answersDoor:
                        while len(self.parcels)>0 and \
                                custLocation == self.parcels[0].destination():
                            cust.acceptParcel(self.parcels[0])
                            yield self.rec.env.timeout(random.expovariate(1/10))
                            self.parcels = self.parcels[1:]
                        cust.signOff()
                        yield self.rec.env.timeout(random.expovariate(1/10))
                    else:
                        while len(self.parcels)>0 and  \
                                custLocation == self.parcels[0].dest:
                            self.returns += self.parcels[0]
                            self.parcels = self.parcels[1:]

                # return to delivery centre
                self.rec.trace("Driver returns to delivery centre")
                yield from self.__drive(self.DC.W)
                self.rec.trace("Driver arrived at delivery centre")
            
                for parcel in self.returns:
                    self.DC.returnFromDelivery(parcel)
                    yield self.rec.env.timeout(RETURN_TIME_PER_PARCEL)

                leftOver = len(self.DC.parcels)+len(self.DC.leftOver)
                self.rec.trace(f"{leftOver:d} parcels left for next day")
            
            yield self.rec.env.timeout(600)
        
            self.rec.trace("Driver goes home")
            
            yield self.rec.env.timeout(nextHour(self.rec.env, 18))

# %% [markdown]
# # Class Delivery Centre

# %% [markdown]
# <img src="img/EventGraph Delivery Centre.png" width=300/>

# %%
class DeliveryCentre:
    
    def __init__(self, rec, M, W):
        self.rec = rec
        self.M = M
        self.W = W
        self.limit = 30000
        
        self.leftOver = []    # list of parcels
        self.parcels = []     # list of parcels scheduled for delivery
        self.dest = []        # list of unique customer destinations
        self.tour = [self.W]  # tour planned for delivery
    
    def __accept(self, parcel):
        custLoc = parcel.destination()
        if custLoc not in self.dest:
            MT = addTargets(self.M, self.dest + [custLoc])
            SH = createLoopG(MT, [self.W] + self.dest + [custLoc])
            if pathLength(SH)<self.limit:
                self.parcels.append(parcel)
                self.dest += [custLoc]
                self.tour = SH
            else: 
                self.leftOver.append(parcel)
        else:
            self.parcels.append(parcel)
        
    def acceptParcel(self, parcel):
        parcel.arrivedAtDeliveryCentre()
        self.__accept(parcel)
            
    def sendForDelivery(self):
        parcels = []
        tour = self.tour
        addresses = []
        
        # pick parcels in sequence to be delivered
        for i in range(1, len(tour)-1):
            dest = tour[i]
            for p in self.parcels:
                if p.destination() == dest and p not in parcels:
                    parcels += [p]
                    p.outForDelivery()
                    if dest not in addresses:
                        addresses += [dest]
         
        # arrange the left overs for next day
        L = self.leftOver
        self.tour = [self.W]
        self.parcels = []
        self.leftOver = []
        self.dest = []
        for p in L:
            self.__accept(p)

        return tour, parcels, addresses
                 
    def returnFromDelivery(self, parcel):
        parcel.returnFromDelivery()
        self.__accept(parcel)

    def getInventory(self):
        return len(self.parcels)+len(self.leftOver)

# %% [markdown]
# # Simulation

# %% [markdown]
# ## Parameters from Specification

# %% [markdown]
# The time required for driving is based on the distance between way points at an average speed of 15km/h.

# %%
AVERAGE_SPEED = 15/3.6

# %% [markdown]
# The **cumulative preparation time** (route planning and
# sorting of the parcels in the delivery order and
# packing the cargo-bike) is assumed to be 50 sec per
# parcel to be delivered.

# %%
PREP_TIME_PER_PARCEL = 50

# %% [markdown]
# **Additional assumption:** The time to **process returned parcels** in the delivery centre is 30 sec per parce.

# %%
RETURN_TIME_PER_PARCEL = 30

# %% [markdown]
# The average time to answer the door.

# %%
AVERAGE_TIME_ANSWER_DOOR = 40

# %%
WAIT_TIME_IF_CUSTOMER_DOESNT_ANSWER_DOOR = 60

# %% [markdown]
# ## Generate Input Data

# %%
def generateDeliveries(p, C, days, seed=0):
    ## p is the average number of parcels per day per customer
    ## C is the number of customers to be served
    ## days is the number of days for which data are to be generated.
    random.seed(seed)
    deliveries = [ [ ] for _ in range(days) ]
    for c in range(C):
        arr = 0
        while True:
            arr += random.expovariate(p)
            day = int(arr)
            if day>=days:
                break
            deliveries[day].append(c)
    return deliveries

# %% [markdown]
# ## Simulation Routine

# %%
def simulation(M, W, C, p=0.2, days=10, seed=0, 
               log=False, plot=False, timing=False):

    random.seed(seed)
    D = generateDeliveries(p, len(C), days, seed)
    
    env = simpy.Environment()
    rec = Recorder(env, M, W, C, days, 
                   log=log, plot=plot, timing=timing)

    print(f"Simulating delivery of {sum([len(d) for d in D]):d} parcels "
          f"over {len(D):d} days to {len(C):d} customers")

    CUSTOMERS = []
    for i in range(len(C)):
        CUSTOMERS.append(Customer(rec, i, C[i]))

    DC = DeliveryCentre(rec, M, W)
    Z = Driver(rec, DC)
    PARCELS = []

    def parcelGeneratorProcess(env, rec, D, C):
        for day in range(len(D)):
            yield env.timeout(nextHour(env, 17.00))
            for c in D[day]:
                cust = CUSTOMERS[c]
                parcel = Parcel(rec, len(PARCELS), day, cust)
                PARCELS.append(parcel)
                DC.acceptParcel(parcel)

    env.process(parcelGeneratorProcess(env, rec, D, C))
    env.run()

    rec.finish()

    if DC.getInventory()>0:
        print(f"Delivery Centre Inventory: {DC.getInventory():d} parcels")

    return rec

# %% [markdown]
# ## Model Verification

# %%
import pickle
with open('simpleData.pickled', 'rb') as f:
    M, C = pickle.load(f)

# %%
W = generateWarehouseLocation(M)

# %%
plotMap(M, T=C, w=W, scale=True)

# %%
rec1 = simulation(M, W, C, p=0.15, days=4, log=True)
# Out:
# Simulating delivery of 48 parcels over 4 days to 100 customers
# [ 0] 17:00:00.0 Parcel 0 for cust 19 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 1 for cust 27 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 2 for cust 30 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 3 for cust 40 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 4 for cust 54 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 5 for cust 72 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 6 for cust 77 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 7 for cust 79 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 8 for cust 80 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 9 for cust 84 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 10 for cust 89 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 11 for cust 89 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 12 for cust 92 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 13 for cust 96 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 14 for cust 96 arr at delivery centre
# [ 0] 18:00:00.0 Driver arrives for work
# [ 0] 18:00:00.0 Parcel 2 for cust 30 out for delivery
# [ 0] 18:00:00.0 Parcel 4 for cust 54 out for delivery
# [ 0] 18:00:00.0 Parcel 3 for cust 40 out for delivery
# [ 0] 18:00:00.0 Parcel 0 for cust 19 out for delivery
# [ 0] 18:00:00.0 Parcel 1 for cust 27 out for delivery
# [ 0] 18:00:00.0 Parcel 5 for cust 72 out for delivery
# [ 0] 18:00:00.0 Parcel 7 for cust 79 out for delivery
# [ 0] 18:05:50.0 Driver leaves for delivery of 7 parcels to 7 customers
# [ 0] 18:05:50.0 Length of delivery tour: 29,415m
# [ 0] 18:05:50.0 Driver drives to Customer 30 at (2380, 5128)
# [ 0] 18:12:35.1 Driver arrived at Customer 30 at (2380, 5128)
# [ 0] 18:14:15.4 Customer 30 at (2380, 5128) answers door
# [ 0] 18:14:15.4 Customer 30 at (2380, 5128) accepts Parcel 2 for cust 30
# [ 0] 18:14:17.3 Customer 30 at (2380, 5128) signs off
# [ 0] 18:14:28.4 Driver drives to Customer 54 at (4955, 6620)
# [ 0] 18:28:15.5 Driver arrived at Customer 54 at (4955, 6620)
# [ 0] 18:30:31.4 Customer 54 at (4955, 6620) answers door
# [ 0] 18:30:31.4 Customer 54 at (4955, 6620) accepts Parcel 4 for cust 54
# [ 0] 18:30:32.0 Customer 54 at (4955, 6620) signs off
# [ 0] 18:30:43.2 Driver drives to Customer 40 at (3440, 6776)
# [ 0] 18:37:24.3 Driver arrived at Customer 40 at (3440, 6776)
# [ 0] 18:38:39.0 Customer 40 at (3440, 6776) answers door
# [ 0] 18:38:39.0 Customer 40 at (3440, 6776) accepts Parcel 3 for cust 40
# [ 0] 18:38:43.2 Customer 40 at (3440, 6776) signs off
# [ 0] 18:38:46.0 Driver drives to Customer 19 at (2066, 7680)
# [ 0] 18:47:52.8 Driver arrived at Customer 19 at (2066, 7680)
# [ 0] 18:48:29.1 Customer 19 at (2066, 7680) answers door
# [ 0] 18:48:29.1 Customer 19 at (2066, 7680) accepts Parcel 0 for cust 19
# [ 0] 18:48:34.9 Customer 19 at (2066, 7680) signs off
# [ 0] 18:48:36.9 Driver drives to Customer 27 at (2380, 1401)
# [ 0] 19:18:28.2 Driver arrived at Customer 27 at (2380, 1401)
# [ 0] 19:18:53.7 Customer 27 at (2380, 1401) answers door
# [ 0] 19:18:53.7 Customer 27 at (2380, 1401) accepts Parcel 1 for cust 27
# [ 0] 19:18:59.0 Customer 27 at (2380, 1401) signs off
# [ 0] 19:19:07.4 Driver drives to Customer 72 at (5755, 1124)
# [ 0] 19:44:36.9 Driver arrived at Customer 72 at (5755, 1124)
# [ 0] 19:45:05.4 Customer 72 at (5755, 1124) answers door
# [ 0] 19:45:05.4 Customer 72 at (5755, 1124) accepts Parcel 5 for cust 72
# [ 0] 19:45:09.1 Customer 72 at (5755, 1124) signs off
# [ 0] 19:45:13.5 Driver drives to Customer 79 at (6105, 2925)
# [ 0] 19:53:39.0 Driver arrived at Customer 79 at (6105, 2925)
# [ 0] 19:54:51.7 Customer 79 at (6105, 2925) answers door
# [ 0] 19:54:51.7 Customer 79 at (6105, 2925) accepts Parcel 7 for cust 79
# [ 0] 19:54:54.6 Customer 79 at (6105, 2925) signs off
# [ 0] 19:55:02.8 Driver returns to delivery centre
# [ 0] 20:12:36.2 Driver arrived at delivery centre
# [ 0] 20:12:36.2 8 parcels left for next day
# [ 0] 20:22:36.2 Driver goes home
# [ 1] 17:00:00.0 Parcel 15 for cust 11 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 16 for cust 32 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 17 for cust 34 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 18 for cust 35 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 19 for cust 76 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 20 for cust 79 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 21 for cust 90 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 22 for cust 97 arr at delivery centre
# [ 1] 18:00:00.0 Driver arrives for work
# [ 1] 18:00:00.0 Parcel 6 for cust 77 out for delivery
# [ 1] 18:00:00.0 Parcel 9 for cust 84 out for delivery
# [ 1] 18:00:00.0 Parcel 10 for cust 89 out for delivery
# [ 1] 18:00:00.0 Parcel 11 for cust 89 out for delivery
# [ 1] 18:00:00.0 Parcel 20 for cust 79 out for delivery
# [ 1] 18:00:00.0 Parcel 12 for cust 92 out for delivery
# [ 1] 18:00:00.0 Parcel 13 for cust 96 out for delivery
# [ 1] 18:00:00.0 Parcel 14 for cust 96 out for delivery
# [ 1] 18:00:00.0 Parcel 22 for cust 97 out for delivery
# [ 1] 18:00:00.0 Parcel 19 for cust 76 out for delivery
# [ 1] 18:00:00.0 Parcel 8 for cust 80 out for delivery
# [ 1] 18:09:10.0 Driver leaves for delivery of 11 parcels to 9 customers
# [ 1] 18:09:10.0 Length of delivery tour: 29,784m
# [ 1] 18:09:10.0 Driver drives to Customer 77 at (6047, 7680)
# [ 1] 18:29:49.8 Driver arrived at Customer 77 at (6047, 7680)
# [ 1] 18:29:50.3 Customer 77 at (6047, 7680) answers door
# [ 1] 18:29:50.3 Customer 77 at (6047, 7680) accepts Parcel 6 for cust 77
# [ 1] 18:30:03.9 Customer 77 at (6047, 7680) signs off
# [ 1] 18:30:08.0 Driver drives to Customer 84 at (6312, 7680)
# [ 1] 18:31:11.6 Driver arrived at Customer 84 at (6312, 7680)
# [ 1] 18:31:13.4 Customer 84 at (6312, 7680) answers door
# [ 1] 18:31:13.4 Customer 84 at (6312, 7680) accepts Parcel 9 for cust 84
# [ 1] 18:31:16.7 Customer 84 at (6312, 7680) signs off
# [ 1] 18:31:19.5 Driver drives to Customer 89 at (6513, 7680)
# [ 1] 18:32:07.7 Driver arrived at Customer 89 at (6513, 7680)
# [ 1] 18:34:10.1 Customer 89 at (6513, 7680) answers door
# [ 1] 18:34:10.1 Customer 89 at (6513, 7680) accepts Parcel 10 for cust 89
# [ 1] 18:34:14.5 Customer 89 at (6513, 7680) accepts Parcel 11 for cust 89
# [ 1] 18:34:17.9 Customer 89 at (6513, 7680) signs off
# [ 1] 18:34:22.3 Driver drives to Customer 79 at (6105, 2925)
# [ 1] 19:14:27.4 Driver arrived at Customer 79 at (6105, 2925)
# [ 1] 19:16:24.8 Customer 79 at (6105, 2925) answers door
# [ 1] 19:16:24.8 Customer 79 at (6105, 2925) accepts Parcel 20 for cust 79
# [ 1] 19:16:34.8 Customer 79 at (6105, 2925) signs off
# [ 1] 19:16:44.5 Driver drives to Customer 92 at (7203, 3440)
# [ 1] 19:21:59.2 Driver arrived at Customer 92 at (7203, 3440)
# [ 1] 19:22:49.5 Customer 92 at (7203, 3440) answers door
# [ 1] 19:22:49.5 Customer 92 at (7203, 3440) accepts Parcel 12 for cust 92
# [ 1] 19:22:54.4 Customer 92 at (7203, 3440) signs off
# [ 1] 19:22:59.7 Driver drives to Customer 96 at (8352, 4112)
# [ 1] 19:28:42.2 Driver arrived at Customer 96 at (8352, 4112)
# [ 1] 19:29:24.3 Customer 96 at (8352, 4112) answers door
# [ 1] 19:29:24.3 Customer 96 at (8352, 4112) accepts Parcel 13 for cust 96
# [ 1] 19:29:24.3 Customer 96 at (8352, 4112) accepts Parcel 14 for cust 96
# [ 1] 19:29:26.5 Customer 96 at (8352, 4112) signs off
# [ 1] 19:29:30.5 Driver drives to Customer 97 at (8543, 4303)
# [ 1] 19:30:35.3 Driver arrived at Customer 97 at (8543, 4303)
# [ 1] 19:30:46.3 Customer 97 at (8543, 4303) answers door
# [ 1] 19:30:46.3 Customer 97 at (8543, 4303) accepts Parcel 22 for cust 97
# [ 1] 19:30:56.4 Customer 97 at (8543, 4303) signs off
# [ 1] 19:31:01.2 Driver drives to Customer 76 at (5981, 897)
# [ 1] 19:52:45.3 Driver arrived at Customer 76 at (5981, 897)
# [ 1] 19:54:08.7 Customer 76 at (5981, 897) answers door
# [ 1] 19:54:08.7 Customer 76 at (5981, 897) accepts Parcel 19 for cust 76
# [ 1] 19:54:17.0 Customer 76 at (5981, 897) signs off
# [ 1] 19:54:22.4 Driver drives to Customer 80 at (6128, 751)
# [ 1] 19:55:12.1 Driver arrived at Customer 80 at (6128, 751)
# [ 1] 19:55:32.7 Customer 80 at (6128, 751) answers door
# [ 1] 19:55:32.7 Customer 80 at (6128, 751) accepts Parcel 8 for cust 80
# [ 1] 19:55:44.8 Customer 80 at (6128, 751) signs off
# [ 1] 19:55:50.2 Driver returns to delivery centre
# [ 1] 20:17:45.9 Driver arrived at delivery centre
# [ 1] 20:17:45.9 5 parcels left for next day
# [ 1] 20:27:45.9 Driver goes home
# [ 2] 17:00:00.0 Parcel 23 for cust 5 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 24 for cust 9 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 25 for cust 15 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 26 for cust 25 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 27 for cust 38 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 28 for cust 50 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 29 for cust 62 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 30 for cust 77 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 31 for cust 78 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 32 for cust 90 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 33 for cust 93 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 34 for cust 94 arr at delivery centre
# [ 2] 18:00:00.0 Driver arrives for work
# [ 2] 18:00:00.0 Parcel 24 for cust 9 out for delivery
# [ 2] 18:00:00.0 Parcel 23 for cust 5 out for delivery
# [ 2] 18:00:00.0 Parcel 21 for cust 90 out for delivery
# [ 2] 18:00:00.0 Parcel 32 for cust 90 out for delivery
# [ 2] 18:00:00.0 Parcel 30 for cust 77 out for delivery
# [ 2] 18:00:00.0 Parcel 28 for cust 50 out for delivery
# [ 2] 18:00:00.0 Parcel 18 for cust 35 out for delivery
# [ 2] 18:00:00.0 Parcel 17 for cust 34 out for delivery
# [ 2] 18:00:00.0 Parcel 26 for cust 25 out for delivery
# [ 2] 18:00:00.0 Parcel 15 for cust 11 out for delivery
# [ 2] 18:00:00.0 Parcel 25 for cust 15 out for delivery
# [ 2] 18:00:00.0 Parcel 27 for cust 38 out for delivery
# [ 2] 18:00:00.0 Parcel 16 for cust 32 out for delivery
# [ 2] 18:10:50.0 Driver leaves for delivery of 13 parcels to 12 customers
# [ 2] 18:10:50.0 Length of delivery tour: 29,497m
# [ 2] 18:10:50.0 Driver drives to Customer 9 at (1650, 4500)
# [ 2] 18:17:59.6 Driver arrived at Customer 9 at (1650, 4500)
# [ 2] 18:18:43.0 Customer 9 at (1650, 4500) answers door
# [ 2] 18:18:43.0 Customer 9 at (1650, 4500) accepts Parcel 24 for cust 9
# [ 2] 18:18:43.5 Customer 9 at (1650, 4500) signs off
# [ 2] 18:18:49.4 Driver drives to Customer 5 at (1320, 5101)
# [ 2] 18:22:32.8 Driver arrived at Customer 5 at (1320, 5101)
# [ 2] 18:22:44.8 Customer 5 at (1320, 5101) answers door
# [ 2] 18:22:44.8 Customer 5 at (1320, 5101) accepts Parcel 23 for cust 5
# [ 2] 18:22:46.5 Customer 5 at (1320, 5101) signs off
# [ 2] 18:22:54.0 Driver drives to Customer 90 at (6542, 5560)
# [ 2] 18:47:56.9 Driver arrived at Customer 90 at (6542, 5560)
# [ 2] 18:48:23.6 Customer 90 at (6542, 5560) answers door
# [ 2] 18:48:23.6 Customer 90 at (6542, 5560) accepts Parcel 21 for cust 90
# [ 2] 18:48:31.9 Customer 90 at (6542, 5560) accepts Parcel 32 for cust 90
# [ 2] 18:48:46.0 Customer 90 at (6542, 5560) signs off
# [ 2] 18:49:07.5 Driver drives to Customer 77 at (6047, 7680)
# [ 2] 19:03:28.9 Driver arrived at Customer 77 at (6047, 7680)
# [ 2] 19:03:56.2 Customer 77 at (6047, 7680) answers door
# [ 2] 19:03:56.2 Customer 77 at (6047, 7680) accepts Parcel 30 for cust 77
# [ 2] 19:03:59.9 Customer 77 at (6047, 7680) signs off
# [ 2] 19:04:06.2 Driver drives to Customer 50 at (4500, 6283)
# [ 2] 19:15:52.7 Driver arrived at Customer 50 at (4500, 6283)
# [ 2] 19:16:59.0 Customer 50 at (4500, 6283) answers door
# [ 2] 19:16:59.0 Customer 50 at (4500, 6283) accepts Parcel 28 for cust 50
# [ 2] 19:17:19.8 Customer 50 at (4500, 6283) signs off
# [ 2] 19:17:36.5 Driver drives to Customer 35 at (3194, 7680)
# [ 2] 19:28:25.2 Driver arrived at Customer 35 at (3194, 7680)
# [ 2] 19:28:33.6 Customer 35 at (3194, 7680) answers door
# [ 2] 19:28:33.6 Customer 35 at (3194, 7680) accepts Parcel 18 for cust 35
# [ 2] 19:29:48.1 Customer 35 at (3194, 7680) signs off
# [ 2] 19:29:58.1 Driver drives to Customer 34 at (3097, 7680)
# [ 2] 19:30:21.4 Driver arrived at Customer 34 at (3097, 7680)
# [ 2] 19:30:24.9 Customer 34 at (3097, 7680) answers door
# [ 2] 19:30:24.9 Customer 34 at (3097, 7680) accepts Parcel 17 for cust 34
# [ 2] 19:30:37.8 Customer 34 at (3097, 7680) signs off
# [ 2] 19:31:21.1 Driver drives to Customer 25 at (2252, 7680)
# [ 2] 19:34:43.9 Driver arrived at Customer 25 at (2252, 7680)
# [ 2] 19:35:04.5 Customer 25 at (2252, 7680) answers door
# [ 2] 19:35:04.5 Customer 25 at (2252, 7680) accepts Parcel 26 for cust 25
# [ 2] 19:35:15.8 Customer 25 at (2252, 7680) signs off
# [ 2] 19:35:19.6 Driver drives to Customer 11 at (1664, 7680)
# [ 2] 19:37:40.7 Driver arrived at Customer 11 at (1664, 7680)
# [ 2] 19:37:50.3 Customer 11 at (1664, 7680) answers door
# [ 2] 19:37:50.3 Customer 11 at (1664, 7680) accepts Parcel 15 for cust 11
# [ 2] 19:38:03.0 Customer 11 at (1664, 7680) signs off
# [ 2] 19:38:03.0 Driver drives to Customer 15 at (1896, 5560)
# [ 2] 19:50:12.6 Driver arrived at Customer 15 at (1896, 5560)
# [ 2] 19:51:21.8 Customer 15 at (1896, 5560) answers door
# [ 2] 19:51:21.8 Customer 15 at (1896, 5560) accepts Parcel 25 for cust 15
# [ 2] 19:51:29.3 Customer 15 at (1896, 5560) signs off
# [ 2] 19:51:30.3 Driver drives to Customer 38 at (3440, 4276)
# [ 2] 20:02:49.1 Driver arrived at Customer 38 at (3440, 4276)
# [ 2] 20:02:54.1 Customer 38 at (3440, 4276) answers door
# [ 2] 20:02:54.1 Customer 38 at (3440, 4276) accepts Parcel 27 for cust 38
# [ 2] 20:03:04.6 Customer 38 at (3440, 4276) signs off
# [ 2] 20:03:25.3 Driver drives to Customer 32 at (2738, 2738)
# [ 2] 20:10:44.0 Driver arrived at Customer 32 at (2738, 2738)
# [ 2] 20:10:57.1 Customer 32 at (2738, 2738) answers door
# [ 2] 20:10:57.1 Customer 32 at (2738, 2738) accepts Parcel 16 for cust 32
# [ 2] 20:11:35.5 Customer 32 at (2738, 2738) signs off
# [ 2] 20:11:36.6 Driver returns to delivery centre
# [ 2] 20:19:49.1 Driver arrived at delivery centre
# [ 2] 20:19:49.1 4 parcels left for next day
# [ 2] 20:29:49.1 Driver goes home
# [ 3] 17:00:00.0 Parcel 35 for cust 2 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 36 for cust 4 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 37 for cust 28 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 38 for cust 37 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 39 for cust 48 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 40 for cust 49 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 41 for cust 50 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 42 for cust 61 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 43 for cust 68 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 44 for cust 87 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 45 for cust 90 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 46 for cust 92 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 47 for cust 93 arr at delivery centre
# [ 3] 18:00:00.0 Driver arrives for work
# [ 3] 18:00:00.0 Parcel 38 for cust 37 out for delivery
# [ 3] 18:00:00.0 Parcel 36 for cust 4 out for delivery
# [ 3] 18:00:00.0 Parcel 35 for cust 2 out for delivery
# [ 3] 18:00:00.0 Parcel 37 for cust 28 out for delivery
# [ 3] 18:00:00.0 Parcel 46 for cust 92 out for delivery
# [ 3] 18:00:00.0 Parcel 33 for cust 93 out for delivery
# [ 3] 18:00:00.0 Parcel 47 for cust 93 out for delivery
# [ 3] 18:00:00.0 Parcel 34 for cust 94 out for delivery
# [ 3] 18:00:00.0 Parcel 29 for cust 62 out for delivery
# [ 3] 18:00:00.0 Parcel 42 for cust 61 out for delivery
# [ 3] 18:00:00.0 Parcel 31 for cust 78 out for delivery
# [ 3] 18:09:10.0 Driver leaves for delivery of 11 parcels to 10 customers
# [ 3] 18:09:10.0 Length of delivery tour: 26,734m
# [ 3] 18:09:10.0 Driver drives to Customer 37 at (3440, 4175)
# [ 3] 18:10:28.0 Driver arrived at Customer 37 at (3440, 4175)
# [ 3] 18:11:44.9 Customer 37 at (3440, 4175) answers door
# [ 3] 18:11:44.9 Customer 37 at (3440, 4175) accepts Parcel 38 for cust 37
# [ 3] 18:11:50.0 Customer 37 at (3440, 4175) signs off
# [ 3] 18:11:50.9 Driver drives to Customer 4 at (1320, 4285)
# [ 3] 18:22:29.3 Driver arrived at Customer 4 at (1320, 4285)
# [ 3] 18:22:42.1 Customer 4 at (1320, 4285) answers door
# [ 3] 18:22:42.1 Customer 4 at (1320, 4285) accepts Parcel 36 for cust 4
# [ 3] 18:22:48.1 Customer 4 at (1320, 4285) signs off
# [ 3] 18:23:03.8 Driver drives to Customer 2 at (1320, 4082)
# [ 3] 18:23:52.6 Driver arrived at Customer 2 at (1320, 4082)
# [ 3] 18:25:11.6 Customer 2 at (1320, 4082) answers door
# [ 3] 18:25:11.6 Customer 2 at (1320, 4082) accepts Parcel 35 for cust 2
# [ 3] 18:25:13.0 Customer 2 at (1320, 4082) signs off
# [ 3] 18:25:20.4 Driver drives to Customer 28 at (2380, 1549)
# [ 3] 18:37:13.7 Driver arrived at Customer 28 at (2380, 1549)
# [ 3] 18:37:55.8 Customer 28 at (2380, 1549) answers door
# [ 3] 18:37:55.8 Customer 28 at (2380, 1549) accepts Parcel 37 for cust 28
# [ 3] 18:38:00.0 Customer 28 at (2380, 1549) signs off
# [ 3] 18:38:20.6 Driver drives to Customer 92 at (7203, 3440)
# [ 3] 19:06:13.6 Driver arrived at Customer 92 at (7203, 3440)
# [ 3] 19:06:26.7 Customer 92 at (7203, 3440) answers door
# [ 3] 19:06:26.7 Customer 92 at (7203, 3440) accepts Parcel 46 for cust 92
# [ 3] 19:06:26.8 Customer 92 at (7203, 3440) signs off
# [ 3] 19:06:27.3 Driver drives to Customer 93 at (7680, 2699)
# [ 3] 19:11:19.6 Driver arrived at Customer 93 at (7680, 2699)
# [ 3] 19:12:05.3 Customer 93 at (7680, 2699) answers door
# [ 3] 19:12:05.3 Customer 93 at (7680, 2699) accepts Parcel 33 for cust 93
# [ 3] 19:12:13.5 Customer 93 at (7680, 2699) accepts Parcel 47 for cust 93
# [ 3] 19:12:42.7 Customer 93 at (7680, 2699) signs off
# [ 3] 19:13:10.6 Driver drives to Customer 94 at (8016, 2380)
# [ 3] 19:15:47.8 Driver arrived at Customer 94 at (8016, 2380)
# [ 3] 19:17:24.1 Customer 94 at (8016, 2380) answers door
# [ 3] 19:17:24.1 Customer 94 at (8016, 2380) accepts Parcel 34 for cust 94
# [ 3] 19:17:24.5 Customer 94 at (8016, 2380) signs off
# [ 3] 19:17:38.3 Driver drives to Customer 62 at (5560, 1408)
# [ 3] 19:37:20.8 Driver arrived at Customer 62 at (5560, 1408)
# [ 3] 19:38:09.1 Customer 62 at (5560, 1408) answers door
# [ 3] 19:38:09.1 Customer 62 at (5560, 1408) accepts Parcel 29 for cust 62
# [ 3] 19:38:19.8 Customer 62 at (5560, 1408) signs off
# [ 3] 19:38:32.3 Driver drives to Customer 61 at (5363, 1123)
# [ 3] 19:40:00.1 Driver arrived at Customer 61 at (5363, 1123)
# [ 3] 19:41:33.3 Customer 61 at (5363, 1123) answers door
# [ 3] 19:41:33.3 Customer 61 at (5363, 1123) accepts Parcel 42 for cust 61
# [ 3] 19:41:43.5 Customer 61 at (5363, 1123) signs off
# [ 3] 19:41:48.2 Driver drives to Customer 78 at (6082, 795)
# [ 3] 19:45:52.5 Driver arrived at Customer 78 at (6082, 795)
# [ 3] 19:46:23.4 Customer 78 at (6082, 795) answers door
# [ 3] 19:46:23.4 Customer 78 at (6082, 795) accepts Parcel 31 for cust 78
# [ 3] 19:46:25.7 Customer 78 at (6082, 795) signs off
# [ 3] 19:46:34.6 Driver returns to delivery centre
# [ 3] 20:08:15.1 Driver arrived at delivery centre
# [ 3] 20:08:15.1 6 parcels left for next day
# [ 3] 20:18:15.1 Driver goes home
# Delivery Centre Inventory: 6 parcels

# %%
rec2 = simulation(M, W, C, p=0.3, days=4, log=True, plot=True)
# Out:
# Simulating delivery of 112 parcels over 4 days to 100 customers
# [ 0] 17:00:00.0 Parcel 0 for cust 15 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 1 for cust 24 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 2 for cust 25 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 3 for cust 30 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 4 for cust 38 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 5 for cust 54 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 6 for cust 56 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 7 for cust 57 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 8 for cust 59 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 9 for cust 59 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 10 for cust 60 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 11 for cust 62 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 12 for cust 65 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 13 for cust 65 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 14 for cust 66 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 15 for cust 68 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 16 for cust 70 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 17 for cust 71 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 18 for cust 74 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 19 for cust 76 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 20 for cust 82 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 21 for cust 89 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 22 for cust 89 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 23 for cust 94 arr at delivery centre
# [ 0] 18:00:00.0 Driver arrives for work
# [ 0] 18:00:00.0 Parcel 2 for cust 25 out for delivery
# [ 0] 18:00:00.0 Parcel 5 for cust 54 out for delivery
# [ 0] 18:00:00.0 Parcel 8 for cust 59 out for delivery
# [ 0] 18:00:00.0 Parcel 9 for cust 59 out for delivery
# [ 0] 18:00:00.0 Parcel 15 for cust 68 out for delivery
# [ 0] 18:00:00.0 Parcel 14 for cust 66 out for delivery
# [ 0] 18:00:00.0 Parcel 7 for cust 57 out for delivery
# [ 0] 18:00:00.0 Parcel 4 for cust 38 out for delivery
# [ 0] 18:00:00.0 Parcel 6 for cust 56 out for delivery
# [ 0] 18:00:00.0 Parcel 12 for cust 65 out for delivery
# [ 0] 18:00:00.0 Parcel 13 for cust 65 out for delivery
# [ 0] 18:00:00.0 Parcel 11 for cust 62 out for delivery
# [ 0] 18:00:00.0 Parcel 10 for cust 60 out for delivery
# [ 0] 18:00:00.0 Parcel 3 for cust 30 out for delivery
# [ 0] 18:00:00.0 Parcel 0 for cust 15 out for delivery
# [ 0] 18:00:00.0 Parcel 1 for cust 24 out for delivery
# [ 0] 18:13:20.0 Driver leaves for delivery of 16 parcels to 14 customers
# [ 0] 18:13:20.0 Length of delivery tour: 29,486m
# [ 0] 18:13:20.0 Driver drives to Customer 25 at (2252, 7680)
# [ 0] 18:36:48.1 Driver arrived at Customer 25 at (2252, 7680)
# [ 0] 18:38:11.3 Customer 25 at (2252, 7680) answers door
# [ 0] 18:38:11.3 Customer 25 at (2252, 7680) accepts Parcel 2 for cust 25
# [ 0] 18:38:28.0 Customer 25 at (2252, 7680) signs off
# [ 0] 18:38:30.1 Driver drives to Customer 54 at (4955, 6620)
# [ 0] 18:53:33.2 Driver arrived at Customer 54 at (4955, 6620)
# [ 0] 18:58:31.3 Customer 54 at (4955, 6620) answers door
# [ 0] 18:58:31.3 Customer 54 at (4955, 6620) accepts Parcel 5 for cust 54
# [ 0] 18:58:41.4 Customer 54 at (4955, 6620) signs off
# [ 0] 18:58:42.2 Driver drives to Customer 59 at (5249, 6620)
# [ 0] 18:59:52.8 Driver arrived at Customer 59 at (5249, 6620)
# [ 0] 19:00:44.5 Customer 59 at (5249, 6620) answers door
# [ 0] 19:00:44.5 Customer 59 at (5249, 6620) accepts Parcel 8 for cust 59
# [ 0] 19:01:27.8 Customer 59 at (5249, 6620) accepts Parcel 9 for cust 59
# [ 0] 19:01:32.9 Customer 59 at (5249, 6620) signs off
# [ 0] 19:01:44.3 Driver drives to Customer 68 at (5560, 6167)
# [ 0] 19:04:47.6 Driver arrived at Customer 68 at (5560, 6167)
# [ 0] 19:05:02.8 Customer 68 at (5560, 6167) answers door
# [ 0] 19:05:02.8 Customer 68 at (5560, 6167) accepts Parcel 15 for cust 68
# [ 0] 19:05:05.2 Customer 68 at (5560, 6167) signs off
# [ 0] 19:05:17.9 Driver drives to Customer 66 at (5560, 5684)
# [ 0] 19:07:13.8 Driver arrived at Customer 66 at (5560, 5684)
# [ 0] 19:07:13.9 Customer 66 at (5560, 5684) answers door
# [ 0] 19:07:13.9 Customer 66 at (5560, 5684) accepts Parcel 14 for cust 66
# [ 0] 19:07:31.2 Customer 66 at (5560, 5684) signs off
# [ 0] 19:07:38.7 Driver drives to Customer 57 at (5209, 5560)
# [ 0] 19:09:32.7 Driver arrived at Customer 57 at (5209, 5560)
# [ 0] 19:09:36.8 Customer 57 at (5209, 5560) answers door
# [ 0] 19:09:36.8 Customer 57 at (5209, 5560) accepts Parcel 7 for cust 57
# [ 0] 19:09:38.1 Customer 57 at (5209, 5560) signs off
# [ 0] 19:09:48.6 Driver drives to Customer 38 at (3440, 4276)
# [ 0] 19:19:32.2 Driver arrived at Customer 38 at (3440, 4276)
# [ 0] 19:20:55.0 Customer 38 at (3440, 4276) answers door
# [ 0] 19:20:55.0 Customer 38 at (3440, 4276) accepts Parcel 4 for cust 38
# [ 0] 19:20:58.3 Customer 38 at (3440, 4276) signs off
# [ 0] 19:21:36.7 Driver drives to Customer 56 at (5106, 2833)
# [ 0] 19:32:37.4 Driver arrived at Customer 56 at (5106, 2833)
# [ 0] 19:32:41.6 Customer 56 at (5106, 2833) answers door
# [ 0] 19:32:41.6 Customer 56 at (5106, 2833) accepts Parcel 6 for cust 56
# [ 0] 19:33:00.9 Customer 56 at (5106, 2833) signs off
# [ 0] 19:33:05.9 Driver drives to Customer 65 at (5560, 2199)
# [ 0] 19:36:23.2 Driver arrived at Customer 65 at (5560, 2199)
# [ 0] 19:36:26.6 Customer 65 at (5560, 2199) answers door
# [ 0] 19:36:26.6 Customer 65 at (5560, 2199) accepts Parcel 12 for cust 65
# [ 0] 19:36:29.8 Customer 65 at (5560, 2199) accepts Parcel 13 for cust 65
# [ 0] 19:36:35.8 Customer 65 at (5560, 2199) signs off
# [ 0] 19:36:51.6 Driver drives to Customer 62 at (5560, 1408)
# [ 0] 19:40:01.4 Driver arrived at Customer 62 at (5560, 1408)
# [ 0] 19:41:20.4 Customer 62 at (5560, 1408) answers door
# [ 0] 19:41:20.4 Customer 62 at (5560, 1408) accepts Parcel 11 for cust 62
# [ 0] 19:41:21.9 Customer 62 at (5560, 1408) signs off
# [ 0] 19:41:29.2 Driver drives to Customer 60 at (5273, 1033)
# [ 0] 19:43:27.5 Driver arrived at Customer 60 at (5273, 1033)
# [ 0] 19:44:09.6 Customer 60 at (5273, 1033) answers door
# [ 0] 19:44:09.6 Customer 60 at (5273, 1033) accepts Parcel 10 for cust 60
# [ 0] 19:44:13.9 Customer 60 at (5273, 1033) signs off
# [ 0] 19:44:34.4 Driver drives to Customer 30 at (2380, 5128)
# [ 0] 20:11:39.5 Driver arrived at Customer 30 at (2380, 5128)
# [ 0] 20:11:52.5 Customer 30 at (2380, 5128) answers door
# [ 0] 20:11:52.5 Customer 30 at (2380, 5128) accepts Parcel 3 for cust 30
# [ 0] 20:11:52.7 Customer 30 at (2380, 5128) signs off
# [ 0] 20:11:53.1 Driver drives to Customer 15 at (1896, 5560)
# [ 0] 20:15:33.0 Driver arrived at Customer 15 at (1896, 5560)
# [ 0] 20:16:18.7 Customer 15 at (1896, 5560) answers door
# [ 0] 20:16:18.7 Customer 15 at (1896, 5560) accepts Parcel 0 for cust 15
# [ 0] 20:16:26.8 Customer 15 at (1896, 5560) signs off
# [ 0] 20:16:56.1 Driver drives to Customer 24 at (2251, 4500)
# [ 0] 20:23:37.6 Driver arrived at Customer 24 at (2251, 4500)
# [ 0] 20:25:29.2 Customer 24 at (2251, 4500) answers door
# [ 0] 20:25:29.2 Customer 24 at (2251, 4500) accepts Parcel 1 for cust 24
# [ 0] 20:25:53.2 Customer 24 at (2251, 4500) signs off
# [ 0] 20:25:53.6 Driver returns to delivery centre
# [ 0] 20:30:39.0 Driver arrived at delivery centre
# [ 0] 20:30:39.0 8 parcels left for next day
# [ 0] 20:40:39.0 Driver goes home
# [ 1] 17:00:00.0 Parcel 24 for cust 2 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 25 for cust 3 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 26 for cust 4 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 27 for cust 12 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 28 for cust 19 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 29 for cust 21 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 30 for cust 28 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 31 for cust 34 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 32 for cust 35 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 33 for cust 36 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 34 for cust 36 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 35 for cust 46 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 36 for cust 57 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 37 for cust 58 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 38 for cust 64 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 39 for cust 66 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 40 for cust 66 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 41 for cust 68 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 42 for cust 77 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 43 for cust 78 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 44 for cust 79 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 45 for cust 83 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 46 for cust 83 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 47 for cust 84 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 48 for cust 88 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 49 for cust 90 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 50 for cust 92 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 51 for cust 93 arr at delivery centre
# [ 1] 18:00:00.0 Driver arrives for work
# [ 1] 18:00:00.0 Parcel 44 for cust 79 out for delivery
# [ 1] 18:00:00.0 Parcel 20 for cust 82 out for delivery
# [ 1] 18:00:00.0 Parcel 45 for cust 83 out for delivery
# [ 1] 18:00:00.0 Parcel 46 for cust 83 out for delivery
# [ 1] 18:00:00.0 Parcel 48 for cust 88 out for delivery
# [ 1] 18:00:00.0 Parcel 50 for cust 92 out for delivery
# [ 1] 18:00:00.0 Parcel 51 for cust 93 out for delivery
# [ 1] 18:00:00.0 Parcel 23 for cust 94 out for delivery
# [ 1] 18:00:00.0 Parcel 38 for cust 64 out for delivery
# [ 1] 18:00:00.0 Parcel 19 for cust 76 out for delivery
# [ 1] 18:00:00.0 Parcel 36 for cust 57 out for delivery
# [ 1] 18:00:00.0 Parcel 39 for cust 66 out for delivery
# [ 1] 18:00:00.0 Parcel 40 for cust 66 out for delivery
# [ 1] 18:00:00.0 Parcel 41 for cust 68 out for delivery
# [ 1] 18:00:00.0 Parcel 16 for cust 70 out for delivery
# [ 1] 18:00:00.0 Parcel 17 for cust 71 out for delivery
# [ 1] 18:00:00.0 Parcel 18 for cust 74 out for delivery
# [ 1] 18:00:00.0 Parcel 42 for cust 77 out for delivery
# [ 1] 18:00:00.0 Parcel 47 for cust 84 out for delivery
# [ 1] 18:00:00.0 Parcel 21 for cust 89 out for delivery
# [ 1] 18:00:00.0 Parcel 22 for cust 89 out for delivery
# [ 1] 18:17:30.0 Driver leaves for delivery of 21 parcels to 18 customers
# [ 1] 18:17:30.0 Length of delivery tour: 29,718m
# [ 1] 18:17:30.0 Driver drives to Customer 79 at (6105, 2925)
# [ 1] 18:35:03.4 Driver arrived at Customer 79 at (6105, 2925)
# [ 1] 18:35:58.7 Customer 79 at (6105, 2925) answers door
# [ 1] 18:35:58.7 Customer 79 at (6105, 2925) accepts Parcel 44 for cust 79
# [ 1] 18:36:10.8 Customer 79 at (6105, 2925) signs off
# [ 1] 18:36:21.4 Driver drives to Customer 82 at (6207, 3027)
# [ 1] 18:36:56.0 Driver arrived at Customer 82 at (6207, 3027)
# [ 1] 18:37:45.8 Customer 82 at (6207, 3027) answers door
# [ 1] 18:37:45.8 Customer 82 at (6207, 3027) accepts Parcel 20 for cust 82
# [ 1] 18:38:09.1 Customer 82 at (6207, 3027) signs off
# [ 1] 18:38:19.3 Driver drives to Customer 83 at (6267, 3087)
# [ 1] 18:38:39.5 Driver arrived at Customer 83 at (6267, 3087)
# [ 1] 18:38:58.1 Customer 83 at (6267, 3087) answers door
# [ 1] 18:38:58.1 Customer 83 at (6267, 3087) accepts Parcel 45 for cust 83
# [ 1] 18:39:05.9 Customer 83 at (6267, 3087) accepts Parcel 46 for cust 83
# [ 1] 18:39:08.2 Customer 83 at (6267, 3087) signs off
# [ 1] 18:39:17.0 Driver drives to Customer 88 at (6439, 3259)
# [ 1] 18:40:15.3 Driver arrived at Customer 88 at (6439, 3259)
# [ 1] 18:40:15.7 Customer 88 at (6439, 3259) answers door
# [ 1] 18:40:15.7 Customer 88 at (6439, 3259) accepts Parcel 48 for cust 88
# [ 1] 18:40:17.3 Customer 88 at (6439, 3259) signs off
# [ 1] 18:40:21.4 Driver drives to Customer 92 at (7203, 3440)
# [ 1] 18:43:42.5 Driver arrived at Customer 92 at (7203, 3440)
# [ 1] 18:44:44.9 Customer 92 at (7203, 3440) answers door
# [ 1] 18:44:44.9 Customer 92 at (7203, 3440) accepts Parcel 50 for cust 92
# [ 1] 18:44:57.5 Customer 92 at (7203, 3440) signs off
# [ 1] 18:45:01.7 Driver drives to Customer 93 at (7680, 2699)
# [ 1] 18:49:54.0 Driver arrived at Customer 93 at (7680, 2699)
# [ 1] 18:50:32.8 Customer 93 at (7680, 2699) answers door
# [ 1] 18:50:32.8 Customer 93 at (7680, 2699) accepts Parcel 51 for cust 93
# [ 1] 18:50:33.2 Customer 93 at (7680, 2699) signs off
# [ 1] 18:50:35.0 Driver drives to Customer 94 at (8016, 2380)
# [ 1] 18:53:12.2 Driver arrived at Customer 94 at (8016, 2380)
# [ 1] 18:55:52.7 Customer 94 at (8016, 2380) answers door
# [ 1] 18:55:52.7 Customer 94 at (8016, 2380) accepts Parcel 23 for cust 94
# [ 1] 18:55:56.1 Customer 94 at (8016, 2380) signs off
# [ 1] 18:56:01.1 Driver drives to Customer 64 at (5560, 1912)
# [ 1] 19:13:41.9 Driver arrived at Customer 64 at (5560, 1912)
# [ 1] 19:14:13.7 Customer 64 at (5560, 1912) answers door
# [ 1] 19:14:13.7 Customer 64 at (5560, 1912) accepts Parcel 38 for cust 64
# [ 1] 19:14:17.2 Customer 64 at (5560, 1912) signs off
# [ 1] 19:14:23.7 Driver drives to Customer 76 at (5981, 897)
# [ 1] 19:19:08.8 Driver arrived at Customer 76 at (5981, 897)
# [ 1] 19:19:19.8 Customer 76 at (5981, 897) answers door
# [ 1] 19:19:19.8 Customer 76 at (5981, 897) accepts Parcel 19 for cust 76
# [ 1] 19:19:20.3 Customer 76 at (5981, 897) signs off
# [ 1] 19:19:22.2 Driver drives to Customer 57 at (5209, 5560)
# [ 1] 19:49:18.2 Driver arrived at Customer 57 at (5209, 5560)
# [ 1] 19:49:47.8 Customer 57 at (5209, 5560) answers door
# [ 1] 19:49:47.8 Customer 57 at (5209, 5560) accepts Parcel 36 for cust 57
# [ 1] 19:49:48.5 Customer 57 at (5209, 5560) signs off
# [ 1] 19:49:53.7 Driver drives to Customer 66 at (5560, 5684)
# [ 1] 19:51:47.7 Driver arrived at Customer 66 at (5560, 5684)
# [ 1] 19:52:03.6 Customer 66 at (5560, 5684) answers door
# [ 1] 19:52:03.6 Customer 66 at (5560, 5684) accepts Parcel 39 for cust 66
# [ 1] 19:52:09.0 Customer 66 at (5560, 5684) accepts Parcel 40 for cust 66
# [ 1] 19:52:10.0 Customer 66 at (5560, 5684) signs off
# [ 1] 19:52:33.9 Driver drives to Customer 68 at (5560, 6167)
# [ 1] 19:54:29.9 Driver arrived at Customer 68 at (5560, 6167)
# [ 1] 19:54:55.6 Customer 68 at (5560, 6167) answers door
# [ 1] 19:54:55.6 Customer 68 at (5560, 6167) accepts Parcel 41 for cust 68
# [ 1] 19:55:13.9 Customer 68 at (5560, 6167) signs off
# [ 1] 19:55:51.3 Driver drives to Customer 70 at (5560, 7234)
# [ 1] 20:00:07.4 Driver arrived at Customer 70 at (5560, 7234)
# [ 1] 20:00:24.3 Customer 70 at (5560, 7234) answers door
# [ 1] 20:00:24.3 Customer 70 at (5560, 7234) accepts Parcel 16 for cust 70
# [ 1] 20:00:30.8 Customer 70 at (5560, 7234) signs off
# [ 1] 20:00:42.8 Driver drives to Customer 71 at (5722, 7680)
# [ 1] 20:03:08.7 Driver arrived at Customer 71 at (5722, 7680)
# [ 1] 20:03:31.0 Customer 71 at (5722, 7680) answers door
# [ 1] 20:03:31.0 Customer 71 at (5722, 7680) accepts Parcel 17 for cust 71
# [ 1] 20:03:34.6 Customer 71 at (5722, 7680) signs off
# [ 1] 20:03:47.8 Driver drives to Customer 74 at (5847, 7680)
# [ 1] 20:04:17.8 Driver arrived at Customer 74 at (5847, 7680)
# [ 1] 20:05:47.8 Customer 74 at (5847, 7680) answers door
# [ 1] 20:05:47.8 Customer 74 at (5847, 7680) accepts Parcel 18 for cust 74
# [ 1] 20:06:13.0 Customer 74 at (5847, 7680) signs off
# [ 1] 20:06:22.8 Driver drives to Customer 77 at (6047, 7680)
# [ 1] 20:07:10.8 Driver arrived at Customer 77 at (6047, 7680)
# [ 1] 20:07:29.7 Customer 77 at (6047, 7680) answers door
# [ 1] 20:07:29.7 Customer 77 at (6047, 7680) accepts Parcel 42 for cust 77
# [ 1] 20:08:06.4 Customer 77 at (6047, 7680) signs off
# [ 1] 20:08:16.6 Driver drives to Customer 84 at (6312, 7680)
# [ 1] 20:09:20.2 Driver arrived at Customer 84 at (6312, 7680)
# [ 1] 20:09:22.9 Customer 84 at (6312, 7680) answers door
# [ 1] 20:09:22.9 Customer 84 at (6312, 7680) accepts Parcel 47 for cust 84
# [ 1] 20:09:23.8 Customer 84 at (6312, 7680) signs off
# [ 1] 20:09:37.6 Driver drives to Customer 89 at (6513, 7680)
# [ 1] 20:10:25.9 Driver arrived at Customer 89 at (6513, 7680)
# [ 1] 20:10:28.4 Customer 89 at (6513, 7680) answers door
# [ 1] 20:10:28.4 Customer 89 at (6513, 7680) accepts Parcel 21 for cust 89
# [ 1] 20:10:28.5 Customer 89 at (6513, 7680) accepts Parcel 22 for cust 89
# [ 1] 20:10:33.5 Customer 89 at (6513, 7680) signs off
# [ 1] 20:10:40.8 Driver returns to delivery centre
# [ 1] 20:33:12.5 Driver arrived at delivery centre
# [ 1] 20:33:12.5 15 parcels left for next day
# [ 1] 20:43:12.5 Driver goes home
# [ 2] 17:00:00.0 Parcel 52 for cust 2 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 53 for cust 6 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 54 for cust 15 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 55 for cust 18 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 56 for cust 20 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 57 for cust 20 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 58 for cust 24 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 59 for cust 28 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 60 for cust 31 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 61 for cust 32 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 62 for cust 36 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 63 for cust 44 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 64 for cust 49 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 65 for cust 50 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 66 for cust 60 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 67 for cust 61 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 68 for cust 63 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 69 for cust 68 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 70 for cust 70 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 71 for cust 71 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 72 for cust 77 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 73 for cust 78 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 74 for cust 80 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 75 for cust 83 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 76 for cust 84 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 77 for cust 89 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 78 for cust 89 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 79 for cust 91 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 80 for cust 94 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 81 for cust 95 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 82 for cust 98 arr at delivery centre
# [ 2] 18:00:00.0 Driver arrives for work
# [ 2] 18:00:00.0 Parcel 63 for cust 44 out for delivery
# [ 2] 18:00:00.0 Parcel 64 for cust 49 out for delivery
# [ 2] 18:00:00.0 Parcel 65 for cust 50 out for delivery
# [ 2] 18:00:00.0 Parcel 35 for cust 46 out for delivery
# [ 2] 18:00:00.0 Parcel 33 for cust 36 out for delivery
# [ 2] 18:00:00.0 Parcel 34 for cust 36 out for delivery
# [ 2] 18:00:00.0 Parcel 62 for cust 36 out for delivery
# [ 2] 18:00:00.0 Parcel 32 for cust 35 out for delivery
# [ 2] 18:00:00.0 Parcel 31 for cust 34 out for delivery
# [ 2] 18:00:00.0 Parcel 28 for cust 19 out for delivery
# [ 2] 18:00:00.0 Parcel 54 for cust 15 out for delivery
# [ 2] 18:00:00.0 Parcel 26 for cust 4 out for delivery
# [ 2] 18:00:00.0 Parcel 25 for cust 3 out for delivery
# [ 2] 18:00:00.0 Parcel 24 for cust 2 out for delivery
# [ 2] 18:00:00.0 Parcel 52 for cust 2 out for delivery
# [ 2] 18:00:00.0 Parcel 29 for cust 21 out for delivery
# [ 2] 18:00:00.0 Parcel 30 for cust 28 out for delivery
# [ 2] 18:00:00.0 Parcel 59 for cust 28 out for delivery
# [ 2] 18:00:00.0 Parcel 56 for cust 20 out for delivery
# [ 2] 18:00:00.0 Parcel 57 for cust 20 out for delivery
# [ 2] 18:00:00.0 Parcel 27 for cust 12 out for delivery
# [ 2] 18:00:00.0 Parcel 61 for cust 32 out for delivery
# [ 2] 18:00:00.0 Parcel 68 for cust 63 out for delivery
# [ 2] 18:00:00.0 Parcel 43 for cust 78 out for delivery
# [ 2] 18:00:00.0 Parcel 73 for cust 78 out for delivery
# [ 2] 18:00:00.0 Parcel 67 for cust 61 out for delivery
# [ 2] 18:00:00.0 Parcel 66 for cust 60 out for delivery
# [ 2] 18:00:00.0 Parcel 37 for cust 58 out for delivery
# [ 2] 18:23:20.0 Driver leaves for delivery of 28 parcels to 22 customers
# [ 2] 18:23:20.0 Length of delivery tour: 29,884m
# [ 2] 18:23:20.0 Driver drives to Customer 44 at (3855, 4915)
# [ 2] 18:25:40.6 Driver arrived at Customer 44 at (3855, 4915)
# [ 2] 18:26:04.4 Customer 44 at (3855, 4915) answers door
# [ 2] 18:26:04.4 Customer 44 at (3855, 4915) accepts Parcel 63 for cust 44
# [ 2] 18:26:11.2 Customer 44 at (3855, 4915) signs off
# [ 2] 18:26:19.9 Driver drives to Customer 49 at (4500, 6156)
# [ 2] 18:32:21.9 Driver arrived at Customer 49 at (4500, 6156)
# [ 2] 18:33:07.4 Customer 49 at (4500, 6156) answers door
# [ 2] 18:33:07.4 Customer 49 at (4500, 6156) accepts Parcel 64 for cust 49
# [ 2] 18:33:12.9 Customer 49 at (4500, 6156) signs off
# [ 2] 18:33:17.5 Driver drives to Customer 50 at (4500, 6283)
# [ 2] 18:33:47.9 Driver arrived at Customer 50 at (4500, 6283)
# [ 2] 18:36:46.4 Customer 50 at (4500, 6283) answers door
# [ 2] 18:36:46.4 Customer 50 at (4500, 6283) accepts Parcel 65 for cust 50
# [ 2] 18:36:49.4 Customer 50 at (4500, 6283) signs off
# [ 2] 18:37:04.4 Driver drives to Customer 46 at (3984, 6620)
# [ 2] 18:40:29.2 Driver arrived at Customer 46 at (3984, 6620)
# [ 2] 18:40:51.7 Customer 46 at (3984, 6620) answers door
# [ 2] 18:40:51.7 Customer 46 at (3984, 6620) accepts Parcel 35 for cust 46
# [ 2] 18:40:56.2 Customer 46 at (3984, 6620) signs off
# [ 2] 18:40:56.8 Driver drives to Customer 36 at (3313, 7680)
# [ 2] 18:47:52.3 Driver arrived at Customer 36 at (3313, 7680)
# [ 2] 18:49:11.9 Customer 36 at (3313, 7680) answers door
# [ 2] 18:49:11.9 Customer 36 at (3313, 7680) accepts Parcel 33 for cust 36
# [ 2] 18:49:24.1 Customer 36 at (3313, 7680) accepts Parcel 34 for cust 36
# [ 2] 18:49:47.4 Customer 36 at (3313, 7680) accepts Parcel 62 for cust 36
# [ 2] 18:49:53.4 Customer 36 at (3313, 7680) signs off
# [ 2] 18:50:04.7 Driver drives to Customer 35 at (3194, 7680)
# [ 2] 18:50:33.3 Driver arrived at Customer 35 at (3194, 7680)
# [ 2] 18:50:38.3 Customer 35 at (3194, 7680) answers door
# [ 2] 18:50:38.3 Customer 35 at (3194, 7680) accepts Parcel 32 for cust 35
# [ 2] 18:50:43.4 Customer 35 at (3194, 7680) signs off
# [ 2] 18:50:45.7 Driver drives to Customer 34 at (3097, 7680)
# [ 2] 18:51:09.0 Driver arrived at Customer 34 at (3097, 7680)
# [ 2] 18:51:10.7 Customer 34 at (3097, 7680) answers door
# [ 2] 18:51:10.7 Customer 34 at (3097, 7680) accepts Parcel 31 for cust 34
# [ 2] 18:51:40.3 Customer 34 at (3097, 7680) signs off
# [ 2] 18:51:42.7 Driver drives to Customer 19 at (2066, 7680)
# [ 2] 18:57:33.8 Driver arrived at Customer 19 at (2066, 7680)
# [ 2] 18:57:40.2 Customer 19 at (2066, 7680) answers door
# [ 2] 18:57:40.2 Customer 19 at (2066, 7680) accepts Parcel 28 for cust 19
# [ 2] 18:57:42.4 Customer 19 at (2066, 7680) signs off
# [ 2] 18:57:47.1 Driver drives to Customer 15 at (1896, 5560)
# [ 2] 19:11:33.2 Driver arrived at Customer 15 at (1896, 5560)
# [ 2] 19:12:04.8 Customer 15 at (1896, 5560) answers door
# [ 2] 19:12:04.8 Customer 15 at (1896, 5560) accepts Parcel 54 for cust 15
# [ 2] 19:12:06.4 Customer 15 at (1896, 5560) signs off
# [ 2] 19:12:51.3 Driver drives to Customer 4 at (1320, 4285)
# [ 2] 19:20:15.5 Driver arrived at Customer 4 at (1320, 4285)
# [ 2] 19:22:58.5 Customer 4 at (1320, 4285) answers door
# [ 2] 19:22:58.5 Customer 4 at (1320, 4285) accepts Parcel 26 for cust 4
# [ 2] 19:23:00.1 Customer 4 at (1320, 4285) signs off
# [ 2] 19:23:05.3 Driver drives to Customer 3 at (1320, 4193)
# [ 2] 19:23:27.4 Driver arrived at Customer 3 at (1320, 4193)
# [ 2] 19:24:12.9 Customer 3 at (1320, 4193) answers door
# [ 2] 19:24:12.9 Customer 3 at (1320, 4193) accepts Parcel 25 for cust 3
# [ 2] 19:24:33.9 Customer 3 at (1320, 4193) signs off
# [ 2] 19:24:40.8 Driver drives to Customer 2 at (1320, 4082)
# [ 2] 19:25:07.4 Driver arrived at Customer 2 at (1320, 4082)
# [ 2] 19:26:47.0 Customer 2 at (1320, 4082) answers door
# [ 2] 19:26:47.0 Customer 2 at (1320, 4082) accepts Parcel 24 for cust 2
# [ 2] 19:26:50.9 Customer 2 at (1320, 4082) accepts Parcel 52 for cust 2
# [ 2] 19:26:57.8 Customer 2 at (1320, 4082) signs off
# [ 2] 19:27:04.7 Driver drives to Customer 21 at (2100, 2659)
# [ 2] 19:34:56.8 Driver arrived at Customer 21 at (2100, 2659)
# [ 2] 19:35:41.1 Customer 21 at (2100, 2659) answers door
# [ 2] 19:35:41.1 Customer 21 at (2100, 2659) accepts Parcel 29 for cust 21
# [ 2] 19:35:43.4 Customer 21 at (2100, 2659) signs off
# [ 2] 19:35:52.8 Driver drives to Customer 28 at (2380, 1549)
# [ 2] 19:40:47.0 Driver arrived at Customer 28 at (2380, 1549)
# [ 2] 19:40:56.9 Customer 28 at (2380, 1549) answers door
# [ 2] 19:40:56.9 Customer 28 at (2380, 1549) accepts Parcel 30 for cust 28
# [ 2] 19:41:01.1 Customer 28 at (2380, 1549) accepts Parcel 59 for cust 28
# [ 2] 19:41:33.9 Customer 28 at (2380, 1549) signs off
# [ 2] 19:41:56.8 Driver drives to Customer 20 at (2080, 1320)
# [ 2] 19:44:03.8 Driver arrived at Customer 20 at (2080, 1320)
# [ 2] 19:45:12.0 Customer 20 at (2080, 1320) answers door
# [ 2] 19:45:12.0 Customer 20 at (2080, 1320) accepts Parcel 56 for cust 20
# [ 2] 19:45:12.3 Customer 20 at (2080, 1320) accepts Parcel 57 for cust 20
# [ 2] 19:45:14.0 Customer 20 at (2080, 1320) signs off
# [ 2] 19:45:16.9 Driver drives to Customer 12 at (1791, 1320)
# [ 2] 19:46:26.3 Driver arrived at Customer 12 at (1791, 1320)
# [ 2] 19:47:27.6 Customer 12 at (1791, 1320) answers door
# [ 2] 19:47:27.6 Customer 12 at (1791, 1320) accepts Parcel 27 for cust 12
# [ 2] 19:47:46.1 Customer 12 at (1791, 1320) signs off
# [ 2] 19:47:54.8 Driver drives to Customer 32 at (2738, 2738)
# [ 2] 19:56:32.0 Driver arrived at Customer 32 at (2738, 2738)
# [ 2] 19:57:22.7 Customer 32 at (2738, 2738) answers door
# [ 2] 19:57:22.7 Customer 32 at (2738, 2738) accepts Parcel 61 for cust 32
# [ 2] 19:57:39.1 Customer 32 at (2738, 2738) signs off
# [ 2] 19:57:39.8 Driver drives to Customer 63 at (5560, 1564)
# [ 2] 20:15:07.9 Driver arrived at Customer 63 at (5560, 1564)
# [ 2] 20:15:11.4 Customer 63 at (5560, 1564) answers door
# [ 2] 20:15:11.4 Customer 63 at (5560, 1564) accepts Parcel 68 for cust 63
# [ 2] 20:15:31.8 Customer 63 at (5560, 1564) signs off
# [ 2] 20:15:32.2 Driver drives to Customer 78 at (6082, 795)
# [ 2] 20:19:28.3 Driver arrived at Customer 78 at (6082, 795)
# [ 2] 20:19:38.5 Customer 78 at (6082, 795) answers door
# [ 2] 20:19:38.5 Customer 78 at (6082, 795) accepts Parcel 43 for cust 78
# [ 2] 20:19:38.9 Customer 78 at (6082, 795) accepts Parcel 73 for cust 78
# [ 2] 20:19:39.1 Customer 78 at (6082, 795) signs off
# [ 2] 20:19:57.7 Driver drives to Customer 61 at (5363, 1123)
# [ 2] 20:24:02.0 Driver arrived at Customer 61 at (5363, 1123)
# [ 2] 20:24:18.0 Customer 61 at (5363, 1123) answers door
# [ 2] 20:24:18.0 Customer 61 at (5363, 1123) accepts Parcel 67 for cust 61
# [ 2] 20:24:19.8 Customer 61 at (5363, 1123) signs off
# [ 2] 20:24:21.4 Driver drives to Customer 60 at (5273, 1033)
# [ 2] 20:24:51.9 Driver arrived at Customer 60 at (5273, 1033)
# [ 2] 20:25:34.6 Customer 60 at (5273, 1033) answers door
# [ 2] 20:25:34.6 Customer 60 at (5273, 1033) accepts Parcel 66 for cust 60
# [ 2] 20:26:09.2 Customer 60 at (5273, 1033) signs off
# [ 2] 20:26:16.2 Driver drives to Customer 58 at (5217, 977)
# [ 2] 20:26:35.2 Driver arrived at Customer 58 at (5217, 977)
# [ 2] 20:28:07.7 Customer 58 at (5217, 977) answers door
# [ 2] 20:28:07.7 Customer 58 at (5217, 977) accepts Parcel 37 for cust 58
# [ 2] 20:28:14.7 Customer 58 at (5217, 977) signs off
# [ 2] 20:28:23.2 Driver returns to delivery centre
# [ 2] 20:49:02.4 Driver arrived at delivery centre
# [ 2] 20:49:02.4 18 parcels left for next day
# [ 2] 20:59:02.4 Driver goes home
# [ 3] 17:00:00.0 Parcel 83 for cust 4 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 84 for cust 6 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 85 for cust 7 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 86 for cust 14 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 87 for cust 22 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 88 for cust 22 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 89 for cust 25 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 90 for cust 28 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 91 for cust 30 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 92 for cust 33 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 93 for cust 37 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 94 for cust 51 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 95 for cust 54 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 96 for cust 55 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 97 for cust 62 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 98 for cust 68 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 99 for cust 69 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 100 for cust 70 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 101 for cust 70 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 102 for cust 76 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 103 for cust 80 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 104 for cust 82 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 105 for cust 82 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 106 for cust 83 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 107 for cust 86 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 108 for cust 88 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 109 for cust 94 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 110 for cust 94 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 111 for cust 98 arr at delivery centre
# [ 3] 18:00:00.0 Driver arrives for work
# [ 3] 18:00:00.0 Parcel 69 for cust 68 out for delivery
# [ 3] 18:00:00.0 Parcel 98 for cust 68 out for delivery
# [ 3] 18:00:00.0 Parcel 107 for cust 86 out for delivery
# [ 3] 18:00:00.0 Parcel 49 for cust 90 out for delivery
# [ 3] 18:00:00.0 Parcel 70 for cust 70 out for delivery
# [ 3] 18:00:00.0 Parcel 100 for cust 70 out for delivery
# [ 3] 18:00:00.0 Parcel 101 for cust 70 out for delivery
# [ 3] 18:00:00.0 Parcel 71 for cust 71 out for delivery
# [ 3] 18:00:00.0 Parcel 72 for cust 77 out for delivery
# [ 3] 18:00:00.0 Parcel 92 for cust 33 out for delivery
# [ 3] 18:00:00.0 Parcel 60 for cust 31 out for delivery
# [ 3] 18:00:00.0 Parcel 91 for cust 30 out for delivery
# [ 3] 18:00:00.0 Parcel 58 for cust 24 out for delivery
# [ 3] 18:00:00.0 Parcel 87 for cust 22 out for delivery
# [ 3] 18:00:00.0 Parcel 88 for cust 22 out for delivery
# [ 3] 18:00:00.0 Parcel 55 for cust 18 out for delivery
# [ 3] 18:00:00.0 Parcel 83 for cust 4 out for delivery
# [ 3] 18:00:00.0 Parcel 53 for cust 6 out for delivery
# [ 3] 18:00:00.0 Parcel 84 for cust 6 out for delivery
# [ 3] 18:00:00.0 Parcel 97 for cust 62 out for delivery
# [ 3] 18:00:00.0 Parcel 102 for cust 76 out for delivery
# [ 3] 18:00:00.0 Parcel 74 for cust 80 out for delivery
# [ 3] 18:00:00.0 Parcel 103 for cust 80 out for delivery
# [ 3] 18:00:00.0 Parcel 93 for cust 37 out for delivery
# [ 3] 18:20:00.0 Driver leaves for delivery of 24 parcels to 18 customers
# [ 3] 18:20:00.0 Length of delivery tour: 29,590m
# [ 3] 18:20:00.0 Driver drives to Customer 68 at (5560, 6167)
# [ 3] 18:32:39.8 Driver arrived at Customer 68 at (5560, 6167)
# [ 3] 18:33:25.2 Customer 68 at (5560, 6167) answers door
# [ 3] 18:33:25.2 Customer 68 at (5560, 6167) accepts Parcel 69 for cust 68
# [ 3] 18:33:41.6 Customer 68 at (5560, 6167) accepts Parcel 98 for cust 68
# [ 3] 18:33:55.8 Customer 68 at (5560, 6167) signs off
# [ 3] 18:34:42.4 Driver drives to Customer 86 at (6369, 5560)
# [ 3] 18:40:22.2 Driver arrived at Customer 86 at (6369, 5560)
# [ 3] 18:41:17.2 Customer 86 at (6369, 5560) answers door
# [ 3] 18:41:17.2 Customer 86 at (6369, 5560) accepts Parcel 107 for cust 86
# [ 3] 18:41:40.8 Customer 86 at (6369, 5560) signs off
# [ 3] 18:41:43.1 Driver drives to Customer 90 at (6542, 5560)
# [ 3] 18:42:24.6 Driver arrived at Customer 90 at (6542, 5560)
# [ 3] 18:42:55.3 Customer 90 at (6542, 5560) answers door
# [ 3] 18:42:55.3 Customer 90 at (6542, 5560) accepts Parcel 49 for cust 90
# [ 3] 18:43:04.4 Customer 90 at (6542, 5560) signs off
# [ 3] 18:43:21.9 Driver drives to Customer 70 at (5560, 7234)
# [ 3] 18:53:59.3 Driver arrived at Customer 70 at (5560, 7234)
# [ 3] 18:54:25.7 Customer 70 at (5560, 7234) answers door
# [ 3] 18:54:25.7 Customer 70 at (5560, 7234) accepts Parcel 70 for cust 70
# [ 3] 18:54:41.3 Customer 70 at (5560, 7234) accepts Parcel 100 for cust 70
# [ 3] 18:54:46.2 Customer 70 at (5560, 7234) accepts Parcel 101 for cust 70
# [ 3] 18:54:55.1 Customer 70 at (5560, 7234) signs off
# [ 3] 18:55:14.1 Driver drives to Customer 71 at (5722, 7680)
# [ 3] 18:57:40.0 Driver arrived at Customer 71 at (5722, 7680)
# [ 3] 18:58:44.0 Customer 71 at (5722, 7680) answers door
# [ 3] 18:58:44.0 Customer 71 at (5722, 7680) accepts Parcel 71 for cust 71
# [ 3] 18:58:54.7 Customer 71 at (5722, 7680) signs off
# [ 3] 18:58:54.7 Driver drives to Customer 77 at (6047, 7680)
# [ 3] 19:00:12.7 Driver arrived at Customer 77 at (6047, 7680)
# [ 3] 19:00:20.8 Customer 77 at (6047, 7680) answers door
# [ 3] 19:00:20.8 Customer 77 at (6047, 7680) accepts Parcel 72 for cust 77
# [ 3] 19:00:27.8 Customer 77 at (6047, 7680) signs off
# [ 3] 19:00:30.8 Driver drives to Customer 33 at (2895, 6075)
# [ 3] 19:18:15.7 Driver arrived at Customer 33 at (2895, 6075)
# [ 3] 19:18:18.4 Customer 33 at (2895, 6075) answers door
# [ 3] 19:18:18.4 Customer 33 at (2895, 6075) accepts Parcel 92 for cust 33
# [ 3] 19:18:38.0 Customer 33 at (2895, 6075) signs off
# [ 3] 19:19:06.7 Driver drives to Customer 31 at (2380, 5304)
# [ 3] 19:23:02.8 Driver arrived at Customer 31 at (2380, 5304)
# [ 3] 19:23:17.3 Customer 31 at (2380, 5304) answers door
# [ 3] 19:23:17.3 Customer 31 at (2380, 5304) accepts Parcel 60 for cust 31
# [ 3] 19:23:22.5 Customer 31 at (2380, 5304) signs off
# [ 3] 19:23:39.1 Driver drives to Customer 30 at (2380, 5128)
# [ 3] 19:24:21.3 Driver arrived at Customer 30 at (2380, 5128)
# [ 3] 19:24:23.9 Customer 30 at (2380, 5128) answers door
# [ 3] 19:24:23.9 Customer 30 at (2380, 5128) accepts Parcel 91 for cust 30
# [ 3] 19:24:34.2 Customer 30 at (2380, 5128) signs off
# [ 3] 19:24:35.5 Driver drives to Customer 24 at (2251, 4500)
# [ 3] 19:27:37.2 Driver arrived at Customer 24 at (2251, 4500)
# [ 3] 19:27:50.7 Customer 24 at (2251, 4500) answers door
# [ 3] 19:27:50.7 Customer 24 at (2251, 4500) accepts Parcel 58 for cust 24
# [ 3] 19:28:08.5 Customer 24 at (2251, 4500) signs off
# [ 3] 19:28:09.0 Driver drives to Customer 22 at (2169, 4500)
# [ 3] 19:28:28.7 Driver arrived at Customer 22 at (2169, 4500)
# [ 3] 19:28:30.2 Customer 22 at (2169, 4500) answers door
# [ 3] 19:28:30.2 Customer 22 at (2169, 4500) accepts Parcel 87 for cust 22
# [ 3] 19:28:35.6 Customer 22 at (2169, 4500) accepts Parcel 88 for cust 22
# [ 3] 19:28:42.3 Customer 22 at (2169, 4500) signs off
# [ 3] 19:29:02.3 Driver drives to Customer 18 at (2033, 4500)
# [ 3] 19:29:34.9 Driver arrived at Customer 18 at (2033, 4500)
# [ 3] 19:30:25.4 Customer 18 at (2033, 4500) answers door
# [ 3] 19:30:25.4 Customer 18 at (2033, 4500) accepts Parcel 55 for cust 18
# [ 3] 19:30:36.6 Customer 18 at (2033, 4500) signs off
# [ 3] 19:30:38.2 Driver drives to Customer 4 at (1320, 4285)
# [ 3] 19:34:21.0 Driver arrived at Customer 4 at (1320, 4285)
# [ 3] 19:37:13.8 Customer 4 at (1320, 4285) answers door
# [ 3] 19:37:13.8 Customer 4 at (1320, 4285) accepts Parcel 83 for cust 4
# [ 3] 19:37:19.1 Customer 4 at (1320, 4285) signs off
# [ 3] 19:37:28.5 Driver drives to Customer 6 at (1434, 3325)
# [ 3] 19:41:30.0 Driver arrived at Customer 6 at (1434, 3325)
# [ 3] 19:41:49.5 Customer 6 at (1434, 3325) answers door
# [ 3] 19:41:49.5 Customer 6 at (1434, 3325) accepts Parcel 53 for cust 6
# [ 3] 19:41:50.0 Customer 6 at (1434, 3325) accepts Parcel 84 for cust 6
# [ 3] 19:41:56.4 Customer 6 at (1434, 3325) signs off
# [ 3] 19:41:58.0 Driver drives to Customer 62 at (5560, 1408)
# [ 3] 20:07:26.1 Driver arrived at Customer 62 at (5560, 1408)
# [ 3] 20:07:27.4 Customer 62 at (5560, 1408) answers door
# [ 3] 20:07:27.4 Customer 62 at (5560, 1408) accepts Parcel 97 for cust 62
# [ 3] 20:07:37.0 Customer 62 at (5560, 1408) signs off
# [ 3] 20:07:47.0 Driver drives to Customer 76 at (5981, 897)
# [ 3] 20:10:31.1 Driver arrived at Customer 76 at (5981, 897)
# [ 3] 20:10:35.6 Customer 76 at (5981, 897) answers door
# [ 3] 20:10:35.6 Customer 76 at (5981, 897) accepts Parcel 102 for cust 76
# [ 3] 20:10:43.5 Customer 76 at (5981, 897) signs off
# [ 3] 20:10:47.8 Driver drives to Customer 80 at (6128, 751)
# [ 3] 20:11:37.5 Driver arrived at Customer 80 at (6128, 751)
# [ 3] 20:11:56.8 Customer 80 at (6128, 751) answers door
# [ 3] 20:11:56.8 Customer 80 at (6128, 751) accepts Parcel 74 for cust 80
# [ 3] 20:12:11.8 Customer 80 at (6128, 751) accepts Parcel 103 for cust 80
# [ 3] 20:12:18.5 Customer 80 at (6128, 751) signs off
# [ 3] 20:12:39.9 Driver drives to Customer 37 at (3440, 4175)
# [ 3] 20:33:17.5 Driver arrived at Customer 37 at (3440, 4175)
# [ 3] 20:33:55.2 Customer 37 at (3440, 4175) answers door
# [ 3] 20:33:55.2 Customer 37 at (3440, 4175) accepts Parcel 93 for cust 37
# [ 3] 20:34:01.5 Customer 37 at (3440, 4175) signs off
# [ 3] 20:34:11.5 Driver returns to delivery centre
# [ 3] 20:35:29.5 Driver arrived at delivery centre
# [ 3] 20:35:29.5 23 parcels left for next day
# [ 3] 20:45:29.5 Driver goes home
# Delivery Centre Inventory: 23 parcels

# %%
rec3 = simulation(M, W, C, p=0.6, days=4, log=True)
# Out:
# Simulating delivery of 227 parcels over 4 days to 100 customers
# [ 0] 17:00:00.0 Parcel 0 for cust 1 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 1 for cust 2 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 2 for cust 7 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 3 for cust 12 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 4 for cust 13 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 5 for cust 15 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 6 for cust 16 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 7 for cust 19 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 8 for cust 23 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 9 for cust 29 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 10 for cust 37 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 11 for cust 38 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 12 for cust 39 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 13 for cust 43 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 14 for cust 43 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 15 for cust 44 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 16 for cust 44 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 17 for cust 44 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 18 for cust 45 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 19 for cust 45 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 20 for cust 46 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 21 for cust 47 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 22 for cust 49 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 23 for cust 50 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 24 for cust 51 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 25 for cust 52 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 26 for cust 53 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 27 for cust 55 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 28 for cust 55 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 29 for cust 56 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 30 for cust 58 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 31 for cust 59 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 32 for cust 61 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 33 for cust 62 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 34 for cust 66 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 35 for cust 68 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 36 for cust 69 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 37 for cust 70 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 38 for cust 70 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 39 for cust 71 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 40 for cust 72 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 41 for cust 73 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 42 for cust 73 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 43 for cust 76 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 44 for cust 76 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 45 for cust 76 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 46 for cust 79 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 47 for cust 84 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 48 for cust 84 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 49 for cust 85 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 50 for cust 86 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 51 for cust 86 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 52 for cust 86 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 53 for cust 87 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 54 for cust 90 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 55 for cust 91 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 56 for cust 95 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 57 for cust 95 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 58 for cust 95 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 59 for cust 97 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 60 for cust 98 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 61 for cust 99 arr at delivery centre
# [ 0] 18:00:00.0 Driver arrives for work
# [ 0] 18:00:00.0 Parcel 15 for cust 44 out for delivery
# [ 0] 18:00:00.0 Parcel 16 for cust 44 out for delivery
# [ 0] 18:00:00.0 Parcel 17 for cust 44 out for delivery
# [ 0] 18:00:00.0 Parcel 12 for cust 39 out for delivery
# [ 0] 18:00:00.0 Parcel 11 for cust 38 out for delivery
# [ 0] 18:00:00.0 Parcel 10 for cust 37 out for delivery
# [ 0] 18:00:00.0 Parcel 13 for cust 43 out for delivery
# [ 0] 18:00:00.0 Parcel 14 for cust 43 out for delivery
# [ 0] 18:00:00.0 Parcel 18 for cust 45 out for delivery
# [ 0] 18:00:00.0 Parcel 19 for cust 45 out for delivery
# [ 0] 18:00:00.0 Parcel 21 for cust 47 out for delivery
# [ 0] 18:00:00.0 Parcel 4 for cust 13 out for delivery
# [ 0] 18:00:00.0 Parcel 8 for cust 23 out for delivery
# [ 0] 18:00:00.0 Parcel 5 for cust 15 out for delivery
# [ 0] 18:00:00.0 Parcel 20 for cust 46 out for delivery
# [ 0] 18:00:00.0 Parcel 24 for cust 51 out for delivery
# [ 0] 18:00:00.0 Parcel 23 for cust 50 out for delivery
# [ 0] 18:00:00.0 Parcel 22 for cust 49 out for delivery
# [ 0] 18:00:00.0 Parcel 7 for cust 19 out for delivery
# [ 0] 18:00:00.0 Parcel 6 for cust 16 out for delivery
# [ 0] 18:00:00.0 Parcel 2 for cust 7 out for delivery
# [ 0] 18:00:00.0 Parcel 0 for cust 1 out for delivery
# [ 0] 18:00:00.0 Parcel 1 for cust 2 out for delivery
# [ 0] 18:00:00.0 Parcel 9 for cust 29 out for delivery
# [ 0] 18:00:00.0 Parcel 3 for cust 12 out for delivery
# [ 0] 18:20:50.0 Driver leaves for delivery of 25 parcels to 21 customers
# [ 0] 18:20:50.0 Length of delivery tour: 28,817m
# [ 0] 18:20:50.0 Driver drives to Customer 44 at (3855, 4915)
# [ 0] 18:23:10.6 Driver arrived at Customer 44 at (3855, 4915)
# [ 0] 18:24:44.0 Customer 44 at (3855, 4915) answers door
# [ 0] 18:24:44.0 Customer 44 at (3855, 4915) accepts Parcel 15 for cust 44
# [ 0] 18:24:50.0 Customer 44 at (3855, 4915) accepts Parcel 16 for cust 44
# [ 0] 18:25:01.3 Customer 44 at (3855, 4915) accepts Parcel 17 for cust 44
# [ 0] 18:25:02.5 Customer 44 at (3855, 4915) signs off
# [ 0] 18:25:07.6 Driver drives to Customer 39 at (3440, 4390)
# [ 0] 18:27:54.7 Driver arrived at Customer 39 at (3440, 4390)
# [ 0] 18:28:03.9 Customer 39 at (3440, 4390) answers door
# [ 0] 18:28:03.9 Customer 39 at (3440, 4390) accepts Parcel 12 for cust 39
# [ 0] 18:28:04.4 Customer 39 at (3440, 4390) signs off
# [ 0] 18:28:33.9 Driver drives to Customer 38 at (3440, 4276)
# [ 0] 18:29:01.3 Driver arrived at Customer 38 at (3440, 4276)
# [ 0] 18:29:11.0 Customer 38 at (3440, 4276) answers door
# [ 0] 18:29:11.0 Customer 38 at (3440, 4276) accepts Parcel 11 for cust 38
# [ 0] 18:29:12.6 Customer 38 at (3440, 4276) signs off
# [ 0] 18:29:14.8 Driver drives to Customer 37 at (3440, 4175)
# [ 0] 18:29:39.0 Driver arrived at Customer 37 at (3440, 4175)
# [ 0] 18:29:58.0 Customer 37 at (3440, 4175) answers door
# [ 0] 18:29:58.0 Customer 37 at (3440, 4175) accepts Parcel 10 for cust 37
# [ 0] 18:30:05.9 Customer 37 at (3440, 4175) signs off
# [ 0] 18:30:07.6 Driver drives to Customer 43 at (3847, 3440)
# [ 0] 18:34:41.7 Driver arrived at Customer 43 at (3847, 3440)
# [ 0] 18:37:40.9 Customer 43 at (3847, 3440) answers door
# [ 0] 18:37:40.9 Customer 43 at (3847, 3440) accepts Parcel 13 for cust 43
# [ 0] 18:38:21.7 Customer 43 at (3847, 3440) accepts Parcel 14 for cust 43
# [ 0] 18:38:23.3 Customer 43 at (3847, 3440) signs off
# [ 0] 18:38:28.5 Driver drives to Customer 45 at (3981, 3440)
# [ 0] 18:39:00.7 Driver arrived at Customer 45 at (3981, 3440)
# [ 0] 18:39:46.2 Customer 45 at (3981, 3440) answers door
# [ 0] 18:39:46.2 Customer 45 at (3981, 3440) accepts Parcel 18 for cust 45
# [ 0] 18:40:07.2 Customer 45 at (3981, 3440) accepts Parcel 19 for cust 45
# [ 0] 18:40:14.1 Customer 45 at (3981, 3440) signs off
# [ 0] 18:40:39.0 Driver drives to Customer 47 at (4173, 3440)
# [ 0] 18:41:25.1 Driver arrived at Customer 47 at (4173, 3440)
# [ 0] 18:41:40.6 Customer 47 at (4173, 3440) answers door
# [ 0] 18:41:40.6 Customer 47 at (4173, 3440) accepts Parcel 21 for cust 47
# [ 0] 18:41:47.5 Customer 47 at (4173, 3440) signs off
# [ 0] 18:41:54.4 Driver drives to Customer 13 at (1798, 4500)
# [ 0] 18:55:38.8 Driver arrived at Customer 13 at (1798, 4500)
# [ 0] 18:56:23.2 Customer 13 at (1798, 4500) answers door
# [ 0] 18:56:23.2 Customer 13 at (1798, 4500) accepts Parcel 4 for cust 13
# [ 0] 18:56:25.4 Customer 13 at (1798, 4500) signs off
# [ 0] 18:56:34.9 Driver drives to Customer 23 at (2206, 5560)
# [ 0] 19:03:50.7 Driver arrived at Customer 23 at (2206, 5560)
# [ 0] 19:04:00.6 Customer 23 at (2206, 5560) answers door
# [ 0] 19:04:00.6 Customer 23 at (2206, 5560) accepts Parcel 8 for cust 23
# [ 0] 19:04:04.7 Customer 23 at (2206, 5560) signs off
# [ 0] 19:04:37.6 Driver drives to Customer 15 at (1896, 5560)
# [ 0] 19:05:52.0 Driver arrived at Customer 15 at (1896, 5560)
# [ 0] 19:07:23.7 Customer 15 at (1896, 5560) answers door
# [ 0] 19:07:23.7 Customer 15 at (1896, 5560) accepts Parcel 5 for cust 15
# [ 0] 19:07:40.7 Customer 15 at (1896, 5560) signs off
# [ 0] 19:07:41.1 Driver drives to Customer 46 at (3984, 6620)
# [ 0] 19:17:47.6 Driver arrived at Customer 46 at (3984, 6620)
# [ 0] 19:17:54.0 Customer 46 at (3984, 6620) answers door
# [ 0] 19:17:54.0 Customer 46 at (3984, 6620) accepts Parcel 20 for cust 46
# [ 0] 19:17:57.0 Customer 46 at (3984, 6620) signs off
# [ 0] 19:18:12.3 Driver drives to Customer 51 at (4500, 6463)
# [ 0] 19:20:53.8 Driver arrived at Customer 51 at (4500, 6463)
# [ 0] 19:22:07.7 Customer 51 at (4500, 6463) answers door
# [ 0] 19:22:07.7 Customer 51 at (4500, 6463) accepts Parcel 24 for cust 51
# [ 0] 19:22:16.5 Customer 51 at (4500, 6463) signs off
# [ 0] 19:22:29.1 Driver drives to Customer 50 at (4500, 6283)
# [ 0] 19:23:12.3 Driver arrived at Customer 50 at (4500, 6283)
# [ 0] 19:24:18.1 Customer 50 at (4500, 6283) answers door
# [ 0] 19:24:18.1 Customer 50 at (4500, 6283) accepts Parcel 23 for cust 50
# [ 0] 19:24:18.8 Customer 50 at (4500, 6283) signs off
# [ 0] 19:24:19.7 Driver drives to Customer 49 at (4500, 6156)
# [ 0] 19:24:50.2 Driver arrived at Customer 49 at (4500, 6156)
# [ 0] 19:26:11.5 Customer 49 at (4500, 6156) answers door
# [ 0] 19:26:11.5 Customer 49 at (4500, 6156) accepts Parcel 22 for cust 49
# [ 0] 19:26:11.9 Customer 49 at (4500, 6156) signs off
# [ 0] 19:26:14.4 Driver drives to Customer 19 at (2066, 7680)
# [ 0] 19:42:04.3 Driver arrived at Customer 19 at (2066, 7680)
# [ 0] 19:42:06.0 Customer 19 at (2066, 7680) answers door
# [ 0] 19:42:06.0 Customer 19 at (2066, 7680) accepts Parcel 7 for cust 19
# [ 0] 19:42:06.1 Customer 19 at (2066, 7680) signs off
# [ 0] 19:42:24.7 Driver drives to Customer 16 at (1914, 7680)
# [ 0] 19:43:01.2 Driver arrived at Customer 16 at (1914, 7680)
# [ 0] 19:43:17.2 Customer 16 at (1914, 7680) answers door
# [ 0] 19:43:17.2 Customer 16 at (1914, 7680) accepts Parcel 6 for cust 16
# [ 0] 19:43:19.0 Customer 16 at (1914, 7680) signs off
# [ 0] 19:43:20.6 Driver drives to Customer 7 at (1449, 7680)
# [ 0] 19:45:12.2 Driver arrived at Customer 7 at (1449, 7680)
# [ 0] 19:45:54.9 Customer 7 at (1449, 7680) answers door
# [ 0] 19:45:54.9 Customer 7 at (1449, 7680) accepts Parcel 2 for cust 7
# [ 0] 19:46:29.5 Customer 7 at (1449, 7680) signs off
# [ 0] 19:46:36.5 Driver drives to Customer 1 at (1078, 6620)
# [ 0] 19:52:20.0 Driver arrived at Customer 1 at (1078, 6620)
# [ 0] 19:53:52.5 Customer 1 at (1078, 6620) answers door
# [ 0] 19:53:52.5 Customer 1 at (1078, 6620) accepts Parcel 0 for cust 1
# [ 0] 19:53:59.5 Customer 1 at (1078, 6620) signs off
# [ 0] 19:54:08.0 Driver drives to Customer 2 at (1320, 4082)
# [ 0] 20:05:15.2 Driver arrived at Customer 2 at (1320, 4082)
# [ 0] 20:06:00.6 Customer 2 at (1320, 4082) answers door
# [ 0] 20:06:00.6 Customer 2 at (1320, 4082) accepts Parcel 1 for cust 2
# [ 0] 20:06:17.0 Customer 2 at (1320, 4082) signs off
# [ 0] 20:06:31.2 Driver drives to Customer 29 at (2380, 1941)
# [ 0] 20:16:50.4 Driver arrived at Customer 29 at (2380, 1941)
# [ 0] 20:19:56.8 Customer 29 at (2380, 1941) answers door
# [ 0] 20:19:56.8 Customer 29 at (2380, 1941) accepts Parcel 9 for cust 29
# [ 0] 20:20:10.5 Customer 29 at (2380, 1941) signs off
# [ 0] 20:20:34.1 Driver drives to Customer 12 at (1791, 1320)
# [ 0] 20:25:24.5 Driver arrived at Customer 12 at (1791, 1320)
# [ 0] 20:25:33.8 Customer 12 at (1791, 1320) answers door
# [ 0] 20:25:33.8 Customer 12 at (1791, 1320) accepts Parcel 3 for cust 12
# [ 0] 20:25:41.4 Customer 12 at (1791, 1320) signs off
# [ 0] 20:25:50.6 Driver returns to delivery centre
# [ 0] 20:42:40.5 Driver arrived at delivery centre
# [ 0] 20:42:40.5 37 parcels left for next day
# [ 0] 20:52:40.5 Driver goes home
# [ 1] 17:00:00.0 Parcel 62 for cust 1 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 63 for cust 2 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 64 for cust 3 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 65 for cust 3 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 66 for cust 4 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 67 for cust 8 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 68 for cust 9 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 69 for cust 11 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 70 for cust 14 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 71 for cust 14 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 72 for cust 15 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 73 for cust 16 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 74 for cust 18 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 75 for cust 19 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 76 for cust 22 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 77 for cust 24 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 78 for cust 28 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 79 for cust 32 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 80 for cust 36 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 81 for cust 39 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 82 for cust 40 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 83 for cust 41 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 84 for cust 45 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 85 for cust 45 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 86 for cust 46 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 87 for cust 46 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 88 for cust 46 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 89 for cust 47 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 90 for cust 50 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 91 for cust 51 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 92 for cust 54 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 93 for cust 54 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 94 for cust 55 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 95 for cust 56 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 96 for cust 57 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 97 for cust 58 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 98 for cust 60 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 99 for cust 62 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 100 for cust 64 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 101 for cust 64 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 102 for cust 67 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 103 for cust 67 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 104 for cust 73 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 105 for cust 75 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 106 for cust 80 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 107 for cust 81 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 108 for cust 82 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 109 for cust 82 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 110 for cust 82 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 111 for cust 85 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 112 for cust 88 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 113 for cust 90 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 114 for cust 93 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 115 for cust 94 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 116 for cust 94 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 117 for cust 94 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 118 for cust 96 arr at delivery centre
# [ 1] 18:00:00.0 Driver arrives for work
# [ 1] 18:00:00.0 Parcel 81 for cust 39 out for delivery
# [ 1] 18:00:00.0 Parcel 84 for cust 45 out for delivery
# [ 1] 18:00:00.0 Parcel 85 for cust 45 out for delivery
# [ 1] 18:00:00.0 Parcel 89 for cust 47 out for delivery
# [ 1] 18:00:00.0 Parcel 25 for cust 52 out for delivery
# [ 1] 18:00:00.0 Parcel 29 for cust 56 out for delivery
# [ 1] 18:00:00.0 Parcel 95 for cust 56 out for delivery
# [ 1] 18:00:00.0 Parcel 46 for cust 79 out for delivery
# [ 1] 18:00:00.0 Parcel 108 for cust 82 out for delivery
# [ 1] 18:00:00.0 Parcel 109 for cust 82 out for delivery
# [ 1] 18:00:00.0 Parcel 110 for cust 82 out for delivery
# [ 1] 18:00:00.0 Parcel 49 for cust 85 out for delivery
# [ 1] 18:00:00.0 Parcel 111 for cust 85 out for delivery
# [ 1] 18:00:00.0 Parcel 100 for cust 64 out for delivery
# [ 1] 18:00:00.0 Parcel 101 for cust 64 out for delivery
# [ 1] 18:00:00.0 Parcel 33 for cust 62 out for delivery
# [ 1] 18:00:00.0 Parcel 99 for cust 62 out for delivery
# [ 1] 18:00:00.0 Parcel 32 for cust 61 out for delivery
# [ 1] 18:00:00.0 Parcel 98 for cust 60 out for delivery
# [ 1] 18:00:00.0 Parcel 30 for cust 58 out for delivery
# [ 1] 18:00:00.0 Parcel 97 for cust 58 out for delivery
# [ 1] 18:00:00.0 Parcel 27 for cust 55 out for delivery
# [ 1] 18:00:00.0 Parcel 28 for cust 55 out for delivery
# [ 1] 18:00:00.0 Parcel 94 for cust 55 out for delivery
# [ 1] 18:00:00.0 Parcel 40 for cust 72 out for delivery
# [ 1] 18:00:00.0 Parcel 43 for cust 76 out for delivery
# [ 1] 18:00:00.0 Parcel 44 for cust 76 out for delivery
# [ 1] 18:00:00.0 Parcel 45 for cust 76 out for delivery
# [ 1] 18:00:00.0 Parcel 106 for cust 80 out for delivery
# [ 1] 18:00:00.0 Parcel 26 for cust 53 out for delivery
# [ 1] 18:00:00.0 Parcel 41 for cust 73 out for delivery
# [ 1] 18:00:00.0 Parcel 42 for cust 73 out for delivery
# [ 1] 18:00:00.0 Parcel 104 for cust 73 out for delivery
# [ 1] 18:00:00.0 Parcel 105 for cust 75 out for delivery
# [ 1] 18:00:00.0 Parcel 50 for cust 86 out for delivery
# [ 1] 18:00:00.0 Parcel 51 for cust 86 out for delivery
# [ 1] 18:00:00.0 Parcel 52 for cust 86 out for delivery
# [ 1] 18:00:00.0 Parcel 54 for cust 90 out for delivery
# [ 1] 18:00:00.0 Parcel 113 for cust 90 out for delivery
# [ 1] 18:00:00.0 Parcel 34 for cust 66 out for delivery
# [ 1] 18:00:00.0 Parcel 102 for cust 67 out for delivery
# [ 1] 18:00:00.0 Parcel 103 for cust 67 out for delivery
# [ 1] 18:00:00.0 Parcel 35 for cust 68 out for delivery
# [ 1] 18:00:00.0 Parcel 36 for cust 69 out for delivery
# [ 1] 18:00:00.0 Parcel 37 for cust 70 out for delivery
# [ 1] 18:00:00.0 Parcel 38 for cust 70 out for delivery
# [ 1] 18:00:00.0 Parcel 39 for cust 71 out for delivery
# [ 1] 18:00:00.0 Parcel 107 for cust 81 out for delivery
# [ 1] 18:00:00.0 Parcel 47 for cust 84 out for delivery
# [ 1] 18:00:00.0 Parcel 48 for cust 84 out for delivery
# [ 1] 18:00:00.0 Parcel 53 for cust 87 out for delivery
# [ 1] 18:00:00.0 Parcel 55 for cust 91 out for delivery
# [ 1] 18:00:00.0 Parcel 31 for cust 59 out for delivery
# [ 1] 18:00:00.0 Parcel 92 for cust 54 out for delivery
# [ 1] 18:00:00.0 Parcel 93 for cust 54 out for delivery
# [ 1] 18:00:00.0 Parcel 91 for cust 51 out for delivery
# [ 1] 18:00:00.0 Parcel 90 for cust 50 out for delivery
# [ 1] 18:47:30.0 Driver leaves for delivery of 57 parcels to 36 customers
# [ 1] 18:47:30.0 Length of delivery tour: 29,958m
# [ 1] 18:47:30.0 Driver drives to Customer 39 at (3440, 4390)
# [ 1] 18:47:56.4 Driver arrived at Customer 39 at (3440, 4390)
# [ 1] 18:49:06.3 Customer 39 at (3440, 4390) answers door
# [ 1] 18:49:06.3 Customer 39 at (3440, 4390) accepts Parcel 81 for cust 39
# [ 1] 18:49:12.9 Customer 39 at (3440, 4390) signs off
# [ 1] 18:49:28.5 Driver drives to Customer 45 at (3981, 3440)
# [ 1] 18:55:26.4 Driver arrived at Customer 45 at (3981, 3440)
# [ 1] 18:55:46.0 Customer 45 at (3981, 3440) answers door
# [ 1] 18:55:46.0 Customer 45 at (3981, 3440) accepts Parcel 84 for cust 45
# [ 1] 18:55:54.9 Customer 45 at (3981, 3440) accepts Parcel 85 for cust 45
# [ 1] 18:56:13.9 Customer 45 at (3981, 3440) signs off
# [ 1] 18:56:29.9 Driver drives to Customer 47 at (4173, 3440)
# [ 1] 18:57:16.0 Driver arrived at Customer 47 at (4173, 3440)
# [ 1] 18:57:58.8 Customer 47 at (4173, 3440) answers door
# [ 1] 18:57:58.8 Customer 47 at (4173, 3440) accepts Parcel 89 for cust 47
# [ 1] 18:57:58.8 Customer 47 at (4173, 3440) signs off
# [ 1] 18:58:00.8 Driver drives to Customer 52 at (4718, 3220)
# [ 1] 19:00:33.5 Driver arrived at Customer 52 at (4718, 3220)
# [ 1] 19:01:01.7 Customer 52 at (4718, 3220) answers door
# [ 1] 19:01:01.7 Customer 52 at (4718, 3220) accepts Parcel 25 for cust 52
# [ 1] 19:01:04.7 Customer 52 at (4718, 3220) signs off
# [ 1] 19:01:05.3 Driver drives to Customer 56 at (5106, 2833)
# [ 1] 19:03:16.9 Driver arrived at Customer 56 at (5106, 2833)
# [ 1] 19:04:35.5 Customer 56 at (5106, 2833) answers door
# [ 1] 19:04:35.5 Customer 56 at (5106, 2833) accepts Parcel 29 for cust 56
# [ 1] 19:05:04.1 Customer 56 at (5106, 2833) accepts Parcel 95 for cust 56
# [ 1] 19:05:07.7 Customer 56 at (5106, 2833) signs off
# [ 1] 19:05:13.0 Driver drives to Customer 79 at (6105, 2925)
# [ 1] 19:10:51.6 Driver arrived at Customer 79 at (6105, 2925)
# [ 1] 19:11:58.0 Customer 79 at (6105, 2925) answers door
# [ 1] 19:11:58.0 Customer 79 at (6105, 2925) accepts Parcel 46 for cust 79
# [ 1] 19:11:58.7 Customer 79 at (6105, 2925) signs off
# [ 1] 19:12:08.9 Driver drives to Customer 82 at (6207, 3027)
# [ 1] 19:12:43.5 Driver arrived at Customer 82 at (6207, 3027)
# [ 1] 19:12:48.9 Customer 82 at (6207, 3027) answers door
# [ 1] 19:12:48.9 Customer 82 at (6207, 3027) accepts Parcel 108 for cust 82
# [ 1] 19:12:52.3 Customer 82 at (6207, 3027) accepts Parcel 109 for cust 82
# [ 1] 19:13:10.0 Customer 82 at (6207, 3027) accepts Parcel 110 for cust 82
# [ 1] 19:13:10.6 Customer 82 at (6207, 3027) signs off
# [ 1] 19:13:11.0 Driver drives to Customer 85 at (6340, 3160)
# [ 1] 19:13:56.1 Driver arrived at Customer 85 at (6340, 3160)
# [ 1] 19:14:17.7 Customer 85 at (6340, 3160) answers door
# [ 1] 19:14:17.7 Customer 85 at (6340, 3160) accepts Parcel 49 for cust 85
# [ 1] 19:14:24.5 Customer 85 at (6340, 3160) accepts Parcel 111 for cust 85
# [ 1] 19:14:44.4 Customer 85 at (6340, 3160) signs off
# [ 1] 19:14:57.0 Driver drives to Customer 64 at (5560, 1912)
# [ 1] 19:21:13.8 Driver arrived at Customer 64 at (5560, 1912)
# [ 1] 19:21:58.6 Customer 64 at (5560, 1912) answers door
# [ 1] 19:21:58.6 Customer 64 at (5560, 1912) accepts Parcel 100 for cust 64
# [ 1] 19:22:00.3 Customer 64 at (5560, 1912) accepts Parcel 101 for cust 64
# [ 1] 19:22:43.5 Customer 64 at (5560, 1912) signs off
# [ 1] 19:22:48.8 Driver drives to Customer 62 at (5560, 1408)
# [ 1] 19:24:49.7 Driver arrived at Customer 62 at (5560, 1408)
# [ 1] 19:25:27.6 Customer 62 at (5560, 1408) answers door
# [ 1] 19:25:27.6 Customer 62 at (5560, 1408) accepts Parcel 33 for cust 62
# [ 1] 19:25:32.4 Customer 62 at (5560, 1408) accepts Parcel 99 for cust 62
# [ 1] 19:25:32.9 Customer 62 at (5560, 1408) signs off
# [ 1] 19:25:39.3 Driver drives to Customer 61 at (5363, 1123)
# [ 1] 19:27:07.1 Driver arrived at Customer 61 at (5363, 1123)
# [ 1] 19:27:13.7 Customer 61 at (5363, 1123) answers door
# [ 1] 19:27:13.7 Customer 61 at (5363, 1123) accepts Parcel 32 for cust 61
# [ 1] 19:27:14.0 Customer 61 at (5363, 1123) signs off
# [ 1] 19:27:23.6 Driver drives to Customer 60 at (5273, 1033)
# [ 1] 19:27:54.1 Driver arrived at Customer 60 at (5273, 1033)
# [ 1] 19:28:33.9 Customer 60 at (5273, 1033) answers door
# [ 1] 19:28:33.9 Customer 60 at (5273, 1033) accepts Parcel 98 for cust 60
# [ 1] 19:28:35.0 Customer 60 at (5273, 1033) signs off
# [ 1] 19:28:43.0 Driver drives to Customer 58 at (5217, 977)
# [ 1] 19:29:01.9 Driver arrived at Customer 58 at (5217, 977)
# [ 1] 19:29:19.0 Customer 58 at (5217, 977) answers door
# [ 1] 19:29:19.0 Customer 58 at (5217, 977) accepts Parcel 30 for cust 58
# [ 1] 19:29:23.8 Customer 58 at (5217, 977) accepts Parcel 97 for cust 58
# [ 1] 19:29:38.8 Customer 58 at (5217, 977) signs off
# [ 1] 19:29:45.5 Driver drives to Customer 55 at (4980, 740)
# [ 1] 19:31:05.9 Driver arrived at Customer 55 at (4980, 740)
# [ 1] 19:32:31.1 Customer 55 at (4980, 740) answers door
# [ 1] 19:32:31.1 Customer 55 at (4980, 740) accepts Parcel 27 for cust 55
# [ 1] 19:32:40.6 Customer 55 at (4980, 740) accepts Parcel 28 for cust 55
# [ 1] 19:32:46.9 Customer 55 at (4980, 740) accepts Parcel 94 for cust 55
# [ 1] 19:32:56.9 Customer 55 at (4980, 740) signs off
# [ 1] 19:33:01.0 Driver drives to Customer 72 at (5755, 1124)
# [ 1] 19:37:23.8 Driver arrived at Customer 72 at (5755, 1124)
# [ 1] 19:37:29.1 Customer 72 at (5755, 1124) answers door
# [ 1] 19:37:29.1 Customer 72 at (5755, 1124) accepts Parcel 40 for cust 72
# [ 1] 19:37:40.6 Customer 72 at (5755, 1124) signs off
# [ 1] 19:37:50.3 Driver drives to Customer 76 at (5981, 897)
# [ 1] 19:39:07.1 Driver arrived at Customer 76 at (5981, 897)
# [ 1] 19:40:09.3 Customer 76 at (5981, 897) answers door
# [ 1] 19:40:09.3 Customer 76 at (5981, 897) accepts Parcel 43 for cust 76
# [ 1] 19:40:10.6 Customer 76 at (5981, 897) accepts Parcel 44 for cust 76
# [ 1] 19:40:34.9 Customer 76 at (5981, 897) accepts Parcel 45 for cust 76
# [ 1] 19:40:51.0 Customer 76 at (5981, 897) signs off
# [ 1] 19:41:15.8 Driver drives to Customer 80 at (6128, 751)
# [ 1] 19:42:05.5 Driver arrived at Customer 80 at (6128, 751)
# [ 1] 19:43:27.9 Customer 80 at (6128, 751) answers door
# [ 1] 19:43:27.9 Customer 80 at (6128, 751) accepts Parcel 106 for cust 80
# [ 1] 19:43:39.3 Customer 80 at (6128, 751) signs off
# [ 1] 19:43:56.0 Driver drives to Customer 53 at (4722, 5560)
# [ 1] 20:12:44.4 Driver arrived at Customer 53 at (4722, 5560)
# [ 1] 20:13:13.7 Customer 53 at (4722, 5560) answers door
# [ 1] 20:13:13.7 Customer 53 at (4722, 5560) accepts Parcel 26 for cust 53
# [ 1] 20:13:29.1 Customer 53 at (4722, 5560) signs off
# [ 1] 20:13:31.2 Driver drives to Customer 73 at (5828, 5560)
# [ 1] 20:17:56.6 Driver arrived at Customer 73 at (5828, 5560)
# [ 1] 20:18:57.6 Customer 73 at (5828, 5560) answers door
# [ 1] 20:18:57.6 Customer 73 at (5828, 5560) accepts Parcel 41 for cust 73
# [ 1] 20:19:03.5 Customer 73 at (5828, 5560) accepts Parcel 42 for cust 73
# [ 1] 20:19:17.6 Customer 73 at (5828, 5560) accepts Parcel 104 for cust 73
# [ 1] 20:19:23.7 Customer 73 at (5828, 5560) signs off
# [ 1] 20:19:39.3 Driver drives to Customer 75 at (5972, 5560)
# [ 1] 20:20:13.8 Driver arrived at Customer 75 at (5972, 5560)
# [ 1] 20:20:17.0 Customer 75 at (5972, 5560) answers door
# [ 1] 20:20:17.0 Customer 75 at (5972, 5560) accepts Parcel 105 for cust 75
# [ 1] 20:20:17.4 Customer 75 at (5972, 5560) signs off
# [ 1] 20:20:44.6 Driver drives to Customer 86 at (6369, 5560)
# [ 1] 20:22:19.9 Driver arrived at Customer 86 at (6369, 5560)
# [ 1] 20:22:46.6 Customer 86 at (6369, 5560) answers door
# [ 1] 20:22:46.6 Customer 86 at (6369, 5560) accepts Parcel 50 for cust 86
# [ 1] 20:23:09.7 Customer 86 at (6369, 5560) accepts Parcel 51 for cust 86
# [ 1] 20:23:38.7 Customer 86 at (6369, 5560) accepts Parcel 52 for cust 86
# [ 1] 20:23:49.6 Customer 86 at (6369, 5560) signs off
# [ 1] 20:23:58.1 Driver drives to Customer 90 at (6542, 5560)
# [ 1] 20:24:39.6 Driver arrived at Customer 90 at (6542, 5560)
# [ 1] 20:24:49.4 Customer 90 at (6542, 5560) answers door
# [ 1] 20:24:49.4 Customer 90 at (6542, 5560) accepts Parcel 54 for cust 90
# [ 1] 20:24:50.4 Customer 90 at (6542, 5560) accepts Parcel 113 for cust 90
# [ 1] 20:25:07.5 Customer 90 at (6542, 5560) signs off
# [ 1] 20:25:29.4 Driver drives to Customer 66 at (5560, 5684)
# [ 1] 20:29:54.9 Driver arrived at Customer 66 at (5560, 5684)
# [ 1] 20:30:55.3 Customer 66 at (5560, 5684) answers door
# [ 1] 20:30:55.3 Customer 66 at (5560, 5684) accepts Parcel 34 for cust 66
# [ 1] 20:31:07.3 Customer 66 at (5560, 5684) signs off
# [ 1] 20:31:12.8 Driver drives to Customer 67 at (5560, 5967)
# [ 1] 20:32:20.7 Driver arrived at Customer 67 at (5560, 5967)
# [ 1] 20:32:35.3 Customer 67 at (5560, 5967) answers door
# [ 1] 20:32:35.3 Customer 67 at (5560, 5967) accepts Parcel 102 for cust 67
# [ 1] 20:32:36.5 Customer 67 at (5560, 5967) accepts Parcel 103 for cust 67
# [ 1] 20:32:42.0 Customer 67 at (5560, 5967) signs off
# [ 1] 20:32:50.4 Driver drives to Customer 68 at (5560, 6167)
# [ 1] 20:33:38.4 Driver arrived at Customer 68 at (5560, 6167)
# [ 1] 20:35:20.9 Customer 68 at (5560, 6167) answers door
# [ 1] 20:35:20.9 Customer 68 at (5560, 6167) accepts Parcel 35 for cust 68
# [ 1] 20:35:48.3 Customer 68 at (5560, 6167) signs off
# [ 1] 20:35:53.7 Driver drives to Customer 69 at (5560, 6381)
# [ 1] 20:36:45.0 Driver arrived at Customer 69 at (5560, 6381)
# [ 1] 20:36:49.2 Customer 69 at (5560, 6381) answers door
# [ 1] 20:36:49.2 Customer 69 at (5560, 6381) accepts Parcel 36 for cust 69
# [ 1] 20:37:04.1 Customer 69 at (5560, 6381) signs off
# [ 1] 20:37:17.3 Driver drives to Customer 70 at (5560, 7234)
# [ 1] 20:40:42.1 Driver arrived at Customer 70 at (5560, 7234)
# [ 1] 20:40:43.3 Customer 70 at (5560, 7234) answers door
# [ 1] 20:40:43.3 Customer 70 at (5560, 7234) accepts Parcel 37 for cust 70
# [ 1] 20:40:49.2 Customer 70 at (5560, 7234) accepts Parcel 38 for cust 70
# [ 1] 20:41:00.8 Customer 70 at (5560, 7234) signs off
# [ 1] 20:41:01.1 Driver drives to Customer 71 at (5722, 7680)
# [ 1] 20:43:27.0 Driver arrived at Customer 71 at (5722, 7680)
# [ 1] 20:45:07.7 Customer 71 at (5722, 7680) answers door
# [ 1] 20:45:07.7 Customer 71 at (5722, 7680) accepts Parcel 39 for cust 71
# [ 1] 20:45:40.5 Customer 71 at (5722, 7680) signs off
# [ 1] 20:45:53.3 Driver drives to Customer 81 at (6158, 7680)
# [ 1] 20:47:37.9 Driver arrived at Customer 81 at (6158, 7680)
# [ 1] 20:47:41.2 Customer 81 at (6158, 7680) answers door
# [ 1] 20:47:41.2 Customer 81 at (6158, 7680) accepts Parcel 107 for cust 81
# [ 1] 20:47:41.9 Customer 81 at (6158, 7680) signs off
# [ 1] 20:47:46.4 Driver drives to Customer 84 at (6312, 7680)
# [ 1] 20:48:23.4 Driver arrived at Customer 84 at (6312, 7680)
# [ 1] 20:48:24.5 Customer 84 at (6312, 7680) answers door
# [ 1] 20:48:24.5 Customer 84 at (6312, 7680) accepts Parcel 47 for cust 84
# [ 1] 20:48:28.8 Customer 84 at (6312, 7680) accepts Parcel 48 for cust 84
# [ 1] 20:48:28.9 Customer 84 at (6312, 7680) signs off
# [ 1] 20:49:05.5 Driver drives to Customer 87 at (6416, 7680)
# [ 1] 20:49:30.5 Driver arrived at Customer 87 at (6416, 7680)
# [ 1] 20:50:38.9 Customer 87 at (6416, 7680) answers door
# [ 1] 20:50:38.9 Customer 87 at (6416, 7680) accepts Parcel 53 for cust 87
# [ 1] 20:50:39.6 Customer 87 at (6416, 7680) signs off
# [ 1] 20:51:02.0 Driver drives to Customer 91 at (6620, 8314)
# [ 1] 20:54:23.1 Driver arrived at Customer 91 at (6620, 8314)
# [ 1] 20:54:32.4 Customer 91 at (6620, 8314) answers door
# [ 1] 20:54:32.4 Customer 91 at (6620, 8314) accepts Parcel 55 for cust 91
# [ 1] 20:54:34.7 Customer 91 at (6620, 8314) signs off
# [ 1] 20:54:45.9 Driver drives to Customer 59 at (5249, 6620)
# [ 1] 21:07:01.5 Driver arrived at Customer 59 at (5249, 6620)
# [ 1] 21:08:52.9 Customer 59 at (5249, 6620) answers door
# [ 1] 21:08:52.9 Customer 59 at (5249, 6620) accepts Parcel 31 for cust 59
# [ 1] 21:08:54.2 Customer 59 at (5249, 6620) signs off
# [ 1] 21:08:54.3 Driver drives to Customer 54 at (4955, 6620)
# [ 1] 21:10:04.9 Driver arrived at Customer 54 at (4955, 6620)
# [ 1] 21:10:23.3 Customer 54 at (4955, 6620) answers door
# [ 1] 21:10:23.3 Customer 54 at (4955, 6620) accepts Parcel 92 for cust 54
# [ 1] 21:10:23.6 Customer 54 at (4955, 6620) accepts Parcel 93 for cust 54
# [ 1] 21:10:32.8 Customer 54 at (4955, 6620) signs off
# [ 1] 21:10:52.4 Driver drives to Customer 51 at (4500, 6463)
# [ 1] 21:13:19.3 Driver arrived at Customer 51 at (4500, 6463)
# [ 1] 21:13:27.6 Customer 51 at (4500, 6463) answers door
# [ 1] 21:13:27.6 Customer 51 at (4500, 6463) accepts Parcel 91 for cust 51
# [ 1] 21:13:28.8 Customer 51 at (4500, 6463) signs off
# [ 1] 21:13:33.0 Driver drives to Customer 50 at (4500, 6283)
# [ 1] 21:14:16.2 Driver arrived at Customer 50 at (4500, 6283)
# [ 1] 21:16:24.1 Customer 50 at (4500, 6283) answers door
# [ 1] 21:16:24.1 Customer 50 at (4500, 6283) accepts Parcel 90 for cust 50
# [ 1] 21:16:25.5 Customer 50 at (4500, 6283) signs off
# [ 1] 21:16:59.5 Driver returns to delivery centre
# [ 1] 21:27:39.4 Driver arrived at delivery centre
# [ 1] 21:27:39.4 37 parcels left for next day
# [ 1] 21:37:39.4 Driver goes home
# [ 2] 17:00:00.0 Parcel 119 for cust 1 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 120 for cust 4 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 121 for cust 6 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 122 for cust 7 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 123 for cust 8 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 124 for cust 13 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 125 for cust 13 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 126 for cust 14 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 127 for cust 16 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 128 for cust 17 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 129 for cust 20 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 130 for cust 23 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 131 for cust 23 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 132 for cust 24 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 133 for cust 28 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 134 for cust 32 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 135 for cust 35 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 136 for cust 35 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 137 for cust 36 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 138 for cust 37 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 139 for cust 37 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 140 for cust 41 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 141 for cust 45 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 142 for cust 49 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 143 for cust 51 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 144 for cust 52 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 145 for cust 56 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 146 for cust 59 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 147 for cust 59 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 148 for cust 60 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 149 for cust 61 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 150 for cust 61 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 151 for cust 62 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 152 for cust 63 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 153 for cust 64 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 154 for cust 68 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 155 for cust 69 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 156 for cust 70 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 157 for cust 75 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 158 for cust 76 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 159 for cust 79 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 160 for cust 81 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 161 for cust 82 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 162 for cust 83 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 163 for cust 83 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 164 for cust 85 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 165 for cust 86 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 166 for cust 86 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 167 for cust 91 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 168 for cust 93 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 169 for cust 95 arr at delivery centre
# [ 2] 18:00:00.0 Driver arrives for work
# [ 2] 18:00:00.0 Parcel 130 for cust 23 out for delivery
# [ 2] 18:00:00.0 Parcel 131 for cust 23 out for delivery
# [ 2] 18:00:00.0 Parcel 72 for cust 15 out for delivery
# [ 2] 18:00:00.0 Parcel 62 for cust 1 out for delivery
# [ 2] 18:00:00.0 Parcel 119 for cust 1 out for delivery
# [ 2] 18:00:00.0 Parcel 66 for cust 4 out for delivery
# [ 2] 18:00:00.0 Parcel 120 for cust 4 out for delivery
# [ 2] 18:00:00.0 Parcel 64 for cust 3 out for delivery
# [ 2] 18:00:00.0 Parcel 65 for cust 3 out for delivery
# [ 2] 18:00:00.0 Parcel 63 for cust 2 out for delivery
# [ 2] 18:00:00.0 Parcel 68 for cust 9 out for delivery
# [ 2] 18:00:00.0 Parcel 124 for cust 13 out for delivery
# [ 2] 18:00:00.0 Parcel 125 for cust 13 out for delivery
# [ 2] 18:00:00.0 Parcel 74 for cust 18 out for delivery
# [ 2] 18:00:00.0 Parcel 76 for cust 22 out for delivery
# [ 2] 18:00:00.0 Parcel 77 for cust 24 out for delivery
# [ 2] 18:00:00.0 Parcel 132 for cust 24 out for delivery
# [ 2] 18:00:00.0 Parcel 138 for cust 37 out for delivery
# [ 2] 18:00:00.0 Parcel 139 for cust 37 out for delivery
# [ 2] 18:00:00.0 Parcel 141 for cust 45 out for delivery
# [ 2] 18:00:00.0 Parcel 144 for cust 52 out for delivery
# [ 2] 18:00:00.0 Parcel 145 for cust 56 out for delivery
# [ 2] 18:00:00.0 Parcel 153 for cust 64 out for delivery
# [ 2] 18:00:00.0 Parcel 159 for cust 79 out for delivery
# [ 2] 18:00:00.0 Parcel 161 for cust 82 out for delivery
# [ 2] 18:00:00.0 Parcel 162 for cust 83 out for delivery
# [ 2] 18:00:00.0 Parcel 163 for cust 83 out for delivery
# [ 2] 18:00:00.0 Parcel 164 for cust 85 out for delivery
# [ 2] 18:00:00.0 Parcel 112 for cust 88 out for delivery
# [ 2] 18:00:00.0 Parcel 114 for cust 93 out for delivery
# [ 2] 18:00:00.0 Parcel 168 for cust 93 out for delivery
# [ 2] 18:00:00.0 Parcel 115 for cust 94 out for delivery
# [ 2] 18:00:00.0 Parcel 116 for cust 94 out for delivery
# [ 2] 18:00:00.0 Parcel 117 for cust 94 out for delivery
# [ 2] 18:00:00.0 Parcel 56 for cust 95 out for delivery
# [ 2] 18:00:00.0 Parcel 57 for cust 95 out for delivery
# [ 2] 18:00:00.0 Parcel 58 for cust 95 out for delivery
# [ 2] 18:00:00.0 Parcel 169 for cust 95 out for delivery
# [ 2] 18:00:00.0 Parcel 60 for cust 98 out for delivery
# [ 2] 18:00:00.0 Parcel 118 for cust 96 out for delivery
# [ 2] 18:00:00.0 Parcel 59 for cust 97 out for delivery
# [ 2] 18:00:00.0 Parcel 61 for cust 99 out for delivery
# [ 2] 18:35:00.0 Driver leaves for delivery of 42 parcels to 28 customers
# [ 2] 18:35:00.0 Length of delivery tour: 29,834m
# [ 2] 18:35:00.0 Driver drives to Customer 23 at (2206, 5560)
# [ 2] 18:44:10.6 Driver arrived at Customer 23 at (2206, 5560)
# [ 2] 18:44:28.6 Customer 23 at (2206, 5560) answers door
# [ 2] 18:44:28.6 Customer 23 at (2206, 5560) accepts Parcel 130 for cust 23
# [ 2] 18:44:35.0 Customer 23 at (2206, 5560) accepts Parcel 131 for cust 23
# [ 2] 18:44:38.4 Customer 23 at (2206, 5560) signs off
# [ 2] 18:45:06.1 Driver drives to Customer 15 at (1896, 5560)
# [ 2] 18:46:20.5 Driver arrived at Customer 15 at (1896, 5560)
# [ 2] 18:48:27.4 Customer 15 at (1896, 5560) answers door
# [ 2] 18:48:27.4 Customer 15 at (1896, 5560) accepts Parcel 72 for cust 15
# [ 2] 18:48:37.5 Customer 15 at (1896, 5560) signs off
# [ 2] 18:48:39.6 Driver drives to Customer 1 at (1078, 6620)
# [ 2] 18:56:10.3 Driver arrived at Customer 1 at (1078, 6620)
# [ 2] 18:59:28.5 Customer 1 at (1078, 6620) answers door
# [ 2] 18:59:28.5 Customer 1 at (1078, 6620) accepts Parcel 62 for cust 1
# [ 2] 18:59:29.6 Customer 1 at (1078, 6620) accepts Parcel 119 for cust 1
# [ 2] 18:59:38.3 Customer 1 at (1078, 6620) signs off
# [ 2] 18:59:40.0 Driver drives to Customer 4 at (1320, 4285)
# [ 2] 19:09:58.5 Driver arrived at Customer 4 at (1320, 4285)
# [ 2] 19:11:29.6 Customer 4 at (1320, 4285) answers door
# [ 2] 19:11:29.6 Customer 4 at (1320, 4285) accepts Parcel 66 for cust 4
# [ 2] 19:11:58.8 Customer 4 at (1320, 4285) accepts Parcel 120 for cust 4
# [ 2] 19:12:15.1 Customer 4 at (1320, 4285) signs off
# [ 2] 19:12:18.9 Driver drives to Customer 3 at (1320, 4193)
# [ 2] 19:12:41.0 Driver arrived at Customer 3 at (1320, 4193)
# [ 2] 19:12:52.1 Customer 3 at (1320, 4193) answers door
# [ 2] 19:12:52.1 Customer 3 at (1320, 4193) accepts Parcel 64 for cust 3
# [ 2] 19:13:06.1 Customer 3 at (1320, 4193) accepts Parcel 65 for cust 3
# [ 2] 19:13:09.6 Customer 3 at (1320, 4193) signs off
# [ 2] 19:13:15.0 Driver drives to Customer 2 at (1320, 4082)
# [ 2] 19:13:41.7 Driver arrived at Customer 2 at (1320, 4082)
# [ 2] 19:13:43.6 Customer 2 at (1320, 4082) answers door
# [ 2] 19:13:43.6 Customer 2 at (1320, 4082) accepts Parcel 63 for cust 2
# [ 2] 19:13:45.0 Customer 2 at (1320, 4082) signs off
# [ 2] 19:13:45.2 Driver drives to Customer 9 at (1650, 4500)
# [ 2] 19:16:44.7 Driver arrived at Customer 9 at (1650, 4500)
# [ 2] 19:16:48.0 Customer 9 at (1650, 4500) answers door
# [ 2] 19:16:48.0 Customer 9 at (1650, 4500) accepts Parcel 68 for cust 9
# [ 2] 19:16:48.7 Customer 9 at (1650, 4500) signs off
# [ 2] 19:16:54.2 Driver drives to Customer 13 at (1798, 4500)
# [ 2] 19:17:29.7 Driver arrived at Customer 13 at (1798, 4500)
# [ 2] 19:18:01.7 Customer 13 at (1798, 4500) answers door
# [ 2] 19:18:01.7 Customer 13 at (1798, 4500) accepts Parcel 124 for cust 13
# [ 2] 19:18:15.2 Customer 13 at (1798, 4500) accepts Parcel 125 for cust 13
# [ 2] 19:18:16.7 Customer 13 at (1798, 4500) signs off
# [ 2] 19:18:22.2 Driver drives to Customer 18 at (2033, 4500)
# [ 2] 19:19:18.6 Driver arrived at Customer 18 at (2033, 4500)
# [ 2] 19:19:59.1 Customer 18 at (2033, 4500) answers door
# [ 2] 19:19:59.1 Customer 18 at (2033, 4500) accepts Parcel 74 for cust 18
# [ 2] 19:20:00.0 Customer 18 at (2033, 4500) signs off
# [ 2] 19:20:05.9 Driver drives to Customer 22 at (2169, 4500)
# [ 2] 19:20:38.6 Driver arrived at Customer 22 at (2169, 4500)
# [ 2] 19:20:57.0 Customer 22 at (2169, 4500) answers door
# [ 2] 19:20:57.0 Customer 22 at (2169, 4500) accepts Parcel 76 for cust 22
# [ 2] 19:21:26.7 Customer 22 at (2169, 4500) signs off
# [ 2] 19:21:27.3 Driver drives to Customer 24 at (2251, 4500)
# [ 2] 19:21:47.0 Driver arrived at Customer 24 at (2251, 4500)
# [ 2] 19:22:08.0 Customer 24 at (2251, 4500) answers door
# [ 2] 19:22:08.0 Customer 24 at (2251, 4500) accepts Parcel 77 for cust 24
# [ 2] 19:22:13.4 Customer 24 at (2251, 4500) accepts Parcel 132 for cust 24
# [ 2] 19:22:26.5 Customer 24 at (2251, 4500) signs off
# [ 2] 19:22:30.3 Driver drives to Customer 37 at (3440, 4175)
# [ 2] 19:28:33.7 Driver arrived at Customer 37 at (3440, 4175)
# [ 2] 19:28:42.8 Customer 37 at (3440, 4175) answers door
# [ 2] 19:28:42.8 Customer 37 at (3440, 4175) accepts Parcel 138 for cust 37
# [ 2] 19:28:46.3 Customer 37 at (3440, 4175) accepts Parcel 139 for cust 37
# [ 2] 19:28:52.6 Customer 37 at (3440, 4175) signs off
# [ 2] 19:29:22.7 Driver drives to Customer 45 at (3981, 3440)
# [ 2] 19:34:28.9 Driver arrived at Customer 45 at (3981, 3440)
# [ 2] 19:35:32.6 Customer 45 at (3981, 3440) answers door
# [ 2] 19:35:32.6 Customer 45 at (3981, 3440) accepts Parcel 141 for cust 45
# [ 2] 19:35:35.8 Customer 45 at (3981, 3440) signs off
# [ 2] 19:35:44.0 Driver drives to Customer 52 at (4718, 3220)
# [ 2] 19:39:02.7 Driver arrived at Customer 52 at (4718, 3220)
# [ 2] 19:39:49.3 Customer 52 at (4718, 3220) answers door
# [ 2] 19:39:49.3 Customer 52 at (4718, 3220) accepts Parcel 144 for cust 52
# [ 2] 19:40:05.2 Customer 52 at (4718, 3220) signs off
# [ 2] 19:40:11.1 Driver drives to Customer 56 at (5106, 2833)
# [ 2] 19:42:22.6 Driver arrived at Customer 56 at (5106, 2833)
# [ 2] 19:42:43.0 Customer 56 at (5106, 2833) answers door
# [ 2] 19:42:43.0 Customer 56 at (5106, 2833) accepts Parcel 145 for cust 56
# [ 2] 19:42:57.6 Customer 56 at (5106, 2833) signs off
# [ 2] 19:43:03.2 Driver drives to Customer 64 at (5560, 1912)
# [ 2] 19:47:29.4 Driver arrived at Customer 64 at (5560, 1912)
# [ 2] 19:47:40.8 Customer 64 at (5560, 1912) answers door
# [ 2] 19:47:40.8 Customer 64 at (5560, 1912) accepts Parcel 153 for cust 64
# [ 2] 19:47:46.8 Customer 64 at (5560, 1912) signs off
# [ 2] 19:48:14.5 Driver drives to Customer 79 at (6105, 2925)
# [ 2] 19:53:11.6 Driver arrived at Customer 79 at (6105, 2925)
# [ 2] 19:53:17.8 Customer 79 at (6105, 2925) answers door
# [ 2] 19:53:17.8 Customer 79 at (6105, 2925) accepts Parcel 159 for cust 79
# [ 2] 19:53:24.0 Customer 79 at (6105, 2925) signs off
# [ 2] 19:53:34.1 Driver drives to Customer 82 at (6207, 3027)
# [ 2] 19:54:08.7 Driver arrived at Customer 82 at (6207, 3027)
# [ 2] 19:54:35.1 Customer 82 at (6207, 3027) answers door
# [ 2] 19:54:35.1 Customer 82 at (6207, 3027) accepts Parcel 161 for cust 82
# [ 2] 19:54:37.4 Customer 82 at (6207, 3027) signs off
# [ 2] 19:54:37.4 Driver drives to Customer 83 at (6267, 3087)
# [ 2] 19:54:57.5 Driver arrived at Customer 83 at (6267, 3087)
# [ 2] 19:55:45.6 Customer 83 at (6267, 3087) answers door
# [ 2] 19:55:45.6 Customer 83 at (6267, 3087) accepts Parcel 162 for cust 83
# [ 2] 19:55:55.2 Customer 83 at (6267, 3087) accepts Parcel 163 for cust 83
# [ 2] 19:55:55.3 Customer 83 at (6267, 3087) signs off
# [ 2] 19:55:58.8 Driver drives to Customer 85 at (6340, 3160)
# [ 2] 19:56:23.6 Driver arrived at Customer 85 at (6340, 3160)
# [ 2] 19:57:22.1 Customer 85 at (6340, 3160) answers door
# [ 2] 19:57:22.1 Customer 85 at (6340, 3160) accepts Parcel 164 for cust 85
# [ 2] 19:57:32.0 Customer 85 at (6340, 3160) signs off
# [ 2] 19:57:39.9 Driver drives to Customer 88 at (6439, 3259)
# [ 2] 19:58:13.5 Driver arrived at Customer 88 at (6439, 3259)
# [ 2] 19:58:20.3 Customer 88 at (6439, 3259) answers door
# [ 2] 19:58:20.3 Customer 88 at (6439, 3259) accepts Parcel 112 for cust 88
# [ 2] 19:58:32.5 Customer 88 at (6439, 3259) signs off
# [ 2] 19:58:38.9 Driver drives to Customer 93 at (7680, 2699)
# [ 2] 20:06:52.4 Driver arrived at Customer 93 at (7680, 2699)
# [ 2] 20:07:37.7 Customer 93 at (7680, 2699) answers door
# [ 2] 20:07:37.7 Customer 93 at (7680, 2699) accepts Parcel 114 for cust 93
# [ 2] 20:07:52.0 Customer 93 at (7680, 2699) accepts Parcel 168 for cust 93
# [ 2] 20:07:54.6 Customer 93 at (7680, 2699) signs off
# [ 2] 20:08:09.0 Driver drives to Customer 94 at (8016, 2380)
# [ 2] 20:10:46.2 Driver arrived at Customer 94 at (8016, 2380)
# [ 2] 20:10:59.3 Customer 94 at (8016, 2380) answers door
# [ 2] 20:10:59.3 Customer 94 at (8016, 2380) accepts Parcel 115 for cust 94
# [ 2] 20:11:40.7 Customer 94 at (8016, 2380) accepts Parcel 116 for cust 94
# [ 2] 20:11:42.0 Customer 94 at (8016, 2380) accepts Parcel 117 for cust 94
# [ 2] 20:12:03.5 Customer 94 at (8016, 2380) signs off
# [ 2] 20:12:03.9 Driver drives to Customer 95 at (8326, 2380)
# [ 2] 20:13:18.3 Driver arrived at Customer 95 at (8326, 2380)
# [ 2] 20:13:30.2 Customer 95 at (8326, 2380) answers door
# [ 2] 20:13:30.2 Customer 95 at (8326, 2380) accepts Parcel 56 for cust 95
# [ 2] 20:13:37.6 Customer 95 at (8326, 2380) accepts Parcel 57 for cust 95
# [ 2] 20:13:46.3 Customer 95 at (8326, 2380) accepts Parcel 58 for cust 95
# [ 2] 20:13:51.4 Customer 95 at (8326, 2380) accepts Parcel 169 for cust 95
# [ 2] 20:13:52.5 Customer 95 at (8326, 2380) signs off
# [ 2] 20:13:55.4 Driver drives to Customer 98 at (8592, 2380)
# [ 2] 20:14:59.2 Driver arrived at Customer 98 at (8592, 2380)
# [ 2] 20:15:12.6 Customer 98 at (8592, 2380) answers door
# [ 2] 20:15:12.6 Customer 98 at (8592, 2380) accepts Parcel 60 for cust 98
# [ 2] 20:15:26.6 Customer 98 at (8592, 2380) signs off
# [ 2] 20:15:50.6 Driver drives to Customer 96 at (8352, 4112)
# [ 2] 20:27:31.9 Driver arrived at Customer 96 at (8352, 4112)
# [ 2] 20:28:08.0 Customer 96 at (8352, 4112) answers door
# [ 2] 20:28:08.0 Customer 96 at (8352, 4112) accepts Parcel 118 for cust 96
# [ 2] 20:28:08.4 Customer 96 at (8352, 4112) signs off
# [ 2] 20:28:24.1 Driver drives to Customer 97 at (8543, 4303)
# [ 2] 20:29:28.9 Driver arrived at Customer 97 at (8543, 4303)
# [ 2] 20:29:43.5 Customer 97 at (8543, 4303) answers door
# [ 2] 20:29:43.5 Customer 97 at (8543, 4303) accepts Parcel 59 for cust 97
# [ 2] 20:29:47.7 Customer 97 at (8543, 4303) signs off
# [ 2] 20:29:55.2 Driver drives to Customer 99 at (8673, 4433)
# [ 2] 20:30:39.1 Driver arrived at Customer 99 at (8673, 4433)
# [ 2] 20:30:50.6 Customer 99 at (8673, 4433) answers door
# [ 2] 20:30:50.6 Customer 99 at (8673, 4433) accepts Parcel 61 for cust 99
# [ 2] 20:31:15.8 Customer 99 at (8673, 4433) signs off
# [ 2] 20:31:17.6 Driver returns to delivery centre
# [ 2] 21:01:36.1 Driver arrived at delivery centre
# [ 2] 21:01:36.1 46 parcels left for next day
# [ 2] 21:11:36.1 Driver goes home
# [ 3] 17:00:00.0 Parcel 170 for cust 0 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 171 for cust 1 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 172 for cust 2 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 173 for cust 8 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 174 for cust 12 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 175 for cust 17 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 176 for cust 17 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 177 for cust 19 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 178 for cust 22 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 179 for cust 22 arr at delivery centre
# ...
# [ 3] 18:00:00.0 Parcel 151 for cust 62 out for delivery
# [ 3] 18:00:00.0 Parcel 149 for cust 61 out for delivery
# [ 3] 18:00:00.0 Parcel 150 for cust 61 out for delivery
# [ 3] 18:00:00.0 Parcel 207 for cust 61 out for delivery
# [ 3] 18:00:00.0 Parcel 148 for cust 60 out for delivery
# [ 3] 18:00:00.0 Parcel 206 for cust 60 out for delivery
# [ 3] 18:00:00.0 Parcel 79 for cust 32 out for delivery
# [ 3] 18:00:00.0 Parcel 134 for cust 32 out for delivery
# [ 3] 18:00:00.0 Parcel 185 for cust 29 out for delivery
# [ 3] 18:00:00.0 Parcel 78 for cust 28 out for delivery
# [ 3] 18:00:00.0 Parcel 133 for cust 28 out for delivery
# [ 3] 18:00:00.0 Parcel 129 for cust 20 out for delivery
# [ 3] 18:00:00.0 Parcel 70 for cust 14 out for delivery
# [ 3] 18:00:00.0 Parcel 71 for cust 14 out for delivery
# [ 3] 18:00:00.0 Parcel 126 for cust 14 out for delivery
# [ 3] 18:00:00.0 Parcel 184 for cust 26 out for delivery
# [ 3] 18:00:00.0 Parcel 128 for cust 17 out for delivery
# [ 3] 18:00:00.0 Parcel 175 for cust 17 out for delivery
# [ 3] 18:00:00.0 Parcel 176 for cust 17 out for delivery
# [ 3] 18:00:00.0 Parcel 121 for cust 6 out for delivery
# [ 3] 18:00:00.0 Parcel 172 for cust 2 out for delivery
# [ 3] 18:00:00.0 Parcel 122 for cust 7 out for delivery
# [ 3] 18:00:00.0 Parcel 67 for cust 8 out for delivery
# [ 3] 18:00:00.0 Parcel 123 for cust 8 out for delivery
# [ 3] 18:00:00.0 Parcel 173 for cust 8 out for delivery
# [ 3] 18:00:00.0 Parcel 69 for cust 11 out for delivery
# [ 3] 18:00:00.0 Parcel 73 for cust 16 out for delivery
# [ 3] 18:00:00.0 Parcel 127 for cust 16 out for delivery
# [ 3] 18:00:00.0 Parcel 75 for cust 19 out for delivery
# [ 3] 18:00:00.0 Parcel 177 for cust 19 out for delivery
# [ 3] 18:00:00.0 Parcel 135 for cust 35 out for delivery
# [ 3] 18:00:00.0 Parcel 136 for cust 35 out for delivery
# [ 3] 18:00:00.0 Parcel 80 for cust 36 out for delivery
# [ 3] 18:00:00.0 Parcel 137 for cust 36 out for delivery
# [ 3] 18:00:00.0 Parcel 83 for cust 41 out for delivery
# [ 3] 18:00:00.0 Parcel 140 for cust 41 out for delivery
# [ 3] 18:00:00.0 Parcel 193 for cust 41 out for delivery
# [ 3] 18:00:00.0 Parcel 82 for cust 40 out for delivery
# [ 3] 18:00:00.0 Parcel 191 for cust 40 out for delivery
# [ 3] 18:00:00.0 Parcel 192 for cust 40 out for delivery
# [ 3] 18:00:00.0 Parcel 86 for cust 46 out for delivery
# [ 3] 18:00:00.0 Parcel 87 for cust 46 out for delivery
# [ 3] 18:00:00.0 Parcel 88 for cust 46 out for delivery
# [ 3] 18:00:00.0 Parcel 201 for cust 54 out for delivery
# [ 3] 18:00:00.0 Parcel 146 for cust 59 out for delivery
# [ 3] 18:00:00.0 Parcel 147 for cust 59 out for delivery
# [ 3] 18:00:00.0 Parcel 143 for cust 51 out for delivery
# [ 3] 18:00:00.0 Parcel 197 for cust 51 out for delivery
# [ 3] 18:00:00.0 Parcel 198 for cust 51 out for delivery
# [ 3] 18:00:00.0 Parcel 142 for cust 49 out for delivery
# [ 3] 18:00:00.0 Parcel 200 for cust 53 out for delivery
# [ 3] 18:00:00.0 Parcel 96 for cust 57 out for delivery
# [ 3] 18:00:00.0 Parcel 202 for cust 57 out for delivery
# [ 3] 18:00:00.0 Parcel 194 for cust 44 out for delivery
# [ 3] 18:50:00.0 Driver leaves for delivery of 60 parcels to 35 customers
# [ 3] 18:50:00.0 Length of delivery tour: 29,946m
# [ 3] 18:50:00.0 Driver drives to Customer 37 at (3440, 4175)
# [ 3] 18:51:18.0 Driver arrived at Customer 37 at (3440, 4175)
# [ 3] 18:51:39.4 Customer 37 at (3440, 4175) answers door
# [ 3] 18:51:39.4 Customer 37 at (3440, 4175) accepts Parcel 187 for cust 37
# [ 3] 18:51:42.9 Customer 37 at (3440, 4175) signs off
# [ 3] 18:51:50.2 Driver drives to Customer 45 at (3981, 3440)
# [ 3] 18:56:56.4 Driver arrived at Customer 45 at (3981, 3440)
# [ 3] 18:57:30.6 Customer 45 at (3981, 3440) answers door
# [ 3] 18:57:30.6 Customer 45 at (3981, 3440) accepts Parcel 195 for cust 45
# [ 3] 18:57:40.4 Customer 45 at (3981, 3440) signs off
# [ 3] 18:57:48.0 Driver drives to Customer 47 at (4173, 3440)
# [ 3] 18:58:34.1 Driver arrived at Customer 47 at (4173, 3440)
# [ 3] 18:58:55.2 Customer 47 at (4173, 3440) answers door
# [ 3] 18:58:55.2 Customer 47 at (4173, 3440) accepts Parcel 196 for cust 47
# [ 3] 18:59:05.3 Customer 47 at (4173, 3440) signs off
# [ 3] 18:59:10.5 Driver drives to Customer 52 at (4718, 3220)
# [ 3] 19:01:43.1 Driver arrived at Customer 52 at (4718, 3220)
# [ 3] 19:02:43.4 Customer 52 at (4718, 3220) answers door
# [ 3] 19:02:43.4 Customer 52 at (4718, 3220) accepts Parcel 199 for cust 52
# [ 3] 19:02:58.9 Customer 52 at (4718, 3220) signs off
# [ 3] 19:03:02.4 Driver drives to Customer 65 at (5560, 2199)
# [ 3] 19:08:31.2 Driver arrived at Customer 65 at (5560, 2199)
# [ 3] 19:08:49.8 Customer 65 at (5560, 2199) answers door
# [ 3] 19:08:49.8 Customer 65 at (5560, 2199) accepts Parcel 208 for cust 65
# [ 3] 19:08:59.7 Customer 65 at (5560, 2199) signs off
# [ 3] 19:09:01.4 Driver drives to Customer 63 at (5560, 1564)
# [ 3] 19:11:33.8 Driver arrived at Customer 63 at (5560, 1564)
# [ 3] 19:12:21.6 Customer 63 at (5560, 1564) answers door
# [ 3] 19:12:21.6 Customer 63 at (5560, 1564) accepts Parcel 152 for cust 63
# [ 3] 19:12:26.4 Customer 63 at (5560, 1564) signs off
# [ 3] 19:12:35.3 Driver drives to Customer 62 at (5560, 1408)
# [ 3] 19:13:12.8 Driver arrived at Customer 62 at (5560, 1408)
# [ 3] 19:13:18.8 Customer 62 at (5560, 1408) answers door
# [ 3] 19:13:18.8 Customer 62 at (5560, 1408) accepts Parcel 151 for cust 62
# [ 3] 19:13:29.8 Customer 62 at (5560, 1408) signs off
# [ 3] 19:13:34.2 Driver drives to Customer 61 at (5363, 1123)
# [ 3] 19:15:02.0 Driver arrived at Customer 61 at (5363, 1123)
# [ 3] 19:15:27.6 Customer 61 at (5363, 1123) answers door
# [ 3] 19:15:27.6 Customer 61 at (5363, 1123) accepts Parcel 149 for cust 61
# [ 3] 19:15:33.0 Customer 61 at (5363, 1123) accepts Parcel 150 for cust 61
# [ 3] 19:15:39.5 Customer 61 at (5363, 1123) accepts Parcel 207 for cust 61
# [ 3] 19:15:51.3 Customer 61 at (5363, 1123) signs off
# [ 3] 19:15:55.2 Driver drives to Customer 60 at (5273, 1033)
# [ 3] 19:16:25.6 Driver arrived at Customer 60 at (5273, 1033)
# [ 3] 19:17:07.9 Customer 60 at (5273, 1033) answers door
# [ 3] 19:17:07.9 Customer 60 at (5273, 1033) accepts Parcel 148 for cust 60
# [ 3] 19:17:08.5 Customer 60 at (5273, 1033) accepts Parcel 206 for cust 60
# [ 3] 19:17:12.1 Customer 60 at (5273, 1033) signs off
# [ 3] 19:17:25.7 Driver drives to Customer 32 at (2738, 2738)
# [ 3] 19:37:29.3 Driver arrived at Customer 32 at (2738, 2738)
# [ 3] 19:37:31.5 Customer 32 at (2738, 2738) answers door
# [ 3] 19:37:31.5 Customer 32 at (2738, 2738) accepts Parcel 79 for cust 32
# [ 3] 19:37:41.2 Customer 32 at (2738, 2738) accepts Parcel 134 for cust 32
# [ 3] 19:37:41.4 Customer 32 at (2738, 2738) signs off
# [ 3] 19:37:47.8 Driver drives to Customer 29 at (2380, 1941)
# [ 3] 19:41:34.6 Driver arrived at Customer 29 at (2380, 1941)
# [ 3] 19:43:02.4 Customer 29 at (2380, 1941) answers door
# [ 3] 19:43:02.4 Customer 29 at (2380, 1941) accepts Parcel 185 for cust 29
# [ 3] 19:43:02.5 Customer 29 at (2380, 1941) signs off
# [ 3] 19:43:10.0 Driver drives to Customer 28 at (2380, 1549)
# [ 3] 19:44:44.0 Driver arrived at Customer 28 at (2380, 1549)
# [ 3] 19:44:46.8 Customer 28 at (2380, 1549) answers door
# [ 3] 19:44:46.8 Customer 28 at (2380, 1549) accepts Parcel 78 for cust 28
# [ 3] 19:45:07.0 Customer 28 at (2380, 1549) accepts Parcel 133 for cust 28
# [ 3] 19:45:18.6 Customer 28 at (2380, 1549) signs off
# [ 3] 19:45:32.1 Driver drives to Customer 20 at (2080, 1320)
# [ 3] 19:47:39.1 Driver arrived at Customer 20 at (2080, 1320)
# [ 3] 19:48:23.3 Customer 20 at (2080, 1320) answers door
# [ 3] 19:48:23.3 Customer 20 at (2080, 1320) accepts Parcel 129 for cust 20
# [ 3] 19:48:23.4 Customer 20 at (2080, 1320) signs off
# [ 3] 19:48:23.8 Driver drives to Customer 14 at (1896, 1320)
# [ 3] 19:49:08.0 Driver arrived at Customer 14 at (1896, 1320)
# [ 3] 19:49:46.7 Customer 14 at (1896, 1320) answers door
# [ 3] 19:49:46.7 Customer 14 at (1896, 1320) accepts Parcel 70 for cust 14
# [ 3] 19:51:07.4 Customer 14 at (1896, 1320) accepts Parcel 71 for cust 14
# [ 3] 19:51:28.0 Customer 14 at (1896, 1320) accepts Parcel 126 for cust 14
# [ 3] 19:51:40.1 Customer 14 at (1896, 1320) signs off
# [ 3] 19:51:53.0 Driver drives to Customer 26 at (2275, 2484)
# [ 3] 19:58:38.9 Driver arrived at Customer 26 at (2275, 2484)
# [ 3] 19:58:49.2 Customer 26 at (2275, 2484) answers door
# [ 3] 19:58:49.2 Customer 26 at (2275, 2484) accepts Parcel 184 for cust 26
# [ 3] 19:59:03.1 Customer 26 at (2275, 2484) signs off
# [ 3] 19:59:06.5 Driver drives to Customer 17 at (1951, 2807)
# [ 3] 20:00:56.2 Driver arrived at Customer 17 at (1951, 2807)
# [ 3] 20:01:00.6 Customer 17 at (1951, 2807) answers door
# [ 3] 20:01:00.6 Customer 17 at (1951, 2807) accepts Parcel 128 for cust 17
# [ 3] 20:01:06.8 Customer 17 at (1951, 2807) accepts Parcel 175 for cust 17
# [ 3] 20:01:10.8 Customer 17 at (1951, 2807) accepts Parcel 176 for cust 17
# [ 3] 20:01:12.7 Customer 17 at (1951, 2807) signs off
# [ 3] 20:01:18.1 Driver drives to Customer 6 at (1434, 3325)
# [ 3] 20:04:13.6 Driver arrived at Customer 6 at (1434, 3325)
# [ 3] 20:05:44.6 Customer 6 at (1434, 3325) answers door
# [ 3] 20:05:44.6 Customer 6 at (1434, 3325) accepts Parcel 121 for cust 6
# [ 3] 20:05:50.3 Customer 6 at (1434, 3325) signs off
# [ 3] 20:05:56.2 Driver drives to Customer 2 at (1320, 4082)
# [ 3] 20:09:08.9 Driver arrived at Customer 2 at (1320, 4082)
# [ 3] 20:09:58.3 Customer 2 at (1320, 4082) answers door
# [ 3] 20:09:58.3 Customer 2 at (1320, 4082) accepts Parcel 172 for cust 2
# [ 3] 20:10:05.7 Customer 2 at (1320, 4082) signs off
# [ 3] 20:10:07.1 Driver drives to Customer 7 at (1449, 7680)
# [ 3] 20:25:01.6 Driver arrived at Customer 7 at (1449, 7680)
# [ 3] 20:26:38.1 Customer 7 at (1449, 7680) answers door
# [ 3] 20:26:38.1 Customer 7 at (1449, 7680) accepts Parcel 122 for cust 7
# [ 3] 20:26:43.9 Customer 7 at (1449, 7680) signs off
# [ 3] 20:26:59.5 Driver drives to Customer 8 at (1550, 7680)
# [ 3] 20:27:23.8 Driver arrived at Customer 8 at (1550, 7680)
# [ 3] 20:27:43.5 Customer 8 at (1550, 7680) answers door
# [ 3] 20:27:43.5 Customer 8 at (1550, 7680) accepts Parcel 67 for cust 8
# [ 3] 20:27:59.9 Customer 8 at (1550, 7680) accepts Parcel 123 for cust 8
# [ 3] 20:28:04.8 Customer 8 at (1550, 7680) accepts Parcel 173 for cust 8
# [ 3] 20:28:07.3 Customer 8 at (1550, 7680) signs off
# [ 3] 20:28:09.5 Driver drives to Customer 11 at (1664, 7680)
# [ 3] 20:28:36.9 Driver arrived at Customer 11 at (1664, 7680)
# [ 3] 20:30:29.4 Customer 11 at (1664, 7680) answers door
# [ 3] 20:30:29.4 Customer 11 at (1664, 7680) accepts Parcel 69 for cust 11
# [ 3] 20:30:38.3 Customer 11 at (1664, 7680) signs off
# [ 3] 20:30:38.8 Driver drives to Customer 16 at (1914, 7680)
# [ 3] 20:31:38.8 Driver arrived at Customer 16 at (1914, 7680)
# [ 3] 20:31:58.4 Customer 16 at (1914, 7680) answers door
# [ 3] 20:31:58.4 Customer 16 at (1914, 7680) accepts Parcel 73 for cust 16
# [ 3] 20:32:01.1 Customer 16 at (1914, 7680) accepts Parcel 127 for cust 16
# [ 3] 20:32:02.0 Customer 16 at (1914, 7680) signs off
# [ 3] 20:32:04.1 Driver drives to Customer 19 at (2066, 7680)
# [ 3] 20:32:40.5 Driver arrived at Customer 19 at (2066, 7680)
# [ 3] 20:32:42.9 Customer 19 at (2066, 7680) answers door
# [ 3] 20:32:42.9 Customer 19 at (2066, 7680) accepts Parcel 75 for cust 19
# [ 3] 20:32:53.0 Customer 19 at (2066, 7680) accepts Parcel 177 for cust 19
# [ 3] 20:32:54.9 Customer 19 at (2066, 7680) signs off
# [ 3] 20:33:04.4 Driver drives to Customer 35 at (3194, 7680)
# [ 3] 20:40:48.1 Driver arrived at Customer 35 at (3194, 7680)
# [ 3] 20:41:26.0 Customer 35 at (3194, 7680) answers door
# [ 3] 20:41:26.0 Customer 35 at (3194, 7680) accepts Parcel 135 for cust 35
# [ 3] 20:41:38.2 Customer 35 at (3194, 7680) accepts Parcel 136 for cust 35
# [ 3] 20:41:45.4 Customer 35 at (3194, 7680) signs off
# [ 3] 20:41:48.7 Driver drives to Customer 36 at (3313, 7680)
# [ 3] 20:42:17.3 Driver arrived at Customer 36 at (3313, 7680)
# [ 3] 20:43:41.2 Customer 36 at (3313, 7680) answers door
# [ 3] 20:43:41.2 Customer 36 at (3313, 7680) accepts Parcel 80 for cust 36
# [ 3] 20:43:45.6 Customer 36 at (3313, 7680) accepts Parcel 137 for cust 36
# [ 3] 20:43:51.7 Customer 36 at (3313, 7680) signs off
# [ 3] 20:44:01.7 Driver drives to Customer 41 at (3440, 6850)
# [ 3] 20:47:51.4 Driver arrived at Customer 41 at (3440, 6850)
# [ 3] 20:48:20.4 Customer 41 at (3440, 6850) answers door
# [ 3] 20:48:20.4 Customer 41 at (3440, 6850) accepts Parcel 83 for cust 41
# [ 3] 20:48:51.8 Customer 41 at (3440, 6850) accepts Parcel 140 for cust 41
# [ 3] 20:49:22.7 Customer 41 at (3440, 6850) accepts Parcel 193 for cust 41
# [ 3] 20:49:49.3 Customer 41 at (3440, 6850) signs off
# [ 3] 20:50:16.5 Driver drives to Customer 40 at (3440, 6776)
# [ 3] 20:50:34.2 Driver arrived at Customer 40 at (3440, 6776)
# [ 3] 20:51:09.0 Customer 40 at (3440, 6776) answers door
# [ 3] 20:51:09.0 Customer 40 at (3440, 6776) accepts Parcel 82 for cust 40
# [ 3] 20:51:15.8 Customer 40 at (3440, 6776) accepts Parcel 191 for cust 40
# [ 3] 20:51:27.9 Customer 40 at (3440, 6776) accepts Parcel 192 for cust 40
# [ 3] 20:51:30.4 Customer 40 at (3440, 6776) signs off
# [ 3] 20:51:33.5 Driver drives to Customer 46 at (3984, 6620)
# [ 3] 20:54:21.5 Driver arrived at Customer 46 at (3984, 6620)
# [ 3] 20:54:23.3 Customer 46 at (3984, 6620) answers door
# [ 3] 20:54:23.3 Customer 46 at (3984, 6620) accepts Parcel 86 for cust 46
# [ 3] 20:54:25.0 Customer 46 at (3984, 6620) accepts Parcel 87 for cust 46
# [ 3] 20:54:25.1 Customer 46 at (3984, 6620) accepts Parcel 88 for cust 46
# [ 3] 20:54:35.7 Customer 46 at (3984, 6620) signs off
# [ 3] 20:54:37.2 Driver drives to Customer 54 at (4955, 6620)
# [ 3] 20:58:30.3 Driver arrived at Customer 54 at (4955, 6620)
# [ 3] 20:59:32.1 Customer 54 at (4955, 6620) answers door
# [ 3] 20:59:32.1 Customer 54 at (4955, 6620) accepts Parcel 201 for cust 54
# [ 3] 20:59:43.5 Customer 54 at (4955, 6620) signs off
# [ 3] 21:00:18.8 Driver drives to Customer 59 at (5249, 6620)
# [ 3] 21:01:29.3 Driver arrived at Customer 59 at (5249, 6620)
# [ 3] 21:01:49.5 Customer 59 at (5249, 6620) answers door
# [ 3] 21:01:49.5 Customer 59 at (5249, 6620) accepts Parcel 146 for cust 59
# [ 3] 21:02:15.0 Customer 59 at (5249, 6620) accepts Parcel 147 for cust 59
# [ 3] 21:02:21.0 Customer 59 at (5249, 6620) signs off
# [ 3] 21:02:25.1 Driver drives to Customer 51 at (4500, 6463)
# [ 3] 21:06:02.6 Driver arrived at Customer 51 at (4500, 6463)
# [ 3] 21:06:06.9 Customer 51 at (4500, 6463) answers door
# [ 3] 21:06:06.9 Customer 51 at (4500, 6463) accepts Parcel 143 for cust 51
# [ 3] 21:06:28.3 Customer 51 at (4500, 6463) accepts Parcel 197 for cust 51
# [ 3] 21:06:44.2 Customer 51 at (4500, 6463) accepts Parcel 198 for cust 51
# [ 3] 21:06:48.1 Customer 51 at (4500, 6463) signs off
# [ 3] 21:06:54.2 Driver drives to Customer 49 at (4500, 6156)
# [ 3] 21:08:07.8 Driver arrived at Customer 49 at (4500, 6156)
# [ 3] 21:08:23.6 Customer 49 at (4500, 6156) answers door
# [ 3] 21:08:23.6 Customer 49 at (4500, 6156) accepts Parcel 142 for cust 49
# [ 3] 21:08:23.9 Customer 49 at (4500, 6156) signs off
# [ 3] 21:08:24.3 Driver drives to Customer 53 at (4722, 5560)
# [ 3] 21:11:40.6 Driver arrived at Customer 53 at (4722, 5560)
# [ 3] 21:11:59.0 Customer 53 at (4722, 5560) answers door
# [ 3] 21:11:59.0 Customer 53 at (4722, 5560) accepts Parcel 200 for cust 53
# [ 3] 21:12:01.4 Customer 53 at (4722, 5560) signs off
# [ 3] 21:12:08.8 Driver drives to Customer 57 at (5209, 5560)
# [ 3] 21:14:05.7 Driver arrived at Customer 57 at (5209, 5560)
# [ 3] 21:14:14.0 Customer 57 at (5209, 5560) answers door
# [ 3] 21:14:14.0 Customer 57 at (5209, 5560) accepts Parcel 96 for cust 57
# [ 3] 21:14:16.3 Customer 57 at (5209, 5560) accepts Parcel 202 for cust 57
# [ 3] 21:14:27.4 Customer 57 at (5209, 5560) signs off
# [ 3] 21:14:40.8 Driver drives to Customer 44 at (3855, 4915)
# [ 3] 21:21:09.8 Driver arrived at Customer 44 at (3855, 4915)
# [ 3] 21:21:24.8 Customer 44 at (3855, 4915) answers door
# [ 3] 21:21:24.8 Customer 44 at (3855, 4915) accepts Parcel 194 for cust 44
# [ 3] 21:21:44.4 Customer 44 at (3855, 4915) signs off
# [ 3] 21:21:47.4 Driver returns to delivery centre
# [ 3] 21:24:08.0 Driver arrived at delivery centre
# [ 3] 21:24:08.0 43 parcels left for next day
# [ 3] 21:34:08.0 Driver goes home
# Delivery Centre Inventory: 43 parcels

# %%
import pickle
with open('testData.pickled', 'rb') as f:
    MX, CX = pickle.load(f)

# %%
WX = generateWarehouseLocation(MX)

# %%
rec4 = simulation(MX, WX, CX, p=0.15, days=7, log=True)
# Out:
# Simulating delivery of 14 parcels over 7 days to 20 customers
# [ 0] 18:00:00.0 Driver arrives for work
# [ 0] 18:00:00.0 Nothing to do today
# [ 0] 18:10:00.0 Driver goes home
# [ 1] 18:00:00.0 Driver arrives for work
# [ 1] 18:00:00.0 Nothing to do today
# [ 1] 18:10:00.0 Driver goes home
# [ 2] 17:00:00.0 Parcel 0 for cust 4 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 1 for cust 12 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 2 for cust 19 arr at delivery centre
# [ 2] 18:00:00.0 Driver arrives for work
# [ 2] 18:00:00.0 Parcel 2 for cust 19 out for delivery
# [ 2] 18:00:00.0 Parcel 0 for cust 4 out for delivery
# [ 2] 18:00:00.0 Parcel 1 for cust 12 out for delivery
# [ 2] 18:02:30.0 Driver leaves for delivery of 3 parcels to 3 customers
# [ 2] 18:02:30.0 Length of delivery tour: 22,650m
# [ 2] 18:02:30.0 Driver drives to Customer 19 at (7950, 3804)
# [ 2] 18:19:05.0 Driver arrived at Customer 19 at (7950, 3804)
# [ 2] 18:19:36.9 Customer 19 at (7950, 3804) answers door
# [ 2] 18:19:36.9 Customer 19 at (7950, 3804) accepts Parcel 2 for cust 19
# [ 2] 18:19:37.0 Customer 19 at (7950, 3804) signs off
# [ 2] 18:19:49.7 Driver drives to Customer 4 at (2200, 2395)
# [ 2] 18:52:53.8 Driver arrived at Customer 4 at (2200, 2395)
# [ 2] 18:53:14.2 Customer 4 at (2200, 2395) answers door
# [ 2] 18:53:14.2 Customer 4 at (2200, 2395) accepts Parcel 0 for cust 4
# [ 2] 18:53:31.6 Customer 4 at (2200, 2395) signs off
# [ 2] 18:53:42.6 Driver drives to Customer 12 at (4500, 7416)
# [ 2] 19:22:59.7 Driver arrived at Customer 12 at (4500, 7416)
# [ 2] 19:22:59.7 Customer 12 at (4500, 7416) answers door
# [ 2] 19:22:59.7 Customer 12 at (4500, 7416) accepts Parcel 1 for cust 12
# [ 2] 19:23:06.5 Customer 12 at (4500, 7416) signs off
# [ 2] 19:23:26.7 Driver returns to delivery centre
# [ 2] 19:35:06.6 Driver arrived at delivery centre
# [ 2] 19:35:06.6 0 parcels left for next day
# [ 2] 19:45:06.6 Driver goes home
# [ 3] 17:00:00.0 Parcel 3 for cust 2 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 4 for cust 3 arr at delivery centre
# [ 3] 18:00:00.0 Driver arrives for work
# [ 3] 18:00:00.0 Parcel 4 for cust 3 out for delivery
# [ 3] 18:00:00.0 Parcel 3 for cust 2 out for delivery
# [ 3] 18:01:40.0 Driver leaves for delivery of 2 parcels to 2 customers
# [ 3] 18:01:40.0 Length of delivery tour: 8,598m
# [ 3] 18:01:40.0 Driver drives to Customer 3 at (1561, 5650)
# [ 3] 18:18:01.4 Driver arrived at Customer 3 at (1561, 5650)
# [ 3] 18:18:12.5 Customer 3 at (1561, 5650) answers door
# [ 3] 18:18:12.5 Customer 3 at (1561, 5650) accepts Parcel 4 for cust 3
# [ 3] 18:18:16.5 Customer 3 at (1561, 5650) signs off
# [ 3] 18:18:36.9 Driver drives to Customer 2 at (1351, 5650)
# [ 3] 18:19:27.3 Driver arrived at Customer 2 at (1351, 5650)
# [ 3] 18:19:35.8 Customer 2 at (1351, 5650) answers door
# [ 3] 18:19:35.8 Customer 2 at (1351, 5650) accepts Parcel 3 for cust 2
# [ 3] 18:19:44.2 Customer 2 at (1351, 5650) signs off
# [ 3] 18:19:46.9 Driver returns to delivery centre
# [ 3] 18:36:58.7 Driver arrived at delivery centre
# [ 3] 18:36:58.7 0 parcels left for next day
# [ 3] 18:46:58.7 Driver goes home
# [ 4] 17:00:00.0 Parcel 5 for cust 6 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 6 for cust 15 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 7 for cust 15 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 8 for cust 18 arr at delivery centre
# [ 4] 18:00:00.0 Driver arrives for work
# [ 4] 18:00:00.0 Parcel 5 for cust 6 out for delivery
# [ 4] 18:00:00.0 Parcel 8 for cust 18 out for delivery
# [ 4] 18:00:00.0 Parcel 6 for cust 15 out for delivery
# [ 4] 18:00:00.0 Parcel 7 for cust 15 out for delivery
# [ 4] 18:03:20.0 Driver leaves for delivery of 4 parcels to 3 customers
# [ 4] 18:03:20.0 Length of delivery tour: 11,802m
# [ 4] 18:03:20.0 Driver drives to Customer 6 at (2200, 4047)
# [ 4] 18:14:20.7 Driver arrived at Customer 6 at (2200, 4047)
# [ 4] 18:16:37.8 Customer 6 at (2200, 4047) answers door
# [ 4] 18:16:37.8 Customer 6 at (2200, 4047) accepts Parcel 5 for cust 6
# [ 4] 18:16:54.1 Customer 6 at (2200, 4047) signs off
# [ 4] 18:17:00.0 Driver drives to Customer 18 at (7290, 4500)
# [ 4] 18:39:10.3 Driver arrived at Customer 18 at (7290, 4500)
# [ 4] 18:39:13.7 Customer 18 at (7290, 4500) answers door
# [ 4] 18:39:13.7 Customer 18 at (7290, 4500) accepts Parcel 8 for cust 18
# [ 4] 18:39:17.6 Customer 18 at (7290, 4500) signs off
# [ 4] 18:39:24.6 Driver drives to Customer 15 at (6800, 4858)
# [ 4] 18:42:48.2 Driver arrived at Customer 15 at (6800, 4858)
# [ 4] 18:44:36.2 Customer 15 at (6800, 4858) answers door
# [ 4] 18:44:36.2 Customer 15 at (6800, 4858) accepts Parcel 6 for cust 15
# [ 4] 18:44:37.3 Customer 15 at (6800, 4858) accepts Parcel 7 for cust 15
# [ 4] 18:44:45.4 Customer 15 at (6800, 4858) signs off
# [ 4] 18:44:57.6 Driver returns to delivery centre
# [ 4] 18:55:35.5 Driver arrived at delivery centre
# [ 4] 18:55:35.5 0 parcels left for next day
# [ 4] 19:05:35.5 Driver goes home
# [ 5] 17:00:00.0 Parcel 9 for cust 2 arr at delivery centre
# [ 5] 18:00:00.0 Driver arrives for work
# [ 5] 18:00:00.0 Parcel 9 for cust 2 out for delivery
# [ 5] 18:00:50.0 Driver leaves for delivery of 1 parcels to 1 customers
# [ 5] 18:00:50.0 Length of delivery tour: 8,598m
# [ 5] 18:00:50.0 Driver drives to Customer 2 at (1351, 5650)
# [ 5] 18:18:01.8 Driver arrived at Customer 2 at (1351, 5650)
# [ 5] 18:18:33.5 Customer 2 at (1351, 5650) answers door
# [ 5] 18:18:33.5 Customer 2 at (1351, 5650) accepts Parcel 9 for cust 2
# [ 5] 18:18:50.3 Customer 2 at (1351, 5650) signs off
# [ 5] 18:18:58.1 Driver returns to delivery centre
# [ 5] 18:36:09.9 Driver arrived at delivery centre
# [ 5] 18:36:09.9 0 parcels left for next day
# [ 5] 18:46:09.9 Driver goes home
# [ 6] 17:00:00.0 Parcel 10 for cust 4 arr at delivery centre
# [ 6] 17:00:00.0 Parcel 11 for cust 6 arr at delivery centre
# [ 6] 17:00:00.0 Parcel 12 for cust 7 arr at delivery centre
# [ 6] 17:00:00.0 Parcel 13 for cust 16 arr at delivery centre
# [ 6] 18:00:00.0 Driver arrives for work
# [ 6] 18:00:00.0 Parcel 13 for cust 16 out for delivery
# [ 6] 18:00:00.0 Parcel 12 for cust 7 out for delivery
# [ 6] 18:00:00.0 Parcel 11 for cust 6 out for delivery
# [ 6] 18:00:00.0 Parcel 10 for cust 4 out for delivery
# [ 6] 18:03:20.0 Driver leaves for delivery of 4 parcels to 4 customers
# [ 6] 18:03:20.0 Length of delivery tour: 13,690m
# [ 6] 18:03:20.0 Driver drives to Customer 16 at (6940, 4500)
# [ 6] 18:13:05.6 Driver arrived at Customer 16 at (6940, 4500)
# [ 6] 18:15:18.4 Customer 16 at (6940, 4500) answers door
# [ 6] 18:15:18.4 Customer 16 at (6940, 4500) accepts Parcel 13 for cust 16
# [ 6] 18:15:27.6 Customer 16 at (6940, 4500) signs off
# [ 6] 18:15:36.5 Driver drives to Customer 7 at (2664, 4500)
# [ 6] 18:32:42.7 Driver arrived at Customer 7 at (2664, 4500)
# [ 6] 18:33:06.3 Customer 7 at (2664, 4500) answers door
# [ 6] 18:33:06.3 Customer 7 at (2664, 4500) accepts Parcel 12 for cust 7
# [ 6] 18:33:15.4 Customer 7 at (2664, 4500) signs off
# [ 6] 18:33:20.2 Driver drives to Customer 6 at (2200, 4047)
# [ 6] 18:37:00.3 Driver arrived at Customer 6 at (2200, 4047)
# [ 6] 18:37:34.6 Customer 6 at (2200, 4047) answers door
# [ 6] 18:37:34.6 Customer 6 at (2200, 4047) accepts Parcel 11 for cust 6
# [ 6] 18:37:38.0 Customer 6 at (2200, 4047) signs off
# [ 6] 18:37:40.1 Driver drives to Customer 4 at (2200, 2395)
# [ 6] 18:44:16.6 Driver arrived at Customer 4 at (2200, 2395)
# [ 6] 18:44:24.9 Customer 4 at (2200, 2395) answers door
# [ 6] 18:44:24.9 Customer 4 at (2200, 2395) accepts Parcel 10 for cust 4
# [ 6] 18:44:34.3 Customer 4 at (2200, 2395) signs off
# [ 6] 18:44:45.0 Driver returns to delivery centre
# [ 6] 19:02:22.2 Driver arrived at delivery centre
# [ 6] 19:02:22.2 0 parcels left for next day
# [ 6] 19:12:22.2 Driver goes home

# %%
rec5 = simulation(MX, WX, CX, p=1.2, days=7, log=True)
# Out:
# Simulating delivery of 151 parcels over 7 days to 20 customers
# [ 0] 17:00:00.0 Parcel 0 for cust 5 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 1 for cust 6 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 2 for cust 6 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 3 for cust 7 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 4 for cust 7 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 5 for cust 8 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 6 for cust 13 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 7 for cust 13 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 8 for cust 15 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 9 for cust 16 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 10 for cust 16 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 11 for cust 16 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 12 for cust 17 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 13 for cust 17 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 14 for cust 18 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 15 for cust 19 arr at delivery centre
# [ 0] 18:00:00.0 Driver arrives for work
# [ 0] 18:00:00.0 Parcel 8 for cust 15 out for delivery
# [ 0] 18:00:00.0 Parcel 9 for cust 16 out for delivery
# [ 0] 18:00:00.0 Parcel 10 for cust 16 out for delivery
# [ 0] 18:00:00.0 Parcel 11 for cust 16 out for delivery
# [ 0] 18:00:00.0 Parcel 12 for cust 17 out for delivery
# [ 0] 18:00:00.0 Parcel 13 for cust 17 out for delivery
# [ 0] 18:00:00.0 Parcel 14 for cust 18 out for delivery
# [ 0] 18:00:00.0 Parcel 15 for cust 19 out for delivery
# [ 0] 18:00:00.0 Parcel 6 for cust 13 out for delivery
# [ 0] 18:00:00.0 Parcel 7 for cust 13 out for delivery
# [ 0] 18:00:00.0 Parcel 3 for cust 7 out for delivery
# [ 0] 18:00:00.0 Parcel 4 for cust 7 out for delivery
# [ 0] 18:00:00.0 Parcel 1 for cust 6 out for delivery
# [ 0] 18:00:00.0 Parcel 2 for cust 6 out for delivery
# [ 0] 18:00:00.0 Parcel 0 for cust 5 out for delivery
# [ 0] 18:00:00.0 Parcel 5 for cust 8 out for delivery
# [ 0] 18:13:20.0 Driver leaves for delivery of 16 parcels to 10 customers
# [ 0] 18:13:20.0 Length of delivery tour: 20,586m
# [ 0] 18:13:20.0 Driver drives to Customer 15 at (6800, 4858)
# [ 0] 18:23:57.9 Driver arrived at Customer 15 at (6800, 4858)
# [ 0] 18:24:14.3 Customer 15 at (6800, 4858) answers door
# [ 0] 18:24:14.3 Customer 15 at (6800, 4858) accepts Parcel 8 for cust 15
# [ 0] 18:24:14.8 Customer 15 at (6800, 4858) signs off
# [ 0] 18:24:18.1 Driver drives to Customer 16 at (6940, 4500)
# [ 0] 18:26:17.6 Driver arrived at Customer 16 at (6940, 4500)
# [ 0] 18:26:28.6 Customer 16 at (6940, 4500) answers door
# [ 0] 18:26:28.6 Customer 16 at (6940, 4500) accepts Parcel 9 for cust 16
# [ 0] 18:26:59.2 Customer 16 at (6940, 4500) accepts Parcel 10 for cust 16
# [ 0] 18:27:03.5 Customer 16 at (6940, 4500) accepts Parcel 11 for cust 16
# [ 0] 18:27:06.9 Customer 16 at (6940, 4500) signs off
# [ 0] 18:27:11.4 Driver drives to Customer 17 at (7049, 4500)
# [ 0] 18:27:37.5 Driver arrived at Customer 17 at (7049, 4500)
# [ 0] 18:29:34.9 Customer 17 at (7049, 4500) answers door
# [ 0] 18:29:34.9 Customer 17 at (7049, 4500) accepts Parcel 12 for cust 17
# [ 0] 18:29:45.0 Customer 17 at (7049, 4500) accepts Parcel 13 for cust 17
# [ 0] 18:29:54.7 Customer 17 at (7049, 4500) signs off
# [ 0] 18:30:07.3 Driver drives to Customer 18 at (7290, 4500)
# [ 0] 18:31:05.1 Driver arrived at Customer 18 at (7290, 4500)
# [ 0] 18:31:24.7 Customer 18 at (7290, 4500) answers door
# [ 0] 18:31:24.7 Customer 18 at (7290, 4500) accepts Parcel 14 for cust 18
# [ 0] 18:31:30.1 Customer 18 at (7290, 4500) signs off
# [ 0] 18:31:40.6 Driver drives to Customer 19 at (7950, 3804)
# [ 0] 18:37:06.1 Driver arrived at Customer 19 at (7950, 3804)
# [ 0] 18:37:06.1 Customer 19 at (7950, 3804) answers door
# [ 0] 18:37:06.1 Customer 19 at (7950, 3804) accepts Parcel 15 for cust 19
# [ 0] 18:37:08.3 Customer 19 at (7950, 3804) signs off
# [ 0] 18:37:12.3 Driver drives to Customer 13 at (5650, 5058)
# [ 0] 18:51:25.3 Driver arrived at Customer 13 at (5650, 5058)
# [ 0] 18:51:36.2 Customer 13 at (5650, 5058) answers door
# [ 0] 18:51:36.2 Customer 13 at (5650, 5058) accepts Parcel 6 for cust 13
# [ 0] 18:51:46.4 Customer 13 at (5650, 5058) accepts Parcel 7 for cust 13
# [ 0] 18:51:51.1 Customer 13 at (5650, 5058) signs off
# [ 0] 18:52:12.0 Driver drives to Customer 7 at (2664, 4500)
# [ 0] 19:06:22.5 Driver arrived at Customer 7 at (2664, 4500)
# [ 0] 19:06:56.1 Customer 7 at (2664, 4500) answers door
# [ 0] 19:06:56.1 Customer 7 at (2664, 4500) accepts Parcel 3 for cust 7
# [ 0] 19:07:01.5 Customer 7 at (2664, 4500) accepts Parcel 4 for cust 7
# [ 0] 19:07:06.6 Customer 7 at (2664, 4500) signs off
# [ 0] 19:07:18.7 Driver drives to Customer 6 at (2200, 4047)
# [ 0] 19:10:58.8 Driver arrived at Customer 6 at (2200, 4047)
# [ 0] 19:11:20.5 Customer 6 at (2200, 4047) answers door
# [ 0] 19:11:20.5 Customer 6 at (2200, 4047) accepts Parcel 1 for cust 6
# [ 0] 19:11:31.3 Customer 6 at (2200, 4047) accepts Parcel 2 for cust 6
# [ 0] 19:11:31.8 Customer 6 at (2200, 4047) signs off
# [ 0] 19:11:37.7 Driver drives to Customer 5 at (2200, 2575)
# [ 0] 19:17:31.0 Driver arrived at Customer 5 at (2200, 2575)
# [ 0] 19:17:43.0 Customer 5 at (2200, 2575) answers door
# [ 0] 19:17:43.0 Customer 5 at (2200, 2575) accepts Parcel 0 for cust 5
# [ 0] 19:17:44.7 Customer 5 at (2200, 2575) signs off
# [ 0] 19:17:52.2 Driver drives to Customer 8 at (2831, 2200)
# [ 0] 19:21:53.6 Driver arrived at Customer 8 at (2831, 2200)
# [ 0] 19:22:20.3 Customer 8 at (2831, 2200) answers door
# [ 0] 19:22:20.3 Customer 8 at (2831, 2200) accepts Parcel 5 for cust 8
# [ 0] 19:22:28.6 Customer 8 at (2831, 2200) signs off
# [ 0] 19:22:42.7 Driver returns to delivery centre
# [ 0] 19:43:38.1 Driver arrived at delivery centre
# [ 0] 19:43:38.1 0 parcels left for next day
# [ 0] 19:53:38.1 Driver goes home
# [ 1] 17:00:00.0 Parcel 16 for cust 0 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 17 for cust 1 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 18 for cust 3 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 19 for cust 5 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 20 for cust 5 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 21 for cust 6 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 22 for cust 7 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 23 for cust 8 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 24 for cust 8 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 25 for cust 9 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 26 for cust 11 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 27 for cust 13 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 28 for cust 14 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 29 for cust 14 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 30 for cust 14 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 31 for cust 15 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 32 for cust 15 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 33 for cust 16 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 34 for cust 18 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 35 for cust 19 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 36 for cust 19 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 37 for cust 19 arr at delivery centre
# [ 1] 18:00:00.0 Driver arrives for work
# [ 1] 18:00:00.0 Parcel 22 for cust 7 out for delivery
# [ 1] 18:00:00.0 Parcel 21 for cust 6 out for delivery
# [ 1] 18:00:00.0 Parcel 19 for cust 5 out for delivery
# [ 1] 18:00:00.0 Parcel 20 for cust 5 out for delivery
# [ 1] 18:00:00.0 Parcel 23 for cust 8 out for delivery
# [ 1] 18:00:00.0 Parcel 24 for cust 8 out for delivery
# [ 1] 18:00:00.0 Parcel 16 for cust 0 out for delivery
# [ 1] 18:00:00.0 Parcel 17 for cust 1 out for delivery
# [ 1] 18:00:00.0 Parcel 18 for cust 3 out for delivery
# [ 1] 18:00:00.0 Parcel 25 for cust 9 out for delivery
# [ 1] 18:00:00.0 Parcel 26 for cust 11 out for delivery
# [ 1] 18:00:00.0 Parcel 28 for cust 14 out for delivery
# [ 1] 18:00:00.0 Parcel 29 for cust 14 out for delivery
# [ 1] 18:00:00.0 Parcel 30 for cust 14 out for delivery
# [ 1] 18:00:00.0 Parcel 27 for cust 13 out for delivery
# [ 1] 18:00:00.0 Parcel 31 for cust 15 out for delivery
# [ 1] 18:00:00.0 Parcel 32 for cust 15 out for delivery
# [ 1] 18:00:00.0 Parcel 33 for cust 16 out for delivery
# [ 1] 18:00:00.0 Parcel 34 for cust 18 out for delivery
# [ 1] 18:00:00.0 Parcel 35 for cust 19 out for delivery
# [ 1] 18:00:00.0 Parcel 36 for cust 19 out for delivery
# [ 1] 18:00:00.0 Parcel 37 for cust 19 out for delivery
# [ 1] 18:18:20.0 Driver leaves for delivery of 22 parcels to 15 customers
# [ 1] 18:18:20.0 Length of delivery tour: 27,072m
# [ 1] 18:18:20.0 Driver drives to Customer 7 at (2664, 4500)
# [ 1] 18:25:40.6 Driver arrived at Customer 7 at (2664, 4500)
# [ 1] 18:27:06.8 Customer 7 at (2664, 4500) answers door
# [ 1] 18:27:06.8 Customer 7 at (2664, 4500) accepts Parcel 22 for cust 7
# [ 1] 18:27:13.6 Customer 7 at (2664, 4500) signs off
# [ 1] 18:27:17.3 Driver drives to Customer 6 at (2200, 4047)
# [ 1] 18:30:57.4 Driver arrived at Customer 6 at (2200, 4047)
# [ 1] 18:31:22.6 Customer 6 at (2200, 4047) answers door
# [ 1] 18:31:22.6 Customer 6 at (2200, 4047) accepts Parcel 21 for cust 6
# [ 1] 18:31:39.1 Customer 6 at (2200, 4047) signs off
# [ 1] 18:31:59.9 Driver drives to Customer 5 at (2200, 2575)
# [ 1] 18:37:53.2 Driver arrived at Customer 5 at (2200, 2575)
# [ 1] 18:39:00.1 Customer 5 at (2200, 2575) answers door
# [ 1] 18:39:00.1 Customer 5 at (2200, 2575) accepts Parcel 19 for cust 5
# [ 1] 18:39:02.2 Customer 5 at (2200, 2575) accepts Parcel 20 for cust 5
# [ 1] 18:40:16.8 Customer 5 at (2200, 2575) signs off
# [ 1] 18:40:26.8 Driver drives to Customer 8 at (2831, 2200)
# [ 1] 18:44:28.2 Driver arrived at Customer 8 at (2831, 2200)
# [ 1] 18:44:31.7 Customer 8 at (2831, 2200) answers door
# [ 1] 18:44:31.7 Customer 8 at (2831, 2200) accepts Parcel 23 for cust 8
# [ 1] 18:44:44.6 Customer 8 at (2831, 2200) accepts Parcel 24 for cust 8
# [ 1] 18:45:27.9 Customer 8 at (2831, 2200) signs off
# [ 1] 18:45:33.1 Driver drives to Customer 0 at (1050, 3870)
# [ 1] 18:59:21.3 Driver arrived at Customer 0 at (1050, 3870)
# [ 1] 19:00:06.7 Customer 0 at (1050, 3870) answers door
# [ 1] 19:00:06.7 Customer 0 at (1050, 3870) accepts Parcel 16 for cust 0
# [ 1] 19:00:10.5 Customer 0 at (1050, 3870) signs off
# [ 1] 19:00:12.9 Driver drives to Customer 1 at (1050, 4197)
# [ 1] 19:01:31.4 Driver arrived at Customer 1 at (1050, 4197)
# [ 1] 19:02:21.9 Customer 1 at (1050, 4197) answers door
# [ 1] 19:02:21.9 Customer 1 at (1050, 4197) accepts Parcel 17 for cust 1
# [ 1] 19:02:21.9 Customer 1 at (1050, 4197) signs off
# [ 1] 19:02:39.2 Driver drives to Customer 3 at (1561, 5650)
# [ 1] 19:10:30.6 Driver arrived at Customer 3 at (1561, 5650)
# [ 1] 19:11:00.7 Customer 3 at (1561, 5650) answers door
# [ 1] 19:11:00.7 Customer 3 at (1561, 5650) accepts Parcel 18 for cust 3
# [ 1] 19:11:01.7 Customer 3 at (1561, 5650) signs off
# [ 1] 19:11:03.0 Driver drives to Customer 9 at (3350, 6938)
# [ 1] 19:23:21.4 Driver arrived at Customer 9 at (3350, 6938)
# [ 1] 19:24:03.4 Customer 9 at (3350, 6938) answers door
# [ 1] 19:24:03.4 Customer 9 at (3350, 6938) accepts Parcel 25 for cust 9
# [ 1] 19:24:24.0 Customer 9 at (3350, 6938) signs off
# [ 1] 19:24:27.3 Driver drives to Customer 11 at (3350, 7151)
# [ 1] 19:25:18.4 Driver arrived at Customer 11 at (3350, 7151)
# [ 1] 19:27:52.1 Customer 11 at (3350, 7151) answers door
# [ 1] 19:27:52.1 Customer 11 at (3350, 7151) accepts Parcel 26 for cust 11
# [ 1] 19:27:53.1 Customer 11 at (3350, 7151) signs off
# [ 1] 19:28:12.4 Driver drives to Customer 14 at (5650, 6269)
# [ 1] 19:40:56.0 Driver arrived at Customer 14 at (5650, 6269)
# [ 1] 19:41:16.2 Customer 14 at (5650, 6269) answers door
# [ 1] 19:41:16.2 Customer 14 at (5650, 6269) accepts Parcel 28 for cust 14
# [ 1] 19:41:17.1 Customer 14 at (5650, 6269) accepts Parcel 29 for cust 14
# [ 1] 19:41:20.3 Customer 14 at (5650, 6269) accepts Parcel 30 for cust 14
# [ 1] 19:41:26.3 Customer 14 at (5650, 6269) signs off
# [ 1] 19:41:42.1 Driver drives to Customer 13 at (5650, 5058)
# [ 1] 19:46:32.7 Driver arrived at Customer 13 at (5650, 5058)
# [ 1] 19:47:51.7 Customer 13 at (5650, 5058) answers door
# [ 1] 19:47:51.7 Customer 13 at (5650, 5058) accepts Parcel 27 for cust 13
# [ 1] 19:47:53.2 Customer 13 at (5650, 5058) signs off
# [ 1] 19:48:00.5 Driver drives to Customer 15 at (6800, 4858)
# [ 1] 19:56:16.4 Driver arrived at Customer 15 at (6800, 4858)
# [ 1] 19:56:58.4 Customer 15 at (6800, 4858) answers door
# [ 1] 19:56:58.4 Customer 15 at (6800, 4858) accepts Parcel 31 for cust 15
# [ 1] 19:57:02.7 Customer 15 at (6800, 4858) accepts Parcel 32 for cust 15
# [ 1] 19:57:23.3 Customer 15 at (6800, 4858) signs off
# [ 1] 19:57:26.5 Driver drives to Customer 16 at (6940, 4500)
# [ 1] 19:59:26.0 Driver arrived at Customer 16 at (6940, 4500)
# [ 1] 19:59:26.8 Customer 16 at (6940, 4500) answers door
# [ 1] 19:59:26.8 Customer 16 at (6940, 4500) accepts Parcel 33 for cust 16
# [ 1] 19:59:27.2 Customer 16 at (6940, 4500) signs off
# [ 1] 19:59:38.6 Driver drives to Customer 18 at (7290, 4500)
# [ 1] 20:01:02.6 Driver arrived at Customer 18 at (7290, 4500)
# [ 1] 20:01:35.3 Customer 18 at (7290, 4500) answers door
# [ 1] 20:01:35.3 Customer 18 at (7290, 4500) accepts Parcel 34 for cust 18
# [ 1] 20:02:04.6 Customer 18 at (7290, 4500) signs off
# [ 1] 20:02:32.5 Driver drives to Customer 19 at (7950, 3804)
# [ 1] 20:07:57.9 Driver arrived at Customer 19 at (7950, 3804)
# [ 1] 20:09:34.2 Customer 19 at (7950, 3804) answers door
# [ 1] 20:09:34.2 Customer 19 at (7950, 3804) accepts Parcel 35 for cust 19
# [ 1] 20:09:34.6 Customer 19 at (7950, 3804) accepts Parcel 36 for cust 19
# [ 1] 20:09:48.4 Customer 19 at (7950, 3804) accepts Parcel 37 for cust 19
# [ 1] 20:10:00.5 Customer 19 at (7950, 3804) signs off
# [ 1] 20:10:11.2 Driver returns to delivery centre
# [ 1] 20:26:46.2 Driver arrived at delivery centre
# [ 1] 20:26:46.2 0 parcels left for next day
# [ 1] 20:36:46.2 Driver goes home
# [ 2] 17:00:00.0 Parcel 38 for cust 0 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 39 for cust 1 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 40 for cust 1 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 41 for cust 3 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 42 for cust 4 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 43 for cust 5 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 44 for cust 7 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 45 for cust 8 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 46 for cust 10 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 47 for cust 10 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 48 for cust 11 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 49 for cust 13 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 50 for cust 14 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 51 for cust 14 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 52 for cust 15 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 53 for cust 19 arr at delivery centre
# [ 2] 18:00:00.0 Driver arrives for work
# [ 2] 18:00:00.0 Parcel 52 for cust 15 out for delivery
# [ 2] 18:00:00.0 Parcel 50 for cust 14 out for delivery
# [ 2] 18:00:00.0 Parcel 51 for cust 14 out for delivery
# [ 2] 18:00:00.0 Parcel 49 for cust 13 out for delivery
# [ 2] 18:00:00.0 Parcel 46 for cust 10 out for delivery
# [ 2] 18:00:00.0 Parcel 47 for cust 10 out for delivery
# [ 2] 18:00:00.0 Parcel 48 for cust 11 out for delivery
# [ 2] 18:00:00.0 Parcel 44 for cust 7 out for delivery
# [ 2] 18:00:00.0 Parcel 41 for cust 3 out for delivery
# [ 2] 18:00:00.0 Parcel 39 for cust 1 out for delivery
# [ 2] 18:00:00.0 Parcel 40 for cust 1 out for delivery
# [ 2] 18:00:00.0 Parcel 38 for cust 0 out for delivery
# [ 2] 18:00:00.0 Parcel 43 for cust 5 out for delivery
# [ 2] 18:00:00.0 Parcel 42 for cust 4 out for delivery
# [ 2] 18:00:00.0 Parcel 45 for cust 8 out for delivery
# [ 2] 18:12:30.0 Driver leaves for delivery of 15 parcels to 12 customers
# [ 2] 18:12:30.0 Length of delivery tour: 28,040m
# [ 2] 18:12:30.0 Driver drives to Customer 15 at (6800, 4858)
# [ 2] 18:23:07.9 Driver arrived at Customer 15 at (6800, 4858)
# [ 2] 18:23:57.8 Customer 15 at (6800, 4858) answers door
# [ 2] 18:23:57.8 Customer 15 at (6800, 4858) accepts Parcel 52 for cust 15
# [ 2] 18:24:21.1 Customer 15 at (6800, 4858) signs off
# [ 2] 18:24:31.3 Driver drives to Customer 14 at (5650, 6269)
# [ 2] 18:34:45.9 Driver arrived at Customer 14 at (5650, 6269)
# [ 2] 18:35:04.6 Customer 14 at (5650, 6269) answers door
# [ 2] 18:35:04.6 Customer 14 at (5650, 6269) accepts Parcel 50 for cust 14
# [ 2] 18:35:12.3 Customer 14 at (5650, 6269) accepts Parcel 51 for cust 14
# [ 2] 18:35:14.6 Customer 14 at (5650, 6269) signs off
# [ 2] 18:35:23.5 Driver drives to Customer 13 at (5650, 5058)
# [ 2] 18:40:14.1 Driver arrived at Customer 13 at (5650, 5058)
# [ 2] 18:40:14.5 Customer 13 at (5650, 5058) answers door
# [ 2] 18:40:14.5 Customer 13 at (5650, 5058) accepts Parcel 49 for cust 13
# [ 2] 18:40:16.1 Customer 13 at (5650, 5058) signs off
# [ 2] 18:40:20.1 Driver drives to Customer 10 at (3350, 7037)
# [ 2] 18:57:27.1 Driver arrived at Customer 10 at (3350, 7037)
# [ 2] 18:58:29.5 Customer 10 at (3350, 7037) answers door
# [ 2] 18:58:29.5 Customer 10 at (3350, 7037) accepts Parcel 46 for cust 10
# [ 2] 18:58:42.1 Customer 10 at (3350, 7037) accepts Parcel 47 for cust 10
# [ 2] 18:58:46.3 Customer 10 at (3350, 7037) signs off
# [ 2] 18:58:56.0 Driver drives to Customer 11 at (3350, 7151)
# [ 2] 18:59:23.3 Driver arrived at Customer 11 at (3350, 7151)
# [ 2] 18:59:25.0 Customer 11 at (3350, 7151) answers door
# [ 2] 18:59:25.0 Customer 11 at (3350, 7151) accepts Parcel 48 for cust 11
# [ 2] 18:59:26.8 Customer 11 at (3350, 7151) signs off
# [ 2] 19:00:06.9 Driver drives to Customer 7 at (2664, 4500)
# [ 2] 19:13:27.8 Driver arrived at Customer 7 at (2664, 4500)
# [ 2] 19:13:41.5 Customer 7 at (2664, 4500) answers door
# [ 2] 19:13:41.5 Customer 7 at (2664, 4500) accepts Parcel 44 for cust 7
# [ 2] 19:13:46.5 Customer 7 at (2664, 4500) signs off
# [ 2] 19:13:54.4 Driver drives to Customer 3 at (1561, 5650)
# [ 2] 19:22:55.2 Driver arrived at Customer 3 at (1561, 5650)
# [ 2] 19:23:09.1 Customer 3 at (1561, 5650) answers door
# [ 2] 19:23:09.1 Customer 3 at (1561, 5650) accepts Parcel 41 for cust 3
# [ 2] 19:23:15.6 Customer 3 at (1561, 5650) signs off
# [ 2] 19:23:18.3 Driver drives to Customer 1 at (1050, 4197)
# [ 2] 19:31:09.7 Driver arrived at Customer 1 at (1050, 4197)
# [ 2] 19:31:11.6 Customer 1 at (1050, 4197) answers door
# [ 2] 19:31:11.6 Customer 1 at (1050, 4197) accepts Parcel 39 for cust 1
# [ 2] 19:31:13.6 Customer 1 at (1050, 4197) accepts Parcel 40 for cust 1
# [ 2] 19:31:21.0 Customer 1 at (1050, 4197) signs off
# [ 2] 19:31:21.8 Driver drives to Customer 0 at (1050, 3870)
# [ 2] 19:32:40.2 Driver arrived at Customer 0 at (1050, 3870)
# [ 2] 19:33:00.9 Customer 0 at (1050, 3870) answers door
# [ 2] 19:33:00.9 Customer 0 at (1050, 3870) accepts Parcel 38 for cust 0
# [ 2] 19:33:04.9 Customer 0 at (1050, 3870) signs off
# [ 2] 19:33:10.2 Driver drives to Customer 5 at (2200, 2575)
# [ 2] 19:45:34.0 Driver arrived at Customer 5 at (2200, 2575)
# [ 2] 19:45:38.2 Customer 5 at (2200, 2575) answers door
# [ 2] 19:45:38.2 Customer 5 at (2200, 2575) accepts Parcel 43 for cust 5
# [ 2] 19:46:02.1 Customer 5 at (2200, 2575) signs off
# [ 2] 19:46:08.5 Driver drives to Customer 4 at (2200, 2395)
# [ 2] 19:46:51.7 Driver arrived at Customer 4 at (2200, 2395)
# [ 2] 19:48:05.2 Customer 4 at (2200, 2395) answers door
# [ 2] 19:48:05.2 Customer 4 at (2200, 2395) accepts Parcel 42 for cust 4
# [ 2] 19:48:42.6 Customer 4 at (2200, 2395) signs off
# [ 2] 19:48:46.8 Driver drives to Customer 8 at (2831, 2200)
# [ 2] 19:52:05.1 Driver arrived at Customer 8 at (2831, 2200)
# [ 2] 19:52:31.2 Customer 8 at (2831, 2200) answers door
# [ 2] 19:52:31.2 Customer 8 at (2831, 2200) accepts Parcel 45 for cust 8
# [ 2] 19:52:43.2 Customer 8 at (2831, 2200) signs off
# [ 2] 19:52:48.8 Driver returns to delivery centre
# [ 2] 20:13:44.2 Driver arrived at delivery centre
# [ 2] 20:13:44.2 1 parcels left for next day
# [ 2] 20:23:44.2 Driver goes home
# [ 3] 17:00:00.0 Parcel 54 for cust 0 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 55 for cust 0 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 56 for cust 2 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 57 for cust 3 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 58 for cust 4 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 59 for cust 5 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 60 for cust 5 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 61 for cust 6 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 62 for cust 7 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 63 for cust 8 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 64 for cust 8 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 65 for cust 9 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 66 for cust 10 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 67 for cust 13 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 68 for cust 14 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 69 for cust 17 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 70 for cust 18 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 71 for cust 18 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 72 for cust 19 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 73 for cust 19 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 74 for cust 19 arr at delivery centre
# [ 3] 18:00:00.0 Driver arrives for work
# [ 3] 18:00:00.0 Parcel 68 for cust 14 out for delivery
# [ 3] 18:00:00.0 Parcel 67 for cust 13 out for delivery
# [ 3] 18:00:00.0 Parcel 69 for cust 17 out for delivery
# [ 3] 18:00:00.0 Parcel 70 for cust 18 out for delivery
# [ 3] 18:00:00.0 Parcel 71 for cust 18 out for delivery
# [ 3] 18:00:00.0 Parcel 53 for cust 19 out for delivery
# [ 3] 18:00:00.0 Parcel 72 for cust 19 out for delivery
# [ 3] 18:00:00.0 Parcel 73 for cust 19 out for delivery
# [ 3] 18:00:00.0 Parcel 74 for cust 19 out for delivery
# [ 3] 18:00:00.0 Parcel 62 for cust 7 out for delivery
# [ 3] 18:00:00.0 Parcel 61 for cust 6 out for delivery
# [ 3] 18:00:00.0 Parcel 59 for cust 5 out for delivery
# [ 3] 18:00:00.0 Parcel 60 for cust 5 out for delivery
# [ 3] 18:00:00.0 Parcel 58 for cust 4 out for delivery
# [ 3] 18:00:00.0 Parcel 63 for cust 8 out for delivery
# [ 3] 18:00:00.0 Parcel 64 for cust 8 out for delivery
# [ 3] 18:00:00.0 Parcel 54 for cust 0 out for delivery
# [ 3] 18:00:00.0 Parcel 55 for cust 0 out for delivery
# [ 3] 18:00:00.0 Parcel 56 for cust 2 out for delivery
# [ 3] 18:00:00.0 Parcel 57 for cust 3 out for delivery
# [ 3] 18:00:00.0 Parcel 65 for cust 9 out for delivery
# [ 3] 18:00:00.0 Parcel 66 for cust 10 out for delivery
# [ 3] 18:18:20.0 Driver leaves for delivery of 22 parcels to 15 customers
# [ 3] 18:18:20.0 Length of delivery tour: 29,666m
# [ 3] 18:18:20.0 Driver drives to Customer 14 at (5650, 6269)
# [ 3] 18:30:00.6 Driver arrived at Customer 14 at (5650, 6269)
# [ 3] 18:30:14.9 Customer 14 at (5650, 6269) answers door
# [ 3] 18:30:14.9 Customer 14 at (5650, 6269) accepts Parcel 68 for cust 14
# [ 3] 18:30:28.2 Customer 14 at (5650, 6269) signs off
# [ 3] 18:30:50.7 Driver drives to Customer 13 at (5650, 5058)
# [ 3] 18:35:41.3 Driver arrived at Customer 13 at (5650, 5058)
# [ 3] 18:37:22.2 Customer 13 at (5650, 5058) answers door
# [ 3] 18:37:22.2 Customer 13 at (5650, 5058) accepts Parcel 67 for cust 13
# [ 3] 18:37:32.1 Customer 13 at (5650, 5058) signs off
# [ 3] 18:37:36.8 Driver drives to Customer 17 at (7049, 4500)
# [ 3] 18:45:26.4 Driver arrived at Customer 17 at (7049, 4500)
# [ 3] 18:47:53.3 Customer 17 at (7049, 4500) answers door
# [ 3] 18:47:53.3 Customer 17 at (7049, 4500) accepts Parcel 69 for cust 17
# [ 3] 18:48:03.5 Customer 17 at (7049, 4500) signs off
# [ 3] 18:48:04.2 Driver drives to Customer 18 at (7290, 4500)
# [ 3] 18:49:02.0 Driver arrived at Customer 18 at (7290, 4500)
# [ 3] 18:49:05.5 Customer 18 at (7290, 4500) answers door
# [ 3] 18:49:05.5 Customer 18 at (7290, 4500) accepts Parcel 70 for cust 18
# [ 3] 18:49:19.4 Customer 18 at (7290, 4500) accepts Parcel 71 for cust 18
# [ 3] 18:49:20.0 Customer 18 at (7290, 4500) signs off
# [ 3] 18:49:20.1 Driver drives to Customer 19 at (7950, 3804)
# [ 3] 18:54:45.6 Driver arrived at Customer 19 at (7950, 3804)
# [ 3] 18:55:05.6 Customer 19 at (7950, 3804) answers door
# [ 3] 18:55:05.6 Customer 19 at (7950, 3804) accepts Parcel 53 for cust 19
# [ 3] 18:55:12.9 Customer 19 at (7950, 3804) accepts Parcel 72 for cust 19
# [ 3] 18:55:18.8 Customer 19 at (7950, 3804) accepts Parcel 73 for cust 19
# [ 3] 18:55:25.6 Customer 19 at (7950, 3804) accepts Parcel 74 for cust 19
# [ 3] 18:55:34.3 Customer 19 at (7950, 3804) signs off
# [ 3] 18:55:45.7 Driver drives to Customer 7 at (2664, 4500)
# [ 3] 19:19:41.4 Driver arrived at Customer 7 at (2664, 4500)
# [ 3] 19:20:03.4 Customer 7 at (2664, 4500) answers door
# [ 3] 19:20:03.4 Customer 7 at (2664, 4500) accepts Parcel 62 for cust 7
# [ 3] 19:20:08.0 Customer 7 at (2664, 4500) signs off
# [ 3] 19:20:52.6 Driver drives to Customer 6 at (2200, 4047)
# [ 3] 19:24:32.7 Driver arrived at Customer 6 at (2200, 4047)
# [ 3] 19:24:44.8 Customer 6 at (2200, 4047) answers door
# [ 3] 19:24:44.8 Customer 6 at (2200, 4047) accepts Parcel 61 for cust 6
# [ 3] 19:24:59.8 Customer 6 at (2200, 4047) signs off
# [ 3] 19:25:05.4 Driver drives to Customer 5 at (2200, 2575)
# [ 3] 19:30:58.7 Driver arrived at Customer 5 at (2200, 2575)
# [ 3] 19:31:16.5 Customer 5 at (2200, 2575) answers door
# [ 3] 19:31:16.5 Customer 5 at (2200, 2575) accepts Parcel 59 for cust 5
# [ 3] 19:31:17.1 Customer 5 at (2200, 2575) accepts Parcel 60 for cust 5
# [ 3] 19:31:37.1 Customer 5 at (2200, 2575) signs off
# [ 3] 19:31:49.2 Driver drives to Customer 4 at (2200, 2395)
# [ 3] 19:32:32.4 Driver arrived at Customer 4 at (2200, 2395)
# [ 3] 19:34:05.7 Customer 4 at (2200, 2395) answers door
# [ 3] 19:34:05.7 Customer 4 at (2200, 2395) accepts Parcel 58 for cust 4
# [ 3] 19:34:11.7 Customer 4 at (2200, 2395) signs off
# [ 3] 19:34:23.0 Driver drives to Customer 8 at (2831, 2200)
# [ 3] 19:37:41.2 Driver arrived at Customer 8 at (2831, 2200)
# [ 3] 19:37:46.3 Customer 8 at (2831, 2200) answers door
# [ 3] 19:37:46.3 Customer 8 at (2831, 2200) accepts Parcel 63 for cust 8
# [ 3] 19:37:51.4 Customer 8 at (2831, 2200) accepts Parcel 64 for cust 8
# [ 3] 19:37:53.7 Customer 8 at (2831, 2200) signs off
# [ 3] 19:37:54.1 Driver drives to Customer 0 at (1050, 3870)
# [ 3] 19:51:42.4 Driver arrived at Customer 0 at (1050, 3870)
# [ 3] 19:53:40.6 Customer 0 at (1050, 3870) answers door
# [ 3] 19:53:40.6 Customer 0 at (1050, 3870) accepts Parcel 54 for cust 0
# [ 3] 19:53:43.0 Customer 0 at (1050, 3870) accepts Parcel 55 for cust 0
# [ 3] 19:53:44.6 Customer 0 at (1050, 3870) signs off
# [ 3] 19:53:46.8 Driver drives to Customer 2 at (1351, 5650)
# [ 3] 20:02:06.3 Driver arrived at Customer 2 at (1351, 5650)
# [ 3] 20:02:25.3 Customer 2 at (1351, 5650) answers door
# [ 3] 20:02:25.3 Customer 2 at (1351, 5650) accepts Parcel 56 for cust 2
# [ 3] 20:02:33.2 Customer 2 at (1351, 5650) signs off
# [ 3] 20:02:34.8 Driver drives to Customer 3 at (1561, 5650)
# [ 3] 20:03:25.2 Driver arrived at Customer 3 at (1561, 5650)
# [ 3] 20:06:24.5 Customer 3 at (1561, 5650) answers door
# [ 3] 20:06:24.5 Customer 3 at (1561, 5650) accepts Parcel 57 for cust 3
# [ 3] 20:07:05.2 Customer 3 at (1561, 5650) signs off
# [ 3] 20:07:06.8 Driver drives to Customer 9 at (3350, 6938)
# [ 3] 20:19:25.3 Driver arrived at Customer 9 at (3350, 6938)
# [ 3] 20:19:46.1 Customer 9 at (3350, 6938) answers door
# [ 3] 20:19:46.1 Customer 9 at (3350, 6938) accepts Parcel 65 for cust 9
# [ 3] 20:19:57.5 Customer 9 at (3350, 6938) signs off
# [ 3] 20:20:18.5 Driver drives to Customer 10 at (3350, 7037)
# [ 3] 20:20:42.3 Driver arrived at Customer 10 at (3350, 7037)
# [ 3] 20:21:09.7 Customer 10 at (3350, 7037) answers door
# [ 3] 20:21:09.7 Customer 10 at (3350, 7037) accepts Parcel 66 for cust 10
# [ 3] 20:21:34.6 Customer 10 at (3350, 7037) signs off
# [ 3] 20:21:38.4 Driver returns to delivery centre
# [ 3] 20:36:23.3 Driver arrived at delivery centre
# [ 3] 20:36:23.3 0 parcels left for next day
# [ 3] 20:46:23.3 Driver goes home
# [ 4] 17:00:00.0 Parcel 75 for cust 0 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 76 for cust 0 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 77 for cust 1 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 78 for cust 1 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 79 for cust 2 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 80 for cust 3 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 81 for cust 3 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 82 for cust 5 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 83 for cust 7 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 84 for cust 8 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 85 for cust 8 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 86 for cust 8 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 87 for cust 10 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 88 for cust 10 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 89 for cust 12 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 90 for cust 13 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 91 for cust 16 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 92 for cust 16 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 93 for cust 16 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 94 for cust 16 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 95 for cust 16 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 96 for cust 17 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 97 for cust 17 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 98 for cust 18 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 99 for cust 19 arr at delivery centre
# [ 4] 18:00:00.0 Driver arrives for work
# [ 4] 18:00:00.0 Parcel 91 for cust 16 out for delivery
# [ 4] 18:00:00.0 Parcel 92 for cust 16 out for delivery
# [ 4] 18:00:00.0 Parcel 93 for cust 16 out for delivery
# [ 4] 18:00:00.0 Parcel 94 for cust 16 out for delivery
# [ 4] 18:00:00.0 Parcel 95 for cust 16 out for delivery
# [ 4] 18:00:00.0 Parcel 96 for cust 17 out for delivery
# [ 4] 18:00:00.0 Parcel 97 for cust 17 out for delivery
# [ 4] 18:00:00.0 Parcel 98 for cust 18 out for delivery
# [ 4] 18:00:00.0 Parcel 90 for cust 13 out for delivery
# [ 4] 18:00:00.0 Parcel 89 for cust 12 out for delivery
# [ 4] 18:00:00.0 Parcel 87 for cust 10 out for delivery
# [ 4] 18:00:00.0 Parcel 88 for cust 10 out for delivery
# [ 4] 18:00:00.0 Parcel 83 for cust 7 out for delivery
# [ 4] 18:00:00.0 Parcel 80 for cust 3 out for delivery
# [ 4] 18:00:00.0 Parcel 81 for cust 3 out for delivery
# [ 4] 18:00:00.0 Parcel 79 for cust 2 out for delivery
# [ 4] 18:00:00.0 Parcel 77 for cust 1 out for delivery
# [ 4] 18:00:00.0 Parcel 78 for cust 1 out for delivery
# [ 4] 18:00:00.0 Parcel 75 for cust 0 out for delivery
# [ 4] 18:00:00.0 Parcel 76 for cust 0 out for delivery
# [ 4] 18:00:00.0 Parcel 82 for cust 5 out for delivery
# [ 4] 18:00:00.0 Parcel 84 for cust 8 out for delivery
# [ 4] 18:00:00.0 Parcel 85 for cust 8 out for delivery
# [ 4] 18:00:00.0 Parcel 86 for cust 8 out for delivery
# [ 4] 18:20:00.0 Driver leaves for delivery of 24 parcels to 13 customers
# [ 4] 18:20:00.0 Length of delivery tour: 27,602m
# [ 4] 18:20:00.0 Driver drives to Customer 16 at (6940, 4500)
# [ 4] 18:29:45.6 Driver arrived at Customer 16 at (6940, 4500)
# [ 4] 18:30:13.2 Customer 16 at (6940, 4500) answers door
# [ 4] 18:30:13.2 Customer 16 at (6940, 4500) accepts Parcel 91 for cust 16
# [ 4] 18:30:20.1 Customer 16 at (6940, 4500) accepts Parcel 92 for cust 16
# [ 4] 18:30:31.2 Customer 16 at (6940, 4500) accepts Parcel 93 for cust 16
# [ 4] 18:30:33.5 Customer 16 at (6940, 4500) accepts Parcel 94 for cust 16
# [ 4] 18:30:42.9 Customer 16 at (6940, 4500) accepts Parcel 95 for cust 16
# [ 4] 18:30:45.3 Customer 16 at (6940, 4500) signs off
# [ 4] 18:30:49.5 Driver drives to Customer 17 at (7049, 4500)
# [ 4] 18:31:15.6 Driver arrived at Customer 17 at (7049, 4500)
# [ 4] 18:33:27.1 Customer 17 at (7049, 4500) answers door
# [ 4] 18:33:27.1 Customer 17 at (7049, 4500) accepts Parcel 96 for cust 17
# [ 4] 18:33:50.0 Customer 17 at (7049, 4500) accepts Parcel 97 for cust 17
# [ 4] 18:34:07.0 Customer 17 at (7049, 4500) signs off
# [ 4] 18:34:07.4 Driver drives to Customer 18 at (7290, 4500)
# [ 4] 18:35:05.2 Driver arrived at Customer 18 at (7290, 4500)
# [ 4] 18:35:11.7 Customer 18 at (7290, 4500) answers door
# [ 4] 18:35:11.7 Customer 18 at (7290, 4500) accepts Parcel 98 for cust 18
# [ 4] 18:35:14.6 Customer 18 at (7290, 4500) signs off
# [ 4] 18:35:30.0 Driver drives to Customer 13 at (5650, 5058)
# [ 4] 18:44:17.5 Driver arrived at Customer 13 at (5650, 5058)
# [ 4] 18:45:31.4 Customer 13 at (5650, 5058) answers door
# [ 4] 18:45:31.4 Customer 13 at (5650, 5058) accepts Parcel 90 for cust 13
# [ 4] 18:45:40.1 Customer 13 at (5650, 5058) signs off
# [ 4] 18:45:52.8 Driver drives to Customer 12 at (4500, 7416)
# [ 4] 18:59:54.7 Driver arrived at Customer 12 at (4500, 7416)
# [ 4] 19:01:00.5 Customer 12 at (4500, 7416) answers door
# [ 4] 19:01:00.5 Customer 12 at (4500, 7416) accepts Parcel 89 for cust 12
# [ 4] 19:01:01.2 Customer 12 at (4500, 7416) signs off
# [ 4] 19:01:02.1 Driver drives to Customer 10 at (3350, 7037)
# [ 4] 19:09:02.8 Driver arrived at Customer 10 at (3350, 7037)
# [ 4] 19:10:24.1 Customer 10 at (3350, 7037) answers door
# [ 4] 19:10:24.1 Customer 10 at (3350, 7037) accepts Parcel 87 for cust 10
# [ 4] 19:10:24.5 Customer 10 at (3350, 7037) accepts Parcel 88 for cust 10
# [ 4] 19:10:27.0 Customer 10 at (3350, 7037) signs off
# [ 4] 19:10:27.4 Driver drives to Customer 7 at (2664, 4500)
# [ 4] 19:23:21.0 Driver arrived at Customer 7 at (2664, 4500)
# [ 4] 19:23:21.6 Customer 7 at (2664, 4500) answers door
# [ 4] 19:23:21.6 Customer 7 at (2664, 4500) accepts Parcel 83 for cust 7
# [ 4] 19:23:40.1 Customer 7 at (2664, 4500) signs off
# [ 4] 19:23:44.2 Driver drives to Customer 3 at (1561, 5650)
# [ 4] 19:32:44.9 Driver arrived at Customer 3 at (1561, 5650)
# [ 4] 19:32:51.9 Customer 3 at (1561, 5650) answers door
# [ 4] 19:32:51.9 Customer 3 at (1561, 5650) accepts Parcel 80 for cust 3
# [ 4] 19:32:53.5 Customer 3 at (1561, 5650) accepts Parcel 81 for cust 3
# [ 4] 19:33:04.2 Customer 3 at (1561, 5650) signs off
# [ 4] 19:33:38.8 Driver drives to Customer 2 at (1351, 5650)
# [ 4] 19:34:29.2 Driver arrived at Customer 2 at (1351, 5650)
# [ 4] 19:34:57.3 Customer 2 at (1351, 5650) answers door
# [ 4] 19:34:57.3 Customer 2 at (1351, 5650) accepts Parcel 79 for cust 2
# [ 4] 19:35:20.4 Customer 2 at (1351, 5650) signs off
# [ 4] 19:35:27.4 Driver drives to Customer 1 at (1050, 4197)
# [ 4] 19:42:28.4 Driver arrived at Customer 1 at (1050, 4197)
# [ 4] 19:43:02.5 Customer 1 at (1050, 4197) answers door
# [ 4] 19:43:02.5 Customer 1 at (1050, 4197) accepts Parcel 77 for cust 1
# [ 4] 19:43:13.9 Customer 1 at (1050, 4197) accepts Parcel 78 for cust 1
# [ 4] 19:43:30.2 Customer 1 at (1050, 4197) signs off
# [ 4] 19:43:44.4 Driver drives to Customer 0 at (1050, 3870)
# [ 4] 19:45:02.9 Driver arrived at Customer 0 at (1050, 3870)
# [ 4] 19:48:09.3 Customer 0 at (1050, 3870) answers door
# [ 4] 19:48:09.3 Customer 0 at (1050, 3870) accepts Parcel 75 for cust 0
# [ 4] 19:48:23.0 Customer 0 at (1050, 3870) accepts Parcel 76 for cust 0
# [ 4] 19:48:46.6 Customer 0 at (1050, 3870) signs off
# [ 4] 19:48:48.9 Driver drives to Customer 5 at (2200, 2575)
# [ 4] 20:01:12.7 Driver arrived at Customer 5 at (2200, 2575)
# [ 4] 20:01:43.4 Customer 5 at (2200, 2575) answers door
# [ 4] 20:01:43.4 Customer 5 at (2200, 2575) accepts Parcel 82 for cust 5
# [ 4] 20:01:52.5 Customer 5 at (2200, 2575) signs off
# [ 4] 20:02:10.0 Driver drives to Customer 8 at (2831, 2200)
# [ 4] 20:06:11.4 Driver arrived at Customer 8 at (2831, 2200)
# [ 4] 20:06:37.7 Customer 8 at (2831, 2200) answers door
# [ 4] 20:06:37.7 Customer 8 at (2831, 2200) accepts Parcel 84 for cust 8
# [ 4] 20:06:53.4 Customer 8 at (2831, 2200) accepts Parcel 85 for cust 8
# [ 4] 20:06:58.3 Customer 8 at (2831, 2200) accepts Parcel 86 for cust 8
# [ 4] 20:07:07.1 Customer 8 at (2831, 2200) signs off
# [ 4] 20:07:26.2 Driver returns to delivery centre
# [ 4] 20:28:21.6 Driver arrived at delivery centre
# [ 4] 20:28:21.6 1 parcels left for next day
# [ 4] 20:38:21.6 Driver goes home
# [ 5] 17:00:00.0 Parcel 100 for cust 0 arr at delivery centre
# [ 5] 17:00:00.0 Parcel 101 for cust 1 arr at delivery centre
# [ 5] 17:00:00.0 Parcel 102 for cust 3 arr at delivery centre
# [ 5] 17:00:00.0 Parcel 103 for cust 3 arr at delivery centre
# [ 5] 17:00:00.0 Parcel 104 for cust 4 arr at delivery centre
# [ 5] 17:00:00.0 Parcel 105 for cust 4 arr at delivery centre
# [ 5] 17:00:00.0 Parcel 106 for cust 6 arr at delivery centre
# [ 5] 17:00:00.0 Parcel 107 for cust 6 arr at delivery centre
# [ 5] 17:00:00.0 Parcel 108 for cust 6 arr at delivery centre
# [ 5] 17:00:00.0 Parcel 109 for cust 8 arr at delivery centre
# [ 5] 17:00:00.0 Parcel 110 for cust 9 arr at delivery centre
# [ 5] 17:00:00.0 Parcel 111 for cust 10 arr at delivery centre
# [ 5] 17:00:00.0 Parcel 112 for cust 11 arr at delivery centre
# [ 5] 17:00:00.0 Parcel 113 for cust 11 arr at delivery centre
# [ 5] 17:00:00.0 Parcel 114 for cust 13 arr at delivery centre
# [ 5] 17:00:00.0 Parcel 115 for cust 13 arr at delivery centre
# [ 5] 17:00:00.0 Parcel 116 for cust 13 arr at delivery centre
# [ 5] 17:00:00.0 Parcel 117 for cust 14 arr at delivery centre
# [ 5] 17:00:00.0 Parcel 118 for cust 15 arr at delivery centre
# [ 5] 17:00:00.0 Parcel 119 for cust 15 arr at delivery centre
# [ 5] 17:00:00.0 Parcel 120 for cust 15 arr at delivery centre
# [ 5] 17:00:00.0 Parcel 121 for cust 16 arr at delivery centre
# [ 5] 17:00:00.0 Parcel 122 for cust 17 arr at delivery centre
# [ 5] 17:00:00.0 Parcel 123 for cust 19 arr at delivery centre
# [ 5] 18:00:00.0 Driver arrives for work
# [ 5] 18:00:00.0 Parcel 121 for cust 16 out for delivery
# [ 5] 18:00:00.0 Parcel 122 for cust 17 out for delivery
# [ 5] 18:00:00.0 Parcel 99 for cust 19 out for delivery
# [ 5] 18:00:00.0 Parcel 123 for cust 19 out for delivery
# [ 5] 18:00:00.0 Parcel 110 for cust 9 out for delivery
# [ 5] 18:00:00.0 Parcel 111 for cust 10 out for delivery
# [ 5] 18:00:00.0 Parcel 112 for cust 11 out for delivery
# [ 5] 18:00:00.0 Parcel 113 for cust 11 out for delivery
# [ 5] 18:00:00.0 Parcel 106 for cust 6 out for delivery
# [ 5] 18:00:00.0 Parcel 107 for cust 6 out for delivery
# [ 5] 18:00:00.0 Parcel 108 for cust 6 out for delivery
# [ 5] 18:00:00.0 Parcel 102 for cust 3 out for delivery
# [ 5] 18:00:00.0 Parcel 103 for cust 3 out for delivery
# [ 5] 18:00:00.0 Parcel 101 for cust 1 out for delivery
# [ 5] 18:00:00.0 Parcel 100 for cust 0 out for delivery
# [ 5] 18:00:00.0 Parcel 104 for cust 4 out for delivery
# [ 5] 18:00:00.0 Parcel 105 for cust 4 out for delivery
# [ 5] 18:00:00.0 Parcel 109 for cust 8 out for delivery
# [ 5] 18:15:00.0 Driver leaves for delivery of 18 parcels to 12 customers
# [ 5] 18:15:00.0 Length of delivery tour: 29,562m
# [ 5] 18:15:00.0 Driver drives to Customer 16 at (6940, 4500)
# [ 5] 18:24:45.6 Driver arrived at Customer 16 at (6940, 4500)
# [ 5] 18:25:49.6 Customer 16 at (6940, 4500) answers door
# [ 5] 18:25:49.6 Customer 16 at (6940, 4500) accepts Parcel 121 for cust 16
# [ 5] 18:26:00.3 Customer 16 at (6940, 4500) signs off
# [ 5] 18:26:00.3 Driver drives to Customer 17 at (7049, 4500)
# [ 5] 18:26:26.5 Driver arrived at Customer 17 at (7049, 4500)
# [ 5] 18:26:34.5 Customer 17 at (7049, 4500) answers door
# [ 5] 18:26:34.5 Customer 17 at (7049, 4500) accepts Parcel 122 for cust 17
# [ 5] 18:26:41.6 Customer 17 at (7049, 4500) signs off
# [ 5] 18:26:44.5 Driver drives to Customer 19 at (7950, 3804)
# [ 5] 18:33:07.8 Driver arrived at Customer 19 at (7950, 3804)
# [ 5] 18:33:10.5 Customer 19 at (7950, 3804) answers door
# [ 5] 18:33:10.5 Customer 19 at (7950, 3804) accepts Parcel 99 for cust 19
# [ 5] 18:33:30.1 Customer 19 at (7950, 3804) accepts Parcel 123 for cust 19
# [ 5] 18:33:58.8 Customer 19 at (7950, 3804) signs off
# [ 5] 18:34:02.4 Driver drives to Customer 9 at (3350, 6938)
# [ 5] 19:04:58.5 Driver arrived at Customer 9 at (3350, 6938)
# [ 5] 19:05:19.5 Customer 9 at (3350, 6938) answers door
# [ 5] 19:05:19.5 Customer 9 at (3350, 6938) accepts Parcel 110 for cust 9
# [ 5] 19:05:36.1 Customer 9 at (3350, 6938) signs off
# [ 5] 19:05:36.8 Driver drives to Customer 10 at (3350, 7037)
# [ 5] 19:06:00.5 Driver arrived at Customer 10 at (3350, 7037)
# [ 5] 19:06:41.5 Customer 10 at (3350, 7037) answers door
# [ 5] 19:06:41.5 Customer 10 at (3350, 7037) accepts Parcel 111 for cust 10
# [ 5] 19:06:42.9 Customer 10 at (3350, 7037) signs off
# [ 5] 19:06:46.3 Driver drives to Customer 11 at (3350, 7151)
# [ 5] 19:07:13.6 Driver arrived at Customer 11 at (3350, 7151)
# [ 5] 19:08:24.5 Customer 11 at (3350, 7151) answers door
# [ 5] 19:08:24.5 Customer 11 at (3350, 7151) accepts Parcel 112 for cust 11
# [ 5] 19:08:25.1 Customer 11 at (3350, 7151) accepts Parcel 113 for cust 11
# [ 5] 19:08:25.4 Customer 11 at (3350, 7151) signs off
# [ 5] 19:08:30.8 Driver drives to Customer 6 at (2200, 4047)
# [ 5] 19:25:31.8 Driver arrived at Customer 6 at (2200, 4047)
# [ 5] 19:25:58.9 Customer 6 at (2200, 4047) answers door
# [ 5] 19:25:58.9 Customer 6 at (2200, 4047) accepts Parcel 106 for cust 6
# [ 5] 19:26:18.8 Customer 6 at (2200, 4047) accepts Parcel 107 for cust 6
# [ 5] 19:26:31.4 Customer 6 at (2200, 4047) accepts Parcel 108 for cust 6
# [ 5] 19:26:42.6 Customer 6 at (2200, 4047) signs off
# [ 5] 19:26:44.2 Driver drives to Customer 3 at (1561, 5650)
# [ 5] 19:35:42.3 Driver arrived at Customer 3 at (1561, 5650)
# [ 5] 19:38:35.1 Customer 3 at (1561, 5650) answers door
# [ 5] 19:38:35.1 Customer 3 at (1561, 5650) accepts Parcel 102 for cust 3
# [ 5] 19:38:40.4 Customer 3 at (1561, 5650) accepts Parcel 103 for cust 3
# [ 5] 19:38:49.9 Customer 3 at (1561, 5650) signs off
# [ 5] 19:38:54.8 Driver drives to Customer 1 at (1050, 4197)
# [ 5] 19:46:46.1 Driver arrived at Customer 1 at (1050, 4197)
# [ 5] 19:46:48.1 Customer 1 at (1050, 4197) answers door
# [ 5] 19:46:48.1 Customer 1 at (1050, 4197) accepts Parcel 101 for cust 1
# [ 5] 19:46:54.4 Customer 1 at (1050, 4197) signs off
# [ 5] 19:46:56.1 Driver drives to Customer 0 at (1050, 3870)
# [ 5] 19:48:14.5 Driver arrived at Customer 0 at (1050, 3870)
# [ 5] 19:48:15.9 Customer 0 at (1050, 3870) answers door
# [ 5] 19:48:15.9 Customer 0 at (1050, 3870) accepts Parcel 100 for cust 0
# [ 5] 19:48:25.5 Customer 0 at (1050, 3870) signs off
# [ 5] 19:48:35.4 Driver drives to Customer 4 at (2200, 2395)
# [ 5] 19:59:05.4 Driver arrived at Customer 4 at (2200, 2395)
# [ 5] 19:59:09.9 Customer 4 at (2200, 2395) answers door
# [ 5] 19:59:09.9 Customer 4 at (2200, 2395) accepts Parcel 104 for cust 4
# [ 5] 19:59:17.8 Customer 4 at (2200, 2395) accepts Parcel 105 for cust 4
# [ 5] 19:59:22.1 Customer 4 at (2200, 2395) signs off
# [ 5] 19:59:26.9 Driver drives to Customer 8 at (2831, 2200)
# [ 5] 20:02:45.2 Driver arrived at Customer 8 at (2831, 2200)
# [ 5] 20:03:45.1 Customer 8 at (2831, 2200) answers door
# [ 5] 20:03:45.1 Customer 8 at (2831, 2200) accepts Parcel 109 for cust 8
# [ 5] 20:03:51.8 Customer 8 at (2831, 2200) signs off
# [ 5] 20:04:13.1 Driver returns to delivery centre
# [ 5] 20:25:08.6 Driver arrived at delivery centre
# [ 5] 20:25:08.6 7 parcels left for next day
# [ 5] 20:35:08.6 Driver goes home
# [ 6] 17:00:00.0 Parcel 124 for cust 0 arr at delivery centre
# [ 6] 17:00:00.0 Parcel 125 for cust 0 arr at delivery centre
# [ 6] 17:00:00.0 Parcel 126 for cust 2 arr at delivery centre
# [ 6] 17:00:00.0 Parcel 127 for cust 4 arr at delivery centre
# [ 6] 17:00:00.0 Parcel 128 for cust 5 arr at delivery centre
# [ 6] 17:00:00.0 Parcel 129 for cust 5 arr at delivery centre
# [ 6] 17:00:00.0 Parcel 130 for cust 5 arr at delivery centre
# [ 6] 17:00:00.0 Parcel 131 for cust 6 arr at delivery centre
# [ 6] 17:00:00.0 Parcel 132 for cust 6 arr at delivery centre
# [ 6] 17:00:00.0 Parcel 133 for cust 8 arr at delivery centre
# [ 6] 17:00:00.0 Parcel 134 for cust 8 arr at delivery centre
# [ 6] 17:00:00.0 Parcel 135 for cust 8 arr at delivery centre
# [ 6] 17:00:00.0 Parcel 136 for cust 11 arr at delivery centre
# [ 6] 17:00:00.0 Parcel 137 for cust 12 arr at delivery centre
# [ 6] 17:00:00.0 Parcel 138 for cust 13 arr at delivery centre
# [ 6] 17:00:00.0 Parcel 139 for cust 14 arr at delivery centre
# [ 6] 17:00:00.0 Parcel 140 for cust 14 arr at delivery centre
# [ 6] 17:00:00.0 Parcel 141 for cust 14 arr at delivery centre
# [ 6] 17:00:00.0 Parcel 142 for cust 16 arr at delivery centre
# [ 6] 17:00:00.0 Parcel 143 for cust 16 arr at delivery centre
# [ 6] 17:00:00.0 Parcel 144 for cust 16 arr at delivery centre
# [ 6] 17:00:00.0 Parcel 145 for cust 17 arr at delivery centre
# [ 6] 17:00:00.0 Parcel 146 for cust 18 arr at delivery centre
# [ 6] 17:00:00.0 Parcel 147 for cust 18 arr at delivery centre
# [ 6] 17:00:00.0 Parcel 148 for cust 19 arr at delivery centre
# [ 6] 17:00:00.0 Parcel 149 for cust 19 arr at delivery centre
# [ 6] 17:00:00.0 Parcel 150 for cust 19 arr at delivery centre
# [ 6] 18:00:00.0 Driver arrives for work
# [ 6] 18:00:00.0 Parcel 118 for cust 15 out for delivery
# [ 6] 18:00:00.0 Parcel 119 for cust 15 out for delivery
# [ 6] 18:00:00.0 Parcel 120 for cust 15 out for delivery
# [ 6] 18:00:00.0 Parcel 142 for cust 16 out for delivery
# [ 6] 18:00:00.0 Parcel 143 for cust 16 out for delivery
# [ 6] 18:00:00.0 Parcel 144 for cust 16 out for delivery
# [ 6] 18:00:00.0 Parcel 145 for cust 17 out for delivery
# [ 6] 18:00:00.0 Parcel 146 for cust 18 out for delivery
# [ 6] 18:00:00.0 Parcel 147 for cust 18 out for delivery
# [ 6] 18:00:00.0 Parcel 114 for cust 13 out for delivery
# [ 6] 18:00:00.0 Parcel 115 for cust 13 out for delivery
# [ 6] 18:00:00.0 Parcel 116 for cust 13 out for delivery
# [ 6] 18:00:00.0 Parcel 138 for cust 13 out for delivery
# [ 6] 18:00:00.0 Parcel 117 for cust 14 out for delivery
# [ 6] 18:00:00.0 Parcel 139 for cust 14 out for delivery
# [ 6] 18:00:00.0 Parcel 140 for cust 14 out for delivery
# [ 6] 18:00:00.0 Parcel 141 for cust 14 out for delivery
# [ 6] 18:00:00.0 Parcel 131 for cust 6 out for delivery
# [ 6] 18:00:00.0 Parcel 132 for cust 6 out for delivery
# [ 6] 18:00:00.0 Parcel 128 for cust 5 out for delivery
# [ 6] 18:00:00.0 Parcel 129 for cust 5 out for delivery
# [ 6] 18:00:00.0 Parcel 130 for cust 5 out for delivery
# [ 6] 18:00:00.0 Parcel 127 for cust 4 out for delivery
# [ 6] 18:00:00.0 Parcel 133 for cust 8 out for delivery
# [ 6] 18:00:00.0 Parcel 134 for cust 8 out for delivery
# [ 6] 18:00:00.0 Parcel 135 for cust 8 out for delivery
# [ 6] 18:00:00.0 Parcel 124 for cust 0 out for delivery
# [ 6] 18:00:00.0 Parcel 125 for cust 0 out for delivery
# [ 6] 18:00:00.0 Parcel 126 for cust 2 out for delivery
# [ 6] 18:00:00.0 Parcel 136 for cust 11 out for delivery
# [ 6] 18:00:00.0 Parcel 137 for cust 12 out for delivery
# [ 6] 18:25:50.0 Driver leaves for delivery of 31 parcels to 14 customers
# [ 6] 18:25:50.0 Length of delivery tour: 29,130m
# [ 6] 18:25:50.0 Driver drives to Customer 15 at (6800, 4858)
# [ 6] 18:36:27.9 Driver arrived at Customer 15 at (6800, 4858)
# [ 6] 18:37:05.6 Customer 15 at (6800, 4858) answers door
# [ 6] 18:37:05.6 Customer 15 at (6800, 4858) accepts Parcel 118 for cust 15
# [ 6] 18:37:11.9 Customer 15 at (6800, 4858) accepts Parcel 119 for cust 15
# [ 6] 18:37:21.9 Customer 15 at (6800, 4858) accepts Parcel 120 for cust 15
# [ 6] 18:37:26.0 Customer 15 at (6800, 4858) signs off
# [ 6] 18:37:27.3 Driver drives to Customer 16 at (6940, 4500)
# [ 6] 18:39:26.9 Driver arrived at Customer 16 at (6940, 4500)
# [ 6] 18:40:12.8 Customer 16 at (6940, 4500) answers door
# [ 6] 18:40:12.8 Customer 16 at (6940, 4500) accepts Parcel 142 for cust 16
# [ 6] 18:40:22.5 Customer 16 at (6940, 4500) accepts Parcel 143 for cust 16
# [ 6] 18:40:38.0 Customer 16 at (6940, 4500) accepts Parcel 144 for cust 16
# [ 6] 18:40:39.4 Customer 16 at (6940, 4500) signs off
# [ 6] 18:41:03.7 Driver drives to Customer 17 at (7049, 4500)
# [ 6] 18:41:29.8 Driver arrived at Customer 17 at (7049, 4500)
# [ 6] 18:42:34.1 Customer 17 at (7049, 4500) answers door
# [ 6] 18:42:34.1 Customer 17 at (7049, 4500) accepts Parcel 145 for cust 17
# [ 6] 18:42:59.0 Customer 17 at (7049, 4500) signs off
# [ 6] 18:43:19.6 Driver drives to Customer 18 at (7290, 4500)
# [ 6] 18:44:17.4 Driver arrived at Customer 18 at (7290, 4500)
# [ 6] 18:45:03.1 Customer 18 at (7290, 4500) answers door
# [ 6] 18:45:03.1 Customer 18 at (7290, 4500) accepts Parcel 146 for cust 18
# [ 6] 18:45:19.7 Customer 18 at (7290, 4500) accepts Parcel 147 for cust 18
# [ 6] 18:45:27.0 Customer 18 at (7290, 4500) signs off
# [ 6] 18:45:42.4 Driver drives to Customer 13 at (5650, 5058)
# [ 6] 18:54:29.9 Driver arrived at Customer 13 at (5650, 5058)
# [ 6] 18:54:38.3 Customer 13 at (5650, 5058) answers door
# [ 6] 18:54:38.3 Customer 13 at (5650, 5058) accepts Parcel 114 for cust 13
# [ 6] 18:54:53.6 Customer 13 at (5650, 5058) accepts Parcel 115 for cust 13
# [ 6] 18:54:59.5 Customer 13 at (5650, 5058) accepts Parcel 116 for cust 13
# [ 6] 18:55:13.6 Customer 13 at (5650, 5058) accepts Parcel 138 for cust 13
# [ 6] 18:55:19.7 Customer 13 at (5650, 5058) signs off
# [ 6] 18:55:35.2 Driver drives to Customer 14 at (5650, 6269)
# [ 6] 19:00:25.9 Driver arrived at Customer 14 at (5650, 6269)
# [ 6] 19:00:29.0 Customer 14 at (5650, 6269) answers door
# [ 6] 19:00:29.0 Customer 14 at (5650, 6269) accepts Parcel 117 for cust 14
# [ 6] 19:00:29.5 Customer 14 at (5650, 6269) accepts Parcel 139 for cust 14
# [ 6] 19:00:56.7 Customer 14 at (5650, 6269) accepts Parcel 140 for cust 14
# [ 6] 19:01:03.4 Customer 14 at (5650, 6269) accepts Parcel 141 for cust 14
# [ 6] 19:01:26.5 Customer 14 at (5650, 6269) signs off
# [ 6] 19:01:55.5 Driver drives to Customer 6 at (2200, 4047)
# [ 6] 19:24:36.7 Driver arrived at Customer 6 at (2200, 4047)
# [ 6] 19:25:20.7 Customer 6 at (2200, 4047) answers door
# [ 6] 19:25:20.7 Customer 6 at (2200, 4047) accepts Parcel 131 for cust 6
# [ 6] 19:25:29.1 Customer 6 at (2200, 4047) accepts Parcel 132 for cust 6
# [ 6] 19:25:31.6 Customer 6 at (2200, 4047) signs off
# [ 6] 19:25:32.6 Driver drives to Customer 5 at (2200, 2575)
# [ 6] 19:31:25.8 Driver arrived at Customer 5 at (2200, 2575)
# [ 6] 19:32:34.3 Customer 5 at (2200, 2575) answers door
# [ 6] 19:32:34.3 Customer 5 at (2200, 2575) accepts Parcel 128 for cust 5
# [ 6] 19:32:56.3 Customer 5 at (2200, 2575) accepts Parcel 129 for cust 5
# [ 6] 19:33:11.4 Customer 5 at (2200, 2575) accepts Parcel 130 for cust 5
# [ 6] 19:33:23.4 Customer 5 at (2200, 2575) signs off
# [ 6] 19:33:28.8 Driver drives to Customer 4 at (2200, 2395)
# [ 6] 19:34:12.0 Driver arrived at Customer 4 at (2200, 2395)
# [ 6] 19:34:26.6 Customer 4 at (2200, 2395) answers door
# [ 6] 19:34:26.6 Customer 4 at (2200, 2395) accepts Parcel 127 for cust 4
# [ 6] 19:34:27.8 Customer 4 at (2200, 2395) signs off
# [ 6] 19:34:33.3 Driver drives to Customer 8 at (2831, 2200)
# [ 6] 19:37:51.6 Driver arrived at Customer 8 at (2831, 2200)
# [ 6] 19:38:25.0 Customer 8 at (2831, 2200) answers door
# [ 6] 19:38:25.0 Customer 8 at (2831, 2200) accepts Parcel 133 for cust 8
# [ 6] 19:38:50.6 Customer 8 at (2831, 2200) accepts Parcel 134 for cust 8
# [ 6] 19:39:18.0 Customer 8 at (2831, 2200) accepts Parcel 135 for cust 8
# [ 6] 19:39:23.4 Customer 8 at (2831, 2200) signs off
# [ 6] 19:39:24.5 Driver drives to Customer 0 at (1050, 3870)
# [ 6] 19:53:12.7 Driver arrived at Customer 0 at (1050, 3870)
# [ 6] 19:54:12.2 Customer 0 at (1050, 3870) answers door
# [ 6] 19:54:12.2 Customer 0 at (1050, 3870) accepts Parcel 124 for cust 0
# [ 6] 19:54:25.4 Customer 0 at (1050, 3870) accepts Parcel 125 for cust 0
# [ 6] 19:54:25.7 Customer 0 at (1050, 3870) signs off
# [ 6] 19:54:31.6 Driver drives to Customer 2 at (1351, 5650)
# [ 6] 20:02:51.1 Driver arrived at Customer 2 at (1351, 5650)
# [ 6] 20:03:37.5 Customer 2 at (1351, 5650) answers door
# [ 6] 20:03:37.5 Customer 2 at (1351, 5650) accepts Parcel 126 for cust 2
# [ 6] 20:03:37.8 Customer 2 at (1351, 5650) signs off
# [ 6] 20:04:02.9 Driver drives to Customer 11 at (3350, 7151)
# [ 6] 20:18:02.9 Driver arrived at Customer 11 at (3350, 7151)
# [ 6] 20:20:14.0 Customer 11 at (3350, 7151) answers door
# [ 6] 20:20:14.0 Customer 11 at (3350, 7151) accepts Parcel 136 for cust 11
# [ 6] 20:20:26.8 Customer 11 at (3350, 7151) signs off
# [ 6] 20:20:27.6 Driver drives to Customer 12 at (4500, 7416)
# [ 6] 20:28:55.7 Driver arrived at Customer 12 at (4500, 7416)
# [ 6] 20:28:58.6 Customer 12 at (4500, 7416) answers door
# [ 6] 20:28:58.6 Customer 12 at (4500, 7416) accepts Parcel 137 for cust 12
# [ 6] 20:29:03.1 Customer 12 at (4500, 7416) signs off
# [ 6] 20:29:03.4 Driver returns to delivery centre
# [ 6] 20:40:43.2 Driver arrived at delivery centre
# [ 6] 20:40:43.2 3 parcels left for next day
# [ 6] 20:50:43.2 Driver goes home
# Delivery Centre Inventory: 3 parcels
