# %% [markdown]
# # Prelude

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import pulp
import math
import random
import pandas as pd
import numpy as np
import simpy

# %% [markdown]
# # Utilities

# %% [markdown]
# ## Points and Distances

# %%
def dist(p1, p2):
    (x1, y1) = p1
    (x2, y2) = p2
    return int(math.sqrt((x1-x2)**2+(y1-y2)**2))

# %% [markdown]
# ## PlotMap

# %%
def label(i):
    return (label(i//26-1)+chr(65+i%26)) if i>25 else chr(65+i)

# %%
def plotMap(G, T=[], P=[], w=None, frame=None,
            style='r-o', lw=1, ms=3, 
            styleT='go', msT=3,
            styleP='b-o', lwP=2, msP=3,
            stylePT='go', msPT=7,
            styleW='ro', msW=9,
            text=None, grid=False, labels=False, 
            size=4, scale=False):


    def round_down(x, level): return (x//level)*level
    def round_up(x, level): return (x//level+1)*level

    if frame is not None:
        V, E = frame
    else:
        V, E = G
        
    xmin = round_down(min([ x for (x, _) in V ]), 100)
    xmax = round_up(max([ x for (x, _) in V ]), 100)
    ymin = round_down(min([ y for (_, y) in V ]), 100)
    ymax = round_up(max([ y for (_, y) in V ]), 100)
    dx = xmax-xmin
    dy = ymax-ymin
    yoffset = (ymax-ymin)//10
    xoffset = (xmax-xmin)//20

    V, E = G

    fig = plt.gcf()
    fig.set_size_inches(size, size)
    plt.xlim(xmin-xoffset, xmax+xoffset)
    plt.ylim(ymin-yoffset, ymax+yoffset)
    
    if not grid:
        plt.axis('off')

    if frame is not None:
        for e in frame[1]:
            if e not in E:
                p1, p2 = e
                plt.plot( [ p1[0], p2[0] ],  [ p1[1], p2[1] ], 
                          'k-', lw=0.5, ms=2)
            
    for e in E:
        p1, p2 = e
        plt.plot( [ p1[0], p2[0] ],
                  [ p1[1], p2[1] ], 
                  style, lw=lw, ms=ms)
    if scale:
        # plot 1000m scale
        ybar = ymin-0.9*yoffset
        D = [ (xmin, ybar+50), (xmin, ybar), (xmin+1000, ybar), (xmin+1000, ybar+50) ]
        plt.plot( [ d[0] for d in D ], [ d[1] for d in D ], 'k-', lw=0.5)
        plt.text(xmin+500, ymin-0.7*yoffset, '1000m' , horizontalalignment='center', size=8)
    
    if labels:
        for i in range(len(V)):
            x, y = V[i]
            plt.text(x+0.0150*dx, y-0.0350*dy, label(i), size=8)
        
    for t in T:
        plt.plot( [ t[0] ], [ t[1] ], 
                  styleT, ms=msT)
        
    plt.plot( [ p[0] for p in P ],
              [ p[1] for p in P ], 
              styleP, lw=lwP, ms=msP)
    
    for p in P:
        if p in T:
            plt.plot( [ p[0] ], [ p[1] ], 
                      stylePT, ms=msPT)
    if w is not None:
        plt.plot( [ w[0] ], [ w[1] ], 
                      styleW, ms=msW)
    if text is not None:
        plt.text(xmax, ymin-0.9*yoffset, text, horizontalalignment='right', size=8)
    if grid:
        plt.grid()
    plt.show()

# %% [markdown]
# ## Add Targets

# %%
def addTargets(M, T):
    V, E = M
    E = E.copy()
    V = V.copy()
    for t in T:
        minD = math.inf
        minE = None
        for e in E:
            P, Q = e
            distT = dist(P, t)+dist(t, Q)-dist(P, Q)
            if distT < minD:
                minD = distT
                minE = e
        P, Q = minE
        E.remove( (P, Q) )
        E.append( (P, t) )
        E.append( (t, Q) )
        V.append(t)
    return V, E

# %% [markdown]
# ## Generate Central Warehouse Location

# %%
from statistics import median

def generateWarehouseLocation(M):
    V, _ = M
    xc = median([ x for (x, y) in V ])
    yc = median([ y for (x, y) in V ])
    cloc = (xc, yc)
    minloc = V[0]
    mindist = dist(minloc, cloc)
    for i in range(1, len(V)):
        d = dist(V[i], cloc)
        if d<mindist:
            minloc = V[i]
            mindist = dist(V[i], cloc)
    return minloc

# %% [markdown]
# ## Time Handling

# %% [markdown]
# **Convention:** In this project we measure simulation time in seconds. The simulation will start at 0:00. Time related methods will be added as they are needed.

# %% [markdown]
# `timestamp(t)` generates a timestamp string in the form `[dd] hh:mm:ss.d`

# %%
def timestamp(t):
    t = round(t, 1)
    day = int(t)//(24*3600)
    t = t - day*24*3600
    hour = int(t)//3600
    t = t - hour*3600
    mins = int(t)//60
    t = t - mins*60
    secs = int(t)
    t = int(round((t-secs)*10,1)) 
    return f"[{day:2d}] {hour:02d}:{mins:02d}:{secs:02d}.{t:1d}"

# %%
timestamp(24*3600*3+17*3600+615.1)
# Out:
# '[ 3] 17:10:15.1'

# %%
timestamp(24*3600*12+3*3600+122.1)
# Out:
# '[12] 03:02:02.1'

# %%
def day(now):
    return int(now//(24*3600))

# %%
def nextHour(env, hour):
    beginningOfDay = int(env.now//(24*3600))*24*3600
    timeOfDay = env.now-beginningOfDay
    if hour*3600 > timeOfDay:
        return hour*3600 - timeOfDay
    else:
        return hour*3600 + 24*3600 - timeOfDay

# %% [markdown]
# ## Plotting Routines

# %%
import scipy.stats as stats

def histPlot(data, title="", xlabel="",
             discrete=False, width=None, height=None):
    
    minx = min(data)
    maxx = max(data)
    μ = np.mean(data)
    σ = np.std(data)
    
    fig = plt.figure()
    fig.set_figwidth(width if width is not None else 4)
    fig.set_figheight(height if height is not None else 2.5)
    ax = fig.gca()

    if discrete:
        bins = [ i-0.5 for i in range(maxx+2) ]
        ax.xaxis.set_major_locator(mpl.ticker.MaxNLocator(integer=True))
        hist=plt.hist(data, bins=bins, rwidth=0.9, density=True)
    else:
        hist=plt.hist(data, density=True)
    plt.xlabel(xlabel)
    plt.ylabel('Density')
    plt.title(title)

    if discrete:
        poisson=stats.poisson(μ)
        x = [ i for i in range(maxx+1) ]
        y =[ poisson.pmf(i) for i in range(maxx+1) ]
        ax.plot(x, y, lw=1, color='red')
    else:
        x = np.linspace(minx, maxx, 100)
        y = [ stats.norm(loc=μ, scale=σ).pdf(p) for p in x]
        ax.plot(x, y, lw=1, color='red')
        
    ax.axvline(x=μ, color='red')
    maxy = max(max(y), max(hist[0]))
    ax.text(maxx, maxy, 
            f'μ={μ:2.2f}\nσ={σ:2.2f}', 
            ha='right', va='top', 
            color='red', fontsize=12)
    
    # ax.grid(True)
    plt.show()

def dailyPlot(data, 
              title="", ylabel="",
              width=None, height=None):
    
    days = len(data)
    
    fig = plt.figure()
    fig.set_figwidth(width if width is not None else 6)
    fig.set_figheight(height if height is not None else 2)
    
    ax = fig.gca()
    diff = (max(data)-min(data)+1)*0.1
    ymin = math.floor(min(data))-diff
    ymax = math.ceil(max(data))+diff
    ax.set_xlim(-0.5, days-1+0.5)
    ax.set_ylim(ymin-0.5, ymax+0.5)
    ax.grid(True)
    
    ms = 2 if len(data)>=100 else 3
    lw = 0.5 if len(data)>=100 else 1

    x = np.arange(0, len(data))
    y = np.array([ y for y in data ])
    b, m = np.polynomial.polynomial.polyfit(x, y, 1)
    ax.xaxis.set_major_locator(mpl.ticker.MaxNLocator(integer=True))
    ax.yaxis.set_major_locator(mpl.ticker.MaxNLocator(integer=True))
    
    plt.plot(x, y, 'bo-', linewidth=lw, markersize=ms)
    plt.plot(x, m*x+b, 'r-')
    
    plt.xlabel('Day')
    plt.ylabel(ylabel)
    plt.title(title)
    plt.show()

def countPlot(A, B, 
              title="", ylabel="",
              width=None, height=None):

    assert(len(A)==len (B))
    days = len(A)
    xmax = days-1
    ymax = A.max()
    
    fig = plt.figure()
    fig.set_figwidth(width if width is not None else 6)
    fig.set_figheight(height if height is not None else 4)
    ax = fig.gca()
    ax.set_xlim(-0.5, xmax+0.5)
    ax.set_ylim(0, ymax)
    
    def double(l, offset=0):
        return [] if l==[] else [l[0]+offset, l[0]+offset]+double(l[1:], offset)
            
    x = double([i for i in range(days)])+[days]
    xz = double([i+days*0.006 for i in range(days)])+[days]
    y = [0+ymax*0.006] + double(list(A), offset=ymax*0.006)
    z = [0] + double(list(B))
        
    ax.yaxis.set_major_locator(mpl.ticker.MaxNLocator(integer=True))
    ax.xaxis.set_major_locator(mpl.ticker.MaxNLocator(integer=True))

    for i in range(days):
        ax.fill_between([i, i+1], 
                        [z[2*i+1], z[2*i+2]], 
                        [y[2*i+1], y[2*i+2]], color='blue', alpha=0.2)

    lw = 1 if days>=50 or ymax>=100 else 2
    ax.plot(x, y, color='blue', lw=lw)
    ax.plot(xz, z, color='red', lw=lw)
    plt.xlabel('Day')
    plt.ylabel(ylabel)
    plt.title(title)
    ax.grid(True)
    plt.show()

# %% [markdown]
# # Finding Shortest Path (as before)

# %%
def pathLength(P):
    return 0 if len(P)<=1 else \
            dist(P[0], P[1])+pathLength(P[1:])

# %%
def shortestPath(M, A, B):

    def h(p): 
        return pathLength(p)+dist(p[-1],B)
    
    # candidates C are pairs of the path so far and 
    # the heuristic function of that path, 
    # sorted by the heuristic function, as maintained by
    # insert function
    def insert(C, p):
        hp = h(p)
        c = (p, hp)
        for i in range(len(C)):
            if C[i][1]>hp:
                return C[:i]+[c]+C[i:]
        return C+[c]   
        
    V, E = M
    assert(A in V and B in V)    
    C = insert([], [A])

    while len(C)>0:
        # take the first candidate out of the list of candidates
        path, _ = C[0]
        C = C[1:]
        if path[-1]==B:
            return path
        else:
            for (x, y) in E:
                if path[-1]==x and y not in path:
                    C = insert(C, path+[y])
                elif path[-1]==y and x not in path:
                    C = insert(C, path+[x])
    return None

# %% [markdown]
# # Finding Short Delivery Route (as before)

# %% [markdown]
# ## Greedy Algorithm

# %%
def FW(M):
    
    V, E = M

    n = len(V)
    d = [ [ math.inf for j in range(n) ] for i in range(n) ]
    p = [ [ None for j in range(n) ] for i in range(n) ]

    for (A, B) in E:
        a = V.index(A)
        b = V.index(B)
        d[a][b] = d[b][a] = dist(A, B)
        p[a][b] = [A, B]
        p[b][a] = [B, A]
    
    for i in range(n):
        d[i][i] = 0
        p[i][i] = [V[i]]
    
    for k in range(n):
        for i in range(n):
            for j in range(n):
                dk = d[i][k] + d[k][j]
                if d[i][j] > dk:
                    d[i][j] = dk
                    p[i][j] = p[i][k][:-1] + p[k][j]
                    
    return d, p

# %%
def createLoopG(M, T, timing=False):
    
    def makeLoop(L, V, P):
        loop = []
        for i in range(len(L)-1):
            A = L[i]
            B = L[i+1]
            a = V.index(A)
            b = V.index(B)
            sub = P[a][b]
            loop += sub if len(loop)==0 else sub[1:]
        return loop
        
    if timing:
        start_time = time.time()
        last_time = time.time()
    
    V, E = M
    D, P = FW(M)   # note these are the distances between all vertices in M (and T)
    W = T[0]
    customers = T[1:]
    if len(T)==1:
        L = T
    elif len(T)<=3:
        L = T + [T[0]]
    else:
        L = T[:3]+[T[0]]
        T = T[3:]
        while len(T)>0:
            
            minExt = math.inf
            minInd = None
            selInd = None
            for k in range(len(T)):
                C = T[k]
                c = V.index(C)
                for i in range(0, len(L)-1):
                    A = L[i]
                    B = L[i+1]
                    a = V.index(A)
                    b = V.index(B)
                    ext = D[a][c] + D[c][b] - D[a][b]
                    if ext<minExt:
                        minExt, minInd, selInd = ext, i+1, k
            L = L[:minInd]+[T[selInd]]+L[minInd:]
            T = T[:selInd]+T[selInd+1:]
            
    if timing:
        print(f"createLoopG:    {time.time()-start_time:6.2f}s")

    return makeLoop(L, V, P)

# %% [markdown]
# # Finding Optimal Delivery Route

# %% [markdown]
# ## Iterative Integer Programming

# %%
def createTables(M, T):

    def reverse(P):
        return [ P[-i] for i in range(1,len(P)+1) ]
    
    def index(x, L):
        for i in range(len(L)):
            if x==L[i]: 
                return i
        return None

    n = len(T)
    d = [ [ math.inf for t in T ] for t in T ]
    p = [ [ None for t in T ] for t in T ]
    for i in range(n):
        d[i][i] = 0
        p[i][i] = [ T[i] ]
    for i in range(n):
        for j in range(n):
            if p[i][j] is None:
                s = shortestPath(M, T[i], T[j])
                d[i][j] = d[j][i] = pathLength(s)
                p[i][j] = s
                p[j][i] = reverse(s)
                for m in range(len(s)-1):
                    smi = index(s[m], T)
                    if smi is None:
                        continue
                    for l in range(m+1, len(s)):
                        sli = index(s[l], T)
                        if sli is None:
                            continue  
                        sub = s[m:l+1]
                        if p[smi][sli] is None:
                            p[smi][sli] = sub
                            p[sli][smi] = reverse(sub)
                            d[smi][sli] = d[sli][smi] = pathLength(sub)
    return d,p

# %%
def roundtrips(x, n):
    
    def isElem(x, l):
        for i in range(len(l)):
            if l[i]==x:
                return True
        return False

    def startpoint(trips):
        for i in range(n):
            for t in trips:
                if isElem(i, t):
                    break
            else:
                return i
    
    def totalLength(trips):
        s=0
        for i in range(0, len(trips)):
            s += len(trips[i])-1
        return s

    trips = []
    while totalLength(trips)<n:
        start = startpoint(trips)
        trip = [ start ]
        i = start
        while len(trip) < n-totalLength(trips):
            for j in range(0, n):
                if pulp.value(x[i][j])==1:
                    trip.append(j)
                    i=j
                    break        
            if pulp.value(x[trip[-1]][start])==1:
                trip.append(start)
                break
        trips.append(trip)
    return sorted(trips, key=lambda t: len(t), reverse=True)

# %%
import time

def createLoop(M, T, timing=False):
    
    if timing:
        start_time = last_time = time.time()
        
    D, P = createTables(M, T)   # These are the distances between customers and warehouse only
    
    if timing:
        print(f"createTables:   {time.time()-start_time:6.2f}s")
        last_time = time.time()
        
    n = len(T)
    # create variables
    x = pulp.LpVariable.dicts("x", ( range(n), range(n) ),
                            lowBound=0, upBound=1, cat=pulp.LpInteger)
    # create problem
    prob = pulp.LpProblem("Loop",pulp.LpMinimize)
    # add objective function
    prob += pulp.lpSum([ D[i][j]*x[i][j] 
                             for i in range(n) for j in range(n) ])
    # add constraints
    constraints=0
    for j in range(n):
        prob += pulp.lpSum([ x[i][j] for i in range(n) if i!=j ]) ==1
    constraints += n
    for i in range(n):
        prob += pulp.lpSum([ x[i][j] for j in range(n) if i!=j ]) ==1
    constraints += n
    for i in range(n):
        for j in range(n):
            if i!=j:
                prob += x[i][j]+x[j][i] <= 1
                constraints += 1
                
    def cycles(k, n):
        if k==1:
            return [ [i] for i in range(0,n) ]
        else:
            sc=cycles(k-1, n)
            all=[]
            for c in sc:
                for i in range(0,n):
                    if c.count(i)==0:
                        all.append(c+[i])
            return all

    for k in range(3, 4):   
        cycs=cycles(k,n)
        for c in cycs:
            c.append(c[0])
            prob+=pulp.lpSum([ x[c[i]][c[i+1]] for i in range(0,k)]) <= k-1
            constraints += 1    
            
    # initialise solver
    solvers = pulp.listSolvers(onlyAvailable=True)
    solver = pulp.getSolver(solvers[0], msg=0, timeLimit=2)
    res = prob.solve(solver)

    if timing:
        print(f"Solver:         {time.time()-last_time:6.2f}s {constraints:6,d} Constraints")
        last_time = time.time()
        
    trips = roundtrips(x, n)
    while len(trips)>1:
        longest = max([ len(t) for t in trips ])
        for t in trips:
            if len(t)<longest:
                prob += pulp.lpSum([ x[t[i]][t[i+1]] + x[t[i+1]][t[i]]
                                        for i in range(0,len(t)-1) ]) <= len(t)-2
                constraints += 1
            else:
                longest = math.inf
                
        res = prob.solve(solver)
        
        if timing:
            print(f"Solver:         {time.time()-last_time:6.2f}s {constraints:6,d} Constraints")
            last_time = time.time()

        trips = roundtrips(x, n)
    trip = trips[0]
    # print(trip)
    loop = []
    for k in range(len(trip)-1):
        sub = P[trip[k]][trip[k+1]]
        loop += sub if len(loop)==0 else sub[1:]
        
    if timing:
        print(f"createLoop:     {time.time()-start_time:6.2f}s")

    return loop

# %% [markdown]
# # Static Route Assignment

# %% [markdown]
# ## Chinese Postman Problem

# %%
import time

def solveCPP(M, PostOffice, n=1, 
             maxLength=None, balance=None, 
             timing=False, timeLimit=10):

    start_time = time.time()
    
    V, E = M

    postoffice = V.index(PostOffice)

    def edge(e): return label(V.index(E[e][0]))+label(V.index(E[e][1]))
    def edges(l): return ",".join([ edge(i) for i in range(len(l)) if l[i]==1 ])
    def path(p): return '-'.join([ label(v) for v in p ])

    Edges = [ edge(e) for e in range(len(E)) ]

    b = pulp.LpVariable.dicts("B", (range(n), range(len(V))), lowBound=0, upBound=1, cat=pulp.LpInteger)

    y0 = pulp.LpVariable.dicts("Y0", (range(n), Edges), lowBound=0) # , upBound=len(E), cat=pulp.LpInteger)
    y1 = pulp.LpVariable.dicts("Y1", (range(n), Edges), lowBound=0) # , upBound=len(E), cat=pulp.LpInteger)
    yp0 = pulp.LpVariable.dicts("YP0", (range(n), Edges), lowBound=0) # , upBound=len(E), cat=pulp.LpInteger)
    yp1 = pulp.LpVariable.dicts("YP1", (range(n), Edges), lowBound=0) # , upBound=len(E), cat=pulp.LpInteger)
    yn0 = pulp.LpVariable.dicts("YN0", (range(n), Edges), lowBound=0) # , upBound=len(E), cat=pulp.LpInteger)
    yn1 = pulp.LpVariable.dicts("YN1", (range(n), Edges), lowBound=0) # , upBound=len(E), cat=pulp.LpInteger)
    
    e0 = pulp.LpVariable.dicts("E0", (range(n), Edges), lowBound=0, upBound=1, cat=pulp.LpInteger)
    e1 = pulp.LpVariable.dicts("E1", (range(n), Edges), lowBound=0, upBound=1, cat=pulp.LpInteger)
    dp0 = pulp.LpVariable.dicts("DP0", (range(n), Edges), lowBound=0, upBound=1, cat=pulp.LpInteger)
    dn0 = pulp.LpVariable.dicts("DN0", (range(n), Edges), lowBound=0, upBound=1, cat=pulp.LpInteger)
    dp1 = pulp.LpVariable.dicts("DP1", (range(n), Edges), lowBound=0, upBound=1, cat=pulp.LpInteger)
    dn1 = pulp.LpVariable.dicts("DN1", (range(n), Edges), lowBound=0, upBound=1, cat=pulp.LpInteger)

    def vars(l,x): return edges([ int(pulp.value(x[l][e])) for e in Edges ])
    def vals(l,x): return [ round(pulp.value(x[l][e]),1) for e in Edges ]
    
    prob = pulp.LpProblem("CPP", pulp.LpMinimize)

    def loopLength(l):
        return pulp.lpSum([ dist(v1,v2)*e0[l][e] for e in Edges for v1 in V for v2 in V if E[Edges.index(e)]==(v1, v2) ]) + \
               pulp.lpSum([ dist(v1,v2)*e1[l][e] for e in Edges for v1 in V for v2 in V if E[Edges.index(e)]==(v1, v2) ])
        
    prob += pulp.lpSum([ loopLength(l) for l in range(n) ])

    # avoid non-trivial loops
    # for l in range(n):
    #    prob += pulp.lpSum([ b[l][v] for v in range(len(V)) ]) >= 2, f"NT_{l}"
        
    if maxLength is not None:
        for l in range(n):
            prob += loopLength(l) <= maxLength, f"Max_{l}"

    if balance is not None:
        d = pulp.LpVariable.dicts("D", range(n), lowBound=0)
        
        for l in range(n):
            prob += d[l] == loopLength(l), f"D_{l}"
            
        for l in range(n):    
            prob += d[l] <= pulp.lpSum([ d[l] for l in range(n) ])*(1+balance)/n, f"DMAX_{l}"
            prob += d[l] >= pulp.lpSum([ d[l] for l in range(n) ])*(1-balance)/n, f"DMIN_{l}"
            
    # Constraint YE: Y-E Relationship [equivalent to (9)]
    BigM = 100*n*len(E)
    for e in Edges:
        for l in range(n):
            prob += y0[l][e] <= BigM*e0[l][e], f"YE0_{l}_{e}"
            prob += y1[l][e] <= BigM*e1[l][e], f"YE1_{l}_{e}"

    # Constraint C: counting [equivalent (8)]
    for v in range(len(V)):
        if v!=postoffice:
            for l in range(n):
                prob += pulp.lpSum([ yp0[l][e]+yp1[l][e] for e in Edges if E[Edges.index(e)][0]==V[v] ]) + \
                        pulp.lpSum([ yn0[l][e]+yn1[l][e] for e in Edges if E[Edges.index(e)][1]==V[v] ]) - \
                        pulp.lpSum([ yp0[l][e]+yp1[l][e] for e in Edges if E[Edges.index(e)][1]==V[v] ]) - \
                        pulp.lpSum([ yn0[l][e]+yn1[l][e] for e in Edges if E[Edges.index(e)][0]==V[v] ]) == -1*b[l][v], \
                        f"C_{l}_"+label(v)
    
    # Invariance Constraint F/B: Relation between variables in each loop every edge is passed this way or that way
    for e in Edges:        
        for l in range(n):
            prob += dp0[l][e]+dn0[l][e] == e0[l][e], f"EF_{l}_{e}"
            prob += dp1[l][e]+dn1[l][e] == e1[l][e], f"EB_{l}_{e}"     
    for e in Edges:        
        for l in range(n):
            prob += yp0[l][e]+yn0[l][e] == y0[l][e], f"YF_{l}_{e}"
            prob += yp1[l][e]+yn1[l][e] == y1[l][e], f"YB_{l}_{e}"   

    # Constraint E10: The duplicate edge is only used if the primary edge was used
    for e in Edges:        
        for l in range(n):
            prob += e1[l][e] <= e0[l][e], f"E10_{l}_{e}" 
    
    # Constraint O: Every edge is passed across all loops at least once [equivalent (2)]
    for e in Edges:
        prob += pulp.lpSum( [ e0[l][e]+e1[l][e] for l in range(n) ] ) >= 1, \
                    f"O_{e}"
        
    # Constraint M: In each loop every edge is passed at most twice [equivalent (7)]
    for e in Edges:        
        for l in range(n):
            prob += e0[l][e]+e1[l][e] <= \
              pulp.lpSum([ 2*b[l][v] for v in range(len(V)) if E[Edges.index(e)][0]==V[v] or E[Edges.index(e)][1]==V[v]]), \
                        f"M_{l}_{e}"

    # Constraint V: In each loop every vertex is entered as often as it is left [equivalent (3)]
    for v in range(len(V)):
        for l in range(n):
            prob += pulp.lpSum([ dp0[l][e]+dp1[l][e]-dn0[l][e]-dn1[l][e] for e in Edges if E[Edges.index(e)][0]==V[v] ]) + \
                    pulp.lpSum([ dn0[l][e]+dn1[l][e]-dp0[l][e]-dp1[l][e] for e in Edges if E[Edges.index(e)][1]==V[v] ]) == 0, \
                        f"V_{l}_"+label(v)

    # print(prob)
    
    solvers = pulp.listSolvers(onlyAvailable=True)
    solver = pulp.getSolver(solvers[0], msg=False, timeLimit=timeLimit)
    status = prob.solve(solver)

    solverTime = time.time()-start_time
        
    if timing:
        print(f"Solver time: {solverTime:7.2f}s")
                
    if status!=1:
        print(pulp.LpStatus[status])
        return []
        
    if solverTime >= timeLimit:
        print("Solution possibly not optimal")
        
    print(f"Total Delivery Path Length: {pulp.value(prob.objective)}")

    def solutions(l):

        DP0 = [ int(pulp.value(dp0[l][e])) for e in Edges ]
        DP1 = [ int(pulp.value(dp1[l][e])) for e in Edges ]
        DN0 = [ int(pulp.value(dn0[l][e])) for e in Edges ]
        DN1 = [ int(pulp.value(dn1[l][e])) for e in Edges ]

        E0 = [ int(pulp.value(e0[l][e])) for e in Edges ]
        E1 = [ int(pulp.value(e1[l][e])) for e in Edges ]

        # candidates C are the paths so far, 
        def insert(C, p): return [p]+C 

        def refine(c, v, e0=None, e1=None):
            assert(e0 is not None or e1 is not None)
            if e0 is not None:
                c0 = c[0].copy()
                c0[e0] = 0
                return (c0, c[1], c[2]+[V.index(v)])
            if e1 is not None:
                c1 = c[1].copy()
                c1[e1] = 0
                return (c[0], c1, c[2]+[V.index(v)])

        def isSolution(cand):
            return sum(cand[0])+sum(cand[1])==0
            
        C = [ (E0, E1, [ V.index(PostOffice) ]) ]
        solutions = []

        while len(C)>0:

            # take the first candidate out of the list of candidates
            cand, C = C[0], C[1:]
            
            if isSolution(cand): 
                # solutions.append(cand[2])
                return [ cand[2] ]
            else:
                last = cand[2][-1]
                for e in range(len(E)):
                    newCand = None
                    if V.index(E[e][0]) == last:  
                        ## print("edge", edge(e), 'forward extends', path(cand[2]))
                        # the edge begins in the current position
                        if cand[0][e] == 1 and DP0[e] == 1:
                            newCand = refine(cand, E[e][1], e0=e)
                        elif cand[1][e] == 1 and DP1[e] == 1:
                            newCand = refine(cand, E[e][1], e1=e) 
                    elif V.index(E[e][1]) == last:   # the edge ends in the current position
                        ## print("edge", edge(e), 'backwards extends', path(cand[2]))
                        if cand[0][e] == 1 and DN0[e] == 1:
                            newCand = refine(cand, E[e][0], e0=e)
                        elif cand[1][e] == 1 and DN1[e] == 1:
                            newCand = refine(cand, E[e][0], e1=e)
                    if newCand is not None:
                        # if isSolution(newCand): return [ newCand[2] ]
                        C = insert(C, newCand)

        return solutions
        
    return [ ( [ path(p) for p in solutions(l) ],  
               [ [ V[v] for v in p ] for p in solutions(l) ],  
               pulp.value(loopLength(l)) ) 
            for l in range(n) ]

# %%
def splitMap(fullMap, L, plot=False):
    Maps, Loops = [], []
    for l in range(len(L)):
        paths, loops, length = L[l]
        loop = loops[0]
        W = loop[0]

        V = []
        E = []
        for i in range(len(loop)-1):
            A, B = loop[i], loop[i+1]
            if A not in V:
                V.append(A)
            if (A, B) not in E and (B, A) not in E:
                E.append((A, B))
        subMap = V, E
        Maps.append(subMap)
        Loops.append(loop)

        if plot:
            #plotMap(fullMap, P=loop, w=W, 
            #        labels=True, scale=True, 
            #        text=f"Loop {l}: {int(length):7,d}m") 

            plotMap(subMap, w=W, frame=fullMap, scale=True, 
                    text=f"Map {l}: Full Roundtrip {int(length):,d}m")
        
    return Maps, Loops

# %% [markdown]
# `shortenLoop(L, T)` shortens a complete coverage loop `L` while adding new targets `T`

# %%
def shortenLoop(L, M, T):
    for t in T:
        minD = math.inf
        minI = None
        for i in range(len(L)-1):
            P, Q = L[i], L[i+1]
            distT = dist(P, t)+dist(t, Q)-dist(P, Q)
            if distT < minD:
                minD = distT
                minI = i
        L = L[:minI+1]+[t]+L[minI+1:]
    success = True
    while success:
        success = False
        for i in range(len(L)-1):
            P = L[i]
            for j in range(i+1, len(L)):
                Q = L[j]
                
                if Q in T:
                    shortcut = shortestPath(M, P, Q)
                    if pathLength(shortcut)<pathLength(L[i:j+1]):
                        L = L[:i]+shortcut+L[j+1:]
                        success = True
                    break
                if Q==P:
                    L = L[:i+1]+L[j+1:]
                    success = True
                    break
            if success:
                break
    return L

# %% [markdown]
# ## Split Customers into Regions

# %%
def pickRegion(C, Maps):
    options = []
    for m in range(len(Maps)):
        V, E = Maps[m]
        for (A, B) in E:  
            if dist(A, C)+dist(C, B) - dist(A, B) <= 1:
                options.append(m)
    return random.choice(options)

# %%
def splitCustomers(C, Maps):
    return [ pickRegion(C[i], Maps) for i in range(len(C)) ]

# %%
def groupCustomersByRegions(C, Maps):
    regions = splitCustomers(C, Maps)
    n = len(Maps)
    CC = [ [] for i in range(n) ]
    for i in range(n):
        for c in range(len(C)):
            if regions[c]==i:
                CC[i].append(C[c])
    return CC

# %% [markdown]
# ## Integrated Planning Using CPP

# %%
def planCPP(M, W, C, n=1, 
            maxLength=None, balance=None, 
            timing=False, timeLimit=10, plot=False):
    L = solveCPP(M, W, n=n, 
                 maxLength=maxLength, balance=balance, 
                 timing=timing, timeLimit=timeLimit)
    if len(L)==0: # unfeasible solution
        return [], [], []
        
    MM, LL = splitMap(M, L)
    CC = groupCustomersByRegions(C, MM)
    
    if plot:
        for i in range(len(MM)):
            plotMap(MM[i], w=W, frame=M, scale=True, 
                    text=f"Map {i}: Full Roundtrip {int(L[i][2]):,d}m")
            MMT = addTargets(MM[i], CC[i])
            path = shortenLoop(LL[i], MMT, [W] + CC[i])
            plotMap(MMT, T=CC[i], P=path, w=W, frame=M, lwP=1, msPT=3, 
                    text=f"Driver {i:d}:  {len(CC[i]):d} Customers, "
                         f"max Roundtrip: {pathLength(path):,d}m")
    return MM, LL, CC

# %%
def getRegions(CC, C):
    regions = [ None for _ in C ]
    for i in range(len(CC)):
        for c in CC[i]:
            regions[C.index(c)] = i
    return regions

# %% [markdown]
# # Class Recorder

# %% [markdown]
# We willl use a class Recorder as a reference point for capturing data during the simulation. There will be only one recorder. It will be created at the beginning of every simulation run. Every entity will carry a reference to the Recorder.

# %%
import time

class Recorder:
    
    def __init__(self, env, M, W, C, D, Plan, days,
                 log=False, plot=False, timing=False):
        self.env = env
        self.M = M
        self.W = W
        self.C = C
        self.D = D
        self.MM, self.LL, self.CC = Plan

        self.parcels = sum([ len(d) for d in D ])
        self.days = days
        self.drivers = len(self.MM)
        
        self.log = log
        self.plot = plot

        # create a data frame for time records per working day
        self.daily = [ pd.DataFrame() for d in range(self.drivers) ]

        for driver in range(self.drivers):
            self.daily[driver]['begin work at'] = [None]*days
            self.daily[driver]['end work at'] = [None]*days
            self.daily[driver]['tour length'] = [None]*days

            self.daily[driver]['parcels left over'] = [0]*days
            self.daily[driver]['parcels arrived'] = [0]*days
            self.daily[driver]['parcels out for delivery'] = [0]*days
            self.daily[driver]['parcels returned from delivery'] = [0]*days
            self.daily[driver]['parcels delivered'] = [0]*days
        

        self.parcel = pd.DataFrame()
        self.parcel['arrived at'] = [None]*self.parcels
        self.parcel['delivered at'] = [None]*self.parcels
        
    def trace(self, event, driver=None):
        if self.log:
            prefix = "" if driver is None else f"D{driver.id:d}: "
            print(timestamp(self.env.now), prefix+event)

    def recordDriverBeginsWork(self, driver):
        self.trace("arrives for work", driver)
        self.daily[driver.id].at[day(self.env.now), 'begin work at'] = int(round(self.env.now))
        
    def recordDriverEndsWork(self, driver):
        self.trace("goes home", driver)
        self.daily[driver.id].at[day(self.env.now), 'end work at'] = int(round(self.env.now))
        
    def recordTourLength(self, driver, length):
        self.daily[driver.id].at[day(self.env.now), 'tour length'] = int(length)

    def recordParcelArrived(self, driver, parcel):
        self.trace(str(parcel)+" arr at delivery centre", driver)
        today = day(self.env.now)
        self.daily[driver.id].at[today, 'parcels arrived'] += 1
        self.parcel.at[parcel.i, 'arrived at'] = today

    def recordParcelOutForDelivery(self, driver, parcel):
        self.trace(str(parcel)+" out for delivery", driver)
        self.daily[driver.id].at[day(self.env.now), 'parcels out for delivery'] += 1
   
    def recordParcelReturnedFromDelivery(self, driver, parcel):
        self.trace(str(parcel)+" returned from delivery", driver)
        self.daily[driver.id].at[day(self.env.now), 'parcels returned from delivery'] += 1

    def recordParcelDelivered(self, driver, parcel):
        self.trace(str(parcel)+" delivered", driver)
        today = day(self.env.now)
        self.daily[driver.id].at[today, 'parcels delivered'] += 1
        self.parcel.at[parcel.i, 'delivered at'] = today
        
    def recordParcelsLeftOver(self, driver, n):
        self.trace(f"{n:d} parcels left over for next day", driver)
        self.daily[driver.id].at[day(self.env.now), 'parcels left over'] = n
        
    def finish(self):
        # simulation is finished for good
        # by removing the simulation environment we can
        # pickle recorder
        self.env = None

        for driver in range(self.drivers):
            self.daily[driver]['working time'] = (self.daily[driver]['end work at']-self.daily[driver]['begin work at'])//60
            self.daily[driver]['cost'] = self.daily[driver]['working time'].apply(lambda x: max(60, x*30/60))
            self.daily[driver]['cost'] += 0.08/1000*self.daily[driver]['tour length']

        self.parcel['delivery delay'] = self.parcel['delivered at']-self.parcel['arrived at']

        self.totalDaily = pd.DataFrame()
        self.totalDaily['cum arrival'] = self.__Data('parcels arrived').cumsum()
        self.totalDaily['cum delivery'] = self.__Data('parcels delivered').cumsum()

    # the Title() and Data() functions have been introduced
    # solely to maintain the code of the plot/hist methods below
    # as far as possible
    
    def __Title(self, title, driver):
        return ("Total " if driver is None else "") + \
                title + \
                " (" + f"{self.days:d} days" + \
                ("" if driver is None else f", Driver {driver:d} only") +")"
        
    def __Data(self, col, driver=None):
        if driver is None:
            total = pd.DataFrame()
            total['sum'] = [0] * self.days
            for d in range(self.drivers):
                total['sum'] += self.daily[d][col]
            return total['sum']
        else:
            return self.daily[driver][col]
        
    def histWorkingTime(self, driver=None):
        histPlot(self.__Data('working time', driver),
                 xlabel='Working Time [min]',
                 title=self.__Title('Daily Working Time', driver))
        
    def plotWorkingTime(self, driver=None):
        dailyPlot(self.__Data('working time', driver),
                  ylabel='Working Time [min]',
                  title=self.__Title('Daily Working Time', driver))

    def histTourLength(self, driver=None):
        histPlot(self.__Data('tour length', driver),
                 xlabel='Tour Length [m]',
                 title=self.__Title('Daily Tour Length', driver))
            
    def plotTourLength(self, driver=None):
        dailyPlot(self.__Data('tour length', driver),
                  ylabel='Tour Length [m]',
                  title=self.__Title('Daily Tour Length', driver))

    def histDailyCost(self, driver=None):
        histPlot(self.__Data('cost', driver),
                 xlabel='Cost [€]',
                 title=self.__Title('Daily Cost', driver))
            
    def plotDailyCost(self, driver=None):
        dailyPlot(self.__Data('cost', driver),
                  ylabel='Cost [€]',
                  title=self.__Title('Daily Cost', driver))

    def histParcelsArrived(self, driver=None):
        histPlot(self.__Data('parcels arrived', driver),
                 discrete=True,
                 xlabel='Parcels Arrived',
                 title=self.__Title('Daily Parcels Arrived', driver))
                
    def plotParcelsArrived(self, driver=None):
        dailyPlot(self.__Data('parcels arrived', driver),
                  ylabel='Parcels',
                  title=self.__Title('Parcels Arrived Daily', driver))

    def histParcelsOutForDelivery(self, driver=None):
        histPlot(self.__Data('parcels out for delivery', driver),
                 discrete=True,
                 xlabel='Parcels',
                 title=self.__Title('Parcels Daily out for Delivery', driver))
        
    def plotParcelsOutForDelivery(self, driver=None):
        dailyPlot(self.__Data('parcels out for delivery', driver),
                  ylabel='Parcels',
                  title=self.__Title('Parcels Daily out for Delivery', driver))
        
    def histParcelsReturnedFromDelivery(self, driver=None):
        histPlot(self.__Data('parcels returned from delivery', driver),
                 discrete=True,
                 xlabel='Parcels',
                 title=self.__Title('Parcels Daily Returned From Delivery', driver))
                
    def plotParcelsReturnedFromDelivery(self, driver=None):
        dailyPlot(self.__Data('parcels returned from delivery', driver),
                  ylabel='Parcels',
                  title=self.__Title('Daily Parcels Returned From Delivery', driver))

    def histParcelsDelivered(self, driver=None):
        histPlot(self.__Data('parcels delivered', driver),
                 discrete=True,
                 xlabel='Parcels',
                 title=self.__Title('Parcels Delivered Daily', driver))

    def plotParcelsDelivered(self, driver=None):
        dailyPlot(self.__Data('parcels delivered', driver),
                  ylabel='Parcels',
                  title=self.__Title('Parcels Delivered Daily', driver))

    def histParcelsLeftOver(self, driver=None):
        histPlot(self.__Data('parcels left over', driver),
                 discrete=True,
                 xlabel='Parcels',
                 title=self.__Title('Daily Left-Over Parcels', driver))
                
    def plotParcelsLeftOver(self, driver=None):
        dailyPlot(self.__Data('parcels left over', driver),
                  ylabel='Parcels',
                  title=self.__Title('Daily Left-Over Parcels', driver))

    def countPlot(self):
        countPlot(self.totalDaily['cum arrival'], 
                  self.totalDaily['cum delivery'], 
                  ylabel='Parcels',
                  title=f'Parcel Arrival/Delivery ({self.parcels:3,d} Parcels, {self.days:d} Days)')
        
    def histParcelDeliveryDelay(self):
        histPlot(self.parcel['delivery delay'].dropna(), 
                 discrete=True,
                 xlabel='Days',
                 title=f'Parcel Delivery Delay in Days ({self.parcels:3,d} Parcels)')

# %% [markdown]
# # Class Customer

# %% [markdown]
# <img src='img/EventGraph Customer.png' width=500/>

# %%
class Customer:
    
    def __init__(self, rec, id, location):
        self.rec = rec
        self.id = id
        self.location = location
        self.atHome = True
        self.answersDoor = False
        self.parcelsReceived = []
        rec.env.process(self.process())
        
    def __str__(self):
        return f"Customer {self.id:d} at {str(self.location):s}"
    
    def leaveHouse(self):
        assert(self.atHome and not self.answersDoor)
        # self.rec.trace(str(self)+" leaves house")
        self.atHome = False
     
    def returnHome(self):
        assert(not self.atHome)
        # self.rec.trace(str(self)+" returns home")
        self.atHome = True
        
    def answerDoor(self, driver):
        if self.atHome:
            answerTime = random.expovariate(1/AVG_TIME_ANSWER_DOOR)
            if answerTime < WAIT_TIME_IF_CUSTOMER_DOESNT_ANSWER_DOOR:                            
                yield self.rec.env.timeout(answerTime)
                self.rec.trace(str(self)+" answers door", driver)
                self.answersDoor = True
            else:
                yield self.rec.env.timeout(WAIT_TIME_IF_CUSTOMER_DOESNT_ANSWER_DOOR)
                self.rec.trace(str(self)+" to slow to answer the door", driver)
                self.answersDoor = False
        else:
            yield self.rec.env.timeout(WAIT_TIME_IF_CUSTOMER_DOESNT_ANSWER_DOOR)
            self.rec.trace(str(self)+" not at home", driver)
            self.answersDoot = False
            
    def acceptParcel(self, driver, parcel):
        assert(self.answersDoor)
        self.parcelsReceived += [parcel]
        self.rec.recordParcelDelivered(driver, parcel)
        
    def signOff(self, driver):
        assert(self.answersDoor)
        self.rec.trace(str(self)+" signs off", driver)
        self.answersDoor = False
        
    def process(self):
        yield self.rec.env.timeout(nextHour(self.rec.env, 8))
        while day(self.rec.env.now)<self.rec.days:
            # in a refinement we may use random times
            self.leaveHouse()
            returnTime = 22 if random.random()<CUSTOMER_NOT_AT_HOME else 18
            yield self.rec.env.timeout(nextHour(self.rec.env, returnTime))
            self.returnHome()
            yield self.rec.env.timeout(nextHour(self.rec.env, 8))

# %% [markdown]
# # Class Parcel

# %% [markdown]
# <img src='img/EventGraph Parcel.png' width=500/>

# %% [markdown]
# Parcels follow through a sequence of states:
# - processing
# - in transit (from manufacture to distribution centre)
# - arrived in distribution centre
# - ready for delivery
# - out for delivery
# - customer not present
# - returned to distribution centre
# - delivered

# %%
class Parcel:
    
    def __init__(self, rec, i, day, cust):
        self.rec = rec
        self.i = i  
        self.arrival = day
        self.cust = cust
        self.status = [  ] # status record and
        self.timing = [  ] # timing

    def __str__(self):
        return f"Parcel {self.i:d} (for cust {self.cust.id:d}"

    def index(self):
        return self.i
    
    def destination(self):
        return self.cust.location
    
    def __reg(self, state):
        self.status += [ state ]
        self.timing += [ self.rec.env.now ]
        
    def arrivedAtDeliveryCentre(self, driver):
        self.__reg('arr at delivery centre')
        self.rec.recordParcelArrived(driver, self)
        
    def outForDelivery(self, driver): 
        self.__reg('out for delivery')
        self.rec.recordParcelOutForDelivery(driver, self)
        
    def returnFromDelivery(self, driver):
        self.__reg('return from delivery')
        self.rec.recordParcelReturnedFromDelivery(driver, self)

# %% [markdown]
# # Class Driver

# %% [markdown]
# <img src='img/EventGraph Driver.png' width=500/>

# %%
class Driver:
    
    def __init__(self, rec, id, DC):
        self.rec = rec
        self.id = id
        self.DC = DC
        self.location = None
        self.parcels = None
        self.returns = None
        self.tour = None
        self.rec.env.process(self.process())
        
    # activity
    def __drive(self, target):
        assert(self.tour[0] == self.location)
        while self.location!=target:
            d = dist(self.location, self.tour[1])
            yield self.rec.env.timeout(d / AVG_SPEED)
            self.location = self.tour[1]
            self.tour = self.tour[1:]
        assert(self.tour[0] == self.location == target)
    
    def arriveForWork(self):
        self.location = self.DC.W
        self.parcels = []
        self.returns = []
        self.tour = [ self.DC.W ]
        # self.rec.trace("arrives for work", self)
        self.rec.recordDriverBeginsWork(self)
    
    def goesHome(self):
        self.location = None
        self.parcels = None
        self.returns = None
        self.tour = None
        # self.rec.trace("goes home", self)
        self.rec.recordDriverEndsWork(self)
        
    def leaveForDelivery(self, tour, parcels, addresses):
        self.tour, self.parcels = tour, parcels
        self.rec.trace(f"leaves for delivery " 
                       f"of {len(parcels):d} parcels "
                       f"to {len(addresses):d} customers", self)
        self.rec.trace(f"Length of delivery tour: {pathLength(tour):,d}m", self)
        if self.rec.plot:
            plotMap(self.rec.Maps[self.id], frame=self.rec.M,
                    T=addresses, P=tour, w=tour[0], 
                    text=f"Day {day(self.rec.env.now):d} D{self.id:d}: {pathLength(tour):,d}m")
        
    def process(self):
        yield self.rec.env.timeout(nextHour(self.rec.env, 18))
        while day(self.rec.env.now)<self.rec.days:
            self.arriveForWork()

            ## chnge to deal with time limit
            startTime = self.rec.env.now 
            
            tour, parcels, addresses = self.DC.sendForDelivery(self)
            if len(parcels)==0: 
                self.rec.trace("Nothing to do today", self)
                self.rec.recordTourLength(self, 0)
            else:
                yield self.rec.env.timeout(PREP_TIME_PER_PARCEL*len(parcels))
                self.rec.recordTourLength(self, pathLength(tour))
                self.leaveForDelivery(tour, parcels, addresses)        
                while len(self.parcels)>0:

                    ## change to deal with time limit
                    currentTime = self.rec.env.now
                    if currentTime-startTime>=self.DC.timeLimit:
                        self.rec.trace("Timelimit reached", self)
                        while len(self.parcels)>0:
                            self.returns += [self.parcels[0]]
                            self.parcels = self.parcels[1:]
                        break
                        
                    # drive to customer
                    custLocation = self.parcels[0].destination()
                    cust = self.parcels[0].cust
                    self.rec.trace("drives to "+str(cust), self)
                    yield from self.__drive(custLocation)
                    self.rec.trace("arrived at "+str(cust), self)
                    # call at customer
                    yield from cust.answerDoor(self)
                    
                    if cust.answersDoor:
                        while len(self.parcels)>0 and \
                                custLocation == self.parcels[0].destination():
                            cust.acceptParcel(self, self.parcels[0])
                            yield self.rec.env.timeout(random.expovariate(1/AVG_TIME_HANDOVER))
                            self.parcels = self.parcels[1:]
                        cust.signOff(self)
                        yield self.rec.env.timeout(random.expovariate(1/AVG_TIME_SIGNOFF))
                    else:
                        while len(self.parcels)>0 and  \
                                custLocation == self.parcels[0].destination():
                            self.returns += [self.parcels[0]]
                            self.parcels = self.parcels[1:]

                # return to delivery centre
                self.rec.trace("returns to delivery centre", self)
                yield from self.__drive(self.DC.W)
                self.rec.trace("arrived at delivery centre", self)

                for parcel in self.returns:
                    self.DC.returnFromDelivery(self, parcel)
                    yield self.rec.env.timeout(RETURN_TIME_PER_PARCEL)
                            
            self.rec.recordParcelsLeftOver(self,
                                           len(self.returns)+
                                           len(self.DC.leftOver[self.id]))
            
            yield self.rec.env.timeout(DAY_END_PROCEDURE)

            self.goesHome()
            
            yield self.rec.env.timeout(nextHour(self.rec.env, 18))

# %% [markdown]
# # Class Delivery Centre

# %% [markdown]
# <img src="img/EventGraph Delivery Centre.png" width=300/>

# %%
class DeliveryCentre:
    
    def __init__(self, rec, M, W, C, D, Plan,
                 limit, timeLimit):
        self.rec = rec
        self.M = M
        self.W = W
        self.C = C
        self.D = D
        self.MM, self.LL, self.CC = Plan
        
        self.limit = limit
        self.timeLimit = timeLimit

        self.overhang = []   # list of parcels to be delivered next day

        # generate and initialise all customers
        # allows mapping from custId to Customer object
        self.customers = [ Customer(rec, i, C[i]) for i in range(len(C)) ]
        
        # generate and initialise all drivers
        self.drivers = [ Driver(rec, i, self) for i in range(len(self.MM)) ]

        self.PARCELS = []    # registry of all the parcels processed
        
        rec.env.process(self.process())
        
    def __accept(self, d, parcel):
        custLoc = parcel.destination()
        
        assert(0<=d<len(self.MM))
        
        ## chnge to deal with time limit estimate
        timeEstimate = \
            len(self.parcels[d])*(PREP_TIME_PER_PARCEL + AVG_TIME_HANDOVER) \
            + len(self.dest[d])*(AVG_TIME_ANSWER_DOOR + AVG_TIME_SIGNOFF)
        
        if custLoc not in self.dest[d]:

            targets = [self.W] + self.dest[d] + [custLoc]

            if self.rec.plot:
                plotMap(self.MM[d], T=targets,  w=self.W, frame=self.M, 
                    size=2, text=f"Driver {d:d}: accept Parcel")

            MT = addTargets(self.MM[d], targets)
            SH = createLoopG(MT, targets)

            MT = addTargets(self.MM[i], targets)
            path = shortenLoop(self.LL[i], MT, targets)

            ## chnge to deal with time limit estimate
            if pathLength(SH)<self.limit and \
                timeEstimate + pathLength(SH)/AVG_SPEED + \
                PREP_TIME_PER_PARCEL + AVG_TIME_ANSWER_DOOR + \
                AVG_TIME_HANDOVER + AVG_TIME_SIGNOFF <= self.timeLimit:
            
                self.parcels[d].append(parcel)
                self.dest[d] += [custLoc]
                self.tour[d] = SH
            else: 
                self.leftOver[d].append(parcel)

            ## chnge to deal with time limit estimate
        elif timeEstimate + pathLength(self.tour[d])/AVG_SPEED + \
                PREP_TIME_PER_PARCEL + AVG_TIME_HANDOVER <= self.timeLimit:
            self.parcels[d].append(parcel)
        else:
            self.leftOver[d].append(parcel)
        
    def sendForDelivery(self, driver):
        d = driver.id
        parcels = []
        tour = self.tour[d]
        addresses = []
        
        # pick parcels in sequence to be delivered
        for i in range(1, len(tour)-1):
            dest = tour[i]
            for p in self.parcels[d]:
                if p.destination() == dest and p not in parcels:
                    parcels += [p]
                    p.outForDelivery(driver)
                    if dest not in addresses:
                        addresses += [dest]
         
        # what cant go out goes straigt for next day
        for p in self.leftOver[d]:
            self.overhang.append(p)
            
        return tour, parcels, addresses
                 
    def returnFromDelivery(self, driver, parcel):
        parcel.returnFromDelivery(driver)
        self.overhang.append(parcel)
        
    def getInventory(self):
        return len(self.overhang)
        
    def process(self):
        regions = getRegions(self.CC, self.C)
        for day in range(len(self.D)):
            yield self.rec.env.timeout(nextHour(self.rec.env, 17.00))
            # make plan how to split workload for the day

            # initialise the workload for all drivers
            self.leftOver = [ [] for driver in self.drivers ]   # list of parcels that can't go out today
            self.parcels = [ [] for driver in self.drivers ]    # list of parcels scheduled for delivery
            self.dest = [ [] for driver in self.drivers ]       # list of unique customer destinations
            self.tour = [ [self.W] for driver in self.drivers ] # tour planned for delivery
            
            # process overhang from previous day (if any)
            for p in self.overhang:
                driverId = regions[p.cust.id]
                self.__accept(driverId, p)
            self.overhang = []

            # generate the parcels newly arriving this day
            for c in self.D[day]:
                parcel = Parcel(self.rec, len(self.PARCELS), 
                                day, self.customers[c])
                self.PARCELS.append(parcel)
                driverId = regions[c]
                parcel.arrivedAtDeliveryCentre(self.drivers[driverId])
                self.__accept(driverId, parcel)

# %% [markdown]
# # Simulation

# %% [markdown]
# ## Parameters from Specification

# %% [markdown]
# The hard time limit for the driver. When this time limit is reached
# on a delivery tour, the driver is supposed to return immediately

# %%
DELIVERY_TIME_LIMIT = 3*3600 # 3 hours

# %% [markdown]
# The proportion of customers that for whatever are not at home or return home late

# %%
CUSTOMER_NOT_AT_HOME = 0.1  # 10%

# %% [markdown]
# The maximum bike range. This is passed as parameter to the Delivery Centre
# and taken into account for the daily tour planning

# %%
BIKE_RANGE = 40000

# %% [markdown]
# The time required for driving is based on the distance between way points at an average speed of 15km/h.

# %%
AVG_SPEED = 15/3.6

# %% [markdown]
# The **cumulative preparation time** (route planning and
# sorting of the parcels in the delivery order and
# packing the cargo-bike) is assumed to be 50 sec per
# parcel to be delivered.

# %%
PREP_TIME_PER_PARCEL = 50

# %% [markdown]
# **Additional assumption:** The time to **process returned parcels** in the delivery centre is 30 sec per parce.

# %%
RETURN_TIME_PER_PARCEL = 30

# %% [markdown]
# The average time to answer the door.

# %%
AVG_TIME_ANSWER_DOOR = 40

# %%
WAIT_TIME_IF_CUSTOMER_DOESNT_ANSWER_DOOR = 60

# %%
AVG_TIME_HANDOVER = 10
AVG_TIME_SIGNOFF = 10

# %%
DAY_END_PROCEDURE = 600

# %% [markdown]
# ## Generate Input Data

# %%
def generateDeliveries(p, C, days, seed=0):
    ## p is the average number of parcels per day per customer
    ## C is the number of customers to be served
    ## days is the number of days for which data are to be generated.
    random.seed(seed)
    deliveries = [ [ ] for _ in range(days) ]
    for c in range(C):
        arr = 0
        while True:
            arr += random.expovariate(p)
            day = int(arr)
            if day>=days:
                break
            deliveries[day].append(c)
    return deliveries

# %% [markdown]
# ## Simulation Routine

# %%
def simulation(M, W, C, Plan, p=0.2, days=10, seed=0, 
               log=False, plot=False, timing=False):

    random.seed(seed)
    D = generateDeliveries(p, len(C), days, seed)
    
    env = simpy.Environment()
    rec = Recorder(env, M, W, C, D, Plan, days,
                   log=log, plot=plot, timing=timing)

    print(f"Simulating delivery of {sum([len(d) for d in D]):d} parcels "
          f"over {len(D):d} days to {len(C):d} customers "
          f"using {rec.drivers:d} drivers")

    # initialise all customer processes
    # initialises delivery center and creates all parcels
    DC = DeliveryCentre(rec, M, W, C, D, Plan,
                        BIKE_RANGE, DELIVERY_TIME_LIMIT)

    env.run()
    rec.finish()

    if DC.getInventory()>0:
        print(f"Delivery Centre Inventory at the end of last day: "
              f"{DC.getInventory():d} parcels")
    
    return rec

# %% [markdown]
# ## Testing

# %% [markdown]
# ### Simple Test Case

# %%
import pickle
with open('simpleData.pickled', 'rb') as f:
    MS, CS = pickle.load(f)

# %%
WS = generateWarehouseLocation(MS)

# %%
plotMap(MS, T=CS, w=WS, scale=True, size=3)

# %%
PlanS = planCPP(MS, WS, CS, n=2, balance=0.2, timing=True, plot=True)
# Out:
# Solver time:   10.34s
# Solution possibly not optimal
# Total Delivery Path Length: 73365.0

# %% [markdown]
# Comparison with Greedy Solution using Static Allocation shows equal performance:

# %%
MMS, LLS, CCS = PlanS
for i in range(len(MMS)):
    print(f"Driver {i:d}")
    MTS = addTargets(MMS[i], CCS[i])
    path = createLoopG(MTS, [WS] + CCS[i])
    plotMap(MTS, T=CCS[i], P=path, w=WS, frame=MS, 
            size=3, text=f"Driver {i:d}: {pathLength(path):,d}m")
# Out:
# Driver 0
# Driver 1

# %%
rec1 = simulation(MS, WS, CS, PlanS, p=0.3, days=7, log=True)
# Out:
# Simulating delivery of 201 parcels over 7 days to 100 customers using 2 drivers
# [ 0] 17:00:00.0 D0: Parcel 0 (for cust 13 arr at delivery centre
# [ 0] 17:00:00.0 D1: Parcel 1 (for cust 15 arr at delivery centre
# [ 0] 17:00:00.0 D0: Parcel 2 (for cust 16 arr at delivery centre
# [ 0] 17:00:00.0 D0: Parcel 3 (for cust 18 arr at delivery centre
# [ 0] 17:00:00.0 D0: Parcel 4 (for cust 19 arr at delivery centre
# [ 0] 17:00:00.0 D1: Parcel 5 (for cust 38 arr at delivery centre
# [ 0] 17:00:00.0 D0: Parcel 6 (for cust 40 arr at delivery centre
# [ 0] 17:00:00.0 D1: Parcel 7 (for cust 45 arr at delivery centre
# [ 0] 17:00:00.0 D1: Parcel 8 (for cust 45 arr at delivery centre
# [ 0] 17:00:00.0 D0: Parcel 9 (for cust 46 arr at delivery centre
# [ 0] 17:00:00.0 D0: Parcel 10 (for cust 48 arr at delivery centre
# [ 0] 17:00:00.0 D0: Parcel 11 (for cust 50 arr at delivery centre
# [ 0] 17:00:00.0 D1: Parcel 12 (for cust 52 arr at delivery centre
# [ 0] 17:00:00.0 D0: Parcel 13 (for cust 53 arr at delivery centre
# [ 0] 17:00:00.0 D1: Parcel 14 (for cust 55 arr at delivery centre
# [ 0] 17:00:00.0 D0: Parcel 15 (for cust 57 arr at delivery centre
# [ 0] 17:00:00.0 D0: Parcel 16 (for cust 70 arr at delivery centre
# [ 0] 17:00:00.0 D0: Parcel 17 (for cust 77 arr at delivery centre
# [ 0] 17:00:00.0 D1: Parcel 18 (for cust 78 arr at delivery centre
# [ 0] 17:00:00.0 D1: Parcel 19 (for cust 82 arr at delivery centre
# [ 0] 17:00:00.0 D1: Parcel 20 (for cust 82 arr at delivery centre
# [ 0] 17:00:00.0 D1: Parcel 21 (for cust 85 arr at delivery centre
# [ 0] 17:00:00.0 D0: Parcel 22 (for cust 89 arr at delivery centre
# [ 0] 17:00:00.0 D0: Parcel 23 (for cust 91 arr at delivery centre
# [ 0] 17:00:00.0 D0: Parcel 24 (for cust 91 arr at delivery centre
# [ 0] 17:00:00.0 D1: Parcel 25 (for cust 93 arr at delivery centre
# [ 0] 18:00:00.0 D0: arrives for work
# [ 0] 18:00:00.0 D0: Parcel 3 (for cust 18 out for delivery
# [ 0] 18:00:00.0 D0: Parcel 0 (for cust 13 out for delivery
# [ 0] 18:00:00.0 D0: Parcel 13 (for cust 53 out for delivery
# [ 0] 18:00:00.0 D0: Parcel 15 (for cust 57 out for delivery
# [ 0] 18:00:00.0 D0: Parcel 11 (for cust 50 out for delivery
# [ 0] 18:00:00.0 D0: Parcel 16 (for cust 70 out for delivery
# [ 0] 18:00:00.0 D0: Parcel 17 (for cust 77 out for delivery
# [ 0] 18:00:00.0 D0: Parcel 22 (for cust 89 out for delivery
# [ 0] 18:00:00.0 D0: Parcel 23 (for cust 91 out for delivery
# [ 0] 18:00:00.0 D0: Parcel 24 (for cust 91 out for delivery
# [ 0] 18:00:00.0 D0: Parcel 10 (for cust 48 out for delivery
# [ 0] 18:00:00.0 D0: Parcel 9 (for cust 46 out for delivery
# [ 0] 18:00:00.0 D0: Parcel 6 (for cust 40 out for delivery
# [ 0] 18:00:00.0 D0: Parcel 4 (for cust 19 out for delivery
# [ 0] 18:00:00.0 D0: Parcel 2 (for cust 16 out for delivery
# [ 0] 18:00:00.0 D1: arrives for work
# [ 0] 18:00:00.0 D1: Parcel 1 (for cust 15 out for delivery
# [ 0] 18:00:00.0 D1: Parcel 5 (for cust 38 out for delivery
# [ 0] 18:00:00.0 D1: Parcel 7 (for cust 45 out for delivery
# [ 0] 18:00:00.0 D1: Parcel 8 (for cust 45 out for delivery
# [ 0] 18:00:00.0 D1: Parcel 12 (for cust 52 out for delivery
# [ 0] 18:00:00.0 D1: Parcel 14 (for cust 55 out for delivery
# [ 0] 18:00:00.0 D1: Parcel 18 (for cust 78 out for delivery
# [ 0] 18:00:00.0 D1: Parcel 19 (for cust 82 out for delivery
# [ 0] 18:00:00.0 D1: Parcel 20 (for cust 82 out for delivery
# [ 0] 18:00:00.0 D1: Parcel 21 (for cust 85 out for delivery
# [ 0] 18:00:00.0 D1: Parcel 25 (for cust 93 out for delivery
# [ 0] 18:09:10.0 D1: leaves for delivery of 11 parcels to 9 customers
# [ 0] 18:09:10.0 D1: Length of delivery tour: 24,280m
# [ 0] 18:09:10.0 D1: drives to Customer 15 at (1896, 5560)
# [ 0] 18:12:30.0 D0: leaves for delivery of 15 parcels to 14 customers
# [ 0] 18:12:30.0 D0: Length of delivery tour: 24,740m
# [ 0] 18:12:30.0 D0: drives to Customer 18 at (2033, 4500)
# [ 0] 18:18:07.7 D0: arrived at Customer 18 at (2033, 4500)
# [ 0] 18:18:50.5 D0: Customer 18 at (2033, 4500) answers door
# [ 0] 18:18:50.5 D0: Parcel 3 (for cust 18 delivered
# [ 0] 18:18:50.5 D0: Customer 18 at (2033, 4500) signs off
# [ 0] 18:18:52.5 D0: drives to Customer 13 at (1798, 4500)
# [ 0] 18:19:35.0 D1: arrived at Customer 15 at (1896, 5560)
# [ 0] 18:19:48.9 D0: arrived at Customer 13 at (1798, 4500)
# [ 0] 18:20:00.6 D0: Customer 13 at (1798, 4500) answers door
# [ 0] 18:20:00.6 D0: Parcel 0 (for cust 13 delivered
# [ 0] 18:20:01.3 D0: Customer 13 at (1798, 4500) signs off
# [ 0] 18:20:03.2 D1: Customer 15 at (1896, 5560) answers door
# [ 0] 18:20:03.2 D1: Parcel 1 (for cust 15 delivered
# [ 0] 18:20:21.0 D0: drives to Customer 53 at (4722, 5560)
# [ 0] 18:20:31.9 D1: Customer 15 at (1896, 5560) signs off
# [ 0] 18:20:35.5 D1: drives to Customer 38 at (3440, 4276)
# [ 0] 18:31:54.2 D1: arrived at Customer 38 at (3440, 4276)
# [ 0] 18:32:15.2 D1: Customer 38 at (3440, 4276) answers door
# [ 0] 18:32:15.2 D1: Parcel 5 (for cust 38 delivered
# [ 0] 18:32:31.8 D1: Customer 38 at (3440, 4276) signs off
# [ 0] 18:32:32.4 D1: drives to Customer 45 at (3981, 3440)
# [ 0] 18:33:48.1 D0: arrived at Customer 53 at (4722, 5560)
# [ 0] 18:34:29.1 D0: Customer 53 at (4722, 5560) answers door
# [ 0] 18:34:29.1 D0: Parcel 13 (for cust 53 delivered
# [ 0] 18:34:30.4 D0: Customer 53 at (4722, 5560) signs off
# [ 0] 18:34:33.8 D0: drives to Customer 57 at (5209, 5560)
# [ 0] 18:36:30.7 D0: arrived at Customer 57 at (5209, 5560)
# [ 0] 18:37:30.7 D0: Customer 57 at (5209, 5560) to slow to answer the door
# [ 0] 18:37:30.7 D0: drives to Customer 50 at (4500, 6283)
# [ 0] 18:38:02.9 D1: arrived at Customer 45 at (3981, 3440)
# [ 0] 18:38:05.2 D1: Customer 45 at (3981, 3440) answers door
# [ 0] 18:38:05.2 D1: Parcel 7 (for cust 45 delivered
# [ 0] 18:38:05.6 D1: Parcel 8 (for cust 45 delivered
# [ 0] 18:38:11.0 D1: Customer 45 at (3981, 3440) signs off
# [ 0] 18:38:17.7 D1: drives to Customer 52 at (4718, 3220)
# [ 0] 18:41:36.5 D1: arrived at Customer 52 at (4718, 3220)
# [ 0] 18:42:36.5 D1: Customer 52 at (4718, 3220) to slow to answer the door
# [ 0] 18:42:36.5 D1: drives to Customer 55 at (4980, 740)
# [ 0] 18:43:14.4 D0: arrived at Customer 50 at (4500, 6283)
# [ 0] 18:44:04.9 D0: Customer 50 at (4500, 6283) answers door
# [ 0] 18:44:04.9 D0: Parcel 11 (for cust 50 delivered
# [ 0] 18:44:16.1 D0: Customer 50 at (4500, 6283) signs off
# [ 0] 18:44:17.7 D0: drives to Customer 70 at (5560, 7234)
# [ 0] 18:52:20.4 D0: arrived at Customer 70 at (5560, 7234)
# [ 0] 18:53:20.4 D0: Customer 70 at (5560, 7234) not at home
# [ 0] 18:53:20.4 D0: drives to Customer 77 at (6047, 7680)
# [ 0] 18:54:53.0 D1: arrived at Customer 55 at (4980, 740)
# [ 0] 18:55:53.0 D1: Customer 55 at (4980, 740) to slow to answer the door
# [ 0] 18:55:53.0 D1: drives to Customer 78 at (6082, 795)
# [ 0] 18:57:04.3 D0: arrived at Customer 77 at (6047, 7680)
# [ 0] 18:57:25.5 D0: Customer 77 at (6047, 7680) answers door
# [ 0] 18:57:25.5 D0: Parcel 17 (for cust 77 delivered
# [ 0] 18:57:34.9 D0: Customer 77 at (6047, 7680) signs off
# [ 0] 18:57:39.8 D0: drives to Customer 89 at (6513, 7680)
# [ 0] 18:59:31.7 D0: arrived at Customer 89 at (6513, 7680)
# [ 0] 18:59:33.6 D0: Customer 89 at (6513, 7680) answers door
# [ 0] 18:59:33.6 D0: Parcel 22 (for cust 89 delivered
# [ 0] 18:59:39.9 D0: Customer 89 at (6513, 7680) signs off
# [ 0] 18:59:41.6 D0: drives to Customer 91 at (6620, 8314)
# [ 0] 19:02:07.4 D1: arrived at Customer 78 at (6082, 795)
# [ 0] 19:02:08.7 D1: Customer 78 at (6082, 795) answers door
# [ 0] 19:02:08.7 D1: Parcel 18 (for cust 78 delivered
# [ 0] 19:02:18.3 D1: Customer 78 at (6082, 795) signs off
# [ 0] 19:02:28.3 D1: drives to Customer 82 at (6207, 3027)
# [ 0] 19:02:39.4 D0: arrived at Customer 91 at (6620, 8314)
# [ 0] 19:02:43.9 D0: Customer 91 at (6620, 8314) answers door
# [ 0] 19:02:43.9 D0: Parcel 23 (for cust 91 delivered
# [ 0] 19:02:51.8 D0: Parcel 24 (for cust 91 delivered
# [ 0] 19:02:56.1 D0: Customer 91 at (6620, 8314) signs off
# [ 0] 19:03:00.9 D0: drives to Customer 48 at (4280, 6620)
# [ 0] 19:13:19.7 D1: arrived at Customer 82 at (6207, 3027)
# [ 0] 19:14:19.6 D1: Customer 82 at (6207, 3027) answers door
# [ 0] 19:14:19.6 D1: Parcel 19 (for cust 82 delivered
# [ 0] 19:14:26.3 D1: Parcel 20 (for cust 82 delivered
# [ 0] 19:14:47.6 D1: Customer 82 at (6207, 3027) signs off
# [ 0] 19:14:57.0 D1: drives to Customer 85 at (6340, 3160)
# [ 0] 19:15:42.2 D1: arrived at Customer 85 at (6340, 3160)
# [ 0] 19:16:07.3 D1: Customer 85 at (6340, 3160) answers door
# [ 0] 19:16:07.3 D1: Parcel 21 (for cust 85 delivered
# [ 0] 19:16:17.3 D1: Customer 85 at (6340, 3160) signs off
# [ 0] 19:16:21.5 D1: drives to Customer 93 at (7680, 2699)
# [ 0] 19:19:09.1 D0: arrived at Customer 48 at (4280, 6620)
# [ 0] 19:19:14.4 D0: Customer 48 at (4280, 6620) answers door
# [ 0] 19:19:14.4 D0: Parcel 10 (for cust 48 delivered
# [ 0] 19:19:25.9 D0: Customer 48 at (4280, 6620) signs off
# [ 0] 19:19:35.6 D0: drives to Customer 46 at (3984, 6620)
# [ 0] 19:20:46.7 D0: arrived at Customer 46 at (3984, 6620)
# [ 0] 19:21:46.7 D0: Customer 46 at (3984, 6620) to slow to answer the door
# [ 0] 19:21:46.7 D0: drives to Customer 40 at (3440, 6776)
# [ 0] 19:24:34.7 D0: arrived at Customer 40 at (3440, 6776)
# [ 0] 19:24:40.1 D0: Customer 40 at (3440, 6776) answers door
# [ 0] 19:24:40.1 D0: Parcel 6 (for cust 40 delivered
# [ 0] 19:25:04.4 D0: Customer 40 at (3440, 6776) signs off
# [ 0] 19:25:08.5 D1: arrived at Customer 93 at (7680, 2699)
# [ 0] 19:25:20.4 D0: drives to Customer 19 at (2066, 7680)
# [ 0] 19:26:08.5 D1: Customer 93 at (7680, 2699) to slow to answer the door
# [ 0] 19:26:08.5 D1: returns to delivery centre
# [ 0] 19:34:27.2 D0: arrived at Customer 19 at (2066, 7680)
# [ 0] 19:35:27.2 D0: Customer 19 at (2066, 7680) to slow to answer the door
# [ 0] 19:35:27.2 D0: drives to Customer 16 at (1914, 7680)
# [ 0] 19:36:03.6 D0: arrived at Customer 16 at (1914, 7680)
# [ 0] 19:36:49.3 D0: Customer 16 at (1914, 7680) answers door
# [ 0] 19:36:49.3 D0: Parcel 2 (for cust 16 delivered
# [ 0] 19:37:06.0 D0: Customer 16 at (1914, 7680) signs off
# [ 0] 19:37:13.3 D0: returns to delivery centre
# [ 0] 19:53:48.3 D1: arrived at delivery centre
# [ 0] 19:53:48.3 D1: Parcel 12 (for cust 52 returned from delivery
# [ 0] 19:54:18.3 D1: Parcel 14 (for cust 55 returned from delivery
# [ 0] 19:54:48.3 D1: Parcel 25 (for cust 93 returned from delivery
# [ 0] 19:55:18.3 D1: 3 parcels left over for next day
# [ 0] 20:02:02.5 D0: arrived at delivery centre
# [ 0] 20:02:02.5 D0: Parcel 15 (for cust 57 returned from delivery
# [ 0] 20:02:32.5 D0: Parcel 16 (for cust 70 returned from delivery
# [ 0] 20:03:02.5 D0: Parcel 9 (for cust 46 returned from delivery
# [ 0] 20:03:32.5 D0: Parcel 4 (for cust 19 returned from delivery
# [ 0] 20:04:02.5 D0: 4 parcels left over for next day
# [ 0] 20:05:18.3 D1: goes home
# [ 0] 20:14:02.5 D0: goes home
# [ 1] 17:00:00.0 D0: Parcel 26 (for cust 1 arr at delivery centre
# [ 1] 17:00:00.0 D1: Parcel 27 (for cust 2 arr at delivery centre
# [ 1] 17:00:00.0 D0: Parcel 28 (for cust 7 arr at delivery centre
# [ 1] 17:00:00.0 D1: Parcel 29 (for cust 12 arr at delivery centre
# [ 1] 17:00:00.0 D0: Parcel 30 (for cust 18 arr at delivery centre
# [ 1] 17:00:00.0 D0: Parcel 31 (for cust 24 arr at delivery centre
# [ 1] 17:00:00.0 D0: Parcel 32 (for cust 24 arr at delivery centre
# [ 1] 17:00:00.0 D1: Parcel 33 (for cust 30 arr at delivery centre
# [ 1] 17:00:00.0 D1: Parcel 34 (for cust 39 arr at delivery centre
# [ 1] 17:00:00.0 D0: Parcel 35 (for cust 44 arr at delivery centre
# [ 1] 17:00:00.0 D0: Parcel 36 (for cust 46 arr at delivery centre
# [ 1] 17:00:00.0 D0: Parcel 37 (for cust 46 arr at delivery centre
# [ 1] 17:00:00.0 D0: Parcel 38 (for cust 48 arr at delivery centre
# [ 1] 17:00:00.0 D0: Parcel 39 (for cust 49 arr at delivery centre
# [ 1] 17:00:00.0 D0: Parcel 40 (for cust 54 arr at delivery centre
# [ 1] 17:00:00.0 D1: Parcel 41 (for cust 58 arr at delivery centre
# [ 1] 17:00:00.0 D1: Parcel 42 (for cust 58 arr at delivery centre
# [ 1] 17:00:00.0 D0: Parcel 43 (for cust 59 arr at delivery centre
# [ 1] 17:00:00.0 D1: Parcel 44 (for cust 61 arr at delivery centre
# [ 1] 17:00:00.0 D1: Parcel 45 (for cust 62 arr at delivery centre
# [ 1] 17:00:00.0 D1: Parcel 46 (for cust 64 arr at delivery centre
# [ 1] 17:00:00.0 D1: Parcel 47 (for cust 65 arr at delivery centre
# [ 1] 17:00:00.0 D0: Parcel 48 (for cust 66 arr at delivery centre
# [ 1] 17:00:00.0 D0: Parcel 49 (for cust 66 arr at delivery centre
# [ 1] 17:00:00.0 D0: Parcel 50 (for cust 73 arr at delivery centre
# [ 1] 17:00:00.0 D1: Parcel 51 (for cust 76 arr at delivery centre
# [ 1] 17:00:00.0 D1: Parcel 52 (for cust 78 arr at delivery centre
# [ 1] 17:00:00.0 D1: Parcel 53 (for cust 92 arr at delivery centre
# [ 1] 17:00:00.0 D1: Parcel 54 (for cust 93 arr at delivery centre
# [ 1] 17:00:00.0 D1: Parcel 55 (for cust 93 arr at delivery centre
# [ 1] 17:00:00.0 D1: Parcel 56 (for cust 94 arr at delivery centre
# [ 1] 17:00:00.0 D1: Parcel 57 (for cust 97 arr at delivery centre
# [ 1] 17:00:00.0 D1: Parcel 58 (for cust 98 arr at delivery centre
# [ 1] 18:00:00.0 D1: arrives for work
# [ 1] 18:00:00.0 D1: Parcel 33 (for cust 30 out for delivery
# [ 1] 18:00:00.0 D1: Parcel 27 (for cust 2 out for delivery
# [ 1] 18:00:00.0 D1: Parcel 29 (for cust 12 out for delivery
# [ 1] 18:00:00.0 D1: Parcel 34 (for cust 39 out for delivery
# [ 1] 18:00:00.0 D1: Parcel 12 (for cust 52 out for delivery
# [ 1] 18:00:00.0 D1: Parcel 53 (for cust 92 out for delivery
# [ 1] 18:00:00.0 D1: Parcel 57 (for cust 97 out for delivery
# [ 1] 18:00:00.0 D1: Parcel 25 (for cust 93 out for delivery
# [ 1] 18:00:00.0 D1: Parcel 54 (for cust 93 out for delivery
# [ 1] 18:00:00.0 D1: Parcel 55 (for cust 93 out for delivery
# [ 1] 18:00:00.0 D1: Parcel 56 (for cust 94 out for delivery
# [ 1] 18:00:00.0 D1: Parcel 47 (for cust 65 out for delivery
# [ 1] 18:00:00.0 D1: Parcel 46 (for cust 64 out for delivery
# [ 1] 18:00:00.0 D1: Parcel 45 (for cust 62 out for delivery
# [ 1] 18:00:00.0 D1: Parcel 51 (for cust 76 out for delivery
# [ 1] 18:00:00.0 D1: Parcel 52 (for cust 78 out for delivery
# [ 1] 18:00:00.0 D1: Parcel 44 (for cust 61 out for delivery
# [ 1] 18:00:00.0 D1: Parcel 41 (for cust 58 out for delivery
# [ 1] 18:00:00.0 D1: Parcel 42 (for cust 58 out for delivery
# [ 1] 18:00:00.0 D1: Parcel 14 (for cust 55 out for delivery
# [ 1] 18:00:00.0 D0: arrives for work
# [ 1] 18:00:00.0 D0: Parcel 31 (for cust 24 out for delivery
# [ 1] 18:00:00.0 D0: Parcel 32 (for cust 24 out for delivery
# [ 1] 18:00:00.0 D0: Parcel 30 (for cust 18 out for delivery
# [ 1] 18:00:00.0 D0: Parcel 35 (for cust 44 out for delivery
# [ 1] 18:00:00.0 D0: Parcel 15 (for cust 57 out for delivery
# [ 1] 18:00:00.0 D0: Parcel 50 (for cust 73 out for delivery
# [ 1] 18:00:00.0 D0: Parcel 48 (for cust 66 out for delivery
# [ 1] 18:00:00.0 D0: Parcel 49 (for cust 66 out for delivery
# [ 1] 18:00:00.0 D0: Parcel 16 (for cust 70 out for delivery
# [ 1] 18:00:00.0 D0: Parcel 43 (for cust 59 out for delivery
# [ 1] 18:00:00.0 D0: Parcel 40 (for cust 54 out for delivery
# [ 1] 18:00:00.0 D0: Parcel 38 (for cust 48 out for delivery
# [ 1] 18:00:00.0 D0: Parcel 9 (for cust 46 out for delivery
# [ 1] 18:00:00.0 D0: Parcel 36 (for cust 46 out for delivery
# [ 1] 18:00:00.0 D0: Parcel 37 (for cust 46 out for delivery
# [ 1] 18:00:00.0 D0: Parcel 26 (for cust 1 out for delivery
# [ 1] 18:00:00.0 D0: Parcel 28 (for cust 7 out for delivery
# [ 1] 18:00:00.0 D0: Parcel 4 (for cust 19 out for delivery
# [ 1] 18:00:00.0 D0: Parcel 39 (for cust 49 out for delivery
# [ 1] 18:15:50.0 D0: leaves for delivery of 19 parcels to 15 customers
# [ 1] 18:15:50.0 D0: Length of delivery tour: 22,277m
# [ 1] 18:15:50.0 D0: drives to Customer 24 at (2251, 4500)
# [ 1] 18:16:40.0 D1: leaves for delivery of 20 parcels to 17 customers
# [ 1] 18:16:40.0 D1: Length of delivery tour: 35,258m
# [ 1] 18:16:40.0 D1: drives to Customer 30 at (2380, 5128)
# [ 1] 18:20:35.4 D0: arrived at Customer 24 at (2251, 4500)
# [ 1] 18:20:56.4 D0: Customer 24 at (2251, 4500) answers door
# [ 1] 18:20:56.4 D0: Parcel 31 (for cust 24 delivered
# [ 1] 18:21:01.8 D0: Parcel 32 (for cust 24 delivered
# [ 1] 18:21:14.8 D0: Customer 24 at (2251, 4500) signs off
# [ 1] 18:21:18.7 D0: drives to Customer 18 at (2033, 4500)
arr at delivery centre
# [ 2] 17:00:00.0 D1: Parcel 88 (for cust 95 arr at delivery centre
# [ 2] 18:00:00.0 D0: arrives for work
# [ 2] 18:00:00.0 D0: Parcel 65 (for cust 24 out for delivery
# [ 2] 18:00:00.0 D0: Parcel 35 (for cust 44 out for delivery
# [ 2] 18:00:00.0 D0: Parcel 15 (for cust 57 out for delivery
# [ 2] 18:00:00.0 D0: Parcel 50 (for cust 73 out for delivery
# [ 2] 18:00:00.0 D0: Parcel 83 (for cust 75 out for delivery
# [ 2] 18:00:00.0 D0: Parcel 84 (for cust 75 out for delivery
# [ 2] 18:00:00.0 D0: Parcel 82 (for cust 68 out for delivery
# [ 2] 18:00:00.0 D0: Parcel 80 (for cust 59 out for delivery
# [ 2] 18:00:00.0 D0: Parcel 76 (for cust 54 out for delivery
# [ 2] 18:00:00.0 D0: Parcel 38 (for cust 48 out for delivery
# [ 2] 18:00:00.0 D0: Parcel 73 (for cust 48 out for delivery
# [ 2] 18:00:00.0 D0: Parcel 9 (for cust 46 out for delivery
# [ 2] 18:00:00.0 D0: Parcel 36 (for cust 46 out for delivery
# [ 2] 18:00:00.0 D0: Parcel 37 (for cust 46 out for delivery
# [ 2] 18:00:00.0 D0: Parcel 70 (for cust 33 out for delivery
# [ 2] 18:00:00.0 D0: Parcel 59 (for cust 1 out for delivery
# [ 2] 18:00:00.0 D0: Parcel 61 (for cust 11 out for delivery
# [ 2] 18:00:00.0 D0: Parcel 66 (for cust 25 out for delivery
# [ 2] 18:00:00.0 D0: Parcel 67 (for cust 25 out for delivery
# [ 2] 18:00:00.0 D0: Parcel 72 (for cust 42 out for delivery
# [ 2] 18:00:00.0 D0: Parcel 75 (for cust 50 out for delivery
# [ 2] 18:00:00.0 D0: Parcel 74 (for cust 49 out for delivery
# [ 2] 18:00:00.0 D1: arrives for work
# [ 2] 18:00:00.0 D1: Parcel 71 (for cust 37 out for delivery
# [ 2] 18:00:00.0 D1: Parcel 69 (for cust 32 out for delivery
# [ 2] 18:00:00.0 D1: Parcel 68 (for cust 29 out for delivery
# [ 2] 18:00:00.0 D1: Parcel 63 (for cust 20 out for delivery
# [ 2] 18:00:00.0 D1: Parcel 29 (for cust 12 out for delivery
# [ 2] 18:00:00.0 D1: Parcel 64 (for cust 21 out for delivery
# [ 2] 18:00:00.0 D1: Parcel 78 (for cust 56 out for delivery
# [ 2] 18:00:00.0 D1: Parcel 81 (for cust 62 out for delivery
# [ 2] 18:00:00.0 D1: Parcel 85 (for cust 80 out for delivery
# [ 2] 18:00:00.0 D1: Parcel 44 (for cust 61 out for delivery
# [ 2] 18:00:00.0 D1: Parcel 79 (for cust 58 out for delivery
# [ 2] 18:00:00.0 D1: Parcel 14 (for cust 55 out for delivery
# [ 2] 18:00:00.0 D1: Parcel 77 (for cust 55 out for delivery
# [ 2] 18:00:00.0 D1: Parcel 53 (for cust 92 out for delivery
# [ 2] 18:00:00.0 D1: Parcel 86 (for cust 92 out for delivery
# [ 2] 18:00:00.0 D1: Parcel 56 (for cust 94 out for delivery
# [ 2] 18:00:00.0 D1: Parcel 87 (for cust 94 out for delivery
# [ 2] 18:00:00.0 D1: Parcel 58 (for cust 98 out for delivery
# [ 2] 18:00:00.0 D1: Parcel 60 (for cust 3 out for delivery
# [ 2] 18:00:00.0 D1: Parcel 62 (for cust 15 out for delivery
# [ 2] 18:00:00.0 D1: Parcel 33 (for cust 30 out for delivery
# [ 2] 18:17:30.0 D1: leaves for delivery of 21 parcels to 18 customers
# [ 2] 18:17:30.0 D1: Length of delivery tour: 35,982m
# [ 2] 18:17:30.0 D1: drives to Customer 37 at (3440, 4175)
# [ 2] 18:18:20.0 D0: leaves for delivery of 22 parcels to 17 customers
# [ 2] 18:18:20.0 D0: Length of delivery tour: 22,318m
# [ 2] 18:18:20.0 D0: drives to Customer 24 at (2251, 4500)
# [ 2] 18:18:48.0 D1: arrived at Customer 37 at (3440, 4175)
# [ 2] 18:19:04.6 D1: Customer 37 at (3440, 4175) answers door
# [ 2] 18:19:04.6 D1: Parcel 71 (for cust 37 delivered
# [ 2] 18:19:05.7 D1: Customer 37 at (3440, 4175) signs off
# [ 2] 18:19:27.1 D1: drives to Customer 32 at (2738, 2738)
# [ 2] 18:23:05.4 D0: arrived at Customer 24 at (2251, 4500)
# [ 2] 18:24:05.4 D0: Customer 24 at (2251, 4500) not at home
# [ 2] 18:24:05.4 D0: drives to Customer 44 at (3855, 4915)
# [ 2] 18:26:21.6 D1: arrived at Customer 32 at (2738, 2738)
# [ 2] 18:27:21.6 D1: Customer 32 at (2738, 2738) to slow to answer the door
# [ 2] 18:27:21.6 D1: drives to Customer 29 at (2380, 1941)
# [ 2] 18:31:08.4 D1: arrived at Customer 29 at (2380, 1941)
# [ 2] 18:31:11.4 D0: arrived at Customer 44 at (3855, 4915)
# [ 2] 18:32:08.4 D1: Customer 29 at (2380, 1941) not at home
# [ 2] 18:32:08.4 D1: drives to Customer 20 at (2080, 1320)
# [ 2] 18:32:11.4 D0: Customer 44 at (3855, 4915) not at home
# [ 2] 18:32:11.4 D0: drives to Customer 57 at (5209, 5560)
# [ 2] 18:35:49.4 D1: arrived at Customer 20 at (2080, 1320)
# [ 2] 18:36:05.0 D1: Customer 20 at (2080, 1320) answers door
# [ 2] 18:36:05.0 D1: Parcel 63 (for cust 20 delivered
# [ 2] 19:50:57.5 D1: Customer 98 at (8592, 2380) answers door
# [ 2] 19:50:57.5 D1: Parcel 58 (for cust 98 delivered
# [ 2] 19:51:09.6 D1: Customer 98 at (8592, 2380) signs off
# [ 2] 19:51:20.4 D1: drives to Customer 3 at (1320, 4193)
# [ 2] 20:00:43.7 D0: arrived at delivery centre
# [ 2] 20:00:43.7 D0: Parcel 65 (for cust 24 returned from delivery
# [ 2] 20:01:13.7 D0: Parcel 35 (for cust 44 returned from delivery
# [ 2] 20:01:43.7 D0: Parcel 38 (for cust 48 returned from delivery
# [ 2] 20:02:13.7 D0: Parcel 73 (for cust 48 returned from delivery
# [ 2] 20:02:43.7 D0: Parcel 70 (for cust 33 returned from delivery
# [ 2] 20:03:13.7 D0: 5 parcels left over for next day
# [ 2] 20:13:13.7 D0: goes home
# [ 2] 20:34:41.5 D1: arrived at Customer 3 at (1320, 4193)
# [ 2] 20:34:51.6 D1: Customer 3 at (1320, 4193) answers door
# [ 2] 20:34:51.6 D1: Parcel 60 (for cust 3 delivered
# [ 2] 20:35:09.4 D1: Customer 3 at (1320, 4193) signs off
# [ 2] 20:35:12.1 D1: drives to Customer 15 at (1896, 5560)
# [ 2] 20:42:58.5 D1: arrived at Customer 15 at (1896, 5560)
# [ 2] 20:43:27.7 D1: Customer 15 at (1896, 5560) answers door
# [ 2] 20:43:27.7 D1: Parcel 62 (for cust 15 delivered
# [ 2] 20:43:38.9 D1: Customer 15 at (1896, 5560) signs off
# [ 2] 20:43:41.5 D1: drives to Customer 30 at (2380, 5128)
# [ 2] 20:47:21.4 D1: arrived at Customer 30 at (2380, 5128)
# [ 2] 20:48:01.0 D1: Customer 30 at (2380, 5128) answers door
# [ 2] 20:48:01.0 D1: Parcel 33 (for cust 30 delivered
# [ 2] 20:48:04.4 D1: Customer 30 at (2380, 5128) signs off
# [ 2] 20:48:06.3 D1: returns to delivery centre
# [ 2] 20:54:51.4 D1: arrived at delivery centre
# [ 2] 20:54:51.4 D1: Parcel 69 (for cust 32 returned from delivery
# [ 2] 20:55:21.4 D1: Parcel 68 (for cust 29 returned from delivery
# [ 2] 20:55:51.4 D1: Parcel 81 (for cust 62 returned from delivery
# [ 2] 20:56:21.4 D1: Parcel 44 (for cust 61 returned from delivery
# [ 2] 20:56:51.4 D1: Parcel 53 (for cust 92 returned from delivery
# [ 2] 20:57:21.4 D1: Parcel 86 (for cust 92 returned from delivery
# [ 2] 20:57:51.4 D1: 7 parcels left over for next day
# [ 2] 21:07:51.4 D1: goes home
# [ 3] 17:00:00.0 D1: Parcel 89 (for cust 2 arr at delivery centre
# [ 3] 17:00:00.0 D1: Parcel 90 (for cust 3 arr at delivery centre
# [ 3] 17:00:00.0 D1: Parcel 91 (for cust 4 arr at delivery centre
# [ 3] 17:00:00.0 D0: Parcel 92 (for cust 8 arr at delivery centre
# [ 3] 17:00:00.0 D0: Parcel 93 (for cust 9 arr at delivery centre
# [ 3] 17:00:00.0 D1: Parcel 94 (for cust 14 arr at delivery centre
# [ 3] 17:00:00.0 D1: Parcel 95 (for cust 14 arr at delivery centre
# [ 3] 17:00:00.0 D0: Parcel 96 (for cust 16 arr at delivery centre
# [ 3] 17:00:00.0 D0: Parcel 97 (for cust 18 arr at delivery centre
# [ 3] 17:00:00.0 D0: Parcel 98 (for cust 19 arr at delivery centre
# [ 3] 17:00:00.0 D0: Parcel 99 (for cust 22 arr at delivery centre
# [ 3] 17:00:00.0 D1: Parcel 100 (for cust 23 arr at delivery centre
# [ 3] 17:00:00.0 D1: Parcel 101 (for cust 43 arr at delivery centre
# [ 3] 17:00:00.0 D0: Parcel 102 (for cust 48 arr at delivery centre
# [ 3] 17:00:00.0 D0: Parcel 103 (for cust 53 arr at delivery centre
# [ 3] 17:00:00.0 D1: Parcel 104 (for cust 56 arr at delivery centre
# [ 3] 17:00:00.0 D0: Parcel 105 (for cust 57 arr at delivery centre
# [ 3] 17:00:00.0 D0: Parcel 106 (for cust 57 arr at delivery centre
# [ 3] 17:00:00.0 D1: Parcel 107 (for cust 58 arr at delivery centre
# [ 3] 17:00:00.0 D1: Parcel 108 (for cust 60 arr at delivery centre
# [ 3] 17:00:00.0 D1: Parcel 109 (for cust 61 arr at delivery centre
# [ 3] 17:00:00.0 D1: Parcel 110 (for cust 64 arr at delivery centre
# [ 3] 17:00:00.0 D0: Parcel 111 (for cust 68 arr at delivery centre
# [ 3] 17:00:00.0 D0: Parcel 112 (for cust 71 arr at delivery centre
# [ 3] 17:00:00.0 D0: Parcel 113 (for cust 71 arr at delivery centre
# [ 3] 17:00:00.0 D0: Parcel 114 (for cust 75 arr at delivery centre
# [ 3] 17:00:00.0 D1: Parcel 115 (for cust 78 arr at delivery centre
# [ 3] 17:00:00.0 D0: Parcel 116 (for cust 86 arr at delivery centre
# [ 3] 17:00:00.0 D1: Parcel 117 (for cust 88 arr at delivery centre
# [ 3] 17:00:00.0 D0: Parcel 118 (for cust 89 arr at delivery centre
# [ 3] 17:00:00.0 D0: Parcel 119 (for cust 89 arr at delivery centre
# [ 3] 17:00:00.0 D1: Parcel 120 (for cust 97 arr at delivery centre
# [ 3] 17:00:00.0 D1: Parcel 121 (for cust 98 arr at delivery centre
# [ 3] 18:00:00.0 D0: arrives for work
# [ 3] 18:00:00.0 D0: Parcel 65 (for cust 24 out for delivery
# [ 3] 18:00:00.0 D0: Parcel 99 (for cust 22 out for delivery
# [ 3] 18:00:00.0 D0: Parcel 97 (for cust 18 out for delivery
# [ 3] 18:00:00.0 D0: Parcel 93 (for cust 9 out for delivery
# [ 3] 18:00:00.0 D0: Parcel 35 (for cust 44 out for delivery
# [ 3] 18:00:00.0 D0: Parcel 38 (for cust 48 out for delivery
# [ 3] 18:00:00.0 D0: Parcel 73 (for cust 48 out for delivery
# [ 3] 18:00:00.0 D0: Parcel 102 (for cust 48 out for delivery
# [ 3] 18:00:00.0 D0: Parcel 98 (for cust 19 out for delivery
# [ 3] 18:00:00.0 D0: Parcel 96 (for cust 16 out for delivery
# [ 3] 18:00:00.0 D0: Parcel 92 (for cust 8 out for delivery
# [ 3] 18:00:00.0 D0: Parcel 70 (for cust 33 out for delivery
# [ 3] 18:00:00.0 D0: Parcel 112 (for cust 71 out for delivery
# [ 3] 18:00:00.0 D0: Parcel 113 (for cust 71 out for delivery
# [ 3] 18:00:00.0 D0: Parcel 118 (for cust 89 out for delivery
# [ 3] 18:00:00.0 D0: Parcel 119 (for cust 89 out for delivery
# [ 3] 18:00:00.0 D0: Parcel 111 (for cust 68 out for delivery
# [ 3] 18:00:00.0 D0: Parcel 114 (for cust 75 out for delivery
# [ 3] 18:00:00.0 D0: Parcel 116 (for cust 86 out for delivery
# [ 3] 18:00:00.0 D0: Parcel 105 (for cust 57 out for delivery
# [ 3] 18:00:00.0 D0: Parcel 106 (for cust 57 out for delivery
# [ 3] 18:00:00.0 D0: Parcel 103 (for cust 53 out for delivery
# [ 3] 18:00:00.0 D1: arrives for work
# [ 3] 18:00:00.0 D1: Parcel 101 (for cust 43 out for delivery
# [ 3] 18:00:00.0 D1: Parcel 104 (for cust 56 out for delivery
# [ 3] 18:00:00.0 D1: Parcel 110 (for cust 64 out for delivery
# [ 3] 18:00:00.0 D1: Parcel 81 (for cust 62 out for delivery
# [ 3] 18:00:00.0 D1: Parcel 115 (for cust 78 out for delivery
# [ 3] 18:00:00.0 D1: Parcel 44 (for cust 61 out for delivery
# [ 3] 18:00:00.0 D1: Parcel 109 (for cust 61 out for delivery
# [ 3] 18:00:00.0 D1: Parcel 108 (for cust 60 out for delivery
# [ 3] 18:00:00.0 D1: Parcel 107 (for cust 58 out for delivery
# [ 3] 18:00:00.0 D1: Parcel 117 (for cust 88 out for delivery
# [ 3] 18:00:00.0 D1: Parcel 53 (for cust 92 out for delivery
# [ 3] 18:00:00.0 D1: Parcel 86 (for cust 92 out for delivery
# [ 3] 18:00:00.0 D1: Parcel 120 (for cust 97 out for delivery
# [ 3] 18:00:00.0 D1: Parcel 88 (for cust 95 out for delivery
# [ 3] 18:00:00.0 D1: Parcel 100 (for cust 23 out for delivery
# [ 3] 18:00:00.0 D1: Parcel 91 (for cust 4 out for delivery
# [ 3] 18:00:00.0 D1: Parcel 90 (for cust 3 out for delivery
# [ 3] 18:00:00.0 D1: Parcel 89 (for cust 2 out for delivery
# [ 3] 18:00:00.0 D1: Parcel 68 (for cust 29 out for delivery
# [ 3] 18:00:00.0 D1: Parcel 94 (for cust 14 out for delivery
# [ 3] 18:00:00.0 D1: Parcel 95 (for cust 14 out for delivery
# [ 3] 18:00:00.0 D1: Parcel 69 (for cust 32 out for delivery
# [ 3] 18:18:20.0 D0: leaves for delivery of 22 parcels to 17 customers
# [ 3] 18:18:20.0 D0: Length of delivery tour: 26,020m
# [ 3] 18:18:20.0 D0: drives to Customer 24 at (2251, 4500)
# [ 3] 18:18:20.0 D1: leaves for delivery of 22 parcels to 19 customers
# [ 3] 18:18:20.0 D1: Length of delivery tour: 35,217m
# [ 3] 18:18:20.0 D1: drives to Customer 43 at (3847, 3440)
# [ 3] 18:23:05.4 D0: arrived at Customer 24 at (2251, 4500)
# [ 3] 18:24:05.4 D0: Customer 24 at (2251, 4500) to slow to answer the door
# [ 3] 18:24:05.4 D0: drives to Customer 22 at (2169, 4500)
# [ 3] 18:24:12.1 D1: arrived at Customer 43 at (3847, 3440)
# [ 3] 18:24:25.0 D0: arrived at Customer 22 at (2169, 4500)
# [ 3] 18:24:32.4 D0: Customer 22 at (2169, 4500) answers door
# [ 3] 18:24:32.4 D0: Parcel 99 (for cust 22 delivered
# [ 3] 18:24:33.2 D0: Customer 22 at (2169, 4500) signs off
# [ 3] 18:24:58.1 D1: Customer 43 at (3847, 3440) answers door
# [ 3] 18:24:58.1 D1: Parcel 101 (for cust 43 delivered
# [ 3] 18:24:59.5 D0: drives to Customer 18 at (2033, 4500)
# [ 3] 18:25:07.2 D1: Customer 43 at (3847, 3440) signs off
# [ 3] 18:25:16.9 D1: drives to Customer 56 at (5106, 2833)
# [ 3] 18:25:32.1 D0: arrived at Customer 18 at (2033, 4500)
# [ 3] 18:25:56.6 D0: Customer 18 at (2033, 4500) answers door
# [ 3] 18:25:56.6 D0: Parcel 97 (for cust 18 delivered
# [ 3] 18:25:58.2 D0: Customer 18 at (2033, 4500) signs off
# [ 3] 18:26:07.4 D0: drives to Customer 9 at (1650, 4500)
# [ 3] 18:27:39.4 D0: arrived at Customer 9 at (1650, 4500)
# [ 3] 18:28:39.4 D0: Customer 9 at (1650, 4500) not at home
# [ 3] 18:28:39.4 D0: drives to Customer 44 at (3855, 4915)
# [ 3] 18:31:19.3 D1: arrived at Customer 56 at (5106, 2833)
# [ 3] 18:31:31.0 D1: Customer 56 at (5106, 2833) answers door
# [ 3] 18:31:31.0 D1: Parcel 104 (for cust 56 delivered
# [ 3] 18:31:47.3 D1: Customer 56 at (5106, 2833) signs off
# [ 3] 18:32:00.5 D1: drives to Customer 64 at (5560, 1912)
# [ 3] 18:36:26.7 D1: arrived at Customer 64 at (5560, 1912)
# [ 3] 18:36:27.8 D1: Customer 64 at (5560, 1912) answers door
# [ 3] 18:36:27.8 D1: Parcel 110 (for cust 64 delivered
# [ 3] 18:36:54.8 D1: Customer 64 at (5560, 1912) signs off
# [ 3] 18:36:55.1 D1: drives to Customer 62 at (5560, 1408)
# [ 3] 18:38:09.6 D0: arrived at Customer 44 at (3855, 4915)
# [ 3] 18:38:13.3 D0: Customer 44 at (3855, 4915) answers door
# [ 3] 18:38:13.3 D0: Parcel 35 (for cust 44 delivered
# [ 3] 18:38:16.8 D0: Customer 44 at (3855, 4915) signs off
# [ 3] 18:38:18.4 D0: drives to Customer 48 at (4280, 6620)
# [ 3] 18:38:56.1 D1: arrived at Customer 62 at (5560, 1408)
# [ 3] 18:39:06.9 D1: Customer 62 at (5560, 1408) answers door
# [ 3] 18:39:06.9 D1: Parcel 81 (for cust 62 delivered
# [ 3] 18:39:11.3 D1: Customer 62 at (5560, 1408) signs off
# ...
# [ 5] 20:17:41.5 D0: Parcel 148 (for cust 1 returned from delivery
# [ 5] 20:18:11.5 D0: Parcel 150 (for cust 7 returned from delivery
# [ 5] 20:18:41.5 D0: Parcel 156 (for cust 36 returned from delivery
# [ 5] 20:19:11.5 D0: Parcel 157 (for cust 36 returned from delivery
# [ 5] 20:19:41.5 D0: 5 parcels left over for next day
# [ 5] 20:25:07.1 D1: arrived at Customer 17 at (1951, 2807)
# [ 5] 20:26:07.1 D1: Customer 17 at (1951, 2807) not at home
# [ 5] 20:26:07.1 D1: drives to Customer 6 at (1434, 3325)
# [ 5] 20:29:02.6 D1: arrived at Customer 6 at (1434, 3325)
# [ 5] 20:29:34.0 D1: Customer 6 at (1434, 3325) answers door
# [ 5] 20:29:34.0 D1: Parcel 149 (for cust 6 delivered
# [ 5] 20:29:41.5 D0: goes home
# [ 5] 20:29:42.1 D1: Customer 6 at (1434, 3325) signs off
# [ 5] 20:29:44.0 D1: returns to delivery centre
# [ 5] 20:45:18.5 D1: arrived at delivery centre
# [ 5] 20:45:18.5 D1: Parcel 161 (for cust 43 returned from delivery
# [ 5] 20:45:48.5 D1: Parcel 53 (for cust 92 returned from delivery
# [ 5] 20:46:18.5 D1: Parcel 86 (for cust 92 returned from delivery
# [ 5] 20:46:48.5 D1: Parcel 172 (for cust 92 returned from delivery
# [ 5] 20:47:18.5 D1: Parcel 164 (for cust 62 returned from delivery
# [ 5] 20:47:48.5 D1: Parcel 69 (for cust 32 returned from delivery
# [ 5] 20:48:18.5 D1: Parcel 154 (for cust 17 returned from delivery
# [ 5] 20:48:48.5 D1: 7 parcels left over for next day
# [ 5] 20:58:48.5 D1: goes home
# [ 6] 17:00:00.0 D0: Parcel 173 (for cust 0 arr at delivery centre
# [ 6] 17:00:00.0 D0: Parcel 174 (for cust 1 arr at delivery centre
# [ 6] 17:00:00.0 D1: Parcel 175 (for cust 2 arr at delivery centre
# [ 6] 17:00:00.0 D0: Parcel 176 (for cust 8 arr at delivery centre
# [ 6] 17:00:00.0 D1: Parcel 177 (for cust 12 arr at delivery centre
# [ 6] 17:00:00.0 D0: Parcel 178 (for cust 22 arr at delivery centre
# [ 6] 17:00:00.0 D1: Parcel 179 (for cust 26 arr at delivery centre
# [ 6] 17:00:00.0 D1: Parcel 180 (for cust 27 arr at delivery centre
# [ 6] 17:00:00.0 D1: Parcel 181 (for cust 30 arr at delivery centre
# [ 6] 17:00:00.0 D1: Parcel 182 (for cust 38 arr at delivery centre
# [ 6] 17:00:00.0 D1: Parcel 183 (for cust 39 arr at delivery centre
# [ 6] 17:00:00.0 D0: Parcel 184 (for cust 42 arr at delivery centre
# [ 6] 17:00:00.0 D0: Parcel 185 (for cust 42 arr at delivery centre
# [ 6] 17:00:00.0 D0: Parcel 186 (for cust 50 arr at delivery centre
# [ 6] 17:00:00.0 D1: Parcel 187 (for cust 60 arr at delivery centre
# [ 6] 17:00:00.0 D1: Parcel 188 (for cust 61 arr at delivery centre
# [ 6] 17:00:00.0 D1: Parcel 189 (for cust 61 arr at delivery centre
# [ 6] 17:00:00.0 D1: Parcel 190 (for cust 63 arr at delivery centre
# [ 6] 17:00:00.0 D0: Parcel 191 (for cust 66 arr at delivery centre
# [ 6] 17:00:00.0 D0: Parcel 192 (for cust 69 arr at delivery centre
# [ 6] 17:00:00.0 D0: Parcel 193 (for cust 73 arr at delivery centre
# [ 6] 17:00:00.0 D0: Parcel 194 (for cust 75 arr at delivery centre
# [ 6] 17:00:00.0 D0: Parcel 195 (for cust 77 arr at delivery centre
# [ 6] 17:00:00.0 D1: Parcel 196 (for cust 79 arr at delivery centre
# [ 6] 17:00:00.0 D0: Parcel 197 (for cust 81 arr at delivery centre
# [ 6] 17:00:00.0 D1: Parcel 198 (for cust 82 arr at delivery centre
# [ 6] 17:00:00.0 D1: Parcel 199 (for cust 92 arr at delivery centre
# [ 6] 17:00:00.0 D1: Parcel 200 (for cust 93 arr at delivery centre
# [ 6] 18:00:00.0 D0: arrives for work
# [ 6] 18:00:00.0 D0: Parcel 178 (for cust 22 out for delivery
# [ 6] 18:00:00.0 D0: Parcel 186 (for cust 50 out for delivery
# [ 6] 18:00:00.0 D0: Parcel 130 (for cust 48 out for delivery
# [ 6] 18:00:00.0 D0: Parcel 184 (for cust 42 out for delivery
# [ 6] 18:00:00.0 D0: Parcel 185 (for cust 42 out for delivery
# [ 6] 18:00:00.0 D0: Parcel 156 (for cust 36 out for delivery
# [ 6] 18:00:00.0 D0: Parcel 157 (for cust 36 out for delivery
# [ 6] 18:00:00.0 D0: Parcel 176 (for cust 8 out for delivery
# [ 6] 18:00:00.0 D0: Parcel 150 (for cust 7 out for delivery
# [ 6] 18:00:00.0 D0: Parcel 148 (for cust 1 out for delivery
# [ 6] 18:00:00.0 D0: Parcel 174 (for cust 1 out for delivery
# [ 6] 18:00:00.0 D0: Parcel 173 (for cust 0 out for delivery
# [ 6] 18:00:00.0 D0: Parcel 195 (for cust 77 out for delivery
# [ 6] 18:00:00.0 D0: Parcel 197 (for cust 81 out for delivery
# [ 6] 18:00:00.0 D0: Parcel 192 (for cust 69 out for delivery
# [ 6] 18:00:00.0 D0: Parcel 191 (for cust 66 out for delivery
# [ 6] 18:00:00.0 D0: Parcel 193 (for cust 73 out for delivery
# [ 6] 18:00:00.0 D0: Parcel 194 (for cust 75 out for delivery
# [ 6] 18:00:00.0 D1: arrives for work
# [ 6] 18:00:00.0 D1: Parcel 181 (for cust 30 out for delivery
# [ 6] 18:00:00.0 D1: Parcel 183 (for cust 39 out for delivery
# [ 6] 18:00:00.0 D1: Parcel 182 (for cust 38 out for delivery
# [ 6] 18:00:00.0 D1: Parcel 69 (for cust 32 out for delivery
# [ 6] 18:00:00.0 D1: Parcel 180 (for cust 27 out for delivery
# [ 6] 18:00:00.0 D1: Parcel 177 (for cust 12 out for delivery
# [ 6] 18:00:00.0 D1: Parcel 179 (for cust 26 out for delivery
# [ 6] 18:00:00.0 D1: Parcel 154 (for cust 17 out for delivery
# [ 6] 18:00:00.0 D1: Parcel 175 (for cust 2 out for delivery
# [ 6] 18:00:00.0 D1: Parcel 161 (for cust 43 out for delivery
# [ 6] 18:00:00.0 D1: Parcel 190 (for cust 63 out for delivery
# [ 6] 18:00:00.0 D1: Parcel 164 (for cust 62 out for delivery
# [ 6] 18:00:00.0 D1: Parcel 188 (for cust 61 out for delivery
# [ 6] 18:00:00.0 D1: Parcel 189 (for cust 61 out for delivery
# [ 6] 18:00:00.0 D1: Parcel 187 (for cust 60 out for delivery
# [ 6] 18:00:00.0 D1: Parcel 196 (for cust 79 out for delivery
# [ 6] 18:00:00.0 D1: Parcel 198 (for cust 82 out for delivery
# [ 6] 18:00:00.0 D1: Parcel 53 (for cust 92 out for delivery
# [ 6] 18:00:00.0 D1: Parcel 86 (for cust 92 out for delivery
# [ 6] 18:00:00.0 D1: Parcel 172 (for cust 92 out for delivery
# [ 6] 18:00:00.0 D1: Parcel 199 (for cust 92 out for delivery
# [ 6] 18:00:00.0 D1: Parcel 200 (for cust 93 out for delivery
# [ 6] 18:15:00.0 D0: leaves for delivery of 18 parcels to 15 customers
# [ 6] 18:15:00.0 D0: Length of delivery tour: 24,775m
# [ 6] 18:15:00.0 D0: drives to Customer 22 at (2169, 4500)
# [ 6] 18:18:20.0 D1: leaves for delivery of 22 parcels to 18 customers
# [ 6] 18:18:20.0 D1: Length of delivery tour: 30,714m
# [ 6] 18:18:20.0 D1: drives to Customer 30 at (2380, 5128)
# [ 6] 18:20:05.0 D0: arrived at Customer 22 at (2169, 4500)
# [ 6] 18:21:05.0 D0: Customer 22 at (2169, 4500) to slow to answer the door
# [ 6] 18:21:05.0 D0: drives to Customer 50 at (4500, 6283)
# [ 6] 18:25:05.1 D1: arrived at Customer 30 at (2380, 5128)
# [ 6] 18:25:37.6 D1: Customer 30 at (2380, 5128) answers door
# [ 6] 18:25:37.6 D1: Parcel 181 (for cust 30 delivered
# [ 6] 18:25:40.7 D1: Customer 30 at (2380, 5128) signs off
# [ 6] 18:25:43.3 D1: drives to Customer 39 at (3440, 4390)
# [ 6] 18:32:54.8 D1: arrived at Customer 39 at (3440, 4390)
# [ 6] 18:32:59.5 D1: Customer 39 at (3440, 4390) answers door
# [ 6] 18:32:59.5 D1: Parcel 183 (for cust 39 delivered
# [ 6] 18:33:01.0 D1: Customer 39 at (3440, 4390) signs off
# [ 6] 18:33:17.8 D1: drives to Customer 38 at (3440, 4276)
# [ 6] 18:33:45.1 D1: arrived at Customer 38 at (3440, 4276)
# [ 6] 18:33:51.1 D1: Customer 38 at (3440, 4276) answers door
# [ 6] 18:33:51.1 D1: Parcel 182 (for cust 38 delivered
# [ 6] 18:34:11.0 D1: Customer 38 at (3440, 4276) signs off
# [ 6] 18:34:28.4 D1: drives to Customer 32 at (2738, 2738)
# [ 6] 18:35:03.4 D0: arrived at Customer 50 at (4500, 6283)
# [ 6] 18:35:09.2 D0: Customer 50 at (4500, 6283) answers door
# [ 6] 18:35:09.2 D0: Parcel 186 (for cust 50 delivered
# [ 6] 18:35:17.4 D0: Customer 50 at (4500, 6283) signs off
# [ 6] 18:35:17.5 D0: drives to Customer 48 at (4280, 6620)
# [ 6] 18:37:31.2 D0: arrived at Customer 48 at (4280, 6620)
# [ 6] 18:38:31.2 D0: Customer 48 at (4280, 6620) to slow to answer the door
# [ 6] 18:38:31.2 D0: drives to Customer 42 at (3440, 7122)
# [ 6] 18:41:47.1 D1: arrived at Customer 32 at (2738, 2738)
# [ 6] 18:42:47.1 D1: Customer 32 at (2738, 2738) not at home
# [ 6] 18:42:47.1 D1: drives to Customer 27 at (2380, 1401)
# [ 6] 18:43:53.3 D0: arrived at Customer 42 at (3440, 7122)
# [ 6] 18:44:25.9 D0: Customer 42 at (3440, 7122) answers door
# [ 6] 18:44:25.9 D0: Parcel 184 (for cust 42 delivered
# [ 6] 18:44:40.0 D0: Parcel 185 (for cust 42 delivered
# [ 6] 18:44:46.8 D0: Customer 42 at (3440, 7122) signs off
# [ 6] 18:44:58.5 D0: drives to Customer 36 at (3313, 7680)
# [ 6] 18:47:42.9 D0: arrived at Customer 36 at (3313, 7680)
# [ 6] 18:48:42.9 D0: Customer 36 at (3313, 7680) to slow to answer the door
# [ 6] 18:48:42.9 D0: drives to Customer 8 at (1550, 7680)
# [ 6] 18:48:43.5 D1: arrived at Customer 27 at (2380, 1401)
# [ 6] 18:49:16.3 D1: Customer 27 at (2380, 1401) answers door
# [ 6] 18:49:16.3 D1: Parcel 180 (for cust 27 delivered
# [ 6] 18:49:37.0 D1: Customer 27 at (2380, 1401) signs off
# [ 6] 18:49:41.2 D1: drives to Customer 12 at (1791, 1320)
# [ 6] 18:52:22.0 D1: arrived at Customer 12 at (1791, 1320)
# [ 6] 18:52:26.1 D1: Customer 12 at (1791, 1320) answers door
# [ 6] 18:52:26.1 D1: Parcel 177 (for cust 12 delivered
# [ 6] 18:52:26.2 D1: Customer 12 at (1791, 1320) signs off
# [ 6] 18:52:28.8 D1: drives to Customer 26 at (2275, 2484)
# [ 6] 18:55:46.0 D0: arrived at Customer 8 at (1550, 7680)
# [ 6] 18:56:46.0 D0: Customer 8 at (1550, 7680) to slow to answer the door
# [ 6] 18:56:46.0 D0: drives to Customer 7 at (1449, 7680)
# [ 6] 18:57:10.2 D0: arrived at Customer 7 at (1449, 7680)
# [ 6] 18:57:25.2 D0: Customer 7 at (1449, 7680) answers door
# [ 6] 18:57:25.2 D0: Parcel 150 (for cust 7 delivered
# [ 6] 18:57:27.7 D0: Customer 7 at (1449, 7680) signs off
# [ 6] 18:57:34.6 D0: drives to Customer 1 at (1078, 6620)
# [ 6] 18:59:39.8 D1: arrived at Customer 26 at (2275, 2484)
# [ 6] 19:00:39.8 D1: Customer 26 at (2275, 2484) to slow to answer the door
# [ 6] 19:00:39.8 D1: drives to Customer 17 at (1951, 2807)
# [ 6] 19:02:29.5 D1: arrived at Customer 17 at (1951, 2807)
# [ 6] 19:02:57.9 D1: Customer 17 at (1951, 2807) answers door
# [ 6] 19:02:57.9 D1: Parcel 154 (for cust 17 delivered
# [ 6] 19:03:02.1 D1: Customer 17 at (1951, 2807) signs off
# [ 6] 19:03:02.9 D1: drives to Customer 2 at (1320, 4082)
# [ 6] 19:03:18.0 D0: arrived at Customer 1 at (1078, 6620)
# [ 6] 19:03:52.1 D0: Customer 1 at (1078, 6620) answers door
# [ 6] 19:03:52.1 D0: Parcel 148 (for cust 1 delivered
# [ 6] 19:03:54.7 D0: Parcel 174 (for cust 1 delivered
# [ 6] 19:03:59.2 D0: Customer 1 at (1078, 6620) signs off
# [ 6] 19:04:04.0 D0: drives to Customer 0 at (882, 6620)
# [ 6] 19:04:51.1 D0: arrived at Customer 0 at (882, 6620)
# [ 6] 19:05:47.9 D0: Customer 0 at (882, 6620) answers door
# [ 6] 19:05:47.9 D0: Parcel 173 (for cust 0 delivered
# [ 6] 19:05:50.5 D0: Customer 0 at (882, 6620) signs off
# [ 6] 19:06:18.0 D0: drives to Customer 77 at (6047, 7680)
# [ 6] 19:09:11.3 D1: arrived at Customer 2 at (1320, 4082)
# [ 6] 19:10:05.6 D1: Customer 2 at (1320, 4082) answers door
# [ 6] 19:10:05.6 D1: Parcel 175 (for cust 2 delivered
# [ 6] 19:10:12.1 D1: Customer 2 at (1320, 4082) signs off
# [ 6] 19:10:33.4 D1: drives to Customer 43 at (3847, 3440)
# [ 6] 19:26:43.9 D1: arrived at Customer 43 at (3847, 3440)
# [ 6] 19:27:01.7 D1: Customer 43 at (3847, 3440) answers door
# [ 6] 19:27:01.7 D1: Parcel 161 (for cust 43 delivered
# [ 6] 19:27:06.6 D1: Customer 43 at (3847, 3440) signs off
# [ 6] 19:27:08.0 D1: drives to Customer 63 at (5560, 1564)
# [ 6] 19:37:11.7 D0: arrived at Customer 77 at (6047, 7680)
# [ 6] 19:38:11.7 D0: Customer 77 at (6047, 7680) to slow to answer the door
# [ 6] 19:38:11.7 D0: drives to Customer 81 at (6158, 7680)
# [ 6] 19:38:38.4 D0: arrived at Customer 81 at (6158, 7680)
# [ 6] 19:38:58.9 D0: Customer 81 at (6158, 7680) answers door
# [ 6] 19:38:58.9 D0: Parcel 197 (for cust 81 delivered
# [ 6] 19:39:00.3 D1: arrived at Customer 63 at (5560, 1564)
# [ 6] 19:39:05.8 D0: Customer 81 at (6158, 7680) signs off
# [ 6] 19:39:16.5 D0: drives to Customer 69 at (5560, 6381)
# [ 6] 19:39:25.8 D1: Customer 63 at (5560, 1564) answers door
# [ 6] 19:39:25.8 D1: Parcel 190 (for cust 63 delivered
# [ 6] 19:39:30.4 D1: Customer 63 at (5560, 1564) signs off
# [ 6] 19:39:55.2 D1: drives to Customer 62 at (5560, 1408)
# [ 6] 19:40:32.6 D1: arrived at Customer 62 at (5560, 1408)
# [ 6] 19:40:55.3 D1: Customer 62 at (5560, 1408) answers door
# [ 6] 19:40:55.3 D1: Parcel 164 (for cust 62 delivered
# [ 6] 19:40:59.7 D1: Customer 62 at (5560, 1408) signs off
# [ 6] 19:41:04.8 D1: drives to Customer 61 at (5363, 1123)
# [ 6] 19:42:32.7 D1: arrived at Customer 61 at (5363, 1123)
# [ 6] 19:43:30.8 D1: Customer 61 at (5363, 1123) answers door
# [ 6] 19:43:30.8 D1: Parcel 188 (for cust 61 delivered
# [ 6] 19:44:20.5 D1: Parcel 189 (for cust 61 delivered
# [ 6] 19:44:40.6 D1: Customer 61 at (5363, 1123) signs off
# [ 6] 19:44:47.2 D1: drives to Customer 60 at (5273, 1033)
# [ 6] 19:45:17.7 D1: arrived at Customer 60 at (5273, 1033)
# [ 6] 19:45:31.4 D1: Customer 60 at (5273, 1033) answers door
# [ 6] 19:45:31.4 D1: Parcel 187 (for cust 60 delivered
# [ 6] 19:45:37.3 D1: Customer 60 at (5273, 1033) signs off
# [ 6] 19:45:41.6 D1: drives to Customer 79 at (6105, 2925)
# [ 6] 19:46:51.8 D0: arrived at Customer 69 at (5560, 6381)
# [ 6] 19:47:02.9 D0: Customer 69 at (5560, 6381) answers door
# [ 6] 19:47:02.9 D0: Parcel 192 (for cust 69 delivered
# [ 6] 19:47:05.0 D0: Customer 69 at (5560, 6381) signs off
# [ 6] 19:47:36.2 D0: drives to Customer 66 at (5560, 5684)
# [ 6] 19:50:23.5 D0: arrived at Customer 66 at (5560, 5684)
# [ 6] 19:50:51.2 D0: Customer 66 at (5560, 5684) answers door
# [ 6] 19:50:51.2 D0: Parcel 191 (for cust 66 delivered
# [ 6] 19:50:52.3 D0: Customer 66 at (5560, 5684) signs off
# [ 6] 19:50:57.2 D0: drives to Customer 73 at (5828, 5560)
# [ 6] 19:52:31.3 D0: arrived at Customer 73 at (5828, 5560)
# [ 6] 19:53:31.3 D0: Customer 73 at (5828, 5560) not at home
# [ 6] 19:53:31.3 D0: drives to Customer 75 at (5972, 5560)
# [ 6] 19:54:05.8 D0: arrived at Customer 75 at (5972, 5560)
# [ 6] 19:54:25.5 D0: Customer 75 at (5972, 5560) answers door
# [ 6] 19:54:25.5 D0: Parcel 194 (for cust 75 delivered
# [ 6] 19:54:32.7 D0: Customer 75 at (5972, 5560) signs off
# [ 6] 19:54:38.0 D1: arrived at Customer 79 at (6105, 2925)
# [ 6] 19:55:11.9 D0: returns to delivery centre
# [ 6] 19:55:38.0 D1: Customer 79 at (6105, 2925) not at home
# [ 6] 19:55:38.0 D1: drives to Customer 82 at (6207, 3027)
# [ 6] 19:56:12.5 D1: arrived at Customer 82 at (6207, 3027)
# [ 6] 19:57:12.5 D1: Customer 82 at (6207, 3027) to slow to answer the door
# [ 6] 19:57:12.5 D1: drives to Customer 92 at (7203, 3440)
# [ 6] 20:01:52.6 D1: arrived at Customer 92 at (7203, 3440)
# [ 6] 20:02:26.0 D1: Customer 92 at (7203, 3440) answers door
# [ 6] 20:02:26.0 D1: Parcel 53 (for cust 92 delivered
# [ 6] 20:02:35.6 D1: Parcel 86 (for cust 92 delivered
# [ 6] 20:02:46.9 D1: Parcel 172 (for cust 92 delivered
# [ 6] 20:02:53.8 D1: Parcel 199 (for cust 92 delivered
# [ 6] 20:03:00.5 D1: Customer 92 at (7203, 3440) signs off
# [ 6] 20:03:04.3 D1: drives to Customer 93 at (7680, 2699)
# [ 6] 20:07:04.9 D0: arrived at delivery centre
# [ 6] 20:07:04.9 D0: Parcel 178 (for cust 22 returned from delivery
# [ 6] 20:07:34.9 D0: Parcel 130 (for cust 48 returned from delivery
# [ 6] 20:07:56.6 D1: arrived at Customer 93 at (7680, 2699)
# [ 6] 20:08:04.9 D0: Parcel 156 (for cust 36 returned from delivery
# [ 6] 20:08:34.9 D0: Parcel 157 (for cust 36 returned from delivery
# [ 6] 20:08:56.6 D1: Customer 93 at (7680, 2699) not at home
# [ 6] 20:08:56.6 D1: returns to delivery centre
# [ 6] 20:09:04.9 D0: Parcel 176 (for cust 8 returned from delivery
# [ 6] 20:09:34.9 D0: Parcel 195 (for cust 77 returned from delivery
# [ 6] 20:10:04.9 D0: Parcel 193 (for cust 73 returned from delivery
# [ 6] 20:10:34.9 D0: 7 parcels left over for next day
# [ 6] 20:20:34.9 D0: goes home
# [ 6] 20:36:36.9 D1: arrived at delivery centre
# [ 6] 20:36:36.9 D1: Parcel 69 (for cust 32 returned from delivery
# [ 6] 20:37:06.9 D1: Parcel 179 (for cust 26 returned from delivery
# [ 6] 20:37:36.9 D1: Parcel 196 (for cust 79 returned from delivery
# [ 6] 20:38:06.9 D1: Parcel 198 (for cust 82 returned from delivery
# [ 6] 20:38:36.9 D1: Parcel 200 (for cust 93 returned from delivery
# [ 6] 20:39:06.9 D1: 5 parcels left over for next day
# [ 6] 20:49:06.9 D1: goes home
# Delivery Centre Inventory at the end of last day: 12 parcels

# %%
for i in range(rec1.drivers):
    rec1.plotTourLength(i)
rec1.plotTourLength()

# %%
rec1.plotParcelsLeftOver(0)

# %%
rec1.plotParcelsLeftOver()

# %%
rec1.histParcelsLeftOver()

# %%
rec1.histParcelDeliveryDelay()

# %% [markdown]
# ### Stable Base Case

# %%
import pickle
with open('testData.pickled', 'rb') as f:
    MT, CT = pickle.load(f)

# %%
WT = generateWarehouseLocation(MT)

# %%
plotMap(MT, T=CT, w=WT, scale=True)

# %%
PlanT = planCPP(MT, WT, CT, n=2, balance=0.2, timing=True, plot=True)
# Out:
# Solver time:   10.34s
# Solution possibly not optimal
# Total Delivery Path Length: 63726.0

# %% [markdown]
# Comparison with Greedy Solution using Static Allocation

# %%
MMT, LLT, CCT = PlanT
for i in range(len(MMT)):
    print(f"Driver {i:d}")
    MMTT = addTargets(MMT[i], CCT[i])
    path = createLoopG(MMTT, [WT] + CCT[i])
    plotMap(MMTT, T=CCT[i], P=path, w=WT, frame=MT, 
            size=3, text=f"Driver {i:d}: {pathLength(path):,d}m")
# Out:
# Driver 0
# Driver 1

# %%
rec2 = simulation(MT, WT, CT, PlanT, p=0.15, days=50)
# Out:
# Simulating delivery of 134 parcels over 50 days to 20 customers using 2 drivers
# Delivery Centre Inventory at the end of last day: 2 parcels

# %%
for i in range(rec1.drivers):
    rec2.plotWorkingTime(i)
rec2.plotWorkingTime()

# %%
for i in range(rec1.drivers):
    rec2.plotTourLength(i)
rec2.plotTourLength()

# %%
for i in range(rec1.drivers):
    rec2.plotDailyCost(i)
rec2.plotDailyCost()

# %%
rec2.plotParcelsLeftOver()

# %%
rec2.countPlot()

# %% [markdown]
# ### High Demand System

# %%
import pickle
with open('data.pickled', 'rb') as f:
    M, C = pickle.load(f)

# %%
W = generateWarehouseLocation(M)

# %%
plotMap(M, T=C, w=W, scale=True)

# %%
Plan = planCPP(M, W, C, n=2, 
                     maxLength=50000, balance=0.5, timeLimit=10, 
                     timing=True, plot=True)
# Out:
# Solver time:    3.11s
# Total Delivery Path Length: 71245.0

# %% [markdown]
# Comparison with Greedy Solution using Static Allocation shows noticeable better performance:

# %%
MM, LL, CC = Plan
for i in range(len(MM)):
    print(f"Driver {i:d}")
    MMT = addTargets(MM[i], CC[i])
    path = createLoopG(MMT, [W] + CC[i])
    plotMap(MMT, T=CC[i], P=path, w=W, frame=M, 
            size=3, msPT=2, lwP=1, 
            text=f"Driver {i:d}: {pathLength(path):,d}m")
# Out:
# Driver 0
# Driver 1

# %%
rec5 = simulation(M, W, C, Plan, p=0.25, days=50)
# Out:
# Simulating delivery of 1249 parcels over 50 days to 100 customers using 2 drivers
# Delivery Centre Inventory at the end of last day: 8 parcels

# %%
for i in range(rec5.drivers):
    rec5.histTourLength(i)
rec5.histTourLength()

# %%
for i in range(rec5.drivers):
    rec5.plotTourLength(i)
rec5.plotTourLength()

# %%
for i in range(rec5.drivers):
    rec5.histWorkingTime(i)
rec5.histWorkingTime()

# %%
for i in range(rec5.drivers):
    rec5.plotWorkingTime(i)
rec5.plotWorkingTime()

# %%
for i in range(rec5.drivers):
    rec5.plotDailyCost(i)
rec5.plotDailyCost()

# %%
rec5.histDailyCost()

# %%
rec5.histParcelsArrived()

# %%
rec5.histParcelsDelivered()

# %%
rec5.histParcelsLeftOver()

# %%
rec5.plotParcelsLeftOver()

# %%
rec5.countPlot()

# %%
rec5.histParcelDeliveryDelay()
