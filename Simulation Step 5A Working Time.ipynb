# %% [markdown]
# # Prelude

# %%
import matplotlib.pyplot as plt
import pulp
import math
import random
import pandas as pd
import numpy as np
import simpy

# %% [markdown]
# # Utilities

# %% [markdown]
# ## Points and Distances

# %%
def dist(p1, p2):
    (x1, y1) = p1
    (x2, y2) = p2
    return int(math.sqrt((x1-x2)**2+(y1-y2)**2))

# %% [markdown]
# ## PlotMap

# %%
def label(i):
    return (label(i//26-1)+chr(65+i%26)) if i>25 else chr(65+i)

# %%
def plotMap(G, T=[], P=[], w=None,
            style='r-o', lw=1, ms=3, 
            styleT='go', msT=3,
            styleP='b-o', lwP=2, msP=3,
            stylePT='go', msPT=7,
            styleW='ro', msW=9,
            text=None, grid=False, labels=False, scale=False):

    V, E = G

    def round_down(x, level): return (x//level)*level
    def round_up(x, level): return (x//level+1)*level
    
    xmin = round_down(min([ x for (x, _) in V ]), 100)
    xmax = round_up(max([ x for (x, _) in V ]), 100)
    ymin = round_down(min([ y for (_, y) in V ]), 100)
    ymax = round_up(max([ y for (_, y) in V ]), 100)
    dx = xmax-xmin
    dy = ymax-ymin
    yoffset = (ymax-ymin)//10
    
    fig = plt.gcf()
    fig.set_size_inches(4, 4)
    plt.xlim(xmin, xmax)
    plt.ylim(ymin-yoffset, ymax)
    
    if not grid:
        plt.axis('off')

    for e in E:
        p1, p2 = e
        plt.plot( [ p1[0], p2[0] ],
                  [ p1[1], p2[1] ], 
                  style, lw=lw, ms=ms)
    if scale:
        # plot 1000m scale
        ybar = ymin-0.9*yoffset
        D = [ (xmin, ybar+50), (xmin, ybar), (xmin+1000, ybar), (xmin+1000, ybar+50) ]
        plt.plot( [ d[0] for d in D ], [ d[1] for d in D ], 'k-', lw=0.5)
        plt.text(xmin+500, ymin-0.7*yoffset, '1000m' , horizontalalignment='center', size=8)
    
    if labels:
        for i in range(len(V)):
            x, y = V[i]
            plt.text(x+0.0150*dx, y-0.0350*dy, label(i), size=8)
        
    for t in T:
        plt.plot( [ t[0] ], [ t[1] ], 
                  styleT, ms=msT)
        
    plt.plot( [ p[0] for p in P ],
              [ p[1] for p in P ], 
              styleP, lw=lwP, ms=msP)
    
    for p in P:
        if p in T:
            plt.plot( [ p[0] ], [ p[1] ], 
                      stylePT, ms=msPT)
    if w is not None:
        plt.plot( [ w[0] ], [ w[1] ], 
                      styleW, ms=msW)
    if text is not None:
        plt.text(xmax, ymin-0.7*yoffset, text, horizontalalignment='right', size=8)
    if grid:
        plt.grid()
    plt.show()

# %% [markdown]
# ## Add Targets

# %%
def addTargets(M, T):
    V, E = M
    E = E.copy()
    V = V.copy()
    for t in T:
        minD = math.inf
        minE = None
        for e in E:
            P, Q = e
            distT = dist(P, t)+dist(t, Q)-dist(P, Q)
            if distT < minD:
                minD = distT
                minE = e
        P, Q = minE
        E.remove( (P, Q) )
        E.append( (P, t) )
        E.append( (t, Q) )
        V.append(t)
    return V, E

# %% [markdown]
# ## Generate Central Warehouse Location

# %%
from statistics import median

def generateWarehouseLocation(M):
    V, _ = M
    xc = median([ x for (x, y) in V ])
    yc = median([ y for (x, y) in V ])
    cloc = (xc, yc)
    minloc = V[0]
    mindist = dist(minloc, cloc)
    for i in range(1, len(V)):
        d = dist(V[i], cloc)
        if d<mindist:
            minloc = V[i]
            mindist = dist(V[i], cloc)
    return minloc

# %% [markdown]
# ## Time Handling

# %% [markdown]
# **Convention:** In this project we measure simulation time in seconds. The simulation will start at 0:00. Time related methods will be added as they are needed.

# %% [markdown]
# `timestamp(t)` generates a timestamp string in the form `[dd] hh:mm:ss.d`

# %%
def timestamp(t):
    t = round(t, 1)
    day = int(t)//(24*3600)
    t = t - day*24*3600
    hour = int(t)//3600
    t = t - hour*3600
    mins = int(t)//60
    t = t - mins*60
    secs = int(t)
    t = int(round((t-secs)*10,1)) 
    return f"[{day:2d}] {hour:02d}:{mins:02d}:{secs:02d}.{t:1d}"

# %%
timestamp(24*3600*3+17*3600+615.1)
# Out:
# '[ 3] 17:10:15.1'

# %%
timestamp(24*3600*12+3*3600+122.1)
# Out:
# '[12] 03:02:02.1'

# %%
def day(now):
    return int(now//(24*3600))

# %%
def nextHour(env, hour):
    beginningOfDay = int(env.now//(24*3600))*24*3600
    timeOfDay = env.now-beginningOfDay
    if hour*3600 > timeOfDay:
        return hour*3600 - timeOfDay
    else:
        return hour*3600 + 24*3600 - timeOfDay

# %% [markdown]
# ## Plotting Routines

# %%
import scipy.stats as stats

def histPlot(data, title="", xlabel="",
             width=None, height=None):
    
    minx = min(data)
    maxx = max(data)
    μ = np.mean(data)
    σ = np.std(data)
    
    fig = plt.figure()
    fig.set_figwidth(width if width is not None else 4)
    fig.set_figheight(height if height is not None else 2.5)
    ax = fig.gca()
        
    hist=plt.hist(data, density=True)
    plt.xlabel(xlabel)
    plt.ylabel('Density')
    plt.title(title)
        
    x = np.linspace(minx, maxx, 100)
    y = [ stats.norm(loc=μ, scale=σ).pdf(p) for p in x]
    ax.plot(x, y, lw=1, color='red')
    ax.axvline(x=μ, color='red')
    maxy = max(max(y), max(hist[0]))
    ax.text(maxx, maxy, 
            f'μ={μ:2.2f}\nσ={σ:2.2f}', 
            ha='right', va='top', 
            color='red', fontsize=12)
    ax.grid(True)
    plt.show()

def dailyPlot(data, 
              title="", ylabel="",
              width=None, height=None):
    
    days = len(data)
    
    fig = plt.figure()
    fig.set_figwidth(width if width is not None else 6)
    fig.set_figheight(height if height is not None else 2)
    
    ax = fig.gca()
    diff = (max(data)-min(data))*0.1
    ymin = int(math.floor(min(data)-diff))
    ymax = int(math.ceil(max(data)+diff))
    ax.set_xlim(-0.5, days-1+0.5)
    ax.set_ylim(ymin, ymax)
    ax.grid(True)
    
    ms = 2 if len(data)>=100 else 3
    lw = 0.5 if len(data)>=100 else 1

    x = np.arange(0, len(data))
    y = np.array([ y for y in data ])
    b, m = np.polynomial.polynomial.polyfit(x, y, 1)
    
    plt.plot(x, y, 'bo-', linewidth=lw, markersize=ms)
    plt.plot(x, m*x+b, 'r-')
    
    plt.xlabel('Day')
    plt.ylabel(ylabel)
    plt.title(title)
    plt.show()

# %% [markdown]
# # Finding Shortest Path (as before)

# %%
def pathLength(P):
    return 0 if len(P)<=1 else \
            dist(P[0], P[1])+pathLength(P[1:])

# %%
def shortestPath(M, A, B):

    def h(p): 
        return pathLength(p)+dist(p[-1],B)
    
    # candidates C are pairs of the path so far and 
    # the heuristic function of that path, 
    # sorted by the heuristic function, as maintained by
    # insert function
    def insert(C, p):
        hp = h(p)
        c = (p, hp)
        for i in range(len(C)):
            if C[i][1]>hp:
                return C[:i]+[c]+C[i:]
        return C+[c]   
        
    V, E = M
    assert(A in V and B in V)    
    C = insert([], [A])

    while len(C)>0:
        # take the first candidate out of the list of candidates
        path, _ = C[0]
        C = C[1:]
        if path[-1]==B:
            return path
        else:
            for (x, y) in E:
                if path[-1]==x and y not in path:
                    C = insert(C, path+[y])
                elif path[-1]==y and x not in path:
                    C = insert(C, path+[x])
    return None

# %% [markdown]
# # Finding Short Delivery Route (as before)

# %% [markdown]
# ## Greedy Algorithm

# %%
def FW(M):
    
    V, E = M

    n = len(V)
    d = [ [ math.inf for j in range(n) ] for i in range(n) ]
    p = [ [ None for j in range(n) ] for i in range(n) ]

    for (A, B) in E:
        a = V.index(A)
        b = V.index(B)
        d[a][b] = d[b][a] = dist(A, B)
        p[a][b] = [A, B]
        p[b][a] = [B, A]
    
    for i in range(n):
        d[i][i] = 0
        p[i][i] = [V[i]]
    
    for k in range(n):
        for i in range(n):
            for j in range(n):
                dk = d[i][k] + d[k][j]
                if d[i][j] > dk:
                    d[i][j] = dk
                    p[i][j] = p[i][k][:-1] + p[k][j]
                    
    return d, p

# %%
def createLoopG(M, T, timing=False):
    
    def makeLoop(L, V, P):
        loop = []
        for i in range(len(L)-1):
            A = L[i]
            B = L[i+1]
            a = V.index(A)
            b = V.index(B)
            sub = P[a][b]
            loop += sub if len(loop)==0 else sub[1:]
        return loop
        
    if timing:
        start_time = time.time()
        last_time = time.time()
        
    V, E = M
    D, P = FW(M)   # note these are the distances between all vertices in M (and T)
    W = T[0]
    customers = T[1:]
    if len(T)==1:
        L = T
    elif len(T)<=3:
        L = T + [T[0]]
    else:
        L = T[:3]+[T[0]]
        T = T[3:]
        while len(T)>0:
            minExt = math.inf
            minInd = None
            selInd = None
            for k in range(len(T)):
                C = T[k]
                c = V.index(C)
                for i in range(0, len(L)-1):
                    A = L[i]
                    B = L[i+1]
                    a = V.index(A)
                    b = V.index(B)
                    ext = D[a][c] + D[c][b] - D[a][b]
                    if ext<minExt:
                        minExt, minInd, selInd = ext, i+1, k
            L = L[:minInd]+[T[selInd]]+L[minInd:]
            T = T[:selInd]+T[selInd+1:]
            
    if timing:
        print(f"createLoopG:    {time.time()-start_time:6.2f}s")

    return makeLoop(L, V, P)

# %% [markdown]
# # Finding Optimal Delivery Route

# %% [markdown]
# ## Iterative Integer Programming

# %%
def createTables(M, T):

    def reverse(P):
        return [ P[-i] for i in range(1,len(P)+1) ]
    
    def index(x, L):
        for i in range(len(L)):
            if x==L[i]: 
                return i
        return None

    n = len(T)
    d = [ [ math.inf for t in T ] for t in T ]
    p = [ [ None for t in T ] for t in T ]
    for i in range(n):
        d[i][i] = 0
        p[i][i] = [ T[i] ]
    for i in range(n):
        for j in range(n):
            if p[i][j] is None:
                s = shortestPath(M, T[i], T[j])
                d[i][j] = d[j][i] = pathLength(s)
                p[i][j] = s
                p[j][i] = reverse(s)
                for m in range(len(s)-1):
                    smi = index(s[m], T)
                    if smi is None:
                        continue
                    for l in range(m+1, len(s)):
                        sli = index(s[l], T)
                        if sli is None:
                            continue  
                        sub = s[m:l+1]
                        if p[smi][sli] is None:
                            p[smi][sli] = sub
                            p[sli][smi] = reverse(sub)
                            d[smi][sli] = d[sli][smi] = pathLength(sub)
    return d,p

# %%
def roundtrips(x, n):
    
    def isElem(x, l):
        for i in range(len(l)):
            if l[i]==x:
                return True
        return False

    def startpoint(trips):
        for i in range(n):
            for t in trips:
                if isElem(i, t):
                    break
            else:
                return i
    
    def totalLength(trips):
        s=0
        for i in range(0, len(trips)):
            s += len(trips[i])-1
        return s

    trips = []
    while totalLength(trips)<n:
        start = startpoint(trips)
        trip = [ start ]
        i = start
        while len(trip) < n-totalLength(trips):
            for j in range(0, n):
                if pulp.value(x[i][j])==1:
                    trip.append(j)
                    i=j
                    break        
            if pulp.value(x[trip[-1]][start])==1:
                trip.append(start)
                break
        trips.append(trip)
    return sorted(trips, key=lambda t: len(t), reverse=True)

# %%
import time

def createLoop(M, T, timing=False):
    
    if timing:
        start_time = last_time = time.time()
        
    D, P = createTables(M, T)   # These are the distances between customers and warehouse only
    
    if timing:
        print(f"createTables:   {time.time()-start_time:6.2f}s")
        last_time = time.time()
        
    n = len(T)
    # create variables
    x = pulp.LpVariable.dicts("x", ( range(n), range(n) ),
                            lowBound=0, upBound=1, cat=pulp.LpInteger)
    # create problem
    prob = pulp.LpProblem("Loop",pulp.LpMinimize)
    # add objective function
    prob += pulp.lpSum([ D[i][j]*x[i][j] 
                             for i in range(n) for j in range(n) ])
    # add constraints
    constraints=0
    for j in range(n):
        prob += pulp.lpSum([ x[i][j] for i in range(n) if i!=j ]) ==1
    constraints += n
    for i in range(n):
        prob += pulp.lpSum([ x[i][j] for j in range(n) if i!=j ]) ==1
    constraints += n
    for i in range(n):
        for j in range(n):
            if i!=j:
                prob += x[i][j]+x[j][i] <= 1
                constraints += 1
                
    def cycles(k, n):
        if k==1:
            return [ [i] for i in range(0,n) ]
        else:
            sc=cycles(k-1, n)
            all=[]
            for c in sc:
                for i in range(0,n):
                    if c.count(i)==0:
                        all.append(c+[i])
            return all

    for k in range(3, 4):   
        cycs=cycles(k,n)
        for c in cycs:
            c.append(c[0])
            prob+=pulp.lpSum([ x[c[i]][c[i+1]] for i in range(0,k)]) <= k-1
            constraints += 1    
            
    # initialise solver
    solvers = pulp.listSolvers(onlyAvailable=True)
    solver = pulp.getSolver(solvers[0], msg=0, timeLimit=2)
    res = prob.solve(solver)

    if timing:
        print(f"Solver:         {time.time()-last_time:6.2f}s {constraints:6,d} Constraints")
        last_time = time.time()
        
    trips = roundtrips(x, n)
    while len(trips)>1:
        longest = max([ len(t) for t in trips ])
        for t in trips:
            if len(t)<longest:
                prob += pulp.lpSum([ x[t[i]][t[i+1]] + x[t[i+1]][t[i]]
                                        for i in range(0,len(t)-1) ]) <= len(t)-2
                constraints += 1
            else:
                longest = math.inf
                
        res = prob.solve(solver)
        
        if timing:
            print(f"Solver:         {time.time()-last_time:6.2f}s {constraints:6,d} Constraints")
            last_time = time.time()

        trips = roundtrips(x, n)
    trip = trips[0]
    # print(trip)
    loop = []
    for k in range(len(trip)-1):
        sub = P[trip[k]][trip[k+1]]
        loop += sub if len(loop)==0 else sub[1:]
        
    if timing:
        print(f"createLoop:     {time.time()-start_time:6.2f}s")

    return loop

# %% [markdown]
# # Class Recorder

# %% [markdown]
# We willl use a class Recorder as a reference point for capturing data during the simulation. There will be only one recorder. It will be created at the beginning of every simulation run. Every entity will carry a reference to the Recorder.

# %%
import time

class Recorder:
    
    def __init__(self, env, M, W, C, days, 
                 log=False, plot=False, timing=False):
        self.env = env
        self.M = M
        self.W = W
        self.C = C
        self.days = days
        self.log = log
        self.plot = plot

        # create a data frame for time records per working day
        self.daily = pd.DataFrame()
        self.daily['begin work at'] = [None]*days
        self.daily['end work at'] = [None]*days
     
    def trace(self, event):
        if self.log:
            print(timestamp(self.env.now), event)

    def recordDriverBeginsWork(self):
        self.trace("Driver arrives for work")
        self.daily.at[day(self.env.now), 'begin work at'] = int(round(self.env.now))
        
    def recordDriverEndsWork(self):
        self.trace("Driver goes home")
        self.daily.at[day(self.env.now), 'end work at'] = int(round(self.env.now))
        
    def finish(self):
        # simulation is finished for good
        # by removing the simulation environment we can
        # pickle recorder
        self.env = None
        self.daily['working time'] = (self.daily['end work at']-self.daily['begin work at'])//60

    def histWorkingTime(self):
        histPlot(self.daily['working time'],
                 xlabel='Working Time [min]',
                 title=f'Daily Working Time ({self.days:d} days)')
        
    def plotWorkingTime(self):
        dailyPlot(self.daily['working time'],
                  ylabel='Working Time [min]',
                  title=f'Daily Working Time ({self.days:d} days)')

# %% [markdown]
# # Class Customer

# %% [markdown]
# <img src='img/EventGraph Customer.png' width=500/>

# %%
class Customer:
    
    def __init__(self, rec, id, location):
        self.rec = rec
        self.id = id
        self.location = location
        self.atHome = True
        self.answersDoor = False
        self.parcelsReceived = []
        rec.env.process(self.process())
        
    def __str__(self):
        return f"Customer {self.id:d} at {str(self.location):s}"
    
    def leaveHouse(self):
        assert(self.atHome and not self.answersDoor)
        # self.rec.trace(str(self)+" leaves house")
        self.atHome = False
     
    def returnHome(self):
        assert(not self.atHome)
        # self.rec.trace(str(self)+" returns home")
        self.atHome = True
        
    def answerDoor(self):
        if self.atHome:
            answerTime = random.expovariate(1/AVERAGE_TIME_ANSWER_DOOR)
            if answerTime < WAIT_TIME_IF_CUSTOMER_DOESNT_ANSWER_DOOR:                            
                yield self.rec.env.timeout(answerTime)
                self.rec.trace(str(self)+" answers door")
                self.answersDoor = True
            else:
                yield self.rec.env.timeout(WAIT_TIME_IF_CUSTOMER_DOESNT_ANSWER_DOOR)
                self.rec.trace(str(self)+" to slow to answer the door")
                self.answersDoor = False
        else:
            yield self.rec.env.timeout(WAIT_TIME_IF_CUSTOMER_DOESNT_ANSWER_DOOR)
            self.rec.trace(str(self)+" not at home")
            self.answersDoot = False
            
    def acceptParcel(self, parcel):
        assert(self.answersDoor)
        self.parcelsReceived += [parcel]
        self.rec.trace(str(self)+" accepts "+str(parcel))
        
    def signOff(self):
        assert(self.answersDoor)
        self.rec.trace(str(self)+" signs off")
        self.answersDoor = False
        
    def process(self):
        yield self.rec.env.timeout(nextHour(self.rec.env, 8))
        while day(self.rec.env.now)<self.rec.days:
            # in a refinement we may use random times
            self.leaveHouse()
            returnTime = 22 if random.random()<CUSTOMER_NOT_AT_HOME else 18
            yield self.rec.env.timeout(nextHour(self.rec.env, returnTime))
            self.returnHome()
            yield self.rec.env.timeout(nextHour(self.rec.env, 8))

# %% [markdown]
# # Class Parcel

# %% [markdown]
# <img src='img/EventGraph Parcel.png' width=500/>

# %% [markdown]
# Parcels follow through a sequence of states:
# - processing
# - in transit (from manufacture to distribution centre)
# - arrived in distribution centre
# - ready for delivery
# - out for delivery
# - customer not present
# - returned to distribution centre
# - delivered

# %%
class Parcel:
    
    def __init__(self, rec, i, day, cust):
        self.rec = rec
        self.i = i  
        self.arrival = day
        self.cust = cust
        self.status = [  ] # status record and
        self.timing = [  ] # timing

    def __str__(self):
        return f"Parcel {self.i:d} for cust {self.cust.id:d}"

    def index(self):
        return self.i
    
    def destination(self):
        return self.cust.location
    
    def __reg(self, state):
        self.status += [ state ]
        self.timing += [ self.rec.env.now ]
        self.rec.trace(str(self)+" "+state)
        
    def arrivedAtDeliveryCentre(self):
        self.__reg('arr at delivery centre')
        
    def outForDelivery(self): 
        self.__reg('out for delivery')
        
    def returnFromDelivery(self):
        self.__reg('return from delivery')

# %% [markdown]
# # Class Driver

# %% [markdown]
# <img src='img/EventGraph Driver.png' width=500/>

# %%
class Driver:
    
    def __init__(self, rec, DC):
        self.rec = rec
        self.DC = DC
        self.location = None
        self.parcels = None
        self.tour = None
        self.rec.env.process(self.process())
        
    # activity
    def __drive(self, target):
        assert(self.tour[0] == self.location)
        while self.location!=target:
            d = dist(self.location, self.tour[1])
            yield self.rec.env.timeout(d / AVERAGE_SPEED)
            self.location = self.tour[1]
            self.tour = self.tour[1:]
        assert(self.tour[0] == self.location == target)
    
    def arriveForWork(self):
        self.location = self.DC.W
        self.parcels = []
        self.returns = []
        self.tour = [ self.DC.W ]
        # self.rec.trace("Driver arrives for work")
        self.rec.recordDriverBeginsWork()
    
    def goesHome(self):
        self.location = None
        self.parcels = None
        self.returns = None
        self.tour = None
        # self.rec.trace("Driver goes home")
        self.rec.recordDriverEndsWork()
        
    def leaveForDelivery(self, tour, parcels, addresses):
        self.tour, self.parcels = tour, parcels
        self.rec.trace(f"Driver leaves for delivery " 
                       f"of {len(parcels):d} parcels "
                       f"to {len(addresses):d} customers")
        self.rec.trace(f"Length of delivery tour: {pathLength(tour):,d}m")
        if self.rec.plot:
            plotMap(self.rec.M, T=addresses, P=tour, w=tour[0], 
                    text=f"Day {day(self.rec.env.now):d}:, {pathLength(tour):,d}m")
        
    def process(self):
        yield self.rec.env.timeout(nextHour(self.rec.env, 18))
        while day(self.rec.env.now)<self.rec.days:
            self.arriveForWork()
            tour, parcels, addresses = self.DC.sendForDelivery()
            if len(parcels)==0: 
                self.rec.trace("Nothing to do today")
            else:
                yield self.rec.env.timeout(PREP_TIME_PER_PARCEL*len(parcels))
                self.leaveForDelivery(tour, parcels, addresses)        
                while len(self.parcels)>0:
                    # drive to customer
                    custLocation = self.parcels[0].destination()
                    cust = self.parcels[0].cust
                    self.rec.trace("Driver drives to "+str(cust))
                    yield from self.__drive(custLocation)
                    self.rec.trace("Driver arrived at "+str(cust))
                    # call at customer
                    yield from cust.answerDoor()
                    
                    if cust.answersDoor:
                        while len(self.parcels)>0 and \
                                custLocation == self.parcels[0].destination():
                            cust.acceptParcel(self.parcels[0])
                            yield self.rec.env.timeout(random.expovariate(1/10))
                            self.parcels = self.parcels[1:]
                        cust.signOff()
                        yield self.rec.env.timeout(random.expovariate(1/10))
                    else:
                        while len(self.parcels)>0 and  \
                                custLocation == self.parcels[0].destination():
                            self.returns += [self.parcels[0]]
                            self.parcels = self.parcels[1:]

                # return to delivery centre
                self.rec.trace("Driver returns to delivery centre")
                yield from self.__drive(self.DC.W)
                self.rec.trace("Driver arrived at delivery centre")
            
                for parcel in self.returns:
                    self.DC.returnFromDelivery(parcel)
                    yield self.rec.env.timeout(RETURN_TIME_PER_PARCEL)

                leftOver = len(self.DC.parcels)+len(self.DC.leftOver)
                self.rec.trace(f"{leftOver:d} parcels left for next day")
            
            yield self.rec.env.timeout(600)
        
            self.goesHome()
            
            yield self.rec.env.timeout(nextHour(self.rec.env, 18))

# %% [markdown]
# # Class Delivery Centre

# %% [markdown]
# <img src="img/EventGraph Delivery Centre.png" width=300/>

# %%
class DeliveryCentre:
    
    def __init__(self, rec, M, W, limit):
        self.rec = rec
        self.M = M
        self.W = W
        self.limit = limit
        
        self.leftOver = []    # list of parcels
        self.parcels = []     # list of parcels scheduled for delivery
        self.dest = []        # list of unique customer destinations
        self.tour = [self.W]  # tour planned for delivery
    
    def __accept(self, parcel):
        custLoc = parcel.destination()
        if custLoc not in self.dest:
            MT = addTargets(self.M, self.dest + [custLoc])
            SH = createLoopG(MT, [self.W] + self.dest + [custLoc])
            if pathLength(SH)<self.limit:
                self.parcels.append(parcel)
                self.dest += [custLoc]
                self.tour = SH
            else: 
                self.leftOver.append(parcel)
        else:
            self.parcels.append(parcel)
        
    def acceptParcel(self, parcel):
        parcel.arrivedAtDeliveryCentre()
        self.__accept(parcel)
            
    def sendForDelivery(self):
        parcels = []
        tour = self.tour
        addresses = []
        
        # pick parcels in sequence to be delivered
        for i in range(1, len(tour)-1):
            dest = tour[i]
            for p in self.parcels:
                if p.destination() == dest and p not in parcels:
                    parcels += [p]
                    p.outForDelivery()
                    if dest not in addresses:
                        addresses += [dest]
         
        # arrange the left overs for next day
        L = self.leftOver
        self.tour = [self.W]
        self.parcels = []
        self.leftOver = []
        self.dest = []
        for p in L:
            self.__accept(p)

        return tour, parcels, addresses
                 
    def returnFromDelivery(self, parcel):
        parcel.returnFromDelivery()
        self.__accept(parcel)

    def getInventory(self):
        return len(self.parcels)+len(self.leftOver)

# %% [markdown]
# # Simulation

# %% [markdown]
# ## Parameters from Specification

# %% [markdown]
# The proportion of customers that for whatever are not at home or return home late

# %%
CUSTOMER_NOT_AT_HOME = 0.1  # 10%

# %% [markdown]
# The maximum bike range. This is passed as parameter to the Delivery Centre
# and taken into account for the daily tour planning

# %%
BIKE_RANGE = 40000

# %% [markdown]
# The time required for driving is based on the distance between way points at an average speed of 15km/h.

# %%
AVERAGE_SPEED = 15/3.6

# %% [markdown]
# The **cumulative preparation time** (route planning and
# sorting of the parcels in the delivery order and
# packing the cargo-bike) is assumed to be 50 sec per
# parcel to be delivered.

# %%
PREP_TIME_PER_PARCEL = 50

# %% [markdown]
# **Additional assumption:** The time to **process returned parcels** in the delivery centre is 30 sec per parce.

# %%
RETURN_TIME_PER_PARCEL = 30

# %% [markdown]
# The average time to answer the door.

# %%
AVERAGE_TIME_ANSWER_DOOR = 40

# %%
WAIT_TIME_IF_CUSTOMER_DOESNT_ANSWER_DOOR = 60

# %% [markdown]
# ## Generate Input Data

# %%
def generateDeliveries(p, C, days, seed=0):
    ## p is the average number of parcels per day per customer
    ## C is the number of customers to be served
    ## days is the number of days for which data are to be generated.
    random.seed(seed)
    deliveries = [ [ ] for _ in range(days) ]
    for c in range(C):
        arr = 0
        while True:
            arr += random.expovariate(p)
            day = int(arr)
            if day>=days:
                break
            deliveries[day].append(c)
    return deliveries

# %% [markdown]
# ## Simulation Routine

# %%
def simulation(M, W, C, p=0.2, days=10, seed=0, 
               log=False, plot=False, timing=False):

    random.seed(seed)
    D = generateDeliveries(p, len(C), days, seed)
    
    env = simpy.Environment()
    rec = Recorder(env, M, W, C, days, 
                   log=log, plot=plot, timing=timing)

    print(f"Simulating delivery of {sum([len(d) for d in D]):d} parcels "
          f"over {len(D):d} days to {len(C):d} customers")

    CUSTOMERS = []
    for i in range(len(C)):
        CUSTOMERS.append(Customer(rec, i, C[i]))

    DC = DeliveryCentre(rec, M, W, BIKE_RANGE)
    Z = Driver(rec, DC)
    PARCELS = []

    def parcelGeneratorProcess(env, rec, D, C):
        for day in range(len(D)):
            yield env.timeout(nextHour(env, 17.00))
            for c in D[day]:
                cust = CUSTOMERS[c]
                parcel = Parcel(rec, len(PARCELS), day, cust)
                PARCELS.append(parcel)
                DC.acceptParcel(parcel)

    env.process(parcelGeneratorProcess(env, rec, D, C))
    env.run()

    rec.finish()

    if DC.getInventory()>0:
        print(f"Delivery Centre Inventory: {DC.getInventory():d} parcels")

    return rec

# %% [markdown]
# ## Test Statistics

# %% [markdown]
# ### Using Simple Data

# %%
import pickle
with open('simpleData.pickled', 'rb') as f:
    M, C = pickle.load(f)

# %%
W = generateWarehouseLocation(M)

# %%
plotMap(M, T=C, w=W, scale=True)

# %%
rec1 = simulation(M, W, C, p=0.15, days=4, log=True)
# Out:
# Simulating delivery of 48 parcels over 4 days to 100 customers
# [ 0] 17:00:00.0 Parcel 0 for cust 19 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 1 for cust 27 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 2 for cust 30 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 3 for cust 40 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 4 for cust 54 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 5 for cust 72 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 6 for cust 77 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 7 for cust 79 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 8 for cust 80 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 9 for cust 84 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 10 for cust 89 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 11 for cust 89 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 12 for cust 92 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 13 for cust 96 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 14 for cust 96 arr at delivery centre
# [ 0] 18:00:00.0 Driver arrives for work
# [ 0] 18:00:00.0 Parcel 2 for cust 30 out for delivery
# [ 0] 18:00:00.0 Parcel 4 for cust 54 out for delivery
# [ 0] 18:00:00.0 Parcel 6 for cust 77 out for delivery
# [ 0] 18:00:00.0 Parcel 9 for cust 84 out for delivery
# [ 0] 18:00:00.0 Parcel 10 for cust 89 out for delivery
# [ 0] 18:00:00.0 Parcel 11 for cust 89 out for delivery
# [ 0] 18:00:00.0 Parcel 3 for cust 40 out for delivery
# [ 0] 18:00:00.0 Parcel 0 for cust 19 out for delivery
# [ 0] 18:00:00.0 Parcel 1 for cust 27 out for delivery
# [ 0] 18:00:00.0 Parcel 5 for cust 72 out for delivery
# [ 0] 18:00:00.0 Parcel 8 for cust 80 out for delivery
# [ 0] 18:00:00.0 Parcel 7 for cust 79 out for delivery
# [ 0] 18:00:00.0 Parcel 12 for cust 92 out for delivery
# [ 0] 18:10:50.0 Driver leaves for delivery of 13 parcels to 12 customers
# [ 0] 18:10:50.0 Length of delivery tour: 38,327m
# [ 0] 18:10:50.0 Driver drives to Customer 30 at (2380, 5128)
# [ 0] 18:17:35.1 Driver arrived at Customer 30 at (2380, 5128)
# [ 0] 18:17:35.9 Customer 30 at (2380, 5128) answers door
# [ 0] 18:17:35.9 Customer 30 at (2380, 5128) accepts Parcel 2 for cust 30
# [ 0] 18:17:36.3 Customer 30 at (2380, 5128) signs off
# [ 0] 18:17:47.7 Driver drives to Customer 54 at (4955, 6620)
# [ 0] 18:31:34.8 Driver arrived at Customer 54 at (4955, 6620)
# [ 0] 18:32:07.4 Customer 54 at (4955, 6620) answers door
# [ 0] 18:32:07.4 Customer 54 at (4955, 6620) accepts Parcel 4 for cust 54
# [ 0] 18:32:36.7 Customer 54 at (4955, 6620) signs off
# [ 0] 18:33:04.6 Driver drives to Customer 77 at (6047, 7680)
# [ 0] 18:41:41.1 Driver arrived at Customer 77 at (6047, 7680)
# [ 0] 18:42:41.1 Customer 77 at (6047, 7680) not at home
# [ 0] 18:42:41.1 Driver drives to Customer 84 at (6312, 7680)
# [ 0] 18:43:44.7 Driver arrived at Customer 84 at (6312, 7680)
# [ 0] 18:44:44.7 Customer 84 at (6312, 7680) to slow to answer the door
# [ 0] 18:44:44.7 Driver drives to Customer 89 at (6513, 7680)
# [ 0] 18:45:32.9 Driver arrived at Customer 89 at (6513, 7680)
# [ 0] 18:46:32.9 Customer 89 at (6513, 7680) not at home
# [ 0] 18:46:32.9 Driver drives to Customer 40 at (3440, 6776)
# [ 0] 19:03:42.3 Driver arrived at Customer 40 at (3440, 6776)
# [ 0] 19:03:44.0 Customer 40 at (3440, 6776) answers door
# [ 0] 19:03:44.0 Customer 40 at (3440, 6776) accepts Parcel 3 for cust 40
# [ 0] 19:03:57.8 Customer 40 at (3440, 6776) signs off
# [ 0] 19:04:09.9 Driver drives to Customer 19 at (2066, 7680)
# [ 0] 19:13:16.6 Driver arrived at Customer 19 at (2066, 7680)
# [ 0] 19:13:59.2 Customer 19 at (2066, 7680) answers door
# [ 0] 19:13:59.2 Customer 19 at (2066, 7680) accepts Parcel 0 for cust 19
# [ 0] 19:14:11.7 Customer 19 at (2066, 7680) signs off
# [ 0] 19:14:35.0 Driver drives to Customer 27 at (2380, 1401)
# [ 0] 19:44:26.4 Driver arrived at Customer 27 at (2380, 1401)
# [ 0] 19:45:07.2 Customer 27 at (2380, 1401) answers door
# [ 0] 19:45:07.2 Customer 27 at (2380, 1401) accepts Parcel 1 for cust 27
# [ 0] 19:45:11.9 Customer 27 at (2380, 1401) signs off
# [ 0] 19:45:19.6 Driver drives to Customer 72 at (5755, 1124)
# [ 0] 20:10:49.1 Driver arrived at Customer 72 at (5755, 1124)
# [ 0] 20:10:58.5 Customer 72 at (5755, 1124) answers door
# [ 0] 20:10:58.5 Customer 72 at (5755, 1124) accepts Parcel 5 for cust 72
# [ 0] 20:11:07.3 Customer 72 at (5755, 1124) signs off
# [ 0] 20:11:07.4 Driver drives to Customer 80 at (6128, 751)
# [ 0] 20:13:13.9 Driver arrived at Customer 80 at (6128, 751)
# [ 0] 20:14:13.9 Customer 80 at (6128, 751) not at home
# [ 0] 20:14:13.9 Driver drives to Customer 79 at (6105, 2925)
# [ 0] 20:24:45.8 Driver arrived at Customer 79 at (6105, 2925)
# [ 0] 20:24:52.3 Customer 79 at (6105, 2925) answers door
# [ 0] 20:24:52.3 Customer 79 at (6105, 2925) accepts Parcel 7 for cust 79
# [ 0] 20:24:56.4 Customer 79 at (6105, 2925) signs off
# [ 0] 20:25:12.0 Driver drives to Customer 92 at (7203, 3440)
# [ 0] 20:30:26.6 Driver arrived at Customer 92 at (7203, 3440)
# [ 0] 20:31:17.3 Customer 92 at (7203, 3440) answers door
# [ 0] 20:31:17.3 Customer 92 at (7203, 3440) accepts Parcel 12 for cust 92
# [ 0] 20:31:21.5 Customer 92 at (7203, 3440) signs off
# [ 0] 20:31:31.2 Driver returns to delivery centre
# [ 0] 20:54:19.2 Driver arrived at delivery centre
# [ 0] 20:54:19.2 Parcel 6 for cust 77 return from delivery
# [ 0] 20:54:49.2 Parcel 9 for cust 84 return from delivery
# [ 0] 20:55:19.2 Parcel 10 for cust 89 return from delivery
# [ 0] 20:55:49.2 Parcel 11 for cust 89 return from delivery
# [ 0] 20:56:19.2 Parcel 8 for cust 80 return from delivery
# [ 0] 20:56:49.2 7 parcels left for next day
# [ 0] 21:06:49.2 Driver goes home
# [ 1] 17:00:00.0 Parcel 15 for cust 11 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 16 for cust 32 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 17 for cust 34 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 18 for cust 35 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 19 for cust 76 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 20 for cust 79 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 21 for cust 90 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 22 for cust 97 arr at delivery centre
# [ 1] 18:00:00.0 Driver arrives for work
# [ 1] 18:00:00.0 Parcel 16 for cust 32 out for delivery
# [ 1] 18:00:00.0 Parcel 19 for cust 76 out for delivery
# [ 1] 18:00:00.0 Parcel 8 for cust 80 out for delivery
# [ 1] 18:00:00.0 Parcel 20 for cust 79 out for delivery
# [ 1] 18:00:00.0 Parcel 13 for cust 96 out for delivery
# [ 1] 18:00:00.0 Parcel 14 for cust 96 out for delivery
# [ 1] 18:00:00.0 Parcel 22 for cust 97 out for delivery
# [ 1] 18:00:00.0 Parcel 15 for cust 11 out for delivery
# [ 1] 18:00:00.0 Parcel 17 for cust 34 out for delivery
# [ 1] 18:00:00.0 Parcel 18 for cust 35 out for delivery
# [ 1] 18:00:00.0 Parcel 6 for cust 77 out for delivery
# [ 1] 18:00:00.0 Parcel 9 for cust 84 out for delivery
# [ 1] 18:00:00.0 Parcel 10 for cust 89 out for delivery
# [ 1] 18:00:00.0 Parcel 11 for cust 89 out for delivery
# [ 1] 18:11:40.0 Driver leaves for delivery of 14 parcels to 12 customers
# [ 1] 18:11:40.0 Length of delivery tour: 38,749m
# [ 1] 18:11:40.0 Driver drives to Customer 32 at (2738, 2738)
# [ 1] 18:19:52.5 Driver arrived at Customer 32 at (2738, 2738)
# [ 1] 18:19:54.1 Customer 32 at (2738, 2738) answers door
# [ 1] 18:19:54.1 Customer 32 at (2738, 2738) accepts Parcel 16 for cust 32
# [ 1] 18:19:54.3 Customer 32 at (2738, 2738) signs off
# [ 1] 18:20:12.9 Driver drives to Customer 76 at (5981, 897)
# [ 1] 18:41:02.5 Driver arrived at Customer 76 at (5981, 897)
# [ 1] 18:41:18.6 Customer 76 at (5981, 897) answers door
# [ 1] 18:41:18.6 Customer 76 at (5981, 897) accepts Parcel 19 for cust 76
# [ 1] 18:41:20.4 Customer 76 at (5981, 897) signs off
# [ 1] 18:41:22.0 Driver drives to Customer 80 at (6128, 751)
# [ 1] 18:42:11.6 Driver arrived at Customer 80 at (6128, 751)
# [ 1] 18:43:11.6 Customer 80 at (6128, 751) not at home
# [ 1] 18:43:11.6 Driver drives to Customer 79 at (6105, 2925)
# [ 1] 18:53:43.6 Driver arrived at Customer 79 at (6105, 2925)
# [ 1] 18:54:26.3 Customer 79 at (6105, 2925) answers door
# [ 1] 18:54:26.3 Customer 79 at (6105, 2925) accepts Parcel 20 for cust 79
# [ 1] 18:55:00.9 Customer 79 at (6105, 2925) signs off
# [ 1] 18:55:07.9 Driver drives to Customer 96 at (8352, 4112)
# [ 1] 19:06:05.0 Driver arrived at Customer 96 at (8352, 4112)
# [ 1] 19:07:05.0 Customer 96 at (8352, 4112) not at home
# [ 1] 19:07:05.0 Driver drives to Customer 97 at (8543, 4303)
# [ 1] 19:08:09.8 Driver arrived at Customer 97 at (8543, 4303)
# [ 1] 19:09:09.8 Customer 97 at (8543, 4303) to slow to answer the door
# [ 1] 19:09:09.8 Driver drives to Customer 11 at (1664, 7680)
# [ 1] 20:01:19.7 Driver arrived at Customer 11 at (1664, 7680)
# [ 1] 20:01:47.6 Customer 11 at (1664, 7680) answers door
# [ 1] 20:01:47.6 Customer 11 at (1664, 7680) accepts Parcel 15 for cust 11
# [ 1] 20:01:56.1 Customer 11 at (1664, 7680) signs off
# [ 1] 20:02:07.5 Driver drives to Customer 34 at (3097, 7680)
# [ 1] 20:07:51.4 Driver arrived at Customer 34 at (3097, 7680)
# [ 1] 20:08:51.4 Customer 34 at (3097, 7680) to slow to answer the door
# [ 1] 20:08:51.4 Driver drives to Customer 35 at (3194, 7680)
# [ 1] 20:09:14.7 Driver arrived at Customer 35 at (3194, 7680)
# [ 1] 20:10:11.4 Customer 35 at (3194, 7680) answers door
# [ 1] 20:10:11.4 Customer 35 at (3194, 7680) accepts Parcel 18 for cust 35
# [ 1] 20:10:58.0 Customer 35 at (3194, 7680) signs off
# [ 1] 20:11:11.7 Driver drives to Customer 77 at (6047, 7680)
# [ 1] 20:31:05.3 Driver arrived at Customer 77 at (6047, 7680)
# [ 1] 20:32:05.3 Customer 77 at (6047, 7680) to slow to answer the door
# [ 1] 20:32:05.3 Driver drives to Customer 84 at (6312, 7680)
# [ 1] 20:33:08.9 Driver arrived at Customer 84 at (6312, 7680)
# [ 1] 20:33:18.1 Customer 84 at (6312, 7680) answers door
# [ 1] 20:33:18.1 Customer 84 at (6312, 7680) accepts Parcel 9 for cust 84
# [ 1] 20:33:25.7 Customer 84 at (6312, 7680) signs off
# [ 1] 20:33:34.9 Driver drives to Customer 89 at (6513, 7680)
# [ 1] 20:34:23.1 Driver arrived at Customer 89 at (6513, 7680)
# [ 1] 20:35:23.1 Customer 89 at (6513, 7680) to slow to answer the door
# [ 1] 20:35:23.1 Driver returns to delivery centre
# [ 1] 20:57:54.8 Driver arrived at delivery centre
# [ 1] 20:57:54.8 Parcel 8 for cust 80 return from delivery
# [ 1] 20:58:24.8 Parcel 13 for cust 96 return from delivery
# [ 1] 20:58:54.8 Parcel 14 for cust 96 return from delivery
# [ 1] 20:59:24.8 Parcel 22 for cust 97 return from delivery
# [ 1] 20:59:54.8 Parcel 17 for cust 34 return from delivery
# [ 1] 21:00:24.8 Parcel 6 for cust 77 return from delivery
# [ 1] 21:00:54.8 Parcel 10 for cust 89 return from delivery
# [ 1] 21:01:24.8 Parcel 11 for cust 89 return from delivery
# [ 1] 21:01:54.8 9 parcels left for next day
# [ 1] 21:11:54.8 Driver goes home
# [ 2] 17:00:00.0 Parcel 23 for cust 5 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 24 for cust 9 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 25 for cust 15 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 26 for cust 25 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 27 for cust 38 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 28 for cust 50 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 29 for cust 62 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 30 for cust 77 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 31 for cust 78 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 32 for cust 90 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 33 for cust 93 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 34 for cust 94 arr at delivery centre
# [ 2] 18:00:00.0 Driver arrives for work
# [ 2] 18:00:00.0 Parcel 24 for cust 9 out for delivery
# [ 2] 18:00:00.0 Parcel 23 for cust 5 out for delivery
# [ 2] 18:00:00.0 Parcel 17 for cust 34 out for delivery
# [ 2] 18:00:00.0 Parcel 28 for cust 50 out for delivery
# [ 2] 18:00:00.0 Parcel 6 for cust 77 out for delivery
# [ 2] 18:00:00.0 Parcel 30 for cust 77 out for delivery
# [ 2] 18:00:00.0 Parcel 10 for cust 89 out for delivery
# [ 2] 18:00:00.0 Parcel 11 for cust 89 out for delivery
# [ 2] 18:00:00.0 Parcel 21 for cust 90 out for delivery
# [ 2] 18:00:00.0 Parcel 32 for cust 90 out for delivery
# [ 2] 18:00:00.0 Parcel 27 for cust 38 out for delivery
# [ 2] 18:00:00.0 Parcel 13 for cust 96 out for delivery
# [ 2] 18:00:00.0 Parcel 14 for cust 96 out for delivery
# [ 2] 18:00:00.0 Parcel 22 for cust 97 out for delivery
# [ 2] 18:00:00.0 Parcel 29 for cust 62 out for delivery
# [ 2] 18:00:00.0 Parcel 31 for cust 78 out for delivery
# [ 2] 18:00:00.0 Parcel 8 for cust 80 out for delivery
# [ 2] 18:14:10.0 Driver leaves for delivery of 17 parcels to 13 customers
# [ 2] 18:14:10.0 Length of delivery tour: 39,405m
# [ 2] 18:14:10.0 Driver drives to Customer 9 at (1650, 4500)
# [ 2] 18:21:19.6 Driver arrived at Customer 9 at (1650, 4500)
# [ 2] 18:22:19.6 Customer 9 at (1650, 4500) not at home
# [ 2] 18:22:19.6 Driver drives to Customer 5 at (1320, 5101)
# [ 2] 18:26:03.0 Driver arrived at Customer 5 at (1320, 5101)
# [ 2] 18:27:03.0 Customer 5 at (1320, 5101) to slow to answer the door
# [ 2] 18:27:03.0 Driver drives to Customer 34 at (3097, 7680)
# [ 2] 18:44:28.5 Driver arrived at Customer 34 at (3097, 7680)
# [ 2] 18:45:19.8 Customer 34 at (3097, 7680) answers door
# [ 2] 18:45:19.8 Customer 34 at (3097, 7680) accepts Parcel 17 for cust 34
# [ 2] 18:45:20.6 Customer 34 at (3097, 7680) signs off
# [ 2] 18:45:21.3 Driver drives to Customer 50 at (4500, 6283)
# [ 2] 18:56:33.3 Driver arrived at Customer 50 at (4500, 6283)
# [ 2] 18:56:51.1 Customer 50 at (4500, 6283) answers door
# [ 2] 18:56:51.1 Customer 50 at (4500, 6283) accepts Parcel 28 for cust 50
# [ 2] 18:56:51.4 Customer 50 at (4500, 6283) signs off
# [ 2] 18:56:55.7 Driver drives to Customer 77 at (6047, 7680)
# [ 2] 19:08:42.2 Driver arrived at Customer 77 at (6047, 7680)
# [ 2] 19:08:42.6 Customer 77 at (6047, 7680) answers door
# [ 2] 19:08:42.6 Customer 77 at (6047, 7680) accepts Parcel 6 for cust 77
# [ 2] 19:09:19.3 Customer 77 at (6047, 7680) accepts Parcel 30 for cust 77
# [ 2] 19:09:36.4 Customer 77 at (6047, 7680) signs off
# [ 2] 19:09:37.1 Driver drives to Customer 89 at (6513, 7680)
# [ 2] 19:11:28.9 Driver arrived at Customer 89 at (6513, 7680)
# [ 2] 19:12:28.9 Customer 89 at (6513, 7680) to slow to answer the door
# [ 2] 19:12:28.9 Driver drives to Customer 90 at (6542, 5560)
# [ 2] 19:28:42.1 Driver arrived at Customer 90 at (6542, 5560)
# [ 2] 19:29:42.1 Customer 90 at (6542, 5560) not at home
# [ 2] 19:29:42.1 Driver drives to Customer 38 at (3440, 4276)
# [ 2] 19:44:45.7 Driver arrived at Customer 38 at (3440, 4276)
# [ 2] 19:44:55.1 Customer 38 at (3440, 4276) answers door
# [ 2] 19:44:55.1 Customer 38 at (3440, 4276) accepts Parcel 27 for cust 38
# [ 2] 19:44:57.4 Customer 38 at (3440, 4276) signs off
# [ 2] 19:45:08.6 Driver drives to Customer 96 at (8352, 4112)
# [ 2] 20:12:45.5 Driver arrived at Customer 96 at (8352, 4112)
# [ 2] 20:13:45.5 Customer 96 at (8352, 4112) to slow to answer the door
# [ 2] 20:13:45.5 Driver drives to Customer 97 at (8543, 4303)
# [ 2] 20:14:50.3 Driver arrived at Customer 97 at (8543, 4303)
# [ 2] 20:14:55.6 Customer 97 at (8543, 4303) answers door
# [ 2] 20:14:55.6 Customer 97 at (8543, 4303) accepts Parcel 22 for cust 97
# [ 2] 20:14:55.6 Customer 97 at (8543, 4303) signs off
# [ 2] 20:15:00.3 Driver drives to Customer 62 at (5560, 1408)
# [ 2] 20:34:00.5 Driver arrived at Customer 62 at (5560, 1408)
# [ 2] 20:34:01.5 Customer 62 at (5560, 1408) answers door
# [ 2] 20:34:01.5 Customer 62 at (5560, 1408) accepts Parcel 29 for cust 62
# [ 2] 20:34:10.8 Customer 62 at (5560, 1408) signs off
# [ 2] 20:34:30.4 Driver drives to Customer 78 at (6082, 795)
# [ 2] 20:37:49.1 Driver arrived at Customer 78 at (6082, 795)
# [ 2] 20:37:57.4 Customer 78 at (6082, 795) answers door
# [ 2] 20:37:57.4 Customer 78 at (6082, 795) accepts Parcel 31 for cust 78
# [ 2] 20:37:58.6 Customer 78 at (6082, 795) signs off
# [ 2] 20:38:02.8 Driver drives to Customer 80 at (6128, 751)
# [ 2] 20:38:17.9 Driver arrived at Customer 80 at (6128, 751)
# [ 2] 20:39:17.9 Customer 80 at (6128, 751) to slow to answer the door
# [ 2] 20:39:17.9 Driver returns to delivery centre
# [ 2] 21:01:13.6 Driver arrived at delivery centre
# [ 2] 21:01:13.6 Parcel 24 for cust 9 return from delivery
# [ 2] 21:01:43.6 Parcel 23 for cust 5 return from delivery
# [ 2] 21:02:13.6 Parcel 10 for cust 89 return from delivery
# [ 2] 21:02:43.6 Parcel 11 for cust 89 return from delivery
# [ 2] 21:03:13.6 Parcel 21 for cust 90 return from delivery
# [ 2] 21:03:43.6 Parcel 32 for cust 90 return from delivery
# [ 2] 21:04:13.6 Parcel 13 for cust 96 return from delivery
# [ 2] 21:04:43.6 Parcel 14 for cust 96 return from delivery
# [ 2] 21:05:13.6 Parcel 8 for cust 80 return from delivery
# [ 2] 21:05:43.6 13 parcels left for next day
# [ 2] 21:15:43.6 Driver goes home
# [ 3] 17:00:00.0 Parcel 35 for cust 2 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 36 for cust 4 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 37 for cust 28 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 38 for cust 37 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 39 for cust 48 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 40 for cust 49 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 41 for cust 50 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 42 for cust 61 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 43 for cust 68 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 44 for cust 87 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 45 for cust 90 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 46 for cust 92 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 47 for cust 93 arr at delivery centre
# [ 3] 18:00:00.0 Driver arrives for work
# [ 3] 18:00:00.0 Parcel 46 for cust 92 out for delivery
# [ 3] 18:00:00.0 Parcel 33 for cust 93 out for delivery
# [ 3] 18:00:00.0 Parcel 47 for cust 93 out for delivery
# [ 3] 18:00:00.0 Parcel 34 for cust 94 out for delivery
# [ 3] 18:00:00.0 Parcel 24 for cust 9 out for delivery
# [ 3] 18:00:00.0 Parcel 36 for cust 4 out for delivery
# [ 3] 18:00:00.0 Parcel 35 for cust 2 out for delivery
# [ 3] 18:00:00.0 Parcel 23 for cust 5 out for delivery
# [ 3] 18:00:00.0 Parcel 25 for cust 15 out for delivery
# [ 3] 18:00:00.0 Parcel 26 for cust 25 out for delivery
# [ 3] 18:00:00.0 Parcel 39 for cust 48 out for delivery
# [ 3] 18:00:00.0 Parcel 44 for cust 87 out for delivery
# [ 3] 18:00:00.0 Parcel 10 for cust 89 out for delivery
# [ 3] 18:00:00.0 Parcel 11 for cust 89 out for delivery
# [ 3] 18:00:00.0 Parcel 43 for cust 68 out for delivery
# [ 3] 18:00:00.0 Parcel 21 for cust 90 out for delivery
# [ 3] 18:00:00.0 Parcel 32 for cust 90 out for delivery
# [ 3] 18:00:00.0 Parcel 45 for cust 90 out for delivery
# [ 3] 18:00:00.0 Parcel 40 for cust 49 out for delivery
# [ 3] 18:00:00.0 Parcel 41 for cust 50 out for delivery
# [ 3] 18:16:40.0 Driver leaves for delivery of 20 parcels to 16 customers
# [ 3] 18:16:40.0 Length of delivery tour: 39,709m
# [ 3] 18:16:40.0 Driver drives to Customer 92 at (7203, 3440)
# [ 3] 18:39:28.2 Driver arrived at Customer 92 at (7203, 3440)
# [ 3] 18:39:49.7 Customer 92 at (7203, 3440) answers door
# [ 3] 18:39:49.7 Customer 92 at (7203, 3440) accepts Parcel 46 for cust 92
# [ 3] 18:39:53.1 Customer 92 at (7203, 3440) signs off
# [ 3] 18:40:00.4 Driver drives to Customer 93 at (7680, 2699)
# [ 3] 18:44:52.8 Driver arrived at Customer 93 at (7680, 2699)
# [ 3] 18:45:52.8 Customer 93 at (7680, 2699) not at home
# [ 3] 18:45:52.8 Driver drives to Customer 94 at (8016, 2380)
# [ 3] 18:48:30.0 Driver arrived at Customer 94 at (8016, 2380)
# [ 3] 18:49:04.1 Customer 94 at (8016, 2380) answers door
# [ 3] 18:49:04.1 Customer 94 at (8016, 2380) accepts Parcel 34 for cust 94
# [ 3] 18:49:13.9 Customer 94 at (8016, 2380) signs off
# [ 3] 18:49:21.5 Driver drives to Customer 9 at (1650, 4500)
# [ 3] 19:26:48.9 Driver arrived at Customer 9 at (1650, 4500)
# [ 3] 19:27:10.0 Customer 9 at (1650, 4500) answers door
# [ 3] 19:27:10.0 Customer 9 at (1650, 4500) accepts Parcel 24 for cust 9
# [ 3] 19:27:20.1 Customer 9 at (1650, 4500) signs off
# [ 3] 19:27:25.3 Driver drives to Customer 4 at (1320, 4285)
# [ 3] 19:29:36.1 Driver arrived at Customer 4 at (1320, 4285)
# [ 3] 19:30:36.1 Customer 4 at (1320, 4285) to slow to answer the door
# [ 3] 19:30:36.1 Driver drives to Customer 2 at (1320, 4082)
# [ 3] 19:31:24.8 Driver arrived at Customer 2 at (1320, 4082)
# [ 3] 19:32:24.8 Customer 2 at (1320, 4082) to slow to answer the door
# [ 3] 19:32:24.8 Driver drives to Customer 5 at (1320, 5101)
# [ 3] 19:36:29.4 Driver arrived at Customer 5 at (1320, 5101)
# [ 3] 19:36:43.2 Customer 5 at (1320, 5101) answers door
# [ 3] 19:36:43.2 Customer 5 at (1320, 5101) accepts Parcel 23 for cust 5
# [ 3] 19:36:47.8 Customer 5 at (1320, 5101) signs off
# [ 3] 19:36:57.7 Driver drives to Customer 15 at (1896, 5560)
# [ 3] 19:41:06.1 Driver arrived at Customer 15 at (1896, 5560)
# [ 3] 19:41:13.0 Customer 15 at (1896, 5560) answers door
# [ 3] 19:41:13.0 Customer 15 at (1896, 5560) accepts Parcel 25 for cust 15
# [ 3] 19:41:24.9 Customer 15 at (1896, 5560) signs off
# [ 3] 19:41:29.7 Driver drives to Customer 25 at (2252, 7680)
# [ 3] 19:59:40.8 Driver arrived at Customer 25 at (2252, 7680)
# [ 3] 20:00:16.5 Customer 25 at (2252, 7680) answers door
# [ 3] 20:00:16.5 Customer 25 at (2252, 7680) accepts Parcel 26 for cust 25
# [ 3] 20:00:18.0 Customer 25 at (2252, 7680) signs off
# [ 3] 20:00:29.1 Driver drives to Customer 48 at (4280, 6620)
# [ 3] 20:12:50.2 Driver arrived at Customer 48 at (4280, 6620)
# [ 3] 20:13:07.7 Customer 48 at (4280, 6620) answers door
# [ 3] 20:13:07.7 Customer 48 at (4280, 6620) accepts Parcel 39 for cust 48
# [ 3] 20:13:14.1 Customer 48 at (4280, 6620) signs off
# [ 3] 20:13:19.4 Driver drives to Customer 87 at (6416, 7680)
# [ 3] 20:26:06.5 Driver arrived at Customer 87 at (6416, 7680)
# [ 3] 20:27:06.5 Customer 87 at (6416, 7680) not at home
# [ 3] 20:27:06.5 Driver drives to Customer 89 at (6513, 7680)
# [ 3] 20:27:29.8 Driver arrived at Customer 89 at (6513, 7680)
# [ 3] 20:27:55.7 Customer 89 at (6513, 7680) answers door
# [ 3] 20:27:55.7 Customer 89 at (6513, 7680) accepts Parcel 10 for cust 89
# [ 3] 20:28:07.5 Customer 89 at (6513, 7680) accepts Parcel 11 for cust 89
# [ 3] 20:28:11.4 Customer 89 at (6513, 7680) signs off
# [ 3] 20:28:21.9 Driver drives to Customer 68 at (5560, 6167)
# [ 3] 20:38:13.8 Driver arrived at Customer 68 at (5560, 6167)
# [ 3] 20:38:16.2 Customer 68 at (5560, 6167) answers door
# [ 3] 20:38:16.2 Customer 68 at (5560, 6167) accepts Parcel 43 for cust 68
# [ 3] 20:38:19.8 Customer 68 at (5560, 6167) signs off
# [ 3] 20:38:33.5 Driver drives to Customer 90 at (6542, 5560)
# [ 3] 20:44:54.8 Driver arrived at Customer 90 at (6542, 5560)
# [ 3] 20:44:57.0 Customer 90 at (6542, 5560) answers door
# [ 3] 20:44:57.0 Customer 90 at (6542, 5560) accepts Parcel 21 for cust 90
# [ 3] 20:45:06.7 Customer 90 at (6542, 5560) accepts Parcel 32 for cust 90
# [ 3] 20:45:07.0 Customer 90 at (6542, 5560) accepts Parcel 45 for cust 90
# [ 3] 20:45:13.3 Customer 90 at (6542, 5560) signs off
# [ 3] 20:45:35.3 Driver drives to Customer 49 at (4500, 6156)
# [ 3] 20:56:08.4 Driver arrived at Customer 49 at (4500, 6156)
# [ 3] 20:56:08.8 Customer 49 at (4500, 6156) answers door
# [ 3] 20:56:08.8 Customer 49 at (4500, 6156) accepts Parcel 40 for cust 49
# [ 3] 20:56:16.3 Customer 49 at (4500, 6156) signs off
# [ 3] 20:56:17.0 Driver drives to Customer 50 at (4500, 6283)
# [ 3] 20:56:47.5 Driver arrived at Customer 50 at (4500, 6283)
# [ 3] 20:57:47.5 Customer 50 at (4500, 6283) to slow to answer the door
# [ 3] 20:57:47.5 Driver returns to delivery centre
# [ 3] 21:06:40.7 Driver arrived at delivery centre
# [ 3] 21:06:40.7 Parcel 33 for cust 93 return from delivery
# [ 3] 21:07:10.7 Parcel 47 for cust 93 return from delivery
# [ 3] 21:07:40.7 Parcel 36 for cust 4 return from delivery
# [ 3] 21:08:10.7 Parcel 35 for cust 2 return from delivery
# [ 3] 21:08:40.7 Parcel 44 for cust 87 return from delivery
# [ 3] 21:09:10.7 Parcel 41 for cust 50 return from delivery
# [ 3] 21:09:40.7 12 parcels left for next day
# [ 3] 21:19:40.7 Driver goes home
# Delivery Centre Inventory: 12 parcels

# %%
rec1.histWorkingTime()
rec1.plotWorkingTime()

# %%
rec2 = simulation(M, W, C, p=0.3, days=4, log=True, plot=True)
# Out:
# Simulating delivery of 112 parcels over 4 days to 100 customers
# [ 0] 17:00:00.0 Parcel 0 for cust 15 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 1 for cust 24 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 2 for cust 25 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 3 for cust 30 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 4 for cust 38 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 5 for cust 54 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 6 for cust 56 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 7 for cust 57 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 8 for cust 59 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 9 for cust 59 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 10 for cust 60 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 11 for cust 62 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 12 for cust 65 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 13 for cust 65 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 14 for cust 66 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 15 for cust 68 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 16 for cust 70 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 17 for cust 71 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 18 for cust 74 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 19 for cust 76 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 20 for cust 82 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 21 for cust 89 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 22 for cust 89 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 23 for cust 94 arr at delivery centre
# [ 0] 18:00:00.0 Driver arrives for work
# [ 0] 18:00:00.0 Parcel 2 for cust 25 out for delivery
# [ 0] 18:00:00.0 Parcel 5 for cust 54 out for delivery
# [ 0] 18:00:00.0 Parcel 8 for cust 59 out for delivery
# [ 0] 18:00:00.0 Parcel 9 for cust 59 out for delivery
# [ 0] 18:00:00.0 Parcel 16 for cust 70 out for delivery
# [ 0] 18:00:00.0 Parcel 17 for cust 71 out for delivery
# [ 0] 18:00:00.0 Parcel 18 for cust 74 out for delivery
# [ 0] 18:00:00.0 Parcel 21 for cust 89 out for delivery
# [ 0] 18:00:00.0 Parcel 22 for cust 89 out for delivery
# [ 0] 18:00:00.0 Parcel 15 for cust 68 out for delivery
# [ 0] 18:00:00.0 Parcel 14 for cust 66 out for delivery
# [ 0] 18:00:00.0 Parcel 7 for cust 57 out for delivery
# [ 0] 18:00:00.0 Parcel 4 for cust 38 out for delivery
# [ 0] 18:00:00.0 Parcel 6 for cust 56 out for delivery
# [ 0] 18:00:00.0 Parcel 20 for cust 82 out for delivery
# [ 0] 18:00:00.0 Parcel 12 for cust 65 out for delivery
# [ 0] 18:00:00.0 Parcel 13 for cust 65 out for delivery
# [ 0] 18:00:00.0 Parcel 11 for cust 62 out for delivery
# [ 0] 18:00:00.0 Parcel 19 for cust 76 out for delivery
# [ 0] 18:00:00.0 Parcel 10 for cust 60 out for delivery
# [ 0] 18:00:00.0 Parcel 3 for cust 30 out for delivery
# [ 0] 18:00:00.0 Parcel 0 for cust 15 out for delivery
# [ 0] 18:00:00.0 Parcel 1 for cust 24 out for delivery
# [ 0] 18:19:10.0 Driver leaves for delivery of 23 parcels to 20 customers
# [ 0] 18:19:10.0 Length of delivery tour: 36,532m
# [ 0] 18:19:10.0 Driver drives to Customer 25 at (2252, 7680)
# [ 0] 18:42:38.1 Driver arrived at Customer 25 at (2252, 7680)
# [ 0] 18:43:38.1 Customer 25 at (2252, 7680) not at home
# [ 0] 18:43:38.1 Driver drives to Customer 54 at (4955, 6620)
# [ 0] 18:58:41.2 Driver arrived at Customer 54 at (4955, 6620)
# [ 0] 18:59:41.2 Customer 54 at (4955, 6620) not at home
# [ 0] 18:59:41.2 Driver drives to Customer 59 at (5249, 6620)
# [ 0] 19:00:51.8 Driver arrived at Customer 59 at (5249, 6620)
# [ 0] 19:01:21.0 Customer 59 at (5249, 6620) answers door
# [ 0] 19:01:21.0 Customer 59 at (5249, 6620) accepts Parcel 8 for cust 59
# [ 0] 19:01:27.0 Customer 59 at (5249, 6620) accepts Parcel 9 for cust 59
# [ 0] 19:01:33.7 Customer 59 at (5249, 6620) signs off
# [ 0] 19:01:42.5 Driver drives to Customer 70 at (5560, 7234)
# [ 0] 19:05:24.5 Driver arrived at Customer 70 at (5560, 7234)
# [ 0] 19:06:24.5 Customer 70 at (5560, 7234) not at home
# [ 0] 19:06:24.5 Driver drives to Customer 71 at (5722, 7680)
# [ 0] 19:08:50.4 Driver arrived at Customer 71 at (5722, 7680)
# [ 0] 19:09:35.9 Customer 71 at (5722, 7680) answers door
# [ 0] 19:09:35.9 Customer 71 at (5722, 7680) accepts Parcel 17 for cust 71
# [ 0] 19:09:41.4 Customer 71 at (5722, 7680) signs off
# [ 0] 19:09:46.0 Driver drives to Customer 74 at (5847, 7680)
# [ 0] 19:10:16.0 Driver arrived at Customer 74 at (5847, 7680)
# [ 0] 19:11:16.0 Customer 74 at (5847, 7680) to slow to answer the door
# [ 0] 19:11:16.0 Driver drives to Customer 89 at (6513, 7680)
# [ 0] 19:13:55.8 Driver arrived at Customer 89 at (6513, 7680)
# [ 0] 19:14:07.9 Customer 89 at (6513, 7680) answers door
# [ 0] 19:14:07.9 Customer 89 at (6513, 7680) accepts Parcel 21 for cust 89
# [ 0] 19:14:22.9 Customer 89 at (6513, 7680) accepts Parcel 22 for cust 89
# [ 0] 19:14:28.6 Customer 89 at (6513, 7680) signs off
# [ 0] 19:14:33.0 Driver drives to Customer 68 at (5560, 6167)
# [ 0] 19:24:24.9 Driver arrived at Customer 68 at (5560, 6167)
# [ 0] 19:24:27.5 Customer 68 at (5560, 6167) answers door
# [ 0] 19:24:27.5 Customer 68 at (5560, 6167) accepts Parcel 15 for cust 68
# [ 0] 19:24:47.4 Customer 68 at (5560, 6167) signs off
# [ 0] 19:24:59.5 Driver drives to Customer 66 at (5560, 5684)
# [ 0] 19:26:55.4 Driver arrived at Customer 66 at (5560, 5684)
# [ 0] 19:27:55.4 Customer 66 at (5560, 5684) to slow to answer the door
# [ 0] 19:27:55.4 Driver drives to Customer 57 at (5209, 5560)
# [ 0] 19:29:49.4 Driver arrived at Customer 57 at (5209, 5560)
# [ 0] 19:30:13.5 Customer 57 at (5209, 5560) answers door
# [ 0] 19:30:13.5 Customer 57 at (5209, 5560) accepts Parcel 7 for cust 57
# [ 0] 19:30:24.8 Customer 57 at (5209, 5560) signs off
# [ 0] 19:30:26.0 Driver drives to Customer 38 at (3440, 4276)
# [ 0] 19:40:09.7 Driver arrived at Customer 38 at (3440, 4276)
# [ 0] 19:40:30.0 Customer 38 at (3440, 4276) answers door
# [ 0] 19:40:30.0 Customer 38 at (3440, 4276) accepts Parcel 4 for cust 38
# [ 0] 19:40:32.3 Customer 38 at (3440, 4276) signs off
# [ 0] 19:40:32.8 Driver drives to Customer 56 at (5106, 2833)
# [ 0] 19:51:33.5 Driver arrived at Customer 56 at (5106, 2833)
# [ 0] 19:52:33.5 Customer 56 at (5106, 2833) to slow to answer the door
# [ 0] 19:52:33.5 Driver drives to Customer 82 at (6207, 3027)
# [ 0] 19:58:46.7 Driver arrived at Customer 82 at (6207, 3027)
# [ 0] 19:58:56.4 Customer 82 at (6207, 3027) answers door
# [ 0] 19:58:56.4 Customer 82 at (6207, 3027) accepts Parcel 20 for cust 82
# [ 0] 19:58:58.0 Customer 82 at (6207, 3027) signs off
# [ 0] 19:59:00.2 Driver drives to Customer 65 at (5560, 2199)
# [ 0] 20:03:23.0 Driver arrived at Customer 65 at (5560, 2199)
# [ 0] 20:03:42.0 Customer 65 at (5560, 2199) answers door
# [ 0] 20:03:42.0 Customer 65 at (5560, 2199) accepts Parcel 12 for cust 65
# [ 0] 20:03:49.9 Customer 65 at (5560, 2199) accepts Parcel 13 for cust 65
# [ 0] 20:03:51.5 Customer 65 at (5560, 2199) signs off
# [ 0] 20:04:36.4 Driver drives to Customer 62 at (5560, 1408)
# [ 0] 20:07:46.2 Driver arrived at Customer 62 at (5560, 1408)
# [ 0] 20:08:46.2 Customer 62 at (5560, 1408) to slow to answer the door
# [ 0] 20:08:46.2 Driver drives to Customer 76 at (5981, 897)
# [ 0] 20:11:30.4 Driver arrived at Customer 76 at (5981, 897)
# [ 0] 20:11:36.8 Customer 76 at (5981, 897) answers door
# [ 0] 20:11:36.8 Customer 76 at (5981, 897) accepts Parcel 19 for cust 76
# [ 0] 20:11:42.0 Customer 76 at (5981, 897) signs off
# [ 0] 20:11:53.4 Driver drives to Customer 60 at (5273, 1033)
# [ 0] 20:15:53.6 Driver arrived at Customer 60 at (5273, 1033)
# [ 0] 20:16:53.6 Customer 60 at (5273, 1033) to slow to answer the door
# [ 0] 20:16:53.6 Driver drives to Customer 30 at (2380, 5128)
# [ 0] 20:43:58.7 Driver arrived at Customer 30 at (2380, 5128)
# [ 0] 20:44:26.0 Customer 30 at (2380, 5128) answers door
# [ 0] 20:44:26.0 Customer 30 at (2380, 5128) accepts Parcel 3 for cust 30
# [ 0] 20:44:50.9 Customer 30 at (2380, 5128) signs off
# [ 0] 20:44:54.8 Driver drives to Customer 15 at (1896, 5560)
# [ 0] 20:48:34.7 Driver arrived at Customer 15 at (1896, 5560)
# [ 0] 20:49:02.3 Customer 15 at (1896, 5560) answers door
# [ 0] 20:49:02.3 Customer 15 at (1896, 5560) accepts Parcel 0 for cust 15
# [ 0] 20:49:09.2 Customer 15 at (1896, 5560) signs off
# [ 0] 20:49:20.3 Driver drives to Customer 24 at (2251, 4500)
# [ 0] 20:56:01.8 Driver arrived at Customer 24 at (2251, 4500)
# [ 0] 20:56:10.8 Customer 24 at (2251, 4500) answers door
# [ 0] 20:56:10.8 Customer 24 at (2251, 4500) accepts Parcel 1 for cust 24
# [ 0] 20:56:20.2 Customer 24 at (2251, 4500) signs off
# [ 0] 20:56:22.7 Driver returns to delivery centre
# [ 0] 21:01:08.0 Driver arrived at delivery centre
# [ 0] 21:01:08.0 Parcel 2 for cust 25 return from delivery
# [ 0] 21:01:38.0 Parcel 5 for cust 54 return from delivery
# [ 0] 21:02:08.0 Parcel 16 for cust 70 return from delivery
# [ 0] 21:02:38.0 Parcel 18 for cust 74 return from delivery
# [ 0] 21:03:08.0 Parcel 14 for cust 66 return from delivery
# [ 0] 21:03:38.0 Parcel 6 for cust 56 return from delivery
# [ 0] 21:04:08.0 Parcel 11 for cust 62 return from delivery
# [ 0] 21:04:38.0 Parcel 10 for cust 60 return from delivery
# [ 0] 21:05:08.0 9 parcels left for next day
# [ 0] 21:15:08.0 Driver goes home
# [ 1] 17:00:00.0 Parcel 24 for cust 2 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 25 for cust 3 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 26 for cust 4 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 27 for cust 12 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 28 for cust 19 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 29 for cust 21 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 30 for cust 28 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 31 for cust 34 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 32 for cust 35 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 33 for cust 36 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 34 for cust 36 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 35 for cust 46 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 36 for cust 57 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 37 for cust 58 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 38 for cust 64 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 39 for cust 66 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 40 for cust 66 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 41 for cust 68 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 42 for cust 77 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 43 for cust 78 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 44 for cust 79 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 45 for cust 83 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 46 for cust 83 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 47 for cust 84 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 48 for cust 88 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 49 for cust 90 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 50 for cust 92 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 51 for cust 93 arr at delivery centre
# [ 1] 18:00:00.0 Driver arrives for work
# [ 1] 18:00:00.0 Parcel 6 for cust 56 out for delivery
# [ 1] 18:00:00.0 Parcel 38 for cust 64 out for delivery
# [ 1] 18:00:00.0 Parcel 11 for cust 62 out for delivery
# [ 1] 18:00:00.0 Parcel 10 for cust 60 out for delivery
# [ 1] 18:00:00.0 Parcel 37 for cust 58 out for delivery
# [ 1] 18:00:00.0 Parcel 44 for cust 79 out for delivery
# [ 1] 18:00:00.0 Parcel 45 for cust 83 out for delivery
# [ 1] 18:00:00.0 Parcel 46 for cust 83 out for delivery
# [ 1] 18:00:00.0 Parcel 48 for cust 88 out for delivery
# [ 1] 18:00:00.0 Parcel 50 for cust 92 out for delivery
# [ 1] 18:00:00.0 Parcel 51 for cust 93 out for delivery
# [ 1] 18:00:00.0 Parcel 23 for cust 94 out for delivery
# [ 1] 18:00:00.0 Parcel 30 for cust 28 out for delivery
# [ 1] 18:00:00.0 Parcel 27 for cust 12 out for delivery
# [ 1] 18:00:00.0 Parcel 29 for cust 21 out for delivery
# [ 1] 18:00:00.0 Parcel 24 for cust 2 out for delivery
# [ 1] 18:00:00.0 Parcel 25 for cust 3 out for delivery
# [ 1] 18:00:00.0 Parcel 26 for cust 4 out for delivery
# [ 1] 18:00:00.0 Parcel 28 for cust 19 out for delivery
# [ 1] 18:00:00.0 Parcel 2 for cust 25 out for delivery
# [ 1] 18:00:00.0 Parcel 5 for cust 54 out for delivery
# [ 1] 18:00:00.0 Parcel 16 for cust 70 out for delivery
# [ 1] 18:00:00.0 Parcel 18 for cust 74 out for delivery
# [ 1] 18:00:00.0 Parcel 42 for cust 77 out for delivery
# [ 1] 18:00:00.0 Parcel 41 for cust 68 out for delivery
# [ 1] 18:00:00.0 Parcel 14 for cust 66 out for delivery
# [ 1] 18:00:00.0 Parcel 39 for cust 66 out for delivery
# [ 1] 18:00:00.0 Parcel 40 for cust 66 out for delivery
# [ 1] 18:00:00.0 Parcel 36 for cust 57 out for delivery
# [ 1] 18:24:10.0 Driver leaves for delivery of 29 parcels to 26 customers
# [ 1] 18:24:10.0 Length of delivery tour: 39,718m
# [ 1] 18:24:10.0 Driver drives to Customer 56 at (5106, 2833)
# [ 1] 18:36:04.5 Driver arrived at Customer 56 at (5106, 2833)
# [ 1] 18:37:04.5 Customer 56 at (5106, 2833) to slow to answer the door
# [ 1] 18:37:04.5 Driver drives to Customer 64 at (5560, 1912)
# [ 1] 18:41:30.6 Driver arrived at Customer 64 at (5560, 1912)
# [ 1] 18:41:59.9 Customer 64 at (5560, 1912) answers door
# [ 1] 18:41:59.9 Customer 64 at (5560, 1912) accepts Parcel 38 for cust 64
# [ 1] 18:42:15.3 Customer 64 at (5560, 1912) signs off
# [ 1] 18:42:17.4 Driver drives to Customer 62 at (5560, 1408)
# [ 1] 18:44:18.4 Driver arrived at Customer 62 at (5560, 1408)
# [ 1] 18:45:18.4 Customer 62 at (5560, 1408) to slow to answer the door
# [ 1] 18:45:18.4 Driver drives to Customer 60 at (5273, 1033)
# [ 1] 18:47:16.7 Driver arrived at Customer 60 at (5273, 1033)
# [ 1] 18:47:40.2 Customer 60 at (5273, 1033) answers door
# [ 1] 18:47:40.2 Customer 60 at (5273, 1033) accepts Parcel 10 for cust 60
# [ 1] 18:47:54.3 Customer 60 at (5273, 1033) signs off
# [ 1] 18:48:00.4 Driver drives to Customer 58 at (5217, 977)
# [ 1] 18:48:19.4 Driver arrived at Customer 58 at (5217, 977)
# [ 1] 18:49:19.4 Customer 58 at (5217, 977) not at home
# [ 1] 18:49:19.4 Driver drives to Customer 79 at (6105, 2925)
# [ 1] 18:58:34.7 Driver arrived at Customer 79 at (6105, 2925)
# [ 1] 18:59:34.7 Customer 79 at (6105, 2925) to slow to answer the door
# [ 1] 18:59:34.7 Driver drives to Customer 83 at (6267, 3087)
# [ 1] 19:00:29.7 Driver arrived at Customer 83 at (6267, 3087)
# [ 1] 19:00:32.8 Customer 83 at (6267, 3087) answers door
# [ 1] 19:00:32.8 Customer 83 at (6267, 3087) accepts Parcel 45 for cust 83
# [ 1] 19:00:33.3 Customer 83 at (6267, 3087) accepts Parcel 46 for cust 83
# [ 1] 19:01:00.5 Customer 83 at (6267, 3087) signs off
# [ 1] 19:01:07.2 Driver drives to Customer 88 at (6439, 3259)
# [ 1] 19:02:05.5 Driver arrived at Customer 88 at (6439, 3259)
# [ 1] 19:03:05.5 Customer 88 at (6439, 3259) not at home
# [ 1] 19:03:05.5 Driver drives to Customer 92 at (7203, 3440)
# [ 1] 19:06:26.6 Driver arrived at Customer 92 at (7203, 3440)
# [ 1] 19:07:26.6 Customer 92 at (7203, 3440) to slow to answer the door
# [ 1] 19:07:26.6 Driver drives to Customer 93 at (7680, 2699)
# [ 1] 19:12:18.9 Driver arrived at Customer 93 at (7680, 2699)
# [ 1] 19:13:18.9 Customer 93 at (7680, 2699) to slow to answer the door
# [ 1] 19:13:18.9 Driver drives to Customer 94 at (8016, 2380)
# [ 1] 19:15:56.1 Driver arrived at Customer 94 at (8016, 2380)
# [ 1] 19:16:40.1 Customer 94 at (8016, 2380) answers door
# [ 1] 19:16:40.1 Customer 94 at (8016, 2380) accepts Parcel 23 for cust 94
# [ 1] 19:16:48.5 Customer 94 at (8016, 2380) signs off
# [ 1] 19:16:51.0 Driver drives to Customer 28 at (2380, 1549)
# [ 1] 19:52:12.8 Driver arrived at Customer 28 at (2380, 1549)
# [ 1] 19:52:16.7 Customer 28 at (2380, 1549) answers door
# [ 1] 19:52:16.7 Customer 28 at (2380, 1549) accepts Parcel 30 for cust 28
# [ 1] 19:52:33.9 Customer 28 at (2380, 1549) signs off
# [ 1] 19:52:55.8 Driver drives to Customer 12 at (1791, 1320)
# [ 1] 19:56:12.1 Driver arrived at Customer 12 at (1791, 1320)
# [ 1] 19:57:12.1 Customer 12 at (1791, 1320) to slow to answer the door
# [ 1] 19:57:12.1 Driver drives to Customer 21 at (2100, 2659)
# [ 1] 20:05:22.7 Driver arrived at Customer 21 at (2100, 2659)
# [ 1] 20:06:22.7 Customer 21 at (2100, 2659) not at home
# [ 1] 20:06:22.7 Driver drives to Customer 2 at (1320, 4082)
# [ 1] 20:13:21.5 Driver arrived at Customer 2 at (1320, 4082)
# [ 1] 20:14:09.5 Customer 2 at (1320, 4082) answers door
# [ 1] 20:14:09.5 Customer 2 at (1320, 4082) accepts Parcel 24 for cust 2
# [ 1] 20:14:14.9 Customer 2 at (1320, 4082) signs off
# [ 1] 20:14:18.5 Driver drives to Customer 3 at (1320, 4193)
# [ 1] 20:14:45.2 Driver arrived at Customer 3 at (1320, 4193)
# [ 1] 20:14:50.0 Customer 3 at (1320, 4193) answers door
# [ 1] 20:14:50.0 Customer 3 at (1320, 4193) accepts Parcel 25 for cust 3
# [ 1] 20:14:55.6 Customer 3 at (1320, 4193) signs off
# [ 1] 20:15:03.9 Driver drives to Customer 4 at (1320, 4285)
# [ 1] 20:15:26.0 Driver arrived at Customer 4 at (1320, 4285)
# [ 1] 20:16:26.0 Customer 4 at (1320, 4285) not at home
# [ 1] 20:16:26.0 Driver drives to Customer 19 at (2066, 7680)
# [ 1] 20:32:59.8 Driver arrived at Customer 19 at (2066, 7680)
# [ 1] 20:33:59.8 Customer 19 at (2066, 7680) to slow to answer the door
# [ 1] 20:33:59.8 Driver drives to Customer 25 at (2252, 7680)
# [ 1] 20:34:44.5 Driver arrived at Customer 25 at (2252, 7680)
# [ 1] 20:35:44.5 Customer 25 at (2252, 7680) to slow to answer the door
# [ 1] 20:35:44.5 Driver drives to Customer 54 at (4955, 6620)
# [ 1] 20:50:47.6 Driver arrived at Customer 54 at (4955, 6620)
# [ 1] 20:51:09.1 Customer 54 at (4955, 6620) answers door
# [ 1] 20:51:09.1 Customer 54 at (4955, 6620) accepts Parcel 5 for cust 54
# [ 1] 20:51:10.1 Customer 54 at (4955, 6620) signs off
# [ 1] 20:51:25.0 Driver drives to Customer 70 at (5560, 7234)
# [ 1] 20:56:17.5 Driver arrived at Customer 70 at (5560, 7234)
# [ 1] 20:57:10.6 Customer 70 at (5560, 7234) answers door
# [ 1] 20:57:10.6 Customer 70 at (5560, 7234) accepts Parcel 16 for cust 70
# [ 1] 20:57:10.9 Customer 70 at (5560, 7234) signs off
# [ 1] 20:57:16.8 Driver drives to Customer 74 at (5847, 7680)
# [ 1] 21:00:12.7 Driver arrived at Customer 74 at (5847, 7680)
# [ 1] 21:00:59.1 Customer 74 at (5847, 7680) answers door
# [ 1] 21:00:59.1 Customer 74 at (5847, 7680) accepts Parcel 18 for cust 74
# [ 1] 21:00:59.4 Customer 74 at (5847, 7680) signs off
# [ 1] 21:01:24.6 Driver drives to Customer 77 at (6047, 7680)
# [ 1] 21:02:12.6 Driver arrived at Customer 77 at (6047, 7680)
# [ 1] 21:03:12.6 Customer 77 at (6047, 7680) to slow to answer the door
# [ 1] 21:03:12.6 Driver drives to Customer 68 at (5560, 6167)
# [ 1] 21:11:12.6 Driver arrived at Customer 68 at (5560, 6167)
# [ 1] 21:12:03.8 Customer 68 at (5560, 6167) answers door
# [ 1] 21:12:03.8 Customer 68 at (5560, 6167) accepts Parcel 41 for cust 68
# [ 1] 21:12:04.7 Customer 68 at (5560, 6167) signs off
# [ 1] 21:12:05.4 Driver drives to Customer 66 at (5560, 5684)
# [ 1] 21:14:01.3 Driver arrived at Customer 66 at (5560, 5684)
# [ 1] 21:14:19.1 Customer 66 at (5560, 5684) answers door
# [ 1] 21:14:19.1 Customer 66 at (5560, 5684) accepts Parcel 14 for cust 66
# [ 1] 21:14:19.4 Customer 66 at (5560, 5684) accepts Parcel 39 for cust 66
# [ 1] 21:14:23.7 Customer 66 at (5560, 5684) accepts Parcel 40 for cust 66
# [ 1] 21:14:23.8 Customer 66 at (5560, 5684) signs off
# [ 1] 21:15:00.4 Driver drives to Customer 57 at (5209, 5560)
# [ 1] 21:16:54.4 Driver arrived at Customer 57 at (5209, 5560)
# [ 1] 21:17:54.4 Customer 57 at (5209, 5560) to slow to answer the door
# [ 1] 21:17:54.4 Driver returns to delivery centre
# [ 1] 21:26:44.3 Driver arrived at delivery centre
# [ 1] 21:26:44.3 Parcel 6 for cust 56 return from delivery
# [ 1] 21:27:14.3 Parcel 11 for cust 62 return from delivery
# [ 1] 21:27:44.3 Parcel 37 for cust 58 return from delivery
# [ 1] 21:28:14.3 Parcel 44 for cust 79 return from delivery
# [ 1] 21:28:44.3 Parcel 48 for cust 88 return from delivery
# [ 1] 21:29:14.3 Parcel 50 for cust 92 return from delivery
# [ 1] 21:29:44.3 Parcel 51 for cust 93 return from delivery
# [ 1] 21:30:14.3 Parcel 27 for cust 12 return from delivery
# [ 1] 21:30:44.3 Parcel 29 for cust 21 return from delivery
# [ 1] 21:31:14.3 Parcel 26 for cust 4 return from delivery
# [ 1] 21:31:44.3 Parcel 28 for cust 19 return from delivery
# [ 1] 21:32:14.3 Parcel 2 for cust 25 return from delivery
# [ 1] 21:32:44.3 Parcel 42 for cust 77 return from delivery
# [ 1] 21:33:14.3 Parcel 36 for cust 57 return from delivery
# [ 1] 21:33:44.3 22 parcels left for next day
# [ 1] 21:43:44.3 Driver goes home
# [ 2] 17:00:00.0 Parcel 52 for cust 2 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 53 for cust 6 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 54 for cust 15 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 55 for cust 18 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 56 for cust 20 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 57 for cust 20 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 58 for cust 24 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 59 for cust 28 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 60 for cust 31 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 61 for cust 32 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 62 for cust 36 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 63 for cust 44 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 64 for cust 49 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 65 for cust 50 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 66 for cust 60 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 67 for cust 61 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 68 for cust 63 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 69 for cust 68 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 70 for cust 70 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 71 for cust 71 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 72 for cust 77 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 73 for cust 78 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 74 for cust 80 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 75 for cust 83 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 76 for cust 84 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 77 for cust 89 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 78 for cust 89 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 79 for cust 91 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 80 for cust 94 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 81 for cust 95 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 82 for cust 98 arr at delivery centre
# [ 2] 18:00:00.0 Driver arrives for work
# [ 2] 18:00:00.0 Parcel 63 for cust 44 out for delivery
# [ 2] 18:00:00.0 Parcel 36 for cust 57 out for delivery
# [ 2] 18:00:00.0 Parcel 49 for cust 90 out for delivery
# [ 2] 18:00:00.0 Parcel 69 for cust 68 out for delivery
# [ 2] 18:00:00.0 Parcel 70 for cust 70 out for delivery
# [ 2] 18:00:00.0 Parcel 71 for cust 71 out for delivery
# [ 2] 18:00:00.0 Parcel 42 for cust 77 out for delivery
# [ 2] 18:00:00.0 Parcel 72 for cust 77 out for delivery
# [ 2] 18:00:00.0 Parcel 47 for cust 84 out for delivery
# [ 2] 18:00:00.0 Parcel 76 for cust 84 out for delivery
# [ 2] 18:00:00.0 Parcel 77 for cust 89 out for delivery
# [ 2] 18:00:00.0 Parcel 78 for cust 89 out for delivery
# [ 2] 18:00:00.0 Parcel 35 for cust 46 out for delivery
# [ 2] 18:00:00.0 Parcel 33 for cust 36 out for delivery
# [ 2] 18:00:00.0 Parcel 34 for cust 36 out for delivery
# [ 2] 18:00:00.0 Parcel 62 for cust 36 out for delivery
# [ 2] 18:00:00.0 Parcel 32 for cust 35 out for delivery
# [ 2] 18:00:00.0 Parcel 31 for cust 34 out for delivery
# [ 2] 18:00:00.0 Parcel 54 for cust 15 out for delivery
# [ 2] 18:00:00.0 Parcel 26 for cust 4 out for delivery
# [ 2] 18:00:00.0 Parcel 29 for cust 21 out for delivery
# [ 2] 18:00:00.0 Parcel 61 for cust 32 out for delivery
# [ 2] 18:00:00.0 Parcel 6 for cust 56 out for delivery
# [ 2] 18:00:00.0 Parcel 68 for cust 63 out for delivery
# [ 2] 18:00:00.0 Parcel 11 for cust 62 out for delivery
# [ 2] 18:00:00.0 Parcel 43 for cust 78 out for delivery
# [ 2] 18:00:00.0 Parcel 73 for cust 78 out for delivery
# [ 2] 18:00:00.0 Parcel 74 for cust 80 out for delivery
# [ 2] 18:00:00.0 Parcel 67 for cust 61 out for delivery
# [ 2] 18:00:00.0 Parcel 66 for cust 60 out for delivery
# [ 2] 18:00:00.0 Parcel 37 for cust 58 out for delivery
# [ 2] 18:00:00.0 Parcel 44 for cust 79 out for delivery
# [ 2] 18:00:00.0 Parcel 75 for cust 83 out for delivery
# [ 2] 18:00:00.0 Parcel 48 for cust 88 out for delivery
# [ 2] 18:00:00.0 Parcel 50 for cust 92 out for delivery
# [ 2] 18:00:00.0 Parcel 51 for cust 93 out for delivery
# [ 2] 18:30:00.0 Driver leaves for delivery of 36 parcels to 30 customers
# [ 2] 18:30:00.0 Length of delivery tour: 39,675m
# [ 2] 18:30:00.0 Driver drives to Customer 44 at (3855, 4915)
# [ 2] 18:32:20.6 Driver arrived at Customer 44 at (3855, 4915)
# [ 2] 18:32:55.5 Customer 44 at (3855, 4915) answers door
# [ 2] 18:32:55.5 Customer 44 at (3855, 4915) accepts Parcel 63 for cust 44
# [ 2] 18:33:00.5 Customer 44 at (3855, 4915) signs off
# [ 2] 18:33:01.6 Driver drives to Customer 57 at (5209, 5560)
# [ 2] 18:39:30.7 Driver arrived at Customer 57 at (5209, 5560)
# [ 2] 18:39:42.3 Customer 57 at (5209, 5560) answers door
# [ 2] 18:39:42.3 Customer 57 at (5209, 5560) accepts Parcel 36 for cust 57
# [ 2] 18:39:45.6 Customer 57 at (5209, 5560) signs off
# [ 2] 18:39:59.7 Driver drives to Customer 90 at (6542, 5560)
# [ 2] 18:45:19.6 Driver arrived at Customer 90 at (6542, 5560)
# [ 2] 18:46:19.6 Customer 90 at (6542, 5560) to slow to answer the door
# [ 2] 18:46:19.6 Driver drives to Customer 68 at (5560, 6167)
# [ 2] 18:52:41.0 Driver arrived at Customer 68 at (5560, 6167)
# [ 2] 18:53:17.2 Customer 68 at (5560, 6167) answers door
# [ 2] 18:53:17.2 Customer 68 at (5560, 6167) accepts Parcel 69 for cust 68
# [ 2] 18:53:17.5 Customer 68 at (5560, 6167) signs off
# [ 2] 18:53:33.3 Driver drives to Customer 70 at (5560, 7234)
# [ 2] 18:57:49.3 Driver arrived at Customer 70 at (5560, 7234)
# [ 2] 18:58:03.9 Customer 70 at (5560, 7234) answers door
# [ 2] 18:58:03.9 Customer 70 at (5560, 7234) accepts Parcel 70 for cust 70
# [ 2] 18:58:08.1 Customer 70 at (5560, 7234) signs off
# [ 2] 18:58:15.6 Driver drives to Customer 71 at (5722, 7680)
# [ 2] 19:00:41.6 Driver arrived at Customer 71 at (5722, 7680)
# [ 2] 19:00:53.0 Customer 71 at (5722, 7680) answers door
# [ 2] 19:00:53.0 Customer 71 at (5722, 7680) accepts Parcel 71 for cust 71
# [ 2] 19:01:18.3 Customer 71 at (5722, 7680) signs off
# [ 2] 19:01:20.1 Driver drives to Customer 77 at (6047, 7680)
# [ 2] 19:02:38.1 Driver arrived at Customer 77 at (6047, 7680)
# [ 2] 19:02:59.5 Customer 77 at (6047, 7680) answers door
# [ 2] 19:02:59.5 Customer 77 at (6047, 7680) accepts Parcel 42 for cust 77
# [ 2] 19:03:02.9 Customer 77 at (6047, 7680) accepts Parcel 72 for cust 77
# [ 2] 19:03:10.2 Customer 77 at (6047, 7680) signs off
# [ 2] 19:03:18.8 Driver drives to Customer 84 at (6312, 7680)
# [ 2] 19:04:22.4 Driver arrived at Customer 84 at (6312, 7680)
# [ 2] 19:05:01.8 Customer 84 at (6312, 7680) answers door
# [ 2] 19:05:01.8 Customer 84 at (6312, 7680) accepts Parcel 47 for cust 84
# [ 2] 19:05:09.4 Customer 84 at (6312, 7680) accepts Parcel 76 for cust 84
# [ 2] 19:05:14.7 Customer 84 at (6312, 7680) signs off
# [ 2] 19:05:24.8 Driver drives to Customer 89 at (6513, 7680)
# [ 2] 19:06:13.0 Driver arrived at Customer 89 at (6513, 7680)
# [ 2] 19:06:33.7 Customer 89 at (6513, 7680) answers door
# [ 2] 19:06:33.7 Customer 89 at (6513, 7680) accepts Parcel 77 for cust 89
# [ 2] 19:06:48.8 Customer 89 at (6513, 7680) accepts Parcel 78 for cust 89
# [ 2] 19:07:04.3 Customer 89 at (6513, 7680) signs off
# [ 2] 19:07:07.7 Driver drives to Customer 46 at (3984, 6620)
# [ 2] 19:21:29.1 Driver arrived at Customer 46 at (3984, 6620)
# [ 2] 19:21:47.7 Customer 46 at (3984, 6620) answers door
# [ 2] 19:21:47.7 Customer 46 at (3984, 6620) accepts Parcel 35 for cust 46
# [ 2] 19:21:57.6 Customer 46 at (3984, 6620) signs off
# [ 2] 19:21:59.3 Driver drives to Customer 36 at (3313, 7680)
# [ 2] 19:28:54.7 Driver arrived at Customer 36 at (3313, 7680)
# [ 2] 19:29:42.5 Customer 36 at (3313, 7680) answers door
# [ 2] 19:29:42.5 Customer 36 at (3313, 7680) accepts Parcel 33 for cust 36
# [ 2] 19:29:47.3 Customer 36 at (3313, 7680) accepts Parcel 34 for cust 36
# [ 2] 19:29:56.3 Customer 36 at (3313, 7680) accepts Parcel 62 for cust 36
# [ 2] 19:29:57.8 Customer 36 at (3313, 7680) signs off
# [ 2] 19:30:08.8 Driver drives to Customer 35 at (3194, 7680)
# [ 2] 19:30:37.4 Driver arrived at Customer 35 at (3194, 7680)
# [ 2] 19:30:54.8 Customer 35 at (3194, 7680) answers door
# [ 2] 19:30:54.8 Customer 35 at (3194, 7680) accepts Parcel 32 for cust 35
# [ 2] 19:31:01.2 Customer 35 at (3194, 7680) signs off
# [ 2] 19:31:06.6 Driver drives to Customer 34 at (3097, 7680)
# [ 2] 19:31:29.9 Driver arrived at Customer 34 at (3097, 7680)
# [ 2] 19:31:55.8 Customer 34 at (3097, 7680) answers door
# [ 2] 19:31:55.8 Customer 34 at (3097, 7680) accepts Parcel 31 for cust 34
# [ 2] 19:32:07.6 Customer 34 at (3097, 7680) signs off
# [ 2] 19:32:11.5 Driver drives to Customer 15 at (1896, 5560)
# [ 2] 19:45:44.1 Driver arrived at Customer 15 at (1896, 5560)
# [ 2] 19:46:26.3 Customer 15 at (1896, 5560) answers door
# [ 2] 19:46:26.3 Customer 15 at (1896, 5560) accepts Parcel 54 for cust 15
# [ 2] 19:46:27.0 Customer 15 at (1896, 5560) signs off
# [ 2] 19:46:30.5 Driver drives to Customer 4 at (1320, 4285)
# [ 2] 19:53:54.8 Driver arrived at Customer 4 at (1320, 4285)
# [ 2] 19:54:49.5 Customer 4 at (1320, 4285) answers door
# [ 2] 19:54:49.5 Customer 4 at (1320, 4285) accepts Parcel 26 for cust 4
# [ 2] 19:54:50.0 Customer 4 at (1320, 4285) signs off
# [ 2] 19:54:59.7 Driver drives to Customer 21 at (2100, 2659)
# [ 2] 20:02:47.2 Driver arrived at Customer 21 at (2100, 2659)
# [ 2] 20:02:48.3 Customer 21 at (2100, 2659) answers door
# [ 2] 20:02:48.3 Customer 21 at (2100, 2659) accepts Parcel 29 for cust 21
# [ 2] 20:02:54.6 Customer 21 at (2100, 2659) signs off
# [ 2] 20:03:16.6 Driver drives to Customer 32 at (2738, 2738)
# [ 2] 20:06:52.8 Driver arrived at Customer 32 at (2738, 2738)
# [ 2] 20:06:53.2 Customer 32 at (2738, 2738) answers door
# [ 2] 20:06:53.2 Customer 32 at (2738, 2738) accepts Parcel 61 for cust 32
# [ 2] 20:07:00.7 Customer 32 at (2738, 2738) signs off
# [ 2] 20:07:01.4 Driver drives to Customer 56 at (5106, 2833)
# [ 2] 20:18:39.6 Driver arrived at Customer 56 at (5106, 2833)
# [ 2] 20:19:39.6 Customer 56 at (5106, 2833) not at home
# [ 2] 20:19:39.6 Driver drives to Customer 63 at (5560, 1564)
# [ 2] 20:25:29.2 Driver arrived at Customer 63 at (5560, 1564)
# [ 2] 20:26:29.2 Customer 63 at (5560, 1564) to slow to answer the door
# [ 2] 20:26:29.2 Driver drives to Customer 62 at (5560, 1408)
# [ 2] 20:27:06.7 Driver arrived at Customer 62 at (5560, 1408)
# [ 2] 20:27:53.1 Customer 62 at (5560, 1408) answers door
# [ 2] 20:27:53.1 Customer 62 at (5560, 1408) accepts Parcel 11 for cust 62
# [ 2] 20:28:06.6 Customer 62 at (5560, 1408) signs off
# [ 2] 20:28:17.7 Driver drives to Customer 78 at (6082, 795)
# [ 2] 20:31:36.4 Driver arrived at Customer 78 at (6082, 795)
# [ 2] 20:31:36.6 Customer 78 at (6082, 795) answers door
# [ 2] 20:31:36.6 Customer 78 at (6082, 795) accepts Parcel 43 for cust 78
# [ 2] 20:31:37.1 Customer 78 at (6082, 795) accepts Parcel 73 for cust 78
# [ 2] 20:31:46.8 Customer 78 at (6082, 795) signs off
# [ 2] 20:33:07.4 Driver drives to Customer 80 at (6128, 751)
# [ 2] 20:33:22.5 Driver arrived at Customer 80 at (6128, 751)
# [ 2] 20:34:22.5 Customer 80 at (6128, 751) to slow to answer the door
# [ 2] 20:34:22.5 Driver drives to Customer 61 at (5363, 1123)
# [ 2] 20:38:41.9 Driver arrived at Customer 61 at (5363, 1123)
# [ 2] 20:39:30.1 Customer 61 at (5363, 1123) answers door
# [ 2] 20:39:30.1 Customer 61 at (5363, 1123) accepts Parcel 67 for cust 61
# [ 2] 20:39:43.1 Customer 61 at (5363, 1123) signs off
# [ 2] 20:39:45.6 Driver drives to Customer 60 at (5273, 1033)
# [ 2] 20:40:16.1 Driver arrived at Customer 60 at (5273, 1033)
# [ 2] 20:41:11.8 Customer 60 at (5273, 1033) answers door
# [ 2] 20:41:11.8 Customer 60 at (5273, 1033) accepts Parcel 66 for cust 60
# [ 2] 20:41:15.2 Customer 60 at (5273, 1033) signs off
# [ 2] 20:41:16.3 Driver drives to Customer 58 at (5217, 977)
# [ 2] 20:41:35.3 Driver arrived at Customer 58 at (5217, 977)
# [ 2] 20:42:00.0 Customer 58 at (5217, 977) answers door
# [ 2] 20:42:00.0 Customer 58 at (5217, 977) accepts Parcel 37 for cust 58
# [ 2] 20:42:04.0 Customer 58 at (5217, 977) signs off
# [ 2] 20:42:05.8 Driver drives to Customer 79 at (6105, 2925)
# [ 2] 20:51:21.2 Driver arrived at Customer 79 at (6105, 2925)
# [ 2] 20:51:43.1 Customer 79 at (6105, 2925) answers door
# [ 2] 20:51:43.1 Customer 79 at (6105, 2925) accepts Parcel 44 for cust 79
# [ 2] 20:52:05.9 Customer 79 at (6105, 2925) signs off
# [ 2] 20:52:11.6 Driver drives to Customer 83 at (6267, 3087)
# [ 2] 20:53:06.5 Driver arrived at Customer 83 at (6267, 3087)
# [ 2] 20:53:30.3 Customer 83 at (6267, 3087) answers door
# [ 2] 20:53:30.3 Customer 83 at (6267, 3087) accepts Parcel 75 for cust 83
# [ 2] 20:53:42.6 Customer 83 at (6267, 3087) signs off
# [ 2] 20:53:50.0 Driver drives to Customer 88 at (6439, 3259)
# [ 2] 20:54:48.3 Driver arrived at Customer 88 at (6439, 3259)
# [ 2] 20:54:53.9 Customer 88 at (6439, 3259) answers door
# [ 2] 20:54:53.9 Customer 88 at (6439, 3259) accepts Parcel 48 for cust 88
# [ 2] 20:55:18.0 Customer 88 at (6439, 3259) signs off
# [ 2] 20:55:23.9 Driver drives to Customer 92 at (7203, 3440)
# [ 2] 20:58:45.0 Driver arrived at Customer 92 at (7203, 3440)
# [ 2] 20:59:45.0 Customer 92 at (7203, 3440) to slow to answer the door
# [ 2] 20:59:45.0 Driver drives to Customer 93 at (7680, 2699)
# [ 2] 21:04:37.3 Driver arrived at Customer 93 at (7680, 2699)
# [ 2] 21:04:57.0 Customer 93 at (7680, 2699) answers door
# [ 2] 21:04:57.0 Customer 93 at (7680, 2699) accepts Parcel 51 for cust 93
# [ 2] 21:05:13.5 Customer 93 at (7680, 2699) signs off
# [ 2] 21:05:18.4 Driver returns to delivery centre
# [ 2] 21:32:58.2 Driver arrived at delivery centre
# [ 2] 21:32:58.2 Parcel 49 for cust 90 return from delivery
# [ 2] 21:33:28.2 Parcel 6 for cust 56 return from delivery
# [ 2] 21:33:58.2 Parcel 68 for cust 63 return from delivery
# [ 2] 21:34:28.2 Parcel 74 for cust 80 return from delivery
# [ 2] 21:34:58.2 Parcel 50 for cust 92 return from delivery
# [ 2] 21:35:28.2 22 parcels left for next day
# [ 2] 21:45:28.2 Driver goes home
# [ 3] 17:00:00.0 Parcel 83 for cust 4 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 84 for cust 6 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 85 for cust 7 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 86 for cust 14 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 87 for cust 22 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 88 for cust 22 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 89 for cust 25 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 90 for cust 28 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 91 for cust 30 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 92 for cust 33 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 93 for cust 37 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 94 for cust 51 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 95 for cust 54 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 96 for cust 55 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 97 for cust 62 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 98 for cust 68 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 99 for cust 69 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 100 for cust 70 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 101 for cust 70 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 102 for cust 76 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 103 for cust 80 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 104 for cust 82 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 105 for cust 82 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 106 for cust 83 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 107 for cust 86 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 108 for cust 88 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 109 for cust 94 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 110 for cust 94 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 111 for cust 98 arr at delivery centre
# [ 3] 18:00:00.0 Driver arrives for work
# [ 3] 18:00:00.0 Parcel 93 for cust 37 out for delivery
# [ 3] 18:00:00.0 Parcel 6 for cust 56 out for delivery
# [ 3] 18:00:00.0 Parcel 59 for cust 28 out for delivery
# [ 3] 18:00:00.0 Parcel 90 for cust 28 out for delivery
# [ 3] 18:00:00.0 Parcel 56 for cust 20 out for delivery
# [ 3] 18:00:00.0 Parcel 57 for cust 20 out for delivery
# [ 3] 18:00:00.0 Parcel 86 for cust 14 out for delivery
# [ 3] 18:00:00.0 Parcel 27 for cust 12 out for delivery
# [ 3] 18:00:00.0 Parcel 53 for cust 6 out for delivery
# [ 3] 18:00:00.0 Parcel 84 for cust 6 out for delivery
# [ 3] 18:00:00.0 Parcel 52 for cust 2 out for delivery
# [ 3] 18:00:00.0 Parcel 83 for cust 4 out for delivery
# [ 3] 18:00:00.0 Parcel 85 for cust 7 out for delivery
# [ 3] 18:00:00.0 Parcel 28 for cust 19 out for delivery
# [ 3] 18:00:00.0 Parcel 2 for cust 25 out for delivery
# [ 3] 18:00:00.0 Parcel 89 for cust 25 out for delivery
# [ 3] 18:00:00.0 Parcel 95 for cust 54 out for delivery
# [ 3] 18:00:00.0 Parcel 100 for cust 70 out for delivery
# [ 3] 18:00:00.0 Parcel 101 for cust 70 out for delivery
# [ 3] 18:00:00.0 Parcel 79 for cust 91 out for delivery
# [ 3] 18:00:00.0 Parcel 99 for cust 69 out for delivery
# [ 3] 18:00:00.0 Parcel 98 for cust 68 out for delivery
# [ 3] 18:00:00.0 Parcel 107 for cust 86 out for delivery
# [ 3] 18:00:00.0 Parcel 49 for cust 90 out for delivery
# [ 3] 18:00:00.0 Parcel 94 for cust 51 out for delivery
# [ 3] 18:00:00.0 Parcel 65 for cust 50 out for delivery
# [ 3] 18:00:00.0 Parcel 64 for cust 49 out for delivery
# [ 3] 18:00:00.0 Parcel 92 for cust 33 out for delivery
# [ 3] 18:00:00.0 Parcel 60 for cust 31 out for delivery
# [ 3] 18:00:00.0 Parcel 91 for cust 30 out for delivery
# [ 3] 18:00:00.0 Parcel 58 for cust 24 out for delivery
# [ 3] 18:00:00.0 Parcel 87 for cust 22 out for delivery
# [ 3] 18:00:00.0 Parcel 88 for cust 22 out for delivery
# [ 3] 18:00:00.0 Parcel 55 for cust 18 out for delivery
# [ 3] 18:28:20.0 Driver leaves for delivery of 34 parcels to 28 customers
# [ 3] 18:28:20.0 Length of delivery tour: 38,053m
# [ 3] 18:28:20.0 Driver drives to Customer 37 at (3440, 4175)
# [ 3] 18:29:38.0 Driver arrived at Customer 37 at (3440, 4175)
# [ 3] 18:29:48.5 Customer 37 at (3440, 4175) answers door
# [ 3] 18:29:48.5 Customer 37 at (3440, 4175) accepts Parcel 93 for cust 37
# [ 3] 18:29:49.8 Customer 37 at (3440, 4175) signs off
# [ 3] 18:30:05.1 Driver drives to Customer 56 at (5106, 2833)
# [ 3] 18:40:41.6 Driver arrived at Customer 56 at (5106, 2833)
# [ 3] 18:40:45.8 Customer 56 at (5106, 2833) answers door
# [ 3] 18:40:45.8 Customer 56 at (5106, 2833) accepts Parcel 6 for cust 56
# [ 3] 18:40:59.0 Customer 56 at (5106, 2833) signs off
# [ 3] 18:41:01.8 Driver drives to Customer 28 at (2380, 1549)
# [ 3] 18:58:01.1 Driver arrived at Customer 28 at (2380, 1549)
# [ 3] 18:58:14.5 Customer 28 at (2380, 1549) answers door
# [ 3] 18:58:14.5 Customer 28 at (2380, 1549) accepts Parcel 59 for cust 28
# [ 3] 18:58:27.8 Customer 28 at (2380, 1549) accepts Parcel 90 for cust 28
# [ 3] 18:58:38.6 Customer 28 at (2380, 1549) signs off
# [ 3] 18:58:52.1 Driver drives to Customer 20 at (2080, 1320)
# [ 3] 19:00:59.1 Driver arrived at Customer 20 at (2080, 1320)
# [ 3] 19:01:28.1 Customer 20 at (2080, 1320) answers door
# [ 3] 19:01:28.1 Customer 20 at (2080, 1320) accepts Parcel 56 for cust 20
# [ 3] 19:01:47.7 Customer 20 at (2080, 1320) accepts Parcel 57 for cust 20
# [ 3] 19:01:49.0 Customer 20 at (2080, 1320) signs off
# [ 3] 19:01:59.3 Driver drives to Customer 14 at (1896, 1320)
# [ 3] 19:02:43.5 Driver arrived at Customer 14 at (1896, 1320)
# [ 3] 19:02:48.5 Customer 14 at (1896, 1320) answers door
# [ 3] 19:02:48.5 Customer 14 at (1896, 1320) accepts Parcel 86 for cust 14
# [ 3] 19:03:01.9 Customer 14 at (1896, 1320) signs off
# [ 3] 19:03:06.3 Driver drives to Customer 12 at (1791, 1320)
# [ 3] 19:03:31.5 Driver arrived at Customer 12 at (1791, 1320)
# [ 3] 19:04:31.5 Customer 12 at (1791, 1320) not at home
# [ 3] 19:04:31.5 Driver drives to Customer 6 at (1434, 3325)
# [ 3] 19:16:28.2 Driver arrived at Customer 6 at (1434, 3325)
# [ 3] 19:17:13.1 Customer 6 at (1434, 3325) answers door
# [ 3] 19:17:13.1 Customer 6 at (1434, 3325) accepts Parcel 53 for cust 6
# [ 3] 19:17:25.3 Customer 6 at (1434, 3325) accepts Parcel 84 for cust 6
# [ 3] 19:17:36.1 Customer 6 at (1434, 3325) signs off
# [ 3] 19:17:38.6 Driver drives to Customer 2 at (1320, 4082)
# [ 3] 19:20:51.3 Driver arrived at Customer 2 at (1320, 4082)
# [ 3] 19:21:51.3 Customer 2 at (1320, 4082) to slow to answer the door
# [ 3] 19:21:51.3 Driver drives to Customer 4 at (1320, 4285)
# [ 3] 19:22:40.0 Driver arrived at Customer 4 at (1320, 4285)
# [ 3] 19:22:51.0 Customer 4 at (1320, 4285) answers door
# [ 3] 19:22:51.0 Customer 4 at (1320, 4285) accepts Parcel 83 for cust 4
# [ 3] 19:22:58.3 Customer 4 at (1320, 4285) signs off
# [ 3] 19:23:09.5 Driver drives to Customer 7 at (1449, 7680)
# [ 3] 19:37:15.3 Driver arrived at Customer 7 at (1449, 7680)
# [ 3] 19:38:15.3 Customer 7 at (1449, 7680) not at home
# [ 3] 19:38:15.3 Driver drives to Customer 19 at (2066, 7680)
# [ 3] 19:40:43.4 Driver arrived at Customer 19 at (2066, 7680)
# [ 3] 19:41:43.4 Customer 19 at (2066, 7680) not at home
# [ 3] 19:41:43.4 Driver drives to Customer 25 at (2252, 7680)
# [ 3] 19:42:28.0 Driver arrived at Customer 25 at (2252, 7680)
# [ 3] 19:43:28.0 Customer 25 at (2252, 7680) not at home
# [ 3] 19:43:28.0 Driver drives to Customer 54 at (4955, 6620)
# [ 3] 20:00:00.4 Driver arrived at Customer 54 at (4955, 6620)
# [ 3] 20:00:11.1 Customer 54 at (4955, 6620) answers door
# [ 3] 20:00:11.1 Customer 54 at (4955, 6620) accepts Parcel 95 for cust 54
# [ 3] 20:00:21.0 Customer 54 at (4955, 6620) signs off
# [ 3] 20:00:24.3 Driver drives to Customer 70 at (5560, 7234)
# [ 3] 20:05:16.9 Driver arrived at Customer 70 at (5560, 7234)
# [ 3] 20:05:24.4 Customer 70 at (5560, 7234) answers door
# [ 3] 20:05:24.4 Customer 70 at (5560, 7234) accepts Parcel 100 for cust 70
# [ 3] 20:05:41.0 Customer 70 at (5560, 7234) accepts Parcel 101 for cust 70
# [ 3] 20:05:49.1 Customer 70 at (5560, 7234) signs off
# [ 3] 20:05:53.0 Driver drives to Customer 91 at (6620, 8314)
# [ 3] 20:14:26.6 Driver arrived at Customer 91 at (6620, 8314)
# [ 3] 20:15:01.9 Customer 91 at (6620, 8314) answers door
# [ 3] 20:15:01.9 Customer 91 at (6620, 8314) accepts Parcel 79 for cust 91
# [ 3] 20:15:02.1 Customer 91 at (6620, 8314) signs off
# [ 3] 20:15:03.5 Driver drives to Customer 69 at (5560, 6381)
# [ 3] 20:27:01.8 Driver arrived at Customer 69 at (5560, 6381)
# [ 3] 20:27:22.0 Customer 69 at (5560, 6381) answers door
# [ 3] 20:27:22.0 Customer 69 at (5560, 6381) accepts Parcel 99 for cust 69
# [ 3] 20:27:59.2 Customer 69 at (5560, 6381) signs off
# [ 3] 20:28:06.3 Driver drives to Customer 68 at (5560, 6167)
# [ 3] 20:28:57.7 Driver arrived at Customer 68 at (5560, 6167)
# [ 3] 20:29:00.8 Customer 68 at (5560, 6167) answers door
# [ 3] 20:29:00.8 Customer 68 at (5560, 6167) accepts Parcel 98 for cust 68
# [ 3] 20:29:15.3 Customer 68 at (5560, 6167) signs off
# [ 3] 20:29:30.5 Driver drives to Customer 86 at (6369, 5560)
# [ 3] 20:35:10.4 Driver arrived at Customer 86 at (6369, 5560)
# [ 3] 20:36:10.0 Customer 86 at (6369, 5560) answers door
# [ 3] 20:36:10.0 Customer 86 at (6369, 5560) accepts Parcel 107 for cust 86
# [ 3] 20:36:18.4 Customer 86 at (6369, 5560) signs off
# [ 3] 20:36:30.3 Driver drives to Customer 90 at (6542, 5560)
# [ 3] 20:37:11.9 Driver arrived at Customer 90 at (6542, 5560)
# [ 3] 20:37:21.5 Customer 90 at (6542, 5560) answers door
# [ 3] 20:37:21.5 Customer 90 at (6542, 5560) accepts Parcel 49 for cust 90
# [ 3] 20:37:34.6 Customer 90 at (6542, 5560) signs off
# [ 3] 20:37:51.6 Driver drives to Customer 51 at (4500, 6463)
# [ 3] 20:50:53.7 Driver arrived at Customer 51 at (4500, 6463)
# [ 3] 20:51:50.8 Customer 51 at (4500, 6463) answers door
# [ 3] 20:51:50.8 Customer 51 at (4500, 6463) accepts Parcel 94 for cust 51
# [ 3] 20:51:55.2 Customer 51 at (4500, 6463) signs off
# [ 3] 20:52:04.1 Driver drives to Customer 50 at (4500, 6283)
# [ 3] 20:52:47.3 Driver arrived at Customer 50 at (4500, 6283)
# [ 3] 20:53:27.0 Customer 50 at (4500, 6283) answers door
# [ 3] 20:53:27.0 Customer 50 at (4500, 6283) accepts Parcel 65 for cust 50
# [ 3] 20:53:50.1 Customer 50 at (4500, 6283) signs off
# [ 3] 20:53:51.2 Driver drives to Customer 49 at (4500, 6156)
# [ 3] 20:54:21.7 Driver arrived at Customer 49 at (4500, 6156)
# [ 3] 20:55:21.7 Customer 49 at (4500, 6156) not at home
# [ 3] 20:55:21.7 Driver drives to Customer 33 at (2895, 6075)
# [ 3] 21:04:32.3 Driver arrived at Customer 33 at (2895, 6075)
# [ 3] 21:05:32.3 Customer 33 at (2895, 6075) to slow to answer the door
# [ 3] 21:05:32.3 Driver drives to Customer 31 at (2380, 5304)
# [ 3] 21:09:28.4 Driver arrived at Customer 31 at (2380, 5304)
# [ 3] 21:09:58.3 Customer 31 at (2380, 5304) answers door
# [ 3] 21:09:58.3 Customer 31 at (2380, 5304) accepts Parcel 60 for cust 31
# [ 3] 21:10:02.8 Customer 31 at (2380, 5304) signs off
# [ 3] 21:10:08.9 Driver drives to Customer 30 at (2380, 5128)
# [ 3] 21:10:51.1 Driver arrived at Customer 30 at (2380, 5128)
# [ 3] 21:10:51.6 Customer 30 at (2380, 5128) answers door
# [ 3] 21:10:51.6 Customer 30 at (2380, 5128) accepts Parcel 91 for cust 30
# [ 3] 21:10:54.1 Customer 30 at (2380, 5128) signs off
# [ 3] 21:11:04.7 Driver drives to Customer 24 at (2251, 4500)
# [ 3] 21:14:06.3 Driver arrived at Customer 24 at (2251, 4500)
# [ 3] 21:14:49.6 Customer 24 at (2251, 4500) answers door
# [ 3] 21:14:49.6 Customer 24 at (2251, 4500) accepts Parcel 58 for cust 24
# [ 3] 21:14:56.4 Customer 24 at (2251, 4500) signs off
# [ 3] 21:15:27.1 Driver drives to Customer 22 at (2169, 4500)
# [ 3] 21:15:46.8 Driver arrived at Customer 22 at (2169, 4500)
# [ 3] 21:16:13.0 Customer 22 at (2169, 4500) answers door
# [ 3] 21:16:13.0 Customer 22 at (2169, 4500) accepts Parcel 87 for cust 22
# [ 3] 21:16:16.7 Customer 22 at (2169, 4500) accepts Parcel 88 for cust 22
# [ 3] 21:16:35.6 Customer 22 at (2169, 4500) signs off
# [ 3] 21:16:38.6 Driver drives to Customer 18 at (2033, 4500)
# [ 3] 21:17:11.2 Driver arrived at Customer 18 at (2033, 4500)
# [ 3] 21:18:11.2 Customer 18 at (2033, 4500) not at home
# [ 3] 21:18:11.2 Driver returns to delivery centre
# [ 3] 21:23:48.9 Driver arrived at delivery centre
# [ 3] 21:23:48.9 Parcel 27 for cust 12 return from delivery
# [ 3] 21:24:18.9 Parcel 52 for cust 2 return from delivery
# [ 3] 21:24:48.9 Parcel 85 for cust 7 return from delivery
# [ 3] 21:25:18.9 Parcel 28 for cust 19 return from delivery
# [ 3] 21:25:48.9 Parcel 2 for cust 25 return from delivery
# [ 3] 21:26:18.9 Parcel 89 for cust 25 return from delivery
# [ 3] 21:26:48.9 Parcel 64 for cust 49 return from delivery
# [ 3] 21:27:18.9 Parcel 92 for cust 33 return from delivery
# [ 3] 21:27:48.9 Parcel 55 for cust 18 return from delivery
# [ 3] 21:28:18.9 26 parcels left for next day
# [ 3] 21:38:18.9 Driver goes home
# Delivery Centre Inventory: 26 parcels

# %%
rec2.histWorkingTime()
rec2.plotWorkingTime()

# %%
rec3 = simulation(M, W, C, p=0.6, days=100)
# Out:
# Simulating delivery of 5939 parcels over 100 days to 100 customers
# Delivery Centre Inventory: 43 parcels

# %%
rec3.histWorkingTime()
rec3.plotWorkingTime()

# %% [markdown]
# ### Using Test Data

# %%
import pickle
with open('testData.pickled', 'rb') as f:
    MX, CX = pickle.load(f)

# %%
WX = generateWarehouseLocation(MX)

# %%
rec4 = simulation(MX, WX, CX, p=0.15, days=7)
# Out:
# Simulating delivery of 14 parcels over 7 days to 20 customers
# Delivery Centre Inventory: 3 parcels

# %%
rec4.histWorkingTime()
rec4.plotWorkingTime()

# %%
rec5 = simulation(MX, WX, CX, p=1.2, days=100)
# Out:
# Simulating delivery of 2342 parcels over 100 days to 20 customers
# Delivery Centre Inventory: 7 parcels

# %%
rec5.histWorkingTime()
rec5.plotWorkingTime()

# %% [markdown]
# ### Using Full Data

# %%
import pickle
with open('data.pickled', 'rb') as f:
    MM, CC = pickle.load(f)

# %%
WW = generateWarehouseLocation(MM)

# %%
plotMap(MM, T=CC, w=WW, scale=True, grid=True)

# %%
rec6 = simulation(MM, WW, CC, p=0.15, days=7)
# Out:
# Simulating delivery of 105 parcels over 7 days to 100 customers
# Delivery Centre Inventory: 11 parcels

# %%
rec6.histWorkingTime()
rec6.plotWorkingTime()

# %%
rec7 = simulation(MM, WW, CC, p=0.15, days=50)
# Out:
# Simulating delivery of 761 parcels over 50 days to 100 customers
# Delivery Centre Inventory: 6 parcels

# %%
rec7.histWorkingTime()
rec7.plotWorkingTime()
